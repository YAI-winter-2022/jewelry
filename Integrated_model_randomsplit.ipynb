# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import random
import albumentations as A
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/'Colab Notebooks'/'yai_9기 겨울방학'/ToyProject
# Out:
# /content/drive/MyDrive/Colab Notebooks/yai_9기 겨울방학/ToyProject

# %%
csv_path = "final.csv"
image_path = "./data/images"
batch_size = 256
epochs = 100
learning_rate = 1e-3
seed = 42

# %%
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
class AllDataset(Dataset):
    def __init__(self, csv_path, image_path, image_transform=transforms.Compose([transforms.ToTensor()])):
        super(AllDataset).__init__()
        csv = pd.read_csv(csv_path)
        csv_np = csv.to_numpy()
        
        self.image_transform = image_transform
        self.ids = list(map(str, csv['Id']))
        self.image_path = image_path
        
        for i in [1, 3, 4, 5, 6, 7, 8]:
            wordset = {word: idx for idx, word in enumerate(np.unique(csv_np[:,i]))}
            for row in range(len(csv_np)):
                csv_np[row][i] = wordset[csv_np[row][i]]
        self.ints = torch.from_numpy(np.array(csv_np[:,[1,3,4,5,6,7,8]], dtype="int"))
        self.floats = torch.from_numpy(np.array(csv_np[:,[2,9,10,11]], dtype="float")).float()
        self.target = torch.from_numpy(np.array(csv_np[:,[12]], dtype="float")).float()
    
    
    def __getitem__(self,idx):
        return self.image_transform(Image.open(self.image_path+'/'+self.ids[idx]+'.jpg')), self.ints[idx],self.floats[idx], self.target[idx]
    
    
    def __len__(self):
        return len(self.ints)

# %%
data_length = len(pd.read_csv(csv_path))
train_length = int(data_length * 0.6)
test_length = int(data_length * 0.2)
val_length = data_length - train_length - test_length

image_transform = transforms.Compose([transforms.ToTensor()
                                     ])

all_dataset = AllDataset(csv_path, image_path, image_transform)
train_dataset, test_dataset = random_split(all_dataset, [train_length, test_length+val_length])
test_dataset, val_dataset = random_split(test_dataset, [test_length, val_length])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Sequential(nn.Linear(512, 4096),
                                         nn.BatchNorm1d(4096),
                                         nn.ReLU(),
                                         nn.Dropout()
                                        )
        self.resenet18 = self.resnet18.to(device)
        
        self.emb1 = torch.nn.Embedding(8, 20)
        self.emb2 = torch.nn.Embedding(11, 20)
        self.emb3 = torch.nn.Embedding(20, 20)
        self.emb4 = torch.nn.Embedding(4, 20)
        self.emb5 = torch.nn.Embedding(4, 20)
        self.emb6 = torch.nn.Embedding(4, 20)
        self.emb7 = torch.nn.Embedding(7, 20)
        self.act = nn.ReLU()
        self.fc = nn.Linear(4, 80)
        self.csvbn = nn.BatchNorm1d(80)
        self.csvfc1 = nn.Linear(220, 8192)
        self.csvfc2 = nn.Linear(8192, 8192)
        self.csvfc3 = nn.Linear(8192, 4096)
        self.csvbn1 = nn.BatchNorm1d(8192)
        self.csvbn2 = nn.BatchNorm1d(8192)
        self.csvbn3 = nn.BatchNorm1d(4096)
        
        self.fc1 = nn.Linear(8192, 4096)
        self.fc2 = nn.Linear(4096, 1)
        self.bn1 = nn.BatchNorm1d(4096)
        self.dropout = nn.Dropout()
    
    def forward(self, image, x, y):
        image = self.resnet18(image)
        
        x1 = self.emb1(x[:,0])
        x2 = self.emb2(x[:,1])
        x3 = self.emb3(x[:,2])
        x4 = self.emb4(x[:,3])
        x5 = self.emb5(x[:,4])
        x6 = self.emb6(x[:,5])
        x7 = self.emb7(x[:,6])
        y = self.csvbn(self.fc(y))
        x = torch.cat((x1, x2, x3, x4, x5, x6, x7, y), dim=1)
        
        x = self.dropout(self.act(self.csvbn1(self.csvfc1(x))))
        x = self.dropout(self.act(self.csvbn2(self.csvfc2(x))))
        x = self.dropout(self.act(self.csvbn3(self.csvfc3(x))))
        x = torch.cat((x, image), dim=1)
        
        x = self.dropout(self.act(self.bn1(self.fc1(x))))
        return self.fc2(x)

# %%
model = Net().to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(epochs):
    model.train()
    criterion.train()
    
    avg_loss = 0

    for Img, X1, X2, Y in train_loader:
        Img = Img.to(device)
        X1 = X1.to(device)
        X2 = X2.to(device)
        Y = Y.to(device)

        model.zero_grad()
        prediction = model(Img, X1, X2)
        loss = torch.sqrt(criterion(prediction, Y)).to(device)
        loss.backward()
        optimizer.step()
        avg_loss += loss / len(train_loader)
    print(f'[Epoch: {epoch+1:>2}] Average loss: {avg_loss:.4f}, ', end='')
    
    model.eval()
    criterion.eval()
    with torch.no_grad():
        val_avg_loss = 0.
        for Image_val, X1_val, X2_val, Y_val in val_loader:
            Image_val = Image_val.to(device)
            X1_val = X1_val.to(device)
            X2_val = X2_val.to(device)
            Y_val = Y_val.to(device)
            val_prediction = model(Image_val, X1_val, X2_val)
            val_loss = torch.sqrt(criterion(val_prediction, Y_val)).to(device)
            val_avg_loss += val_loss / len(val_loader)
        
        print(f"val_loss: {val_avg_loss:.4f}")
# Out:
# [Epoch:  1] Average loss: 5837.5381, val_loss: 4876.1885
# [Epoch:  2] Average loss: 4645.3989, val_loss: 4555.1294
# [Epoch:  3] Average loss: 4507.3721, val_loss: 4760.3242
# [Epoch:  4] Average loss: 4524.9629, val_loss: 4702.8218
# [Epoch:  5] Average loss: 4381.4688, val_loss: 4176.9644
# [Epoch:  6] Average loss: 4217.8428, val_loss: 4699.3325
# [Epoch:  7] Average loss: 4178.2700, val_loss: 4466.4702
# [Epoch:  8] Average loss: 4133.1826, val_loss: 3883.9302
# [Epoch:  9] Average loss: 4137.2236, val_loss: 4133.2832
# [Epoch: 10] Average loss: 4043.6770, val_loss: 4286.2769
# [Epoch: 11] Average loss: 4373.8501, val_loss: 4347.2700
# [Epoch: 12] Average loss: 4005.2690, val_loss: 4010.6816
# [Epoch: 13] Average loss: 3973.8616, val_loss: 4105.8228
# [Epoch: 14] Average loss: 3855.2073, val_loss: 3775.3821
# [Epoch: 15] Average loss: 3753.5767, val_loss: 4003.3188
# [Epoch: 16] Average loss: 3834.0518, val_loss: 3731.3049
# [Epoch: 17] Average loss: 3742.6770, val_loss: 3600.1265
# [Epoch: 18] Average loss: 3714.1392, val_loss: 3735.9238
# [Epoch: 19] Average loss: 3574.4980, val_loss: 3234.0762
# [Epoch: 20] Average loss: 4087.8794, val_loss: 3657.0332
# [Epoch: 21] Average loss: 3324.7581, val_loss: 3452.8931
# [Epoch: 22] Average loss: 3315.1316, val_loss: 3224.5806
# [Epoch: 23] Average loss: 3264.3179, val_loss: 2564.9729
# [Epoch: 24] Average loss: 3135.4651, val_loss: 2625.0122
# [Epoch: 25] Average loss: 3123.5645, val_loss: 2894.9414
# [Epoch: 26] Average loss: 2988.6631, val_loss: 2812.4695
# [Epoch: 27] Average loss: 2811.0522, val_loss: 2632.8633
# [Epoch: 28] Average loss: 2760.2388, val_loss: 2493.0571
# [Epoch: 29] Average loss: 2712.2175, val_loss: 2271.4248
# [Epoch: 30] Average loss: 2713.7136, val_loss: 1885.5859
# [Epoch: 31] Average loss: 2622.9448, val_loss: 2001.9570
# [Epoch: 32] Average loss: 2530.9641, val_loss: 1819.9629
# [Epoch: 33] Average loss: 2450.1572, val_loss: 2069.6123
# [Epoch: 34] Average loss: 2446.5017, val_loss: 1752.1481
# [Epoch: 35] Average loss: 2320.2183, val_loss: 1692.8629
# [Epoch: 36] Average loss: 2340.0901, val_loss: 1994.7275
# [Epoch: 37] Average loss: 2234.4229, val_loss: 1724.3403
# [Epoch: 38] Average loss: 2095.4507, val_loss: 1738.0520
# [Epoch: 39] Average loss: 2067.6475, val_loss: 1818.7341
# [Epoch: 40] Average loss: 1908.7887, val_loss: 1840.8359
# [Epoch: 41] Average loss: 1979.3881, val_loss: 1564.1340
# [Epoch: 42] Average loss: 3855.7007, val_loss: 1915.6958
# [Epoch: 43] Average loss: 1856.0947, val_loss: 1916.3422
# [Epoch: 44] Average loss: 2560.4705, val_loss: 2370.9211
# [Epoch: 45] Average loss: 1690.6929, val_loss: 1337.0751
# [Epoch: 46] Average loss: 1910.8497, val_loss: 1414.4928
# [Epoch: 47] Average loss: 1793.5496, val_loss: 1497.9974
# [Epoch: 48] Average loss: 1722.2445, val_loss: 1308.7111
# [Epoch: 49] Average loss: 1676.5239, val_loss: 1437.6362
# [Epoch: 50] Average loss: 3104.1790, val_loss: 2009.3593
# [Epoch: 51] Average loss: 1422.1869, val_loss: 1432.6394
# [Epoch: 52] Average loss: 1491.8470, val_loss: 1322.4763
# [Epoch: 53] Average loss: 1566.2837, val_loss: 1730.4639
# [Epoch: 54] Average loss: 1412.0653, val_loss: 1690.6841
# [Epoch: 55] Average loss: 1720.8003, val_loss: 1217.7344
# [Epoch: 56] Average loss: 1576.9104, val_loss: 1326.6705
# [Epoch: 57] Average loss: 1498.8795, val_loss: 1219.8552
# [Epoch: 58] Average loss: 1462.7676, val_loss: 1239.8890
# [Epoch: 59] Average loss: 1548.4900, val_loss: 1033.0657
# [Epoch: 60] Average loss: 1317.9594, val_loss: 943.9173
# [Epoch: 61] Average loss: 1398.2498, val_loss: 1194.7004
# [Epoch: 62] Average loss: 1372.6794, val_loss: 1182.4894
# [Epoch: 63] Average loss: 1319.4672, val_loss: 2368.6975
# [Epoch: 64] Average loss: 1833.0588, val_loss: 1355.0204
# [Epoch: 65] Average loss: 1331.7706, val_loss: 1110.8889
# [Epoch: 66] Average loss: 1283.0686, val_loss: 1022.2450
# [Epoch: 67] Average loss: 1533.3798, val_loss: 1380.6035
# [Epoch: 68] Average loss: 1378.1755, val_loss: 1100.2617
# [Epoch: 69] Average loss: 1435.1187, val_loss: 1168.8754
# [Epoch: 70] Average loss: 1111.5809, val_loss: 1149.0259
# [Epoch: 71] Average loss: 1368.6965, val_loss: 1151.8805
# [Epoch: 72] Average loss: 1068.1866, val_loss: 1009.2688
# [Epoch: 73] Average loss: 1303.4015, val_loss: 1219.6504
# [Epoch: 74] Average loss: 1196.1084, val_loss: 1120.9042
# [Epoch: 75] Average loss: 1325.9771, val_loss: 1238.7407
# [Epoch: 76] Average loss: 1273.5581, val_loss: 1486.5527
# [Epoch: 77] Average loss: 1240.3096, val_loss: 1628.7018
# [Epoch: 78] Average loss: 1251.1860, val_loss: 2063.6921
# [Epoch: 79] Average loss: 1575.2125, val_loss: 1947.4335
# [Epoch: 80] Average loss: 1334.5624, val_loss: 1244.1940
# [Epoch: 81] Average loss: 1332.7974, val_loss: 1415.5613
# [Epoch: 82] Average loss: 1479.7860, val_loss: 1383.1119
# [Epoch: 83] Average loss: 1304.3531, val_loss: 1468.4246
# [Epoch: 84] Average loss: 1053.0266, val_loss: 1464.8550
# [Epoch: 85] Average loss: 1274.4606, val_loss: 1168.6226
# [Epoch: 86] Average loss: 1167.3925, val_loss: 1057.4019
# [Epoch: 87] Average loss: 1167.3624, val_loss: 1018.0029
# [Epoch: 88] Average loss: 1194.2488, val_loss: 1283.6531
# [Epoch: 89] Average loss: 1207.3619, val_loss: 1085.6207
# [Epoch: 90] Average loss: 1152.2936, val_loss: 1286.5542
# [Epoch: 91] Average loss: 1065.8173, val_loss: 1154.8209
# [Epoch: 92] Average loss: 1150.9551, val_loss: 1051.4360
# [Epoch: 93] Average loss: 1049.0414, val_loss: 1157.8662
# [Epoch: 94] Average loss: 1124.0173, val_loss: 1127.9514
# [Epoch: 95] Average loss: 1222.0662, val_loss: 1105.3513
# [Epoch: 96] Average loss: 1115.6079, val_loss: 1109.1282
# [Epoch: 97] Average loss: 1111.1991, val_loss: 1204.0074
# [Epoch: 98] Average loss: 1214.8904, val_loss: 1414.8997
# [Epoch: 99] Average loss: 1090.0847, val_loss: 1122.0404
# [Epoch: 100] Average loss: 1062.8821, val_loss: 1176.6711

# %%
PATH = './model/'
Name = 'model_randomsplit.pt'
torch.save(model.state_dict(), PATH+Name)

# %%
RMSEs = []
accuracys = []

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 20000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    accuracys.append(accuracy)
    RMSEs.append(RMSE)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}",)
# Out:
# 결과값:41056.65$, 예측값 :31488.27$
# 결과값:64733.52$, 예측값 :57526.11$
# 결과값:68738.52$, 예측값 :47341.23$
# Accuracy: -34.34   RMSE : 14157.97

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 20,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 15000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:41056.65$, 예측값 :31488.27$
# 결과값:16247.87$, 예측값 :11541.52$
# 결과값:15690.71$, 예측값 :10386.10$
# 결과값:18681.64$, 예측값 :14535.44$
# 결과값:19164.77$, 예측값 :19025.06$
# 결과값:18054.65$, 예측값 :38006.69$
# 결과값:64733.52$, 예측값 :57526.11$
# 결과값:68738.52$, 예측값 :47341.23$
# 결과값:18073.74$, 예측값 :15272.35$
# 결과값:15504.29$, 예측값 :10041.52$
# 결과값:16186.73$, 예측값 :10393.86$
# Accuracy: 72.41   RMSE : 10172.04

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 15,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 10000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:15690.71$, 예측값 :10386.10$
# 결과값:13549.56$, 예측값 :12022.19$
# 결과값:41056.65$, 예측값 :31488.27$
# 결과값:13019.69$, 예측값 :11182.03$
# 결과값:68738.52$, 예측값 :47341.23$
# 결과값:13336.86$, 예측값 :9224.62$
# 결과값:12820.09$, 예측값 :10193.05$
# 결과값:11445.17$, 예측값 :8999.46$
# 결과값:19164.77$, 예측값 :19025.06$
# 결과값:11775.93$, 예측값 :8920.51$
# 결과값:13164.25$, 예측값 :8750.92$
# 결과값:12627.71$, 예측값 :9339.55$
# 결과값:13219.49$, 예측값 :10247.59$
# 결과값:16247.87$, 예측값 :11541.52$
# 결과값:18681.64$, 예측값 :14535.44$
# 결과값:64733.52$, 예측값 :57526.11$
# 결과값:18073.74$, 예측값 :15272.35$
# 결과값:16186.73$, 예측값 :10393.86$
# 결과값:15504.29$, 예측값 :10041.52$
# 결과값:18054.65$, 예측값 :38006.69$
# 결과값:13595.21$, 예측값 :9624.02$
# Accuracy: 77.06   RMSE : 7674.09

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 10,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:3188.48$, 예측값 :2787.16$
# 결과값:1180.63$, 예측값 :627.07$
# 결과값:1142.87$, 예측값 :675.93$
# 결과값:840.96$, 예측값 :1319.38$
# 결과값:1739.86$, 예측값 :883.76$
# 결과값:2127.22$, 예측값 :1629.97$
# 결과값:1065.06$, 예측값 :976.03$
# 결과값:2123.92$, 예측값 :1927.44$
# 결과값:2663.32$, 예측값 :2408.23$
# 결과값:1820.77$, 예측값 :2032.05$
# 결과값:1458.21$, 예측값 :1899.99$
# 결과값:2350.94$, 예측값 :2183.04$
# 결과값:1576.77$, 예측값 :1391.50$
# 결과값:815.15$, 예측값 :869.39$
# 결과값:1016.45$, 예측값 :858.88$
# 결과값:3375.01$, 예측값 :2700.87$
# 결과값:1092.72$, 예측값 :1430.00$
# 결과값:1819.56$, 예측값 :1546.49$
# 결과값:1155.08$, 예측값 :927.43$
# 결과값:4947.13$, 예측값 :3807.80$
# 결과값:1525.93$, 예측값 :1541.06$
# 결과값:2103.41$, 예측값 :1567.16$
# 결과값:8586.55$, 예측값 :7417.83$
# 결과값:2289.26$, 예측값 :2112.62$
# 결과값:1013.53$, 예측값 :992.22$
# 결과값:2179.46$, 예측값 :2104.18$
# 결과값:2785.64$, 예측값 :2633.34$
# 결과값:1320.14$, 예측값 :1076.96$
# 결과값:2099.21$, 예측값 :1725.67$
# 결과값:1069.70$, 예측값 :1052.63$
# 결과값:5436.44$, 예측값 :3566.85$
# 결과값:2016.71$, 예측값 :2405.88$
# 결과값:2352.55$, 예측값 :1769.55$
# 결과값:1401.30$, 예측값 :1325.31$
# 결과값:1936.06$, 예측값 :1802.51$
# 결과값:1329.03$, 예측값 :1002.26$
# 결과값:1645.30$, 예측값 :1516.83$
# 결과값:2290.68$, 예측값 :2191.74$
# 결과값:1536.29$, 예측값 :1786.29$
# 결과값:15690.71$, 예측값 :10386.10$
# 결과값:1988.57$, 예측값 :1520.66$
# 결과값:2028.08$, 예측값 :1890.82$
# 결과값:1052.87$, 예측값 :1121.50$
# 결과값:2002.26$, 예측값 :1399.89$
# 결과값:1553.91$, 예측값 :1692.26$
# 결과값:1865.76$, 예측값 :1561.14$
# 결과값:2021.49$, 예측값 :1751.17$
# 결과값:1301.11$, 예측값 :1257.05$
# 결과값:11445.17$, 예측값 :8999.46$
# 결과값:2018.99$, 예측값 :1201.21$
# 결과값:1078.14$, 예측값 :1134.74$
# 결과값:1199.94$, 예측값 :937.46$
# 결과값:2347.68$, 예측값 :2289.71$
# 결과값:1459.35$, 예측값 :1322.02$
# 결과값:1630.65$, 예측값 :1160.86$
# 결과값:929.06$, 예측값 :501.07$
# 결과값:2149.05$, 예측값 :1759.97$
# 결과값:1502.54$, 예측값 :897.21$
# 결과값:1818.08$, 예측값 :1745.02$
# 결과값:2044.11$, 예측값 :2154.58$
# 결과값:1867.89$, 예측값 :1607.10$
# 결과값:5430.25$, 예측값 :4052.54$
# 결과값:1681.45$, 예측값 :758.57$
# 결과값:1626.73$, 예측값 :1440.43$
# 결과값:1985.85$, 예측값 :2191.68$
# 결과값:2296.25$, 예측값 :1786.36$
# 결과값:2253.96$, 예측값 :2438.75$
# 결과값:1941.39$, 예측값 :1738.63$
# 결과값:1408.65$, 예측값 :1089.66$
# 결과값:832.33$, 예측값 :966.01$
# 결과값:6560.13$, 예측값 :6707.22$
# 결과값:2227.14$, 예측값 :2318.87$
# 결과값:1042.07$, 예측값 :1002.47$
# 결과값:2471.74$, 예측값 :2481.06$
# 결과값:3202.85$, 예측값 :3114.43$
# 결과값:2051.69$, 예측값 :1950.82$
# 결과값:2054.99$, 예측값 :1933.08$
# 결과값:1578.46$, 예측값 :774.77$
# 결과값:1250.19$, 예측값 :1084.92$
# 결과값:1801.69$, 예측값 :1148.76$
# 결과값:2323.93$, 예측값 :2218.18$
# 결과값:2784.64$, 예측값 :2590.03$
# 결과값:944.29$, 예측값 :532.37$
# 결과값:4012.24$, 예측값 :3708.13$
# 결과값:2623.10$, 예측값 :1905.13$
# 결과값:1168.23$, 예측값 :1196.77$
# 결과값:1326.11$, 예측값 :1072.72$
# 결과값:1598.46$, 예측값 :1502.02$
# 결과값:1855.11$, 예측값 :1693.78$
# 결과값:2411.29$, 예측값 :4468.85$
# 결과값:2088.42$, 예측값 :2124.43$
# 결과값:1507.58$, 예측값 :1099.83$
# 결과값:1008.24$, 예측값 :526.23$
# 결과값:2014.73$, 예측값 :1927.26$
# 결과값:2368.37$, 예측값 :2385.77$
# 결과값:1733.48$, 예측값 :1516.09$
# 결과값:1140.06$, 예측값 :715.18$
# 결과값:1205.93$, 예측값 :967.40$
# 결과값:3397.09$, 예측값 :2891.00$
# 결과값:1053.92$, 예측값 :1067.84$
# 결과값:2011.69$, 예측값 :2042.78$
# 결과값:2059.48$, 예측값 :1959.53$
# 결과값:974.29$, 예측값 :799.51$
# 결과값:2028.19$, 예측값 :1607.78$
# 결과값:1752.65$, 예측값 :1856.35$
# 결과값:2066.85$, 예측값 :2109.22$
# 결과값:1504.20$, 예측값 :1322.19$
# 결과값:1880.29$, 예측값 :2111.39$
# 결과값:2071.35$, 예측값 :2057.18$
# 결과값:2088.62$, 예측값 :1826.89$
# 결과값:1458.27$, 예측값 :1142.18$
# 결과값:3427.05$, 예측값 :3313.10$
# 결과값:2508.64$, 예측값 :2235.43$
# 결과값:3825.69$, 예측값 :4061.12$
# 결과값:1867.55$, 예측값 :1484.41$
# 결과값:2018.05$, 예측값 :1787.87$
# 결과값:1425.61$, 예측값 :1306.05$
# 결과값:1103.49$, 예측값 :738.82$
# 결과값:1681.61$, 예측값 :1112.25$
# 결과값:1406.93$, 예측값 :1385.91$
# 결과값:1032.64$, 예측값 :617.86$
# 결과값:998.15$, 예측값 :865.43$
# 결과값:12820.09$, 예측값 :10193.05$
# 결과값:2528.27$, 예측값 :1802.91$
# 결과값:1326.87$, 예측값 :1299.62$
# 결과값:845.48$, 예측값 :978.11$
# 결과값:1969.33$, 예측값 :1551.97$
# 결과값:1973.90$, 예측값 :2192.74$
# 결과값:788.23$, 예측값 :1340.99$
# 결과값:1445.41$, 예측값 :1324.49$
# 결과값:1931.92$, 예측값 :1510.39$
# 결과값:1169.48$, 예측값 :1101.46$
# 결과값:2020.58$, 예측값 :1747.49$
# 결과값:1445.12$, 예측값 :817.71$
# 결과값:1437.21$, 예측값 :1299.29$
# 결과값:2086.47$, 예측값 :1984.16$
# 결과값:2568.80$, 예측값 :2444.76$
# 결과값:1401.35$, 예측값 :1304.14$
# 결과값:2575.46$, 예측값 :3296.96$
# 결과값:1203.45$, 예측값 :927.03$
# 결과값:2282.33$, 예측값 :1922.12$
# 결과값:1695.27$, 예측값 :1420.63$
# 결과값:2187.20$, 예측값 :2318.67$
# 결과값:1156.91$, 예측값 :696.90$
# 결과값:1536.39$, 예측값 :1643.56$
# 결과값:1421.51$, 예측값 :1538.38$
# 결과값:840.96$, 예측값 :640.74$
# 결과값:1810.48$, 예측값 :1499.76$
# 결과값:2111.99$, 예측값 :2227.50$
# 결과값:1012.99$, 예측값 :1066.98$
# 결과값:3456.76$, 예측값 :4363.63$
# 결과값:4453.83$, 예측값 :2169.00$
# 결과값:904.35$, 예측값 :1296.32$
# 결과값:2359.81$, 예측값 :2474.08$
# 결과값:1430.75$, 예측값 :1318.59$
# 결과값:1985.09$, 예측값 :2063.24$
# 결과값:3448.44$, 예측값 :2736.67$
# 결과값:1521.07$, 예측값 :1201.18$
# 결과값:1214.62$, 예측값 :1044.93$
# 결과값:2679.02$, 예측값 :2349.15$
# 결과값:2056.05$, 예측값 :1793.57$
# 결과값:1041.82$, 예측값 :948.65$
# 결과값:1270.22$, 예측값 :1247.05$
# 결과값:2279.60$, 예측값 :2294.01$
# 결과값:2551.46$, 예측값 :2445.05$
# 결과값:944.20$, 예측값 :1057.58$
# 결과값:2585.08$, 예측값 :2076.39$
# 결과값:1768.87$, 예측값 :1492.92$
# 결과값:2081.08$, 예측값 :1865.60$
# 결과값:1237.55$, 예측값 :1016.59$
# 결과값:1590.39$, 예측값 :1170.19$
# 결과값:1349.48$, 예측값 :1304.60$
# 결과값:1879.72$, 예측값 :1847.85$
# 결과값:2232.52$, 예측값 :2024.60$
# 결과값:4958.89$, 예측값 :4109.02$
# 결과값:2011.10$, 예측값 :1346.94$
# 결과값:2058.37$, 예측값 :2101.88$
# 결과값:1124.75$, 예측값 :695.69$
# 결과값:1741.58$, 예측값 :1329.10$
# 결과값:1149.61$, 예측값 :918.95$
# 결과값:1401.03$, 예측값 :1329.99$
# 결과값:1682.51$, 예측값 :1597.44$
# 결과값:1678.31$, 예측값 :1426.86$
# 결과값:4988.83$, 예측값 :5610.06$
# 결과값:1642.87$, 예측값 :1595.52$
# 결과값:1055.71$, 예측값 :1286.81$
# 결과값:2061.16$, 예측값 :2147.27$
# 결과값:2568.78$, 예측값 :2526.85$
# 결과값:1166.56$, 예측값 :1069.42$
# 결과값:2243.55$, 예측값 :1792.65$
# 결과값:1957.87$, 예측값 :1598.88$
# 결과값:1565.85$, 예측값 :880.57$
# 결과값:2198.03$, 예측값 :2020.24$
# 결과값:2074.15$, 예측값 :2178.91$
# 결과값:1131.56$, 예측값 :788.26$
# 결과값:1481.34$, 예측값 :1652.08$
# 결과값:952.01$, 예측값 :933.00$
# 결과값:1485.28$, 예측값 :959.24$
# 결과값:1267.50$, 예측값 :772.97$
# 결과값:1309.56$, 예측값 :1033.53$
# 결과값:2680.62$, 예측값 :2739.12$
# 결과값:1800.70$, 예측값 :1440.73$
# 결과값:2027.41$, 예측값 :1815.17$
# 결과값:1623.88$, 예측값 :5341.70$
# 결과값:1462.04$, 예측값 :1274.38$
# 결과값:981.38$, 예측값 :1107.87$
# 결과값:1347.34$, 예측값 :1109.08$
# 결과값:981.38$, 예측값 :1049.97$
# 결과값:1020.96$, 예측값 :1073.20$
# 결과값:1596.87$, 예측값 :1385.20$
# 결과값:1406.15$, 예측값 :1224.27$
# 결과값:1799.85$, 예측값 :3056.52$
# 결과값:1697.10$, 예측값 :1225.03$
# 결과값:817.66$, 예측값 :1384.26$
# 결과값:944.42$, 예측값 :1344.24$
# 결과값:2123.65$, 예측값 :1927.99$
# 결과값:2050.02$, 예측값 :1780.72$
# 결과값:1986.70$, 예측값 :1388.82$
# 결과값:1985.15$, 예측값 :2195.46$
# 결과값:1975.38$, 예측값 :1847.80$
# 결과값:1025.00$, 예측값 :1014.77$
# 결과값:2034.00$, 예측값 :1970.94$
# 결과값:1132.50$, 예측값 :703.93$
# 결과값:896.75$, 예측값 :990.99$
# 결과값:1527.02$, 예측값 :1027.02$
# 결과값:1763.52$, 예측값 :1348.01$
# 결과값:2115.20$, 예측값 :1557.47$
# 결과값:1650.76$, 예측값 :1251.65$
# 결과값:925.63$, 예측값 :1050.40$
# 결과값:974.29$, 예측값 :837.12$
# 결과값:1409.15$, 예측값 :1502.54$
# 결과값:947.09$, 예측값 :1150.93$
# 결과값:2142.21$, 예측값 :1829.20$
# 결과값:1051.23$, 예측값 :1047.02$
# 결과값:1582.45$, 예측값 :1269.39$
# 결과값:2080.80$, 예측값 :2042.23$
# 결과값:2180.11$, 예측값 :2042.19$
# 결과값:1086.48$, 예측값 :1042.20$
# 결과값:2249.55$, 예측값 :2133.08$
# 결과값:2033.31$, 예측값 :2108.37$
# 결과값:1264.15$, 예측값 :1031.85$
# 결과값:2023.78$, 예측값 :1956.21$
# 결과값:2011.20$, 예측값 :1942.73$
# 결과값:1055.79$, 예측값 :927.90$
# 결과값:2490.50$, 예측값 :2177.03$
# 결과값:3419.67$, 예측값 :3216.58$
# 결과값:1400.94$, 예측값 :1266.76$
# 결과값:1105.87$, 예측값 :1084.25$
# 결과값:2104.08$, 예측값 :2112.25$
# 결과값:5305.87$, 예측값 :3932.41$
# 결과값:1088.41$, 예측값 :1019.55$
# 결과값:2213.67$, 예측값 :2055.69$
# 결과값:2069.87$, 예측값 :2119.86$
# 결과값:1188.42$, 예측값 :965.89$
# 결과값:2179.02$, 예측값 :1811.23$
# 결과값:2305.57$, 예측값 :1902.31$
# 결과값:1244.88$, 예측값 :960.46$
# 결과값:3641.97$, 예측값 :2610.49$
# 결과값:875.07$, 예측값 :611.80$
# 결과값:1354.57$, 예측값 :1215.55$
# 결과값:1273.41$, 예측값 :657.13$
# 결과값:2408.00$, 예측값 :1934.94$
# 결과값:974.56$, 예측값 :1402.94$
# 결과값:1034.63$, 예측값 :821.12$
# 결과값:2618.67$, 예측값 :2501.80$
# 결과값:1162.86$, 예측값 :1056.14$
# 결과값:7313.18$, 예측값 :5616.70$
# 결과값:1086.75$, 예측값 :830.40$
# 결과값:1587.41$, 예측값 :1549.42$
# 결과값:945.89$, 예측값 :1438.67$
# 결과값:2306.50$, 예측값 :2020.02$
# 결과값:1257.99$, 예측값 :740.27$
# 결과값:924.65$, 예측값 :1409.55$
# 결과값:2315.40$, 예측값 :2108.40$
# 결과값:1433.29$, 예측값 :1356.37$
# 결과값:2055.24$, 예측값 :1957.08$
# 결과값:2749.80$, 예측값 :2542.18$
# 결과값:1163.80$, 예측값 :1037.01$
# 결과값:926.46$, 예측값 :507.76$
# 결과값:1251.53$, 예측값 :1217.20$
# 결과값:1658.80$, 예측값 :1606.48$
# 결과값:1972.25$, 예측값 :1711.69$
# 결과값:967.36$, 예측값 :759.19$
# 결과값:1920.08$, 예측값 :1827.20$
# 결과값:923.11$, 예측값 :1222.51$
# 결과값:2111.03$, 예측값 :2197.77$
# 결과값:1340.49$, 예측값 :1345.67$
# 결과값:2366.05$, 예측값 :1778.73$
# 결과값:2048.45$, 예측값 :2036.59$
# 결과값:1520.79$, 예측값 :1167.07$
# 결과값:1167.35$, 예측값 :1268.06$
# 결과값:2035.49$, 예측값 :1585.36$
# 결과값:1707.56$, 예측값 :1574.56$
# 결과값:4395.96$, 예측값 :2460.88$
# 결과값:1447.35$, 예측값 :1369.18$
# 결과값:1920.05$, 예측값 :2586.89$
# 결과값:2074.83$, 예측값 :1833.69$
# 결과값:2071.45$, 예측값 :2090.89$
# 결과값:1815.26$, 예측값 :1640.50$
# 결과값:18681.64$, 예측값 :14535.44$
# 결과값:2369.40$, 예측값 :2225.97$
# 결과값:1159.56$, 예측값 :784.26$
# 결과값:2080.19$, 예측값 :2079.54$
# 결과값:2354.31$, 예측값 :2194.61$
# 결과값:963.92$, 예측값 :1229.19$
# 결과값:2052.06$, 예측값 :2114.13$
# 결과값:1063.30$, 예측값 :942.86$
# 결과값:3590.27$, 예측값 :2750.07$
# 결과값:68738.52$, 예측값 :47341.23$
# 결과값:18054.65$, 예측값 :38006.69$
# 결과값:1164.92$, 예측값 :990.01$
# 결과값:1014.76$, 예측값 :1132.15$
# 결과값:2042.57$, 예측값 :1852.99$
# 결과값:1329.46$, 예측값 :1742.56$
# 결과값:1822.67$, 예측값 :1117.37$
# 결과값:1093.01$, 예측값 :426.62$
# 결과값:954.65$, 예측값 :496.45$
# 결과값:1324.27$, 예측값 :899.79$
# 결과값:1180.03$, 예측값 :1211.49$
# 결과값:3856.69$, 예측값 :2958.89$
# 결과값:1876.75$, 예측값 :1433.35$
# 결과값:1087.84$, 예측값 :1266.96$
# 결과값:2344.61$, 예측값 :1954.79$
# 결과값:1063.75$, 예측값 :882.97$
# 결과값:13336.86$, 예측값 :9224.62$
# 결과값:2680.62$, 예측값 :2355.38$
# 결과값:2480.15$, 예측값 :2279.88$
# 결과값:2187.06$, 예측값 :1700.22$
# 결과값:1381.90$, 예측값 :1185.41$
# 결과값:19164.77$, 예측값 :19025.06$
# 결과값:3071.64$, 예측값 :2963.31$
# 결과값:1382.59$, 예측값 :1312.73$
# 결과값:3184.13$, 예측값 :2779.59$
# 결과값:1705.29$, 예측값 :1401.27$
# 결과값:2352.62$, 예측값 :2324.56$
# 결과값:1275.76$, 예측값 :1069.02$
# 결과값:1423.99$, 예측값 :1284.69$
# 결과값:1974.76$, 예측값 :1354.30$
# 결과값:2527.87$, 예측값 :2282.60$
# 결과값:1318.95$, 예측값 :1307.06$
# 결과값:1010.70$, 예측값 :908.79$
# 결과값:1322.72$, 예측값 :773.69$
# 결과값:1338.58$, 예측값 :1328.64$
# 결과값:16247.87$, 예측값 :11541.52$
# 결과값:3349.00$, 예측값 :2711.02$
# 결과값:2835.39$, 예측값 :5038.17$
# 결과값:9433.00$, 예측값 :11854.80$
# 결과값:1532.76$, 예측값 :1329.12$
# 결과값:2723.69$, 예측값 :2405.42$
# 결과값:1580.00$, 예측값 :1140.98$
# 결과값:1013.49$, 예측값 :578.87$
# 결과값:1094.04$, 예측값 :890.63$
# 결과값:1100.09$, 예측값 :739.53$
# 결과값:1267.50$, 예측값 :1382.15$
# 결과값:2020.46$, 예측값 :2030.01$
# 결과값:1268.26$, 예측값 :1286.06$
# 결과값:2105.05$, 예측값 :2147.15$
# 결과값:971.75$, 예측값 :1023.46$
# 결과값:2090.73$, 예측값 :1875.39$
# 결과값:2046.52$, 예측값 :1790.91$
# 결과값:1202.65$, 예측값 :584.86$
# 결과값:1156.87$, 예측값 :1252.92$
# 결과값:902.26$, 예측값 :992.55$
# 결과값:13219.49$, 예측값 :10247.59$
# 결과값:2412.96$, 예측값 :2510.71$
# 결과값:1317.62$, 예측값 :790.05$
# 결과값:1031.12$, 예측값 :856.45$
# 결과값:4545.71$, 예측값 :4980.64$
# 결과값:1162.92$, 예측값 :701.02$
# 결과값:2099.91$, 예측값 :2148.70$
# 결과값:2304.07$, 예측값 :1805.10$
# 결과값:2060.18$, 예측값 :2224.66$
# 결과값:1065.24$, 예측값 :1109.37$
# 결과값:1796.39$, 예측값 :1634.06$
# 결과값:1773.52$, 예측값 :1666.59$
# 결과값:1650.45$, 예측값 :1048.62$
# 결과값:2073.77$, 예측값 :1671.19$
# 결과값:1800.75$, 예측값 :1494.72$
# 결과값:2310.06$, 예측값 :1975.54$
# 결과값:2077.89$, 예측값 :1497.52$
# 결과값:1529.59$, 예측값 :1407.66$
# 결과값:16186.73$, 예측값 :10393.86$
# 결과값:3560.20$, 예측값 :2806.66$
# 결과값:928.72$, 예측값 :517.16$
# 결과값:2455.49$, 예측값 :2311.43$
# 결과값:1183.09$, 예측값 :1039.64$
# 결과값:1957.05$, 예측값 :1773.77$
# 결과값:2113.06$, 예측값 :2053.43$
# 결과값:1035.63$, 예측값 :803.33$
# 결과값:1162.67$, 예측값 :941.70$
# 결과값:974.29$, 예측값 :599.90$
# 결과값:1089.95$, 예측값 :1156.03$
# 결과값:13019.69$, 예측값 :11182.03$
# 결과값:1536.74$, 예측값 :1606.24$
# 결과값:2067.07$, 예측값 :1918.64$
# 결과값:2507.91$, 예측값 :2381.88$
# 결과값:3680.92$, 예측값 :3346.02$
# 결과값:1030.68$, 예측값 :795.52$
# 결과값:1119.17$, 예측값 :701.79$
# 결과값:4161.25$, 예측값 :3550.03$
# 결과값:2113.36$, 예측값 :1748.57$
# 결과값:2934.67$, 예측값 :2807.46$
# 결과값:2304.07$, 예측값 :1685.48$
# 결과값:974.29$, 예측값 :900.29$
# 결과값:1504.15$, 예측값 :1363.45$
# 결과값:901.80$, 예측값 :867.25$
# 결과값:2050.63$, 예측값 :2330.13$
# 결과값:2094.93$, 예측값 :1807.73$
# 결과값:1686.12$, 예측값 :1028.62$
# 결과값:1093.23$, 예측값 :1328.98$
# 결과값:2067.68$, 예측값 :1925.60$
# 결과값:1122.21$, 예측값 :903.00$
# 결과값:15504.29$, 예측값 :10041.52$
# 결과값:868.34$, 예측값 :1053.17$
# 결과값:1065.76$, 예측값 :650.28$
# 결과값:1985.77$, 예측값 :1946.71$
# 결과값:1973.18$, 예측값 :1575.85$
# 결과값:1604.91$, 예측값 :1484.73$
# 결과값:1773.89$, 예측값 :2167.31$
# 결과값:2089.62$, 예측값 :2151.37$
# 결과값:2034.96$, 예측값 :1726.02$
# 결과값:5430.62$, 예측값 :4250.87$
# 결과값:977.78$, 예측값 :806.82$
# 결과값:1973.74$, 예측값 :1583.99$
# 결과값:3842.37$, 예측값 :4199.25$
# 결과값:1030.22$, 예측값 :678.66$
# 결과값:3466.30$, 예측값 :2726.71$
# 결과값:1389.25$, 예측값 :976.30$
# 결과값:1521.83$, 예측값 :1712.65$
# 결과값:971.75$, 예측값 :611.59$
# 결과값:5306.89$, 예측값 :5400.30$
# 결과값:2119.15$, 예측값 :2180.31$
# 결과값:2047.50$, 예측값 :2098.28$
# 결과값:2370.80$, 예측값 :1654.57$
# 결과값:1162.92$, 예측값 :925.52$
# 결과값:3638.36$, 예측값 :6512.71$
# 결과값:2048.45$, 예측값 :2032.58$
# 결과값:5375.50$, 예측값 :2672.36$
# 결과값:2186.82$, 예측값 :2346.81$
# 결과값:2043.45$, 예측값 :1523.22$
# 결과값:1799.85$, 예측값 :824.08$
# 결과값:1036.38$, 예측값 :695.33$
# 결과값:2133.55$, 예측값 :1803.94$
# 결과값:1416.14$, 예측값 :642.99$
# 결과값:839.64$, 예측값 :792.62$
# 결과값:3505.15$, 예측값 :2857.35$
# 결과값:922.67$, 예측값 :1475.44$
# 결과값:1143.13$, 예측값 :700.44$
# 결과값:1516.10$, 예측값 :1259.29$
# 결과값:9640.53$, 예측값 :6309.01$
# 결과값:930.75$, 예측값 :982.67$
# 결과값:2904.99$, 예측값 :2791.16$
# 결과값:855.14$, 예측값 :1246.25$
# 결과값:2044.29$, 예측값 :1801.46$
# 결과값:1660.49$, 예측값 :1203.54$
# 결과값:1030.65$, 예측값 :903.76$
# 결과값:2032.44$, 예측값 :2058.64$
# 결과값:2870.92$, 예측값 :2465.29$
# 결과값:2020.70$, 예측값 :1763.98$
# 결과값:2061.87$, 예측값 :2148.15$
# 결과값:1510.20$, 예측값 :1274.58$
# 결과값:2078.07$, 예측값 :2037.51$
# 결과값:3792.23$, 예측값 :3228.08$
# 결과값:2140.92$, 예측값 :3145.23$
# 결과값:846.08$, 예측값 :815.70$
# 결과값:1859.00$, 예측값 :1479.11$
# 결과값:955.64$, 예측값 :789.47$
# 결과값:2936.27$, 예측값 :2349.06$
# 결과값:3819.36$, 예측값 :2727.28$
# 결과값:3546.45$, 예측값 :3054.08$
# 결과값:4092.84$, 예측값 :1972.32$
# 결과값:2358.92$, 예측값 :3184.59$
# 결과값:1622.57$, 예측값 :1412.55$
# 결과값:1283.45$, 예측값 :991.38$
# 결과값:2187.06$, 예측값 :1689.36$
# 결과값:1535.38$, 예측값 :1185.20$
# 결과값:2023.92$, 예측값 :2212.75$
# 결과값:1013.32$, 예측값 :1038.53$
# 결과값:1147.00$, 예측값 :1033.03$
# 결과값:2344.52$, 예측값 :2196.26$
# 결과값:2296.49$, 예측값 :1507.61$
# 결과값:1176.27$, 예측값 :1040.21$
# 결과값:2560.39$, 예측값 :2443.68$
# 결과값:1086.40$, 예측값 :1015.98$
# 결과값:1514.71$, 예측값 :1183.53$
# 결과값:1738.11$, 예측값 :1509.30$
# 결과값:1504.10$, 예측값 :788.69$
# 결과값:3655.62$, 예측값 :5541.93$
# 결과값:1705.31$, 예측값 :1709.08$
# 결과값:2095.57$, 예측값 :1847.57$
# 결과값:4133.16$, 예측값 :3658.74$
# 결과값:2015.29$, 예측값 :2204.01$
# 결과값:935.25$, 예측값 :1020.63$
# 결과값:2050.95$, 예측값 :1926.47$
# 결과값:974.29$, 예측값 :461.18$
# 결과값:1815.28$, 예측값 :1577.29$
# 결과값:6035.25$, 예측값 :3913.78$
# 결과값:1148.68$, 예측값 :1076.13$
# 결과값:1258.73$, 예측값 :1275.78$
# 결과값:1704.53$, 예측값 :1551.39$
# 결과값:904.35$, 예측값 :904.51$
# 결과값:1520.79$, 예측값 :1632.34$
# 결과값:2062.70$, 예측값 :2215.02$
# 결과값:1499.88$, 예측값 :1340.87$
# 결과값:1514.71$, 예측값 :1176.84$
# 결과값:1284.20$, 예측값 :1244.02$
# 결과값:2805.18$, 예측값 :2694.25$
# 결과값:1427.21$, 예측값 :1257.05$
# 결과값:901.78$, 예측값 :1180.58$
# 결과값:1322.54$, 예측값 :1182.65$
# 결과값:2063.15$, 예측값 :1511.94$
# 결과값:924.67$, 예측값 :1197.23$
# 결과값:3642.69$, 예측값 :2536.44$
# 결과값:2094.84$, 예측값 :2040.21$
# 결과값:1056.32$, 예측값 :924.48$
# 결과값:1044.25$, 예측값 :1066.83$
# 결과값:1533.66$, 예측값 :2045.82$
# 결과값:925.63$, 예측값 :544.83$
# 결과값:809.54$, 예측값 :255.71$
# 결과값:2157.93$, 예측값 :2191.47$
# 결과값:1521.74$, 예측값 :1418.17$
# 결과값:2061.92$, 예측값 :1822.98$
# 결과값:1679.05$, 예측값 :1648.97$
# 결과값:1366.03$, 예측값 :1690.64$
# 결과값:1922.03$, 예측값 :1811.30$
# 결과값:1277.78$, 예측값 :1028.24$
# 결과값:2551.39$, 예측값 :2533.87$
# 결과값:1562.27$, 예측값 :1326.21$
# 결과값:897.74$, 예측값 :1364.43$
# 결과값:1133.52$, 예측값 :1009.04$
# 결과값:811.49$, 예측값 :690.90$
# 결과값:6862.55$, 예측값 :4215.96$
# 결과값:2969.47$, 예측값 :2261.10$
# 결과값:1112.06$, 예측값 :1450.32$
# 결과값:1978.20$, 예측값 :2043.39$
# 결과값:2415.62$, 예측값 :2153.44$
# 결과값:2087.15$, 예측값 :1592.60$
# 결과값:973.91$, 예측값 :1043.63$
# 결과값:2341.58$, 예측값 :2465.16$
# 결과값:1731.56$, 예측값 :1765.88$
# 결과값:2473.38$, 예측값 :3124.85$
# 결과값:1411.99$, 예측값 :1084.91$
# 결과값:2006.18$, 예측값 :2066.69$
# 결과값:7247.40$, 예측값 :6288.39$
# 결과값:1183.24$, 예측값 :995.62$
# 결과값:1263.85$, 예측값 :859.55$
# 결과값:2351.70$, 예측값 :2088.26$
# 결과값:1960.82$, 예측값 :1981.62$
# 결과값:1498.35$, 예측값 :1316.01$
# 결과값:4397.38$, 예측값 :2626.93$
# 결과값:1169.50$, 예측값 :1041.33$
# 결과값:2118.77$, 예측값 :2144.47$
# 결과값:2516.77$, 예측값 :2288.75$
# 결과값:2077.11$, 예측값 :1908.24$
# 결과값:1465.45$, 예측값 :1413.55$
# 결과값:1211.76$, 예측값 :1202.60$
# 결과값:969.79$, 예측값 :903.36$
# 결과값:1199.98$, 예측값 :1083.87$
# 결과값:901.31$, 예측값 :818.81$
# 결과값:1520.66$, 예측값 :1626.89$
# 결과값:1414.37$, 예측값 :612.40$
# 결과값:2111.87$, 예측값 :2123.03$
# 결과값:1264.41$, 예측값 :887.10$
# 결과값:880.52$, 예측값 :1247.67$
# 결과값:1118.81$, 예측값 :767.40$
# 결과값:2099.04$, 예측값 :2283.93$
# 결과값:1254.22$, 예측값 :1129.59$
# 결과값:2048.33$, 예측값 :1664.63$
# 결과값:1975.61$, 예측값 :1747.33$
# 결과값:1447.35$, 예측값 :1176.84$
# 결과값:1058.99$, 예측값 :931.08$
# 결과값:1060.00$, 예측값 :1042.71$
# 결과값:2080.00$, 예측값 :1866.27$
# 결과값:6840.40$, 예측값 :5386.53$
# 결과값:1196.50$, 예측값 :807.56$
# 결과값:1057.31$, 예측값 :978.45$
# 결과값:1650.32$, 예측값 :1322.85$
# 결과값:1281.90$, 예측값 :1090.33$
# 결과값:764.56$, 예측값 :779.23$
# 결과값:1990.23$, 예측값 :2143.83$
# 결과값:2422.26$, 예측값 :2459.93$
# 결과값:958.65$, 예측값 :845.90$
# 결과값:974.29$, 예측값 :788.66$
# 결과값:2316.25$, 예측값 :1703.62$
# 결과값:1324.17$, 예측값 :556.50$
# 결과값:1968.16$, 예측값 :2244.31$
# 결과값:1406.85$, 예측값 :1285.26$
# 결과값:1131.52$, 예측값 :821.30$
# 결과값:1264.82$, 예측값 :1387.91$
# 결과값:13549.56$, 예측값 :12022.19$
# 결과값:1124.77$, 예측값 :1147.93$
# 결과값:1012.33$, 예측값 :630.14$
# 결과값:5297.83$, 예측값 :2811.16$
# 결과값:1147.17$, 예측값 :1053.16$
# 결과값:1156.64$, 예측값 :1041.55$
# 결과값:1567.03$, 예측값 :4060.70$
# 결과값:1984.06$, 예측값 :2116.28$
# 결과값:1699.36$, 예측값 :1387.02$
# 결과값:1950.75$, 예측값 :1901.01$
# 결과값:1532.76$, 예측값 :1466.05$
# 결과값:2223.08$, 예측값 :2059.71$
# 결과값:838.36$, 예측값 :1164.41$
# 결과값:18073.74$, 예측값 :15272.35$
# 결과값:1322.72$, 예측값 :1222.71$
# 결과값:2123.49$, 예측값 :2308.32$
# 결과값:1969.78$, 예측값 :1530.05$
# 결과값:2038.17$, 예측값 :2022.55$
# 결과값:1166.15$, 예측값 :1098.82$
# 결과값:1534.72$, 예측값 :827.15$
# 결과값:1402.39$, 예측값 :1323.93$
# 결과값:2059.52$, 예측값 :1827.59$
# 결과값:2028.19$, 예측값 :1891.40$
# 결과값:1422.76$, 예측값 :1381.65$
# 결과값:4431.54$, 예측값 :2631.98$
# 결과값:1067.44$, 예측값 :1062.85$
# 결과값:6206.88$, 예측값 :5265.95$
# 결과값:1304.75$, 예측값 :1153.73$
# 결과값:3381.53$, 예측값 :3012.90$
# 결과값:1093.73$, 예측값 :921.10$
# 결과값:1055.32$, 예측값 :870.08$
# 결과값:1718.73$, 예측값 :1371.80$
# 결과값:2025.94$, 예측값 :1689.46$
# 결과값:1454.46$, 예측값 :1542.85$
# 결과값:1346.11$, 예측값 :1314.68$
# 결과값:2582.83$, 예측값 :2651.30$
# 결과값:1369.69$, 예측값 :1087.89$
# 결과값:1133.31$, 예측값 :1330.61$
# 결과값:879.73$, 예측값 :1248.18$
# 결과값:1055.41$, 예측값 :1147.74$
# 결과값:2237.73$, 예측값 :1681.51$
# 결과값:822.22$, 예측값 :1055.79$
# 결과값:1212.17$, 예측값 :1056.86$
# 결과값:1458.81$, 예측값 :1210.87$
# 결과값:1702.84$, 예측값 :1412.28$
# 결과값:13164.25$, 예측값 :8750.92$
# 결과값:882.52$, 예측값 :860.69$
# 결과값:1003.72$, 예측값 :1114.83$
# 결과값:1039.76$, 예측값 :976.63$
# 결과값:2069.27$, 예측값 :2149.80$
# 결과값:2048.45$, 예측값 :1984.49$
# 결과값:4115.50$, 예측값 :2844.06$
# 결과값:1188.41$, 예측값 :896.33$
# 결과값:2080.00$, 예측값 :1832.26$
# 결과값:1088.41$, 예측값 :957.70$
# 결과값:2902.28$, 예측값 :2733.98$
# 결과값:2111.82$, 예측값 :2101.07$
# 결과값:1534.52$, 예측값 :1241.85$
# 결과값:2064.34$, 예측값 :1961.36$
# 결과값:1530.87$, 예측값 :863.68$
# 결과값:1624.24$, 예측값 :898.29$
# 결과값:1805.77$, 예측값 :950.14$
# 결과값:2191.89$, 예측값 :1990.53$
# 결과값:1263.99$, 예측값 :1162.94$
# 결과값:2922.70$, 예측값 :2716.96$
# 결과값:1428.81$, 예측값 :1462.26$
# 결과값:829.54$, 예측값 :848.63$
# 결과값:2448.26$, 예측값 :2155.09$
# 결과값:1063.53$, 예측값 :761.83$
# 결과값:837.87$, 예측값 :1450.33$
# 결과값:1429.50$, 예측값 :818.31$
# 결과값:2448.27$, 예측값 :2121.28$
# 결과값:6851.88$, 예측값 :6586.35$
# 결과값:2080.00$, 예측값 :1679.49$
# 결과값:2111.79$, 예측값 :2023.69$
# 결과값:1427.39$, 예측값 :867.84$
# 결과값:5421.55$, 예측값 :3445.86$
# 결과값:1920.85$, 예측값 :1563.68$
# 결과값:899.37$, 예측값 :864.51$
# 결과값:2088.84$, 예측값 :2094.55$
# 결과값:9518.21$, 예측값 :7260.29$
# 결과값:2080.30$, 예측값 :2419.75$
# 결과값:2109.47$, 예측값 :1644.61$
# 결과값:965.38$, 예측값 :880.65$
# 결과값:1939.42$, 예측값 :2000.92$
# 결과값:13595.21$, 예측값 :9624.02$
# 결과값:1328.93$, 예측값 :1104.52$
# 결과값:3830.65$, 예측값 :2773.86$
# 결과값:64733.52$, 예측값 :57526.11$
# 결과값:2109.12$, 예측값 :1865.33$
# 결과값:2036.90$, 예측값 :1548.17$
# 결과값:2405.80$, 예측값 :1441.89$
# 결과값:4373.52$, 예측값 :2383.82$
# 결과값:2019.55$, 예측값 :1436.90$
# 결과값:1738.37$, 예측값 :1470.74$
# 결과값:1204.23$, 예측값 :987.64$
# 결과값:1308.87$, 예측값 :1028.78$
# 결과값:1798.16$, 예측값 :1589.02$
# 결과값:1867.55$, 예측값 :1427.73$
# 결과값:2448.28$, 예측값 :2161.86$
# 결과값:7274.90$, 예측값 :8342.33$
# 결과값:963.25$, 예측값 :1008.20$
# 결과값:12627.71$, 예측값 :9339.55$
# 결과값:3083.53$, 예측값 :2681.63$
# 결과값:1533.95$, 예측값 :1320.09$
# 결과값:3173.58$, 예측값 :2760.15$
# 결과값:1766.17$, 예측값 :888.07$
# 결과값:1673.86$, 예측값 :1785.20$
# 결과값:846.74$, 예측값 :687.45$
# 결과값:1682.51$, 예측값 :1691.43$
# 결과값:3506.60$, 예측값 :2865.27$
# 결과값:3521.16$, 예측값 :2919.30$
# 결과값:4030.43$, 예측값 :3069.99$
# 결과값:1155.32$, 예측값 :1011.26$
# 결과값:1624.52$, 예측값 :1418.98$
# 결과값:2352.39$, 예측값 :2084.76$
# 결과값:2059.28$, 예측값 :2158.88$
# 결과값:1678.17$, 예측값 :1067.67$
# 결과값:2006.18$, 예측값 :1763.11$
# 결과값:1034.31$, 예측값 :619.95$
# 결과값:1730.63$, 예측값 :1237.85$
# 결과값:3143.29$, 예측값 :3132.12$
# 결과값:1955.13$, 예측값 :1693.34$
# 결과값:1699.36$, 예측값 :1458.15$
# 결과값:2419.01$, 예측값 :2180.36$
# 결과값:2354.21$, 예측값 :2482.06$
# 결과값:1462.87$, 예측값 :1601.79$
# 결과값:1991.83$, 예측값 :1616.44$
# 결과값:1650.29$, 예측값 :996.19$
# 결과값:3001.29$, 예측값 :2454.33$
# 결과값:1012.26$, 예측값 :479.66$
# 결과값:1801.64$, 예측값 :1666.95$
# 결과값:1681.70$, 예측값 :1301.48$
# 결과값:2359.81$, 예측값 :2228.49$
# 결과값:2736.16$, 예측값 :2469.23$
# 결과값:975.86$, 예측값 :568.04$
# 결과값:3368.06$, 예측값 :2916.06$
# 결과값:1170.21$, 예측값 :1161.42$
# 결과값:3728.59$, 예측값 :3071.89$
# 결과값:1307.26$, 예측값 :732.87$
# 결과값:3646.86$, 예측값 :4377.17$
# 결과값:1443.29$, 예측값 :1132.94$
# 결과값:4338.46$, 예측값 :2827.12$
# 결과값:2962.27$, 예측값 :1946.88$
# 결과값:2527.87$, 예측값 :2177.86$
# 결과값:2059.58$, 예측값 :1762.09$
# 결과값:2225.57$, 예측값 :2266.14$
# 결과값:1063.69$, 예측값 :697.58$
# 결과값:1785.30$, 예측값 :1610.88$
# 결과값:1031.12$, 예측값 :1028.78$
# 결과값:1532.76$, 예측값 :737.79$
# 결과값:1242.86$, 예측값 :1223.54$
# 결과값:2156.38$, 예측값 :1631.09$
# 결과값:1684.98$, 예측값 :1373.87$
# 결과값:1111.09$, 예측값 :1099.57$
# 결과값:2059.79$, 예측값 :2527.65$
# 결과값:1404.00$, 예측값 :1378.97$
# 결과값:2289.26$, 예측값 :2206.09$
# 결과값:1973.83$, 예측값 :1668.93$
# 결과값:1836.29$, 예측값 :1569.85$
# 결과값:1371.01$, 예측값 :1131.75$
# 결과값:1047.87$, 예측값 :1398.70$
# 결과값:2110.10$, 예측값 :1475.53$
# 결과값:1110.81$, 예측값 :1181.84$
# 결과값:2059.40$, 예측값 :2021.55$
# 결과값:1672.38$, 예측값 :3103.06$
# 결과값:1033.64$, 예측값 :1294.93$
# 결과값:840.78$, 예측값 :872.53$
# 결과값:2053.24$, 예측값 :1978.59$
# 결과값:2081.59$, 예측값 :1894.62$
# 결과값:1114.08$, 예측값 :1235.08$
# 결과값:2076.37$, 예측값 :2226.94$
# 결과값:1409.60$, 예측값 :997.41$
# 결과값:1401.03$, 예측값 :1193.35$
# 결과값:2038.02$, 예측값 :2021.26$
# 결과값:2566.67$, 예측값 :2249.45$
# 결과값:4378.37$, 예측값 :2631.96$
# 결과값:2404.83$, 예측값 :2196.11$
# 결과값:1960.60$, 예측값 :1665.19$
# 결과값:1425.99$, 예측값 :1280.79$
# 결과값:1407.79$, 예측값 :1319.25$
# 결과값:2321.01$, 예측값 :1679.90$
# 결과값:1872.51$, 예측값 :2009.49$
# 결과값:1533.95$, 예측값 :1329.75$
# 결과값:1426.36$, 예측값 :1156.30$
# 결과값:2106.18$, 예측값 :1918.48$
# 결과값:1502.60$, 예측값 :1334.42$
# 결과값:924.26$, 예측값 :866.04$
# 결과값:1481.29$, 예측값 :1161.05$
# 결과값:951.15$, 예측값 :651.53$
# 결과값:1065.76$, 예측값 :928.68$
# 결과값:2240.16$, 예측값 :1662.74$
# 결과값:1983.34$, 예측값 :2176.19$
# 결과값:1752.51$, 예측값 :1373.71$
# 결과값:1601.05$, 예측값 :1144.28$
# 결과값:1648.09$, 예측값 :1590.81$
# 결과값:2088.23$, 예측값 :1742.23$
# 결과값:1678.34$, 예측값 :1395.79$
# 결과값:6493.52$, 예측값 :5617.58$
# 결과값:1799.85$, 예측값 :971.19$
# 결과값:1147.23$, 예측값 :735.17$
# 결과값:2273.98$, 예측값 :2188.84$
# 결과값:983.07$, 예측값 :1025.66$
# 결과값:2054.53$, 예측값 :1823.44$
# 결과값:2082.57$, 예측값 :1838.11$
# 결과값:1445.12$, 예측값 :1546.37$
# 결과값:1432.27$, 예측값 :1459.82$
# 결과값:2935.14$, 예측값 :2483.70$
# 결과값:2034.08$, 예측값 :2010.20$
# 결과값:2119.15$, 예측값 :2287.40$
# 결과값:1796.44$, 예측값 :1449.68$
# 결과값:1030.65$, 예측값 :864.15$
# 결과값:2772.47$, 예측값 :2733.73$
# 결과값:1435.74$, 예측값 :1390.96$
# 결과값:2061.94$, 예측값 :1983.40$
# 결과값:2011.95$, 예측값 :1922.03$
# 결과값:3651.12$, 예측값 :2971.87$
# 결과값:1782.88$, 예측값 :2280.38$
# 결과값:2354.34$, 예측값 :2496.01$
# 결과값:1549.36$, 예측값 :1575.39$
# 결과값:2041.08$, 예측값 :1783.23$
# 결과값:2033.24$, 예측값 :1938.00$
# 결과값:3343.19$, 예측값 :2349.73$
# 결과값:1277.78$, 예측값 :1253.94$
# 결과값:4340.03$, 예측값 :3164.00$
# 결과값:2508.11$, 예측값 :2102.92$
# 결과값:1978.08$, 예측값 :2142.74$
# 결과값:2096.03$, 예측값 :2288.89$
# 결과값:1474.59$, 예측값 :1387.72$
# 결과값:1597.90$, 예측값 :1193.99$
# 결과값:926.68$, 예측값 :979.31$
# 결과값:5298.17$, 예측값 :4676.43$
# 결과값:2095.55$, 예측값 :1443.44$
# 결과값:1539.35$, 예측값 :1667.52$
# 결과값:1658.89$, 예측값 :1467.92$
# 결과값:899.25$, 예측값 :1080.44$
# 결과값:1277.07$, 예측값 :1006.14$
# 결과값:1954.96$, 예측값 :1593.69$
# 결과값:1044.84$, 예측값 :1125.75$
# 결과값:1697.76$, 예측값 :1937.79$
# 결과값:2435.56$, 예측값 :2449.28$
# 결과값:1442.43$, 예측값 :1265.60$
# 결과값:1984.26$, 예측값 :1838.00$
# 결과값:2322.91$, 예측값 :1404.26$
# 결과값:2091.23$, 예측값 :2901.71$
# 결과값:926.36$, 예측값 :944.07$
# 결과값:2263.09$, 예측값 :2158.90$
# 결과값:979.42$, 예측값 :413.24$
# 결과값:2319.32$, 예측값 :2299.06$
# 결과값:2112.50$, 예측값 :2098.69$
# 결과값:1393.76$, 예측값 :1103.42$
# 결과값:1049.51$, 예측값 :885.25$
# 결과값:1116.82$, 예측값 :899.64$
# 결과값:807.91$, 예측값 :864.22$
# 결과값:923.72$, 예측값 :546.96$
# 결과값:1997.75$, 예측값 :2057.93$
# 결과값:2053.39$, 예측값 :1758.16$
# 결과값:2023.07$, 예측값 :2247.57$
# 결과값:2076.53$, 예측값 :2017.11$
# 결과값:2106.20$, 예측값 :2074.99$
# 결과값:1497.35$, 예측값 :1518.24$
# 결과값:2150.69$, 예측값 :1785.68$
# 결과값:896.04$, 예측값 :1360.47$
# 결과값:2024.69$, 예측값 :1941.08$
# 결과값:2054.93$, 예측값 :2538.28$
# 결과값:1339.58$, 예측값 :743.14$
# 결과값:2028.20$, 예측값 :2057.90$
# 결과값:794.37$, 예측값 :1077.17$
# 결과값:2055.16$, 예측값 :1817.79$
# 결과값:1012.43$, 예측값 :1159.16$
# 결과값:2025.35$, 예측값 :1912.64$
# 결과값:2425.61$, 예측값 :2583.13$
# 결과값:1262.33$, 예측값 :904.74$
# 결과값:2623.08$, 예측값 :2215.19$
# 결과값:2902.58$, 예측값 :2396.60$
# 결과값:1120.05$, 예측값 :870.59$
# 결과값:2471.74$, 예측값 :2530.02$
# 결과값:3754.13$, 예측값 :3249.51$
# 결과값:2068.73$, 예측값 :1771.81$
# 결과값:3840.15$, 예측값 :3968.87$
# 결과값:2320.21$, 예측값 :1882.80$
# 결과값:1740.70$, 예측값 :1111.28$
# 결과값:1163.62$, 예측값 :987.03$
# 결과값:1985.09$, 예측값 :1953.31$
# 결과값:3916.89$, 예측값 :4534.46$
# 결과값:2983.04$, 예측값 :3698.30$
# 결과값:2708.48$, 예측값 :2492.44$
# 결과값:1148.96$, 예측값 :1109.66$
# 결과값:1311.55$, 예측값 :1118.64$
# 결과값:1141.09$, 예측값 :750.12$
# 결과값:1326.65$, 예측값 :1204.37$
# 결과값:1060.56$, 예측값 :996.35$
# 결과값:1351.32$, 예측값 :823.44$
# 결과값:1329.07$, 예측값 :1003.81$
# 결과값:1824.39$, 예측값 :1401.75$
# 결과값:1347.34$, 예측값 :1276.72$
# 결과값:1702.71$, 예측값 :1492.25$
# 결과값:858.18$, 예측값 :1030.09$
# 결과값:1579.27$, 예측값 :1121.47$
# 결과값:2111.87$, 예측값 :2031.84$
# 결과값:2053.24$, 예측값 :1931.28$
# 결과값:1529.25$, 예측값 :2210.82$
# 결과값:1022.92$, 예측값 :886.38$
# 결과값:1932.68$, 예측값 :1705.63$
# 결과값:1864.54$, 예측값 :1811.68$
# 결과값:1973.14$, 예측값 :1662.73$
# 결과값:1534.52$, 예측값 :1148.19$
# 결과값:1430.74$, 예측값 :1137.02$
# 결과값:1282.85$, 예측값 :1339.72$
# 결과값:1515.05$, 예측값 :4981.08$
# 결과값:7283.46$, 예측값 :4320.36$
# 결과값:1066.25$, 예측값 :994.56$
# 결과값:2042.62$, 예측값 :2064.30$
# 결과값:1309.45$, 예측값 :805.64$
# 결과값:3664.60$, 예측값 :3532.23$
# 결과값:1292.65$, 예측값 :1219.31$
# 결과값:2356.77$, 예측값 :1871.66$
# 결과값:1600.60$, 예측값 :1554.26$
# 결과값:2100.82$, 예측값 :1901.04$
# 결과값:2447.17$, 예측값 :2115.02$
# 결과값:1603.42$, 예측값 :1615.99$
# 결과값:2946.60$, 예측값 :2630.31$
# 결과값:2053.49$, 예측값 :1995.10$
# 결과값:6829.35$, 예측값 :6312.59$
# 결과값:1972.43$, 예측값 :1720.36$
# 결과값:1124.39$, 예측값 :619.91$
# 결과값:1985.94$, 예측값 :1992.76$
# 결과값:1967.26$, 예측값 :1350.75$
# 결과값:2020.46$, 예측값 :1902.46$
# 결과값:4447.63$, 예측값 :2429.48$
# 결과값:6571.50$, 예측값 :4286.01$
# 결과값:1212.10$, 예측값 :611.82$
# 결과값:1382.22$, 예측값 :1352.35$
# 결과값:1166.56$, 예측값 :1074.87$
# 결과값:2686.39$, 예측값 :3057.16$
# 결과값:945.76$, 예측값 :1049.39$
# 결과값:2061.76$, 예측값 :2147.95$
# 결과값:967.69$, 예측값 :1045.83$
# 결과값:1624.24$, 예측값 :1474.69$
# 결과값:2041.76$, 예측값 :2095.16$
# 결과값:41056.65$, 예측값 :31488.27$
# 결과값:1659.65$, 예측값 :1447.69$
# 결과값:1312.31$, 예측값 :1230.29$
# 결과값:981.36$, 예측값 :1090.94$
# 결과값:2067.16$, 예측값 :1975.27$
# 결과값:2092.22$, 예측값 :2113.30$
# 결과값:1165.31$, 예측값 :986.77$
# 결과값:2078.47$, 예측값 :2352.79$
# 결과값:1038.49$, 예측값 :781.71$
# 결과값:1875.93$, 예측값 :1580.80$
# 결과값:11775.93$, 예측값 :8920.51$
# 결과값:2197.80$, 예측값 :1709.00$
# Accuracy: 89.15   RMSE : 1269.51

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)

fig, axes = plt.subplots(1, 2,figsize = (12, 7), sharey = True)

prediction1 = prediction[prediction['label'] < 10000]
axes[0].plot(prediction1.index, prediction1['pred'],label='Prediction',        
        linestyle = '--',)
axes[0].plot(prediction1.index, prediction1['label'], label = 'Truth',
        linestyle = '--',)
axes[0].set_xticks([])
axes[0].legend()
axes[0].set_title("Price under 10000$")
prediction2 = prediction[prediction['label'] > 10000]
axes[1].plot(prediction2.index, prediction2['pred'],label='Prediction',        
        linestyle = '--',)
axes[1].plot(prediction2.index, prediction2['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
axes[1].set_xticks([])
axes[1].legend()
axes[1].set_title("Price over 10000$")
plt.ylabel('prices')
plt.show()
