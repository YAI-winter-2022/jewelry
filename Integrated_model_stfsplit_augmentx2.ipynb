# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import random
import albumentations as A
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
csv_train_path = "trainx2.csv"
csv_test_path = "test.csv"
csv_val_path = "val.csv"
image_path = "./imagesx2"
batch_size = 256
epochs = 100
learning_rate = 1e-3
seed = 42

# %%
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
class AllDataset(Dataset):
    def __init__(self, csv_path, image_path, image_transform=transforms.Compose([transforms.ToTensor()])):
        super(AllDataset).__init__()
        csv = pd.read_csv(csv_path)
        csv_np = csv.to_numpy()
        
        self.image_transform = image_transform
        self.ids = list(map(str, csv['Id']))
        self.image_path = image_path
        
        for i in [1, 3, 4, 5, 6, 7, 8]:
            wordset = {word: idx for idx, word in enumerate(np.unique(csv_np[:,i]))}
            for row in range(len(csv_np)):
                csv_np[row][i] = wordset[csv_np[row][i]]
        self.ints = torch.from_numpy(np.array(csv_np[:,[1,3,4,5,6,7,8]], dtype="int"))
        self.floats = torch.from_numpy(np.array(csv_np[:,[2,9,10,11]], dtype="float")).float()
        self.target = torch.from_numpy(np.array(csv_np[:,[12]], dtype="float")).float()
    
    
    def __getitem__(self,idx):
        return self.image_transform(Image.open(self.image_path+'/'+self.ids[idx]+'.jpg')), self.ints[idx],self.floats[idx], self.target[idx]
    
    
    def __len__(self):
        return len(self.ints)

# %%
image_transform = transforms.Compose([transforms.ToTensor()
                                     ])
train_dataset = AllDataset(csv_train_path, image_path, image_transform)
test_dataset = AllDataset(csv_test_path, image_path, image_transform)
val_dataset = AllDataset(csv_val_path, image_path, image_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Sequential(nn.Linear(512, 4096),
                                         nn.BatchNorm1d(4096),
                                         nn.ReLU(),
                                         nn.Dropout()
                                        )
        self.resenet18 = self.resnet18.to(device)
        
        self.emb1 = torch.nn.Embedding(8, 20)
        self.emb2 = torch.nn.Embedding(11, 20)
        self.emb3 = torch.nn.Embedding(20, 20)
        self.emb4 = torch.nn.Embedding(4, 20)
        self.emb5 = torch.nn.Embedding(4, 20)
        self.emb6 = torch.nn.Embedding(4, 20)
        self.emb7 = torch.nn.Embedding(7, 20)
        self.act = nn.ReLU()
        self.fc = nn.Linear(4, 80)
        self.csvbn = nn.BatchNorm1d(80)
        self.csvfc1 = nn.Linear(220, 8192)
        self.csvfc2 = nn.Linear(8192, 8192)
        self.csvfc3 = nn.Linear(8192, 4096)
        self.csvbn1 = nn.BatchNorm1d(8192)
        self.csvbn2 = nn.BatchNorm1d(8192)
        self.csvbn3 = nn.BatchNorm1d(4096)
        
        self.fc1 = nn.Linear(8192, 4096)
        self.fc2 = nn.Linear(4096, 1)
        self.bn1 = nn.BatchNorm1d(4096)
        self.dropout = nn.Dropout()
    
    def forward(self, image, x, y):
        image = self.resnet18(image)
        
        x1 = self.emb1(x[:,0])
        x2 = self.emb2(x[:,1])
        x3 = self.emb3(x[:,2])
        x4 = self.emb4(x[:,3])
        x5 = self.emb5(x[:,4])
        x6 = self.emb6(x[:,5])
        x7 = self.emb7(x[:,6])
        y = self.csvbn(self.fc(y))
        x = torch.cat((x1, x2, x3, x4, x5, x6, x7, y), dim=1)
        
        x = self.dropout(self.act(self.csvbn1(self.csvfc1(x))))
        x = self.dropout(self.act(self.csvbn2(self.csvfc2(x))))
        x = self.dropout(self.act(self.csvbn3(self.csvfc3(x))))
        x = torch.cat((x, image), dim=1)
        
        x = self.dropout(self.act(self.bn1(self.fc1(x))))
        return self.fc2(x)

# %%
model = Net().to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(epochs):
    model.train()
    criterion.train()
    
    avg_loss = 0

    for Img, X1, X2, Y in train_loader:
        Img = Img.to(device)
        X1 = X1.to(device)
        X2 = X2.to(device)
        Y = Y.to(device)

        model.zero_grad()
        prediction = model(Img, X1, X2)
        loss = torch.sqrt(criterion(prediction, Y)).to(device)
        loss.backward()
        optimizer.step()
        avg_loss += loss / len(train_loader)
    print(f'[Epoch: {epoch+1:>2}] Average loss: {avg_loss:.4f}, ', end='')
    
    model.eval()
    criterion.eval()
    with torch.no_grad():
        val_avg_loss = 0.
        for Image_val, X1_val, X2_val, Y_val in val_loader:
            Image_val = Image_val.to(device)
            X1_val = X1_val.to(device)
            X2_val = X2_val.to(device)
            Y_val = Y_val.to(device)
            val_prediction = model(Image_val, X1_val, X2_val)
            val_loss = torch.sqrt(criterion(val_prediction, Y_val)).to(device)
            val_avg_loss += val_loss / len(val_loader)
        
        print(f"val_loss: {val_avg_loss:.4f}")
# Out:
# [Epoch:  1] Average loss: 5686.2437, val_loss: 4234.9546
# [Epoch:  2] Average loss: 6303.9937, val_loss: 4746.1514
# [Epoch:  3] Average loss: 5707.0073, val_loss: 4191.2554
# [Epoch:  4] Average loss: 5663.1699, val_loss: 4483.0786
# [Epoch:  5] Average loss: 5523.1738, val_loss: 4203.1084
# [Epoch:  6] Average loss: 5945.5137, val_loss: 4281.5234
# [Epoch:  7] Average loss: 5378.5796, val_loss: 3949.7498
# [Epoch:  8] Average loss: 5354.4614, val_loss: 4103.6104
# [Epoch:  9] Average loss: 5853.5811, val_loss: 4027.0698
# [Epoch: 10] Average loss: 5258.7061, val_loss: 4189.2891
# [Epoch: 11] Average loss: 5423.8711, val_loss: 4128.5596
# [Epoch: 12] Average loss: 5447.5566, val_loss: 4045.8872
# [Epoch: 13] Average loss: 4909.3721, val_loss: 3560.7534
# [Epoch: 14] Average loss: 4983.5259, val_loss: 3940.2058
# [Epoch: 15] Average loss: 5040.6465, val_loss: 3247.8472
# [Epoch: 16] Average loss: 5299.3906, val_loss: 3544.1711
# [Epoch: 17] Average loss: 5097.0571, val_loss: 3953.2744
# [Epoch: 18] Average loss: 4685.1553, val_loss: 3688.3499
# [Epoch: 19] Average loss: 5122.2534, val_loss: 3565.1772
# [Epoch: 20] Average loss: 4536.3359, val_loss: 3389.6792
# [Epoch: 21] Average loss: 4548.9331, val_loss: 3585.0237
# [Epoch: 22] Average loss: 4893.9946, val_loss: 3553.5737
# [Epoch: 23] Average loss: 4282.9932, val_loss: 3605.3540
# [Epoch: 24] Average loss: 4282.9824, val_loss: 3111.8301
# [Epoch: 25] Average loss: 4074.6855, val_loss: 2855.4402
# [Epoch: 26] Average loss: 4085.1406, val_loss: 3092.3240
# [Epoch: 27] Average loss: 4043.1794, val_loss: 3280.9529
# [Epoch: 28] Average loss: 4560.8262, val_loss: 3151.5693
# [Epoch: 29] Average loss: 3715.1392, val_loss: 3126.5396
# [Epoch: 30] Average loss: 3684.0972, val_loss: 2809.9849
# [Epoch: 31] Average loss: 3608.7419, val_loss: 2481.5312
# [Epoch: 32] Average loss: 4211.1602, val_loss: 2838.2737
# [Epoch: 33] Average loss: 3430.4971, val_loss: 2295.7627
# [Epoch: 34] Average loss: 3297.7771, val_loss: 2553.4790
# [Epoch: 35] Average loss: 3348.5298, val_loss: 2237.7732
# [Epoch: 36] Average loss: 3100.4939, val_loss: 2201.0181
# [Epoch: 37] Average loss: 3019.4067, val_loss: 2079.4839
# [Epoch: 38] Average loss: 2992.2234, val_loss: 1797.2123
# [Epoch: 39] Average loss: 2901.6846, val_loss: 2146.4268
# [Epoch: 40] Average loss: 2810.0432, val_loss: 1924.6938
# [Epoch: 41] Average loss: 2566.8438, val_loss: 2020.1768
# [Epoch: 42] Average loss: 2549.2332, val_loss: 1964.0552
# [Epoch: 43] Average loss: 3201.8843, val_loss: 1520.8502
# [Epoch: 44] Average loss: 2730.3335, val_loss: 1763.0314
# [Epoch: 45] Average loss: 2370.8701, val_loss: 2274.8193
# [Epoch: 46] Average loss: 2309.0635, val_loss: 1843.4377
# [Epoch: 47] Average loss: 2255.9724, val_loss: 1872.5974
# [Epoch: 48] Average loss: 2257.0632, val_loss: 1637.1191
# [Epoch: 49] Average loss: 1995.3101, val_loss: 1877.4170
# [Epoch: 50] Average loss: 2129.0862, val_loss: 2114.6257
# [Epoch: 51] Average loss: 2119.1589, val_loss: 1697.1249
# [Epoch: 52] Average loss: 1878.2687, val_loss: 1645.9801
# [Epoch: 53] Average loss: 1858.9272, val_loss: 1600.3287
# [Epoch: 54] Average loss: 2626.5271, val_loss: 1678.9299
# [Epoch: 55] Average loss: 2640.7422, val_loss: 1740.9362
# [Epoch: 56] Average loss: 1725.6755, val_loss: 1244.9320
# [Epoch: 57] Average loss: 2289.3005, val_loss: 1749.9761
# [Epoch: 58] Average loss: 2175.5061, val_loss: 1532.2156
# [Epoch: 59] Average loss: 1793.6044, val_loss: 2370.6216
# [Epoch: 60] Average loss: 1588.8750, val_loss: 1606.1824
# [Epoch: 61] Average loss: 1813.2935, val_loss: 1548.1781
# [Epoch: 62] Average loss: 1787.1072, val_loss: 1402.6682
# [Epoch: 63] Average loss: 1766.4559, val_loss: 1469.2589
# [Epoch: 64] Average loss: 1864.6641, val_loss: 1465.2429
# [Epoch: 65] Average loss: 2646.4551, val_loss: 1743.0929
# [Epoch: 66] Average loss: 1570.7920, val_loss: 1322.0615
# [Epoch: 67] Average loss: 1388.5575, val_loss: 1596.2380
# [Epoch: 68] Average loss: 1728.0735, val_loss: 1295.8739
# [Epoch: 69] Average loss: 2166.3984, val_loss: 1451.7249
# [Epoch: 70] Average loss: 1850.1433, val_loss: 1550.8463
# [Epoch: 71] Average loss: 1693.2983, val_loss: 1533.6497
# [Epoch: 72] Average loss: 1727.3629, val_loss: 1386.7258
# [Epoch: 73] Average loss: 1576.9570, val_loss: 1426.5897
# [Epoch: 74] Average loss: 1449.0906, val_loss: 1358.1896
# [Epoch: 75] Average loss: 1408.8429, val_loss: 1495.8021
# [Epoch: 76] Average loss: 1605.9220, val_loss: 1586.5255
# [Epoch: 77] Average loss: 1552.4275, val_loss: 1420.4502
# [Epoch: 78] Average loss: 1329.5482, val_loss: 1493.0967
# [Epoch: 79] Average loss: 1436.1844, val_loss: 1476.0363
# [Epoch: 80] Average loss: 1513.7517, val_loss: 1897.4751
# [Epoch: 81] Average loss: 1459.8369, val_loss: 1775.6116
# [Epoch: 82] Average loss: 1349.1720, val_loss: 1306.5791
# [Epoch: 83] Average loss: 1229.3496, val_loss: 1696.9293
# [Epoch: 84] Average loss: 1374.4669, val_loss: 1384.5112
# [Epoch: 85] Average loss: 1510.3070, val_loss: 1364.0896
# [Epoch: 86] Average loss: 1551.1763, val_loss: 1436.0662
# [Epoch: 87] Average loss: 1207.1969, val_loss: 1456.1914
# [Epoch: 88] Average loss: 1707.9626, val_loss: 1366.4436
# [Epoch: 89] Average loss: 1477.9559, val_loss: 1685.5723
# [Epoch: 90] Average loss: 1344.0750, val_loss: 1501.5801
# [Epoch: 91] Average loss: 1126.8914, val_loss: 1377.0791
# [Epoch: 92] Average loss: 1183.2424, val_loss: 1536.3787
# [Epoch: 93] Average loss: 1663.4974, val_loss: 1416.9435
# [Epoch: 94] Average loss: 1899.0017, val_loss: 1525.1407
# [Epoch: 95] Average loss: 1130.0886, val_loss: 1329.1366
# [Epoch: 96] Average loss: 1749.9058, val_loss: 1593.3337
# [Epoch: 97] Average loss: 1361.7770, val_loss: 1679.1650
# [Epoch: 98] Average loss: 1443.4019, val_loss: 1309.0035
# [Epoch: 99] Average loss: 1409.8082, val_loss: 1363.3993
# [Epoch: 100] Average loss: 1537.0999, val_loss: 1479.2162

# %%
PATH = './model/'
Name = 'model_stfsplit.pt'
torch.save(model.state_dict(), PATH+Name)

# %%
RMSEs = []
accuracys = []

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 20000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    accuracys.append(accuracy)
    RMSEs.append(RMSE)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}",)
# Out:
# 결과값:70749.53$, 예측값 :52381.81$
# 결과값:49865.46$, 예측값 :39156.19$
# 결과값:55408.52$, 예측값 :40149.52$
# 결과값:41719.09$, 예측값 :54398.07$
# 결과값:37753.27$, 예측값 :35957.27$
# 결과값:49075.34$, 예측값 :45115.45$
# Accuracy: -27.94   RMSE : 12003.90

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 20,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 15000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:18439.82$, 예측값 :11845.20$
# 결과값:18729.27$, 예측값 :10119.41$
# 결과값:55408.52$, 예측값 :40149.52$
# 결과값:15379.60$, 예측값 :16863.99$
# 결과값:16186.73$, 예측값 :15121.84$
# 결과값:37753.27$, 예측값 :35957.27$
# 결과값:17875.20$, 예측값 :20547.77$
# 결과값:16067.35$, 예측값 :8743.88$
# 결과값:70749.53$, 예측값 :52381.81$
# 결과값:16216.19$, 예측값 :19964.35$
# 결과값:15476.93$, 예측값 :17985.49$
# 결과값:49075.34$, 예측값 :45115.45$
# 결과값:49865.46$, 예측값 :39156.19$
# 결과값:16480.38$, 예측값 :21226.58$
# 결과값:41719.09$, 예측값 :54398.07$
# 결과값:18681.64$, 예측값 :17697.83$
# Accuracy: 78.10   RMSE : 8254.28

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 15,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 10000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:16480.38$, 예측값 :21226.58$
# 결과값:13262.90$, 예측값 :10999.50$
# 결과값:18439.82$, 예측값 :11845.20$
# 결과값:49075.34$, 예측값 :45115.45$
# 결과값:12627.71$, 예측값 :16686.78$
# 결과값:13500.16$, 예측값 :18014.84$
# 결과값:55408.52$, 예측값 :40149.52$
# 결과값:13328.09$, 예측값 :7412.13$
# 결과값:18729.27$, 예측값 :10119.41$
# 결과값:13410.72$, 예측값 :13457.12$
# 결과값:11755.98$, 예측값 :9170.48$
# 결과값:18681.64$, 예측값 :17697.83$
# 결과값:17875.20$, 예측값 :20547.77$
# 결과값:13490.76$, 예측값 :20999.32$
# 결과값:15379.60$, 예측값 :16863.99$
# 결과값:13326.63$, 예측값 :13888.00$
# 결과값:13336.86$, 예측값 :14267.04$
# 결과값:70749.53$, 예측값 :52381.81$
# 결과값:16216.19$, 예측값 :19964.35$
# 결과값:16186.73$, 예측값 :15121.84$
# 결과값:37753.27$, 예측값 :35957.27$
# 결과값:12996.87$, 예측값 :14730.30$
# 결과값:15476.93$, 예측값 :17985.49$
# 결과값:49865.46$, 예측값 :39156.19$
# 결과값:41719.09$, 예측값 :54398.07$
# 결과값:16067.35$, 예측값 :8743.88$
# Accuracy: 81.47   RMSE : 6890.24

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 10,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:1429.00$, 예측값 :1460.88$
# 결과값:13336.86$, 예측값 :14267.04$
# 결과값:1763.52$, 예측값 :2417.50$
# 결과값:1805.77$, 예측값 :2859.82$
# 결과값:1993.46$, 예측값 :3931.82$
# 결과값:2006.01$, 예측값 :2420.52$
# 결과값:2350.82$, 예측값 :3274.49$
# 결과값:2078.78$, 예측값 :3622.74$
# 결과값:2068.73$, 예측값 :4441.60$
# 결과값:2262.98$, 예측값 :2210.39$
# 결과값:1022.80$, 예측값 :1285.90$
# 결과값:2074.51$, 예측값 :2004.84$
# 결과값:943.90$, 예측값 :1465.16$
# 결과값:2055.02$, 예측값 :2076.05$
# 결과값:2448.26$, 예측값 :2255.29$
# 결과값:1031.12$, 예측값 :1248.44$
# 결과값:15476.93$, 예측값 :17985.49$
# 결과값:2100.82$, 예측값 :2328.84$
# 결과값:1565.85$, 예측값 :1684.65$
# 결과값:2077.11$, 예측값 :2273.89$
# 결과값:2028.98$, 예측값 :6134.65$
# 결과값:1030.65$, 예측값 :1255.40$
# 결과값:1139.13$, 예측값 :1630.61$
# 결과값:1276.32$, 예측값 :1413.10$
# 결과값:1423.83$, 예측값 :1519.67$
# 결과값:2071.45$, 예측값 :3396.24$
# 결과값:1279.25$, 예측값 :1311.40$
# 결과값:1576.77$, 예측값 :2270.30$
# 결과값:2071.48$, 예측값 :2019.98$
# 결과값:13490.76$, 예측값 :20999.32$
# 결과값:2122.91$, 예측값 :7110.41$
# 결과값:18729.27$, 예측값 :10119.41$
# 결과값:1881.17$, 예측값 :1758.02$
# 결과값:1462.03$, 예측값 :2246.29$
# 결과값:1530.31$, 예측값 :2064.42$
# 결과값:1041.72$, 예측값 :1535.09$
# 결과값:1256.24$, 예측값 :1493.42$
# 결과값:1153.26$, 예측값 :1441.70$
# 결과값:1091.99$, 예측값 :848.90$
# 결과값:1876.75$, 예측값 :1635.77$
# 결과값:1533.62$, 예측값 :2236.65$
# 결과값:1972.37$, 예측값 :2198.44$
# 결과값:2080.00$, 예측값 :2900.01$
# 결과값:2337.00$, 예측값 :7332.63$
# 결과값:2274.17$, 예측값 :2500.64$
# 결과값:2351.54$, 예측값 :3657.68$
# 결과값:13328.09$, 예측값 :7412.13$
# 결과값:1460.31$, 예측값 :2301.58$
# 결과값:1329.03$, 예측값 :1388.55$
# 결과값:6086.00$, 예측값 :13363.33$
# 결과값:1986.62$, 예측값 :1937.76$
# 결과값:2075.91$, 예측값 :3349.65$
# 결과값:1696.00$, 예측값 :2198.66$
# 결과값:1371.84$, 예측값 :1481.45$
# 결과값:1093.02$, 예측값 :1333.82$
# 결과값:1310.14$, 예측값 :1394.11$
# 결과값:1786.33$, 예측값 :2218.23$
# 결과값:1698.05$, 예측값 :1643.42$
# 결과값:2082.67$, 예측값 :2363.22$
# 결과값:2313.96$, 예측값 :3018.30$
# 결과값:1326.87$, 예측값 :1278.65$
# 결과값:1030.22$, 예측값 :1905.26$
# 결과값:1972.16$, 예측값 :2353.08$
# 결과값:1722.11$, 예측값 :3200.49$
# 결과값:926.91$, 예측값 :830.07$
# 결과값:2006.40$, 예측값 :2553.54$
# 결과값:2596.11$, 예측값 :5376.59$
# 결과값:1041.16$, 예측값 :1304.30$
# 결과값:2047.47$, 예측값 :4661.23$
# 결과값:1675.74$, 예측값 :2415.04$
# 결과값:2508.02$, 예측값 :2511.49$
# 결과값:2213.67$, 예측값 :2949.37$
# 결과값:2851.75$, 예측값 :2869.31$
# 결과값:2247.53$, 예측값 :2549.06$
# 결과값:1587.41$, 예측값 :2230.23$
# 결과값:1056.49$, 예측값 :1715.98$
# 결과값:2105.01$, 예측값 :2041.42$
# 결과값:2263.49$, 예측값 :1508.32$
# 결과값:1042.26$, 예측값 :1849.17$
# 결과값:2508.64$, 예측값 :6651.91$
# 결과값:1718.73$, 예측값 :1924.07$
# 결과값:1188.42$, 예측값 :1429.88$
# 결과값:1030.68$, 예측값 :1538.77$
# 결과값:1544.19$, 예측값 :1382.91$
# 결과값:1164.21$, 예측값 :1336.53$
# 결과값:1965.55$, 예측값 :2290.33$
# 결과값:1424.92$, 예측값 :1979.80$
# 결과값:2080.00$, 예측값 :3038.49$
# 결과값:3521.16$, 예측값 :1346.14$
# 결과값:6150.68$, 예측값 :5809.86$
# 결과값:1124.70$, 예측값 :2028.02$
# 결과값:1445.15$, 예측값 :1612.86$
# 결과값:1012.99$, 예측값 :1260.18$
# 결과값:1123.55$, 예측값 :1858.78$
# 결과값:2324.68$, 예측값 :3925.82$
# 결과값:926.34$, 예측값 :1168.56$
# 결과값:1291.97$, 예측값 :1312.90$
# 결과값:1752.72$, 예측값 :4553.59$
# 결과값:1951.16$, 예측값 :2666.51$
# 결과값:1120.39$, 예측값 :1285.98$
# 결과값:1048.37$, 예측값 :1399.37$
# 결과값:1212.63$, 예측값 :1462.28$
# 결과값:2762.91$, 예측값 :2480.34$
# 결과값:1277.73$, 예측값 :1490.77$
# 결과값:1404.00$, 예측값 :2087.43$
# 결과값:1135.92$, 예측값 :952.60$
# 결과값:819.30$, 예측값 :1341.94$
# 결과값:1658.74$, 예측값 :1636.05$
# 결과값:1183.00$, 예측값 :1737.04$
# 결과값:1063.09$, 예측값 :1610.58$
# 결과값:1156.91$, 예측값 :1488.34$
# 결과값:1191.82$, 예측값 :1226.44$
# 결과값:2102.50$, 예측값 :2095.71$
# 결과값:945.76$, 예측값 :1146.85$
# 결과값:2145.16$, 예측값 :3563.85$
# 결과값:1701.95$, 예측값 :1597.16$
# 결과값:1720.61$, 예측값 :1297.74$
# 결과값:2015.41$, 예측값 :1870.35$
# 결과값:3784.61$, 예측값 :6689.51$
# 결과값:1993.12$, 예측값 :2131.24$
# 결과값:1752.65$, 예측값 :1657.10$
# 결과값:2318.26$, 예측값 :3192.89$
# 결과값:1929.08$, 예측값 :2056.80$
# 결과값:2304.07$, 예측값 :2271.95$
# 결과값:3129.89$, 예측값 :5124.50$
# 결과값:2044.65$, 예측값 :2554.75$
# 결과값:2092.25$, 예측값 :6012.14$
# 결과값:1124.10$, 예측값 :1957.06$
# 결과값:1768.87$, 예측값 :1666.78$
# 결과값:1114.96$, 예측값 :1435.32$
# 결과값:945.96$, 예측값 :1348.66$
# 결과값:2304.45$, 예측값 :2728.62$
# 결과값:2157.27$, 예측값 :2801.36$
# 결과값:1973.70$, 예측값 :2364.19$
# 결과값:2056.00$, 예측값 :2366.85$
# 결과값:1537.92$, 예측값 :1984.24$
# 결과값:1996.74$, 예측값 :2069.57$
# 결과값:1723.88$, 예측값 :1759.41$
# 결과값:1474.41$, 예측값 :2134.61$
# 결과값:1862.80$, 예측값 :3613.04$
# 결과값:2053.38$, 예측값 :5734.59$
# 결과값:1672.34$, 예측값 :1965.12$
# 결과값:1085.42$, 예측값 :1138.90$
# 결과값:1032.69$, 예측값 :1291.25$
# 결과값:2187.19$, 예측값 :2494.86$
# 결과값:1983.47$, 예측값 :1958.65$
# 결과값:1293.26$, 예측값 :1451.29$
# 결과값:1615.89$, 예측값 :1621.68$
# 결과값:2242.06$, 예측값 :1817.25$
# 결과값:2090.55$, 예측값 :2318.28$
# 결과값:1303.33$, 예측값 :1237.37$
# 결과값:2118.77$, 예측값 :2437.92$
# 결과값:1310.83$, 예측값 :1282.63$
# 결과값:2527.87$, 예측값 :2679.87$
# 결과값:1789.73$, 예측값 :1731.65$
# 결과값:1038.49$, 예측값 :1708.91$
# 결과값:2453.69$, 예측값 :2329.46$
# 결과값:1624.52$, 예측값 :1643.02$
# 결과값:1347.34$, 예측값 :1215.81$
# 결과값:2084.78$, 예측값 :2152.16$
# 결과값:981.38$, 예측값 :1192.38$
# 결과값:2029.39$, 예측값 :2131.09$
# 결과값:1660.49$, 예측값 :1649.25$
# 결과값:1346.68$, 예측값 :696.02$
# 결과값:853.18$, 예측값 :1373.89$
# 결과값:3460.94$, 예측값 :3020.53$
# 결과값:1028.04$, 예측값 :1240.88$
# 결과값:2062.70$, 예측값 :2689.38$
# 결과값:1508.36$, 예측값 :1812.16$
# 결과값:1532.04$, 예측값 :1344.25$
# 결과값:2045.06$, 예측값 :2375.78$
# 결과값:1093.95$, 예측값 :1491.14$
# 결과값:9598.23$, 예측값 :15028.41$
# 결과값:2757.79$, 예측값 :5228.03$
# 결과값:1015.23$, 예측값 :690.34$
# 결과값:2471.39$, 예측값 :8318.47$
# 결과값:1040.08$, 예측값 :1297.71$
# 결과값:2048.45$, 예측값 :3156.11$
# 결과값:946.42$, 예측값 :1364.76$
# 결과값:2619.85$, 예측값 :2905.56$
# 결과값:1839.55$, 예측값 :1858.79$
# 결과값:1188.76$, 예측값 :1465.16$
# 결과값:1143.64$, 예측값 :1492.65$
# 결과값:1427.29$, 예측값 :1500.84$
# 결과값:1699.36$, 예측값 :1492.18$
# 결과값:2544.90$, 예측값 :2466.00$
# 결과값:1445.34$, 예측값 :1643.82$
# 결과값:1150.70$, 예측값 :1578.45$
# 결과값:2105.76$, 예측값 :2715.88$
# 결과값:2126.49$, 예측값 :2677.44$
# 결과값:4148.72$, 예측값 :10198.12$
# 결과값:2817.63$, 예측값 :3475.76$
# 결과값:2028.12$, 예측값 :2388.07$
# 결과값:1562.27$, 예측값 :1659.95$
# 결과값:4379.77$, 예측값 :8288.48$
# 결과값:1325.28$, 예측값 :1990.25$
# 결과값:1255.25$, 예측값 :795.47$
# 결과값:13326.63$, 예측값 :13888.00$
# 결과값:1277.72$, 예측값 :1467.95$
# 결과값:3456.76$, 예측값 :2178.71$
# 결과값:1463.57$, 예측값 :1544.43$
# 결과값:969.38$, 예측값 :1481.90$
# 결과값:2062.41$, 예측값 :2114.08$
# 결과값:1836.29$, 예측값 :1932.22$
# 결과값:2078.36$, 예측값 :6842.30$
# 결과값:2062.70$, 예측값 :2824.08$
# 결과값:4443.40$, 예측값 :19561.30$
# 결과값:2048.36$, 예측값 :1964.86$
# 결과값:1335.20$, 예측값 :1355.11$
# 결과값:1524.67$, 예측값 :1859.81$
# 결과값:2448.26$, 예측값 :2439.62$
# 결과값:947.09$, 예측값 :977.75$
# 결과값:1199.71$, 예측값 :1305.81$
# 결과값:1211.61$, 예측값 :1565.94$
# 결과값:3260.31$, 예측값 :2176.55$
# 결과값:1184.83$, 예측값 :1697.19$
# 결과값:2021.84$, 예측값 :3890.16$
# 결과값:2011.25$, 예측값 :3748.79$
# 결과값:2421.52$, 예측값 :2989.18$
# 결과값:2680.62$, 예측값 :2519.54$
# 결과값:2775.23$, 예측값 :6142.83$
# 결과값:70749.53$, 예측값 :52381.81$
# 결과값:2069.61$, 예측값 :2266.13$
# 결과값:1975.64$, 예측값 :2503.36$
# 결과값:3519.28$, 예측값 :3506.66$
# 결과값:2337.00$, 예측값 :2436.43$
# 결과값:1055.41$, 예측값 :1072.64$
# 결과값:764.56$, 예측값 :1763.13$
# 결과값:2008.35$, 예측값 :2363.78$
# 결과값:1141.31$, 예측값 :1407.55$
# 결과값:1498.35$, 예측값 :1935.43$
# 결과값:1126.24$, 예측값 :1864.01$
# 결과값:1742.54$, 예측값 :1855.72$
# 결과값:1260.79$, 예측값 :1436.22$
# 결과값:1529.59$, 예측값 :2297.61$
# 결과값:1010.79$, 예측값 :1638.94$
# 결과값:13262.90$, 예측값 :10999.50$
# 결과값:1963.28$, 예측값 :3261.81$
# 결과값:17875.20$, 예측값 :20547.77$
# 결과값:904.91$, 예측값 :1529.02$
# 결과값:975.06$, 예측값 :1298.70$
# 결과값:1031.20$, 예측값 :1468.12$
# 결과값:1660.49$, 예측값 :1422.47$
# 결과값:1267.50$, 예측값 :1553.61$
# 결과값:974.54$, 예측값 :1430.09$
# 결과값:901.80$, 예측값 :1213.83$
# 결과값:1407.85$, 예측값 :1670.95$
# 결과값:1031.66$, 예측값 :1285.36$
# 결과값:1969.80$, 예측값 :3010.36$
# 결과값:2028.32$, 예측값 :2368.41$
# 결과값:829.54$, 예측값 :1192.99$
# 결과값:1679.17$, 예측값 :2157.86$
# 결과값:1430.75$, 예측값 :1926.35$
# 결과값:2036.90$, 예측값 :2028.25$
# 결과값:2043.65$, 예측값 :2470.05$
# 결과값:3229.56$, 예측값 :3459.82$
# 결과값:902.31$, 예측값 :1490.39$
# 결과값:2665.60$, 예측값 :2472.87$
# 결과값:1885.25$, 예측값 :1859.59$
# 결과값:750.97$, 예측값 :961.31$
# 결과값:1985.97$, 예측값 :2810.52$
# 결과값:2113.04$, 예측값 :5447.65$
# 결과값:1854.92$, 예측값 :1787.89$
# 결과값:1739.96$, 예측값 :2529.85$
# 결과값:954.02$, 예측값 :727.92$
# 결과값:1034.60$, 예측값 :1287.95$
# 결과값:1283.79$, 예측값 :1366.24$
# 결과값:1473.19$, 예측값 :12309.28$
# 결과값:1581.86$, 예측값 :1658.42$
# 결과값:1403.12$, 예측값 :2001.31$
# 결과값:3267.15$, 예측값 :3036.40$
# 결과값:1155.32$, 예측값 :1274.31$
# 결과값:1794.04$, 예측값 :1885.77$
# 결과값:2304.43$, 예측값 :2483.98$
# 결과값:1326.33$, 예측값 :1346.31$
# 결과값:1470.58$, 예측값 :2692.12$
# 결과값:1176.27$, 예측값 :1461.97$
# 결과값:753.77$, 예측값 :1077.13$
# 결과값:6829.35$, 예측값 :15671.79$
# 결과값:1854.94$, 예측값 :1961.74$
# 결과값:1018.39$, 예측값 :1261.44$
# 결과값:15379.60$, 예측값 :16863.99$
# 결과값:2179.02$, 예측값 :2681.33$
# 결과값:1036.97$, 예측값 :1465.50$
# 결과값:1784.47$, 예측값 :2040.37$
# 결과값:1452.83$, 예측값 :1530.89$
# 결과값:2993.13$, 예측값 :2843.29$
# 결과값:1444.09$, 예측값 :1345.31$
# 결과값:2337.05$, 예측값 :4063.40$
# 결과값:3650.11$, 예측값 :4713.36$
# 결과값:944.20$, 예측값 :1059.19$
# 결과값:1173.20$, 예측값 :1469.33$
# 결과값:1057.50$, 예측값 :1847.81$
# 결과값:1474.41$, 예측값 :2104.61$
# 결과값:2356.77$, 예측값 :2542.17$
# 결과값:1149.58$, 예측값 :1671.27$
# 결과값:1598.58$, 예측값 :2307.65$
# 결과값:1786.96$, 예측값 :1666.74$
# 결과값:898.56$, 예측값 :1232.16$
# 결과값:1418.06$, 예측값 :2695.07$
# 결과값:1403.95$, 예측값 :2167.44$
# 결과값:1093.73$, 예측값 :1742.85$
# 결과값:2070.39$, 예측값 :2301.30$
# 결과값:808.48$, 예측값 :1776.79$
# 결과값:2031.70$, 예측값 :4352.51$
# 결과값:1399.57$, 예측값 :1694.16$
# 결과값:3068.11$, 예측값 :3412.42$
# 결과값:3018.02$, 예측값 :7007.94$
# 결과값:1354.03$, 예측값 :1738.50$
# 결과값:1534.57$, 예측값 :1772.29$
# 결과값:1731.02$, 예측값 :2704.68$
# 결과값:1057.31$, 예측값 :1377.19$
# 결과값:2044.11$, 예측값 :2521.16$
# 결과값:1366.28$, 예측값 :1897.51$
# 결과값:1417.83$, 예측값 :1591.30$
# 결과값:1212.10$, 예측값 :1496.79$
# 결과값:1604.70$, 예측값 :2786.63$
# 결과값:1332.09$, 예측값 :1272.60$
# 결과값:2350.82$, 예측값 :6260.40$
# 결과값:2179.32$, 예측값 :2338.22$
# 결과값:2241.65$, 예측값 :2141.89$
# 결과값:1141.09$, 예측값 :1759.98$
# 결과값:2106.18$, 예측값 :2421.41$
# 결과값:1867.55$, 예측값 :1852.90$
# 결과값:1534.45$, 예측값 :809.89$
# 결과값:1428.42$, 예측값 :1703.61$
# 결과값:2069.41$, 예측값 :2195.81$
# 결과값:2043.45$, 예측값 :2478.44$
# 결과값:3632.78$, 예측값 :3061.07$
# 결과값:3829.74$, 예측값 :6646.08$
# 결과값:1960.82$, 예측값 :4259.00$
# 결과값:1302.80$, 예측값 :2999.63$
# 결과값:2113.97$, 예측값 :2685.34$
# 결과값:2033.24$, 예측값 :10862.93$
# 결과값:2631.11$, 예측값 :1992.91$
# 결과값:2031.58$, 예측값 :2242.51$
# 결과값:1555.63$, 예측값 :1241.74$
# 결과값:940.86$, 예측값 :1280.89$
# 결과값:2471.36$, 예측값 :2424.90$
# 결과값:16480.38$, 예측값 :21226.58$
# 결과값:1145.23$, 예측값 :1315.72$
# 결과값:1163.62$, 예측값 :1537.90$
# 결과값:1532.39$, 예측값 :2276.23$
# 결과값:1196.50$, 예측값 :1550.81$
# 결과값:1170.83$, 예측값 :1395.21$
# 결과값:2412.96$, 예측값 :2080.96$
# 결과값:1328.98$, 예측값 :1511.90$
# 결과값:2057.27$, 예측값 :4026.49$
# 결과값:2031.45$, 예측값 :2929.31$
# 결과값:1697.76$, 예측값 :1779.69$
# 결과값:2028.20$, 예측값 :5802.25$
# 결과값:866.33$, 예측값 :1433.24$
# 결과값:1132.50$, 예측값 :1119.38$
# 결과값:1018.38$, 예측값 :728.75$
# 결과값:959.62$, 예측값 :1307.37$
# 결과값:1022.52$, 예측값 :1600.61$
# 결과값:1465.45$, 예측값 :1948.81$
# 결과값:2508.85$, 예측값 :2544.52$
# 결과값:1773.89$, 예측값 :2345.79$
# 결과값:9348.54$, 예측값 :6881.14$
# 결과값:1039.70$, 예측값 :1318.84$
# 결과값:2074.80$, 예측값 :1991.34$
# 결과값:2480.77$, 예측값 :2727.34$
# 결과값:3655.62$, 예측값 :2583.52$
# 결과값:1540.60$, 예측값 :1857.16$
# 결과값:1101.12$, 예측값 :1341.98$
# 결과값:1532.76$, 예측값 :1341.00$
# 결과값:2161.39$, 예측값 :2834.35$
# 결과값:2080.06$, 예측값 :2691.83$
# 결과값:2452.64$, 예측값 :3201.53$
# 결과값:1291.89$, 예측값 :1391.86$
# 결과값:1114.81$, 예측값 :1339.55$
# 결과값:2149.05$, 예측값 :2670.83$
# 결과값:1837.89$, 예측값 :1955.57$
# 결과값:826.78$, 예측값 :1370.57$
# 결과값:1118.85$, 예측값 :1217.19$
# 결과값:838.41$, 예측값 :1346.16$
# 결과값:1702.71$, 예측값 :1832.94$
# 결과값:18439.82$, 예측값 :11845.20$
# 결과값:2337.35$, 예측값 :3186.54$
# 결과값:2021.49$, 예측값 :2593.59$
# 결과값:2060.18$, 예측값 :3617.86$
# 결과값:1965.55$, 예측값 :2647.30$
# 결과값:1681.61$, 예측값 :1988.75$
# 결과값:1660.54$, 예측값 :1465.87$
# 결과값:1281.80$, 예측값 :1466.24$
# 결과값:2088.91$, 예측값 :2414.48$
# 결과값:1030.06$, 예측값 :1268.89$
# 결과값:1931.92$, 예측값 :1990.18$
# 결과값:2723.69$, 예측값 :2549.91$
# 결과값:4011.70$, 예측값 :4261.52$
# 결과값:1400.63$, 예측값 :1693.45$
# 결과값:1740.29$, 예측값 :2594.49$
# 결과값:1116.82$, 예측값 :1348.29$
# 결과값:2098.19$, 예측값 :2313.89$
# 결과값:1328.93$, 예측값 :1439.84$
# 결과값:1090.42$, 예측값 :1592.78$
# 결과값:3173.68$, 예측값 :3802.88$
# 결과값:2036.90$, 예측값 :1996.86$
# 결과값:2784.33$, 예측값 :3565.17$
# 결과값:1973.83$, 예측값 :2382.90$
# 결과값:2040.22$, 예측값 :2814.55$
# 결과값:2304.05$, 예측값 :3967.90$
# 결과값:1658.90$, 예측값 :1763.42$
# 결과값:2018.71$, 예측값 :2240.53$
# 결과값:3650.16$, 예측값 :3138.85$
# 결과값:1281.14$, 예측값 :1387.46$
# 결과값:2104.09$, 예측값 :2369.85$
# 결과값:1822.02$, 예측값 :2016.03$
# 결과값:1582.79$, 예측값 :2753.50$
# 결과값:893.71$, 예측값 :1671.60$
# 결과값:2152.82$, 예측값 :3526.59$
# 결과값:2516.77$, 예측값 :3085.31$
# 결과값:2364.87$, 예측값 :2406.80$
# 결과값:1650.73$, 예측값 :2174.10$
# 결과값:4861.95$, 예측값 :7766.28$
# 결과값:1423.71$, 예측값 :1415.51$
# 결과값:974.29$, 예측값 :1141.93$
# 결과값:2245.14$, 예측값 :3965.64$
# 결과값:2259.29$, 예측값 :3340.16$
# 결과값:2076.53$, 예측값 :4499.12$
# 결과값:1624.24$, 예측값 :1902.88$
# 결과값:2112.84$, 예측값 :2199.60$
# 결과값:1036.26$, 예측값 :2130.56$
# 결과값:1311.52$, 예측값 :1417.01$
# 결과값:1697.10$, 예측값 :1396.74$
# 결과값:1997.77$, 예측값 :2146.31$
# 결과값:1597.90$, 예측값 :2254.19$
# 결과값:1024.19$, 예측값 :2211.17$
# 결과값:1861.10$, 예측값 :2971.47$
# 결과값:1379.74$, 예측값 :1023.53$
# 결과값:2041.08$, 예측값 :2083.00$
# 결과값:1739.94$, 예측값 :2478.03$
# 결과값:1122.50$, 예측값 :1674.48$
# 결과값:1027.01$, 예측값 :1352.75$
# 결과값:1799.85$, 예측값 :2084.26$
# 결과값:853.01$, 예측값 :954.48$
# 결과값:6087.33$, 예측값 :11046.79$
# 결과값:2002.90$, 예측값 :2092.97$
# 결과값:12996.87$, 예측값 :14730.30$
# 결과값:974.35$, 예측값 :1316.22$
# 결과값:2296.93$, 예측값 :2475.93$
# 결과값:16186.73$, 예측값 :15121.84$
# 결과값:2044.36$, 예측값 :2378.73$
# 결과값:808.01$, 예측값 :1123.60$
# 결과값:2105.05$, 예측값 :2190.93$
# 결과값:2070.33$, 예측값 :2094.69$
# 결과값:1991.83$, 예측값 :3337.38$
# 결과값:2362.83$, 예측값 :5602.53$
# 결과값:1799.85$, 예측값 :1101.25$
# 결과값:2094.05$, 예측값 :2545.34$
# 결과값:2399.71$, 예측값 :4985.22$
# 결과값:1872.54$, 예측값 :1899.89$
# 결과값:2290.68$, 예측값 :1929.90$
# 결과값:895.73$, 예측값 :1556.53$
# 결과값:1950.75$, 예측값 :2077.28$
# 결과값:1765.71$, 예측값 :2956.40$
# 결과값:2192.54$, 예측값 :2389.41$
# 결과값:2187.15$, 예측값 :5228.07$
# 결과값:875.42$, 예측값 :962.66$
# 결과값:2106.37$, 예측값 :2274.48$
# 결과값:821.61$, 예측값 :1583.36$
# 결과값:2331.52$, 예측값 :2225.09$
# 결과값:2070.35$, 예측값 :3784.10$
# 결과값:2353.56$, 예측값 :2303.86$
# 결과값:1986.07$, 예측값 :2163.14$
# 결과값:1432.39$, 예측값 :1410.61$
# 결과값:974.35$, 예측값 :1361.85$
# 결과값:2099.04$, 예측값 :3697.73$
# 결과값:4782.45$, 예측값 :4896.14$
# 결과값:1751.37$, 예측값 :2305.20$
# 결과값:2061.80$, 예측값 :3063.00$
# 결과값:2987.55$, 예측값 :6993.84$
# 결과값:1006.26$, 예측값 :1507.35$
# 결과값:4833.72$, 예측값 :4031.82$
# 결과값:3664.60$, 예측값 :3864.55$
# 결과값:3233.01$, 예측값 :2923.95$
# 결과값:944.85$, 예측값 :1279.01$
# 결과값:2197.80$, 예측값 :2120.62$
# 결과값:1032.64$, 예측값 :2420.79$
# 결과값:1474.59$, 예측값 :1820.20$
# 결과값:1034.69$, 예측값 :1611.78$
# 결과값:2067.68$, 예측값 :2494.09$
# 결과값:1169.51$, 예측값 :1481.82$
# 결과값:2246.26$, 예측값 :2944.22$
# 결과값:958.73$, 예측값 :665.22$
# 결과값:1650.38$, 예측값 :1552.51$
# 결과값:1142.87$, 예측값 :1516.79$
# 결과값:2080.46$, 예측값 :2754.98$
# 결과값:1463.57$, 예측값 :1770.77$
# 결과값:2014.75$, 예측값 :2385.80$
# 결과값:977.83$, 예측값 :1181.78$
# 결과값:2123.38$, 예측값 :2466.27$
# 결과값:924.62$, 예측값 :1164.45$
# 결과값:1115.81$, 예측값 :839.26$
# 결과값:1425.61$, 예측값 :1563.20$
# 결과값:1063.62$, 예측값 :1350.54$
# 결과값:1504.71$, 예측값 :1891.36$
# 결과값:2061.11$, 예측값 :2729.46$
# 결과값:1166.56$, 예측값 :1570.36$
# 결과값:1970.54$, 예측값 :4767.88$
# 결과값:4861.95$, 예측값 :7400.08$
# 결과값:2292.07$, 예측값 :2277.97$
# 결과값:1538.85$, 예측값 :1686.58$
# 결과값:2736.71$, 예측값 :2759.72$
# 결과값:1426.55$, 예측값 :1432.20$
# 결과값:1922.98$, 예측값 :2381.90$
# 결과값:2086.21$, 예측값 :2548.08$
# 결과값:3815.09$, 예측값 :6114.59$
# 결과값:18681.64$, 예측값 :17697.83$
# 결과값:2055.21$, 예측값 :2626.54$
# 결과값:2074.89$, 예측값 :2321.90$
# 결과값:3327.44$, 예측값 :4195.83$
# 결과값:1191.85$, 예측값 :1222.47$
# 결과값:1428.81$, 예측값 :2087.75$
# 결과값:2077.89$, 예측값 :2548.90$
# 결과값:1683.22$, 예측값 :1919.37$
# 결과값:1669.15$, 예측값 :2290.56$
# 결과값:943.90$, 예측값 :1485.91$
# 결과값:2724.90$, 예측값 :2805.53$
# 결과값:2568.78$, 예측값 :2484.81$
# 결과값:2053.49$, 예측값 :2265.04$
# 결과값:1430.74$, 예측값 :2070.73$
# 결과값:1473.68$, 예측값 :2355.32$
# 결과값:1446.08$, 예측값 :1802.44$
# 결과값:1698.83$, 예측값 :1458.54$
# 결과값:1583.70$, 예측값 :1853.17$
# 결과값:3483.07$, 예측값 :4069.55$
# 결과값:2049.90$, 예측값 :3068.97$
# 결과값:1063.04$, 예측값 :1376.84$
# 결과값:1622.57$, 예측값 :2240.86$
# 결과값:1788.78$, 예측값 :1478.26$
# 결과값:1105.87$, 예측값 :1427.28$
# 결과값:904.35$, 예측값 :1198.90$
# 결과값:2060.62$, 예측값 :3603.00$
# 결과값:4521.00$, 예측값 :3856.36$
# 결과값:2045.64$, 예측값 :2138.22$
# 결과값:1526.62$, 예측값 :2237.23$
# 결과값:1743.35$, 예측값 :1676.62$
# 결과값:1322.54$, 예측값 :1330.21$
# 결과값:1819.29$, 예측값 :1658.24$
# 결과값:1147.78$, 예측값 :1296.04$
# 결과값:1682.12$, 예측값 :1970.00$
# 결과값:1880.97$, 예측값 :2776.29$
# 결과값:1623.88$, 예측값 :3915.50$
# 결과값:1528.57$, 예측값 :1668.76$
# 결과값:4408.70$, 예측값 :4926.25$
# 결과값:1204.23$, 예측값 :1388.40$
# 결과값:2054.93$, 예측값 :4142.87$
# 결과값:2095.89$, 예측값 :2333.29$
# 결과값:2083.80$, 예측값 :2428.63$
# 결과값:2727.75$, 예측값 :1866.01$
# 결과값:1088.97$, 예측값 :1721.67$
# 결과값:1028.53$, 예측값 :1255.59$
# 결과값:1717.94$, 예측값 :1718.60$
# 결과값:2030.57$, 예측값 :3437.84$
# 결과값:1968.02$, 예측값 :2379.89$
# 결과값:1140.55$, 예측값 :1891.19$
# 결과값:2904.99$, 예측값 :4471.11$
# 결과값:946.40$, 예측값 :1666.21$
# 결과값:1992.91$, 예측값 :2403.00$
# 결과값:863.25$, 예측값 :999.84$
# 결과값:1134.51$, 예측값 :1129.08$
# 결과값:1580.00$, 예측값 :2339.30$
# 결과값:2551.39$, 예측값 :5159.29$
# 결과값:2051.69$, 예측값 :4416.57$
# 결과값:1843.82$, 예측값 :1662.91$
# 결과값:1447.35$, 예측값 :1360.02$
# 결과값:992.57$, 예측값 :1507.15$
# 결과값:4510.98$, 예측값 :4489.12$
# 결과값:49865.46$, 예측값 :39156.19$
# 결과값:969.79$, 예측값 :1275.97$
# 결과값:1985.94$, 예측값 :4162.31$
# 결과값:1056.32$, 예측값 :1424.70$
# 결과값:3908.68$, 예측값 :3373.86$
# 결과값:1882.12$, 예측값 :1829.96$
# 결과값:1650.45$, 예측값 :1889.75$
# 결과값:1382.34$, 예측값 :2359.15$
# 결과값:2448.32$, 예측값 :2528.70$
# 결과값:2139.78$, 예측값 :3285.08$
# 결과값:2435.56$, 예측값 :2988.53$
# 결과값:1537.39$, 예측값 :1944.99$
# 결과값:1598.08$, 예측값 :2603.82$
# 결과값:41719.09$, 예측값 :54398.07$
# 결과값:930.75$, 예측값 :1419.40$
# 결과값:2125.23$, 예측값 :3448.72$
# 결과값:4430.27$, 예측값 :8014.84$
# 결과값:1538.81$, 예측값 :2322.73$
# 결과값:1159.37$, 예측값 :1176.67$
# 결과값:1400.94$, 예측값 :1489.64$
# 결과값:1175.14$, 예측값 :1320.29$
# 결과값:2086.97$, 예측값 :2283.16$
# 결과값:2035.49$, 예측값 :2147.91$
# 결과값:1011.55$, 예측값 :2092.40$
# 결과값:3054.69$, 예측값 :3757.51$
# 결과값:902.12$, 예측값 :1424.16$
# 결과값:2018.05$, 예측값 :2735.67$
# 결과값:1273.41$, 예측값 :1420.58$
# 결과값:1100.09$, 예측값 :1242.36$
# 결과값:2062.01$, 예측값 :2336.64$
# 결과값:1282.57$, 예측값 :1449.73$
# 결과값:945.34$, 예측값 :1338.85$
# 결과값:1539.35$, 예측값 :2085.74$
# 결과값:1672.80$, 예측값 :2270.66$
# 결과값:4352.31$, 예측값 :5242.21$
# 결과값:2014.73$, 예측값 :2189.75$
# 결과값:1864.54$, 예측값 :2322.83$
# 결과값:2070.48$, 예측값 :2519.31$
# 결과값:1935.25$, 예측값 :1916.64$
# 결과값:1348.62$, 예측값 :2780.54$
# 결과값:1800.96$, 예측값 :2071.87$
# 결과값:1107.02$, 예측값 :1766.38$
# 결과값:49075.34$, 예측값 :45115.45$
# 결과값:1997.86$, 예측값 :2200.21$
# 결과값:1462.04$, 예측값 :1281.58$
# 결과값:974.29$, 예측값 :1393.08$
# 결과값:2204.14$, 예측값 :2739.00$
# 결과값:2066.92$, 예측값 :4084.80$
# 결과값:1165.41$, 예측값 :1262.38$
# 결과값:2568.80$, 예측값 :2460.12$
# 결과값:2802.83$, 예측값 :2686.80$
# 결과값:3514.31$, 예측값 :3343.91$
# 결과값:1973.23$, 예측값 :1983.49$
# 결과값:12627.71$, 예측값 :16686.78$
# 결과값:16067.35$, 예측값 :8743.88$
# 결과값:1659.72$, 예측값 :1587.58$
# 결과값:877.68$, 예측값 :1294.37$
# 결과값:1599.11$, 예측값 :3435.91$
# 결과값:954.65$, 예측값 :1006.17$
# 결과값:2078.35$, 예측값 :2484.02$
# 결과값:1164.15$, 예측값 :1551.65$
# 결과값:1990.53$, 예측값 :3186.61$
# 결과값:2097.46$, 예측값 :4634.49$
# 결과값:2033.31$, 예측값 :2393.12$
# 결과값:2353.97$, 예측값 :2534.57$
# 결과값:2953.85$, 예측값 :8180.69$
# 결과값:1103.49$, 예측값 :1545.42$
# 결과값:1180.68$, 예측값 :1702.74$
# 결과값:1056.25$, 예측값 :1249.40$
# 결과값:1093.95$, 예측값 :1395.68$
# 결과값:4856.94$, 예측값 :7001.04$
# 결과값:1327.11$, 예측값 :1665.91$
# 결과값:1199.98$, 예측값 :1372.22$
# 결과값:3135.82$, 예측값 :2821.34$
# 결과값:1358.27$, 예측값 :1840.84$
# 결과값:2273.98$, 예측값 :2738.64$
# 결과값:1554.79$, 예측값 :1381.14$
# 결과값:1242.86$, 예측값 :1095.95$
# 결과값:5991.94$, 예측값 :5919.88$
# 결과값:927.64$, 예측값 :1188.99$
# 결과값:2040.00$, 예측값 :5887.37$
# 결과값:1606.66$, 예측값 :994.37$
# 결과값:2087.09$, 예측값 :5822.53$
# 결과값:2934.68$, 예측값 :4344.16$
# 결과값:1424.77$, 예측값 :1537.55$
# 결과값:1030.65$, 예측값 :1231.20$
# 결과값:1948.11$, 예측값 :2965.89$
# 결과값:4007.88$, 예측값 :5763.60$
# 결과값:1972.43$, 예측값 :1724.19$
# 결과값:2055.01$, 예측값 :2264.95$
# 결과값:2874.53$, 예측값 :4377.07$
# 결과값:1094.00$, 예측값 :1655.70$
# 결과값:2031.06$, 예측값 :7040.34$
# 결과값:1603.42$, 예측값 :1872.14$
# 결과값:1988.78$, 예측값 :2324.93$
# 결과값:37753.27$, 예측값 :35957.27$
# 결과값:1058.89$, 예측값 :1231.07$
# 결과값:1972.58$, 예측값 :5025.12$
# 결과값:2104.05$, 예측값 :2469.27$
# 결과값:901.78$, 예측값 :785.60$
# 결과값:1292.93$, 예측값 :1357.77$
# 결과값:1604.91$, 예측값 :1109.92$
# 결과값:1044.12$, 예측값 :1182.29$
# 결과값:2112.20$, 예측값 :2268.29$
# 결과값:1381.79$, 예측값 :2080.32$
# 결과값:848.80$, 예측값 :1528.11$
# 결과값:1250.19$, 예측값 :1170.68$
# 결과값:1473.78$, 예측값 :2365.67$
# 결과값:886.62$, 예측값 :1508.39$
# 결과값:1746.93$, 예측값 :8133.79$
# 결과값:1096.51$, 예측값 :1660.41$
# 결과값:2249.55$, 예측값 :2101.03$
# 결과값:1424.23$, 예측값 :425.47$
# 결과값:1135.48$, 예측값 :1291.92$
# 결과값:2299.43$, 예측값 :2719.69$
# 결과값:2048.36$, 예측값 :2391.25$
# 결과값:1978.08$, 예측값 :2482.92$
# 결과값:2315.11$, 예측값 :2838.59$
# 결과값:4115.50$, 예측값 :4746.61$
# 결과값:926.68$, 예측값 :1299.25$
# 결과값:2459.12$, 예측값 :6827.67$
# 결과값:1997.22$, 예측값 :2421.99$
# 결과값:2073.70$, 예측값 :4831.32$
# 결과값:1205.93$, 예측값 :1574.17$
# 결과값:1884.69$, 예측값 :1761.90$
# 결과값:2249.20$, 예측값 :1852.41$
# 결과값:6006.28$, 예측값 :4234.05$
# 결과값:2067.92$, 예측값 :4123.55$
# 결과값:2331.76$, 예측값 :2211.68$
# 결과값:1751.48$, 예측값 :1594.38$
# 결과값:7258.54$, 예측값 :17032.99$
# 결과값:11755.98$, 예측값 :9170.48$
# 결과값:1973.14$, 예측값 :2324.54$
# 결과값:4327.67$, 예측값 :6452.87$
# 결과값:1738.11$, 예측값 :1657.37$
# 결과값:1403.68$, 예측값 :1482.81$
# 결과값:2088.91$, 예측값 :2246.14$
# 결과값:1012.26$, 예측값 :1008.66$
# 결과값:1199.98$, 예측값 :1323.85$
# 결과값:4092.84$, 예측값 :3372.61$
# 결과값:2059.52$, 예측값 :3287.21$
# 결과값:3001.29$, 예측값 :8176.74$
# 결과값:2304.07$, 예측값 :2361.36$
# 결과값:1428.12$, 예측값 :1531.78$
# 결과값:1096.64$, 예측값 :1719.41$
# 결과값:2089.62$, 예측값 :2426.29$
# 결과값:1093.01$, 예측값 :1332.92$
# 결과값:2027.51$, 예측값 :2236.79$
# 결과값:1091.99$, 예측값 :1287.08$
# 결과값:2048.45$, 예측값 :5343.82$
# 결과값:2034.78$, 예측값 :2603.05$
# 결과값:1086.84$, 예측값 :1334.69$
# 결과값:1066.07$, 예측값 :1444.40$
# 결과값:3442.51$, 예측값 :7697.13$
# 결과값:1347.34$, 예측값 :1468.02$
# 결과값:4161.25$, 예측값 :11363.24$
# 결과값:2066.16$, 예측값 :2861.57$
# 결과값:2223.08$, 예측값 :1841.22$
# 결과값:2583.82$, 예측값 :1868.56$
# 결과값:1061.40$, 예측값 :1250.41$
# 결과값:2551.35$, 예측값 :2492.60$
# 결과값:2282.33$, 예측값 :2295.34$
# 결과값:2528.27$, 예측값 :1695.33$
# 결과값:994.18$, 예측값 :1916.59$
# 결과값:2079.38$, 예측값 :2174.65$
# 결과값:1504.10$, 예측값 :2002.37$
# 결과값:1401.03$, 예측값 :1850.24$
# 결과값:1063.64$, 예측값 :1269.06$
# 결과값:974.57$, 예측값 :1338.00$
# 결과값:898.08$, 예측값 :886.28$
# 결과값:2063.52$, 예측값 :2338.99$
# 결과값:2002.26$, 예측값 :2031.05$
# 결과값:1473.04$, 예측값 :2232.95$
# 결과값:1349.89$, 예측값 :1724.63$
# 결과값:1172.15$, 예측값 :1548.04$
# 결과값:2082.03$, 예측값 :2626.48$
# 결과값:4158.33$, 예측값 :3037.71$
# 결과값:1582.45$, 예측값 :2276.43$
# 결과값:969.79$, 예측값 :1371.98$
# 결과값:3480.49$, 예측값 :3310.00$
# 결과값:2154.96$, 예측값 :3092.94$
# 결과값:2322.22$, 예측값 :1784.63$
# 결과값:2354.34$, 예측값 :1952.36$
# 결과값:2696.13$, 예측값 :4184.01$
# 결과값:868.34$, 예측값 :1563.21$
# 결과값:2109.20$, 예측값 :2220.32$
# 결과값:1149.54$, 예측값 :1747.54$
# 결과값:2061.92$, 예측값 :2474.08$
# 결과값:1790.94$, 예측값 :1798.38$
# 결과값:838.36$, 예측값 :1212.47$
# 결과값:4029.32$, 예측값 :4358.96$
# 결과값:9640.53$, 예측값 :10651.98$
# 결과값:839.64$, 예측값 :698.44$
# 결과값:3049.30$, 예측값 :2217.02$
# 결과값:1040.25$, 예측값 :1247.13$
# 결과값:2111.79$, 예측값 :4529.92$
# 결과값:2064.42$, 예측값 :2451.77$
# 결과값:3709.10$, 예측값 :20499.30$
# 결과값:1463.08$, 예측값 :2153.82$
# 결과값:1184.12$, 예측값 :1370.95$
# 결과값:1790.38$, 예측값 :2242.86$
# 결과값:1453.33$, 예측값 :1642.64$
# 결과값:2030.54$, 예측값 :5717.78$
# 결과값:2061.99$, 예측값 :2791.55$
# 결과값:55408.52$, 예측값 :40149.52$
# 결과값:1309.02$, 예측값 :1817.56$
# 결과값:1354.57$, 예측값 :1613.41$
# 결과값:805.98$, 예측값 :1042.26$
# 결과값:1145.90$, 예측값 :1465.65$
# 결과값:2081.37$, 예측값 :2649.42$
# 결과값:1368.98$, 예측값 :1366.48$
# 결과값:2023.78$, 예측값 :2627.24$
# 결과값:1997.75$, 예측값 :4584.80$
# 결과값:1042.12$, 예측값 :1313.61$
# 결과값:3172.28$, 예측값 :3711.71$
# 결과값:2040.00$, 예측값 :5634.21$
# 결과값:2015.34$, 예측값 :2873.43$
# 결과값:1358.39$, 예측값 :1280.58$
# 결과값:2079.61$, 예측값 :6242.93$
# 결과값:1986.00$, 예측값 :2651.31$
# 결과값:1702.84$, 예측값 :1960.80$
# 결과값:846.08$, 예측값 :1003.56$
# 결과값:2785.64$, 예측값 :3625.28$
# 결과값:1164.88$, 예측값 :1306.94$
# 결과값:1993.46$, 예측값 :3019.98$
# 결과값:1645.60$, 예측값 :1664.57$
# 결과값:2263.09$, 예측값 :2994.47$
# 결과값:1799.78$, 예측값 :1879.67$
# 결과값:1968.26$, 예측값 :1988.31$
# 결과값:962.18$, 예측값 :1427.88$
# 결과값:2752.50$, 예측값 :2579.85$
# 결과값:1822.60$, 예측값 :2007.41$
# 결과값:1329.81$, 예측값 :1309.48$
# 결과값:1135.71$, 예측값 :1557.71$
# 결과값:1680.03$, 예측값 :2459.67$
# 결과값:1498.19$, 예측값 :1600.33$
# 결과값:2180.03$, 예측값 :2000.45$
# 결과값:2101.62$, 예측값 :5819.19$
# 결과값:3021.19$, 예측값 :3351.97$
# 결과값:2304.07$, 예측값 :2253.63$
# 결과값:1162.92$, 예측값 :1319.16$
# 결과값:2104.08$, 예측값 :5461.84$
# 결과값:13500.16$, 예측값 :18014.84$
# 결과값:1140.06$, 예측값 :1208.62$
# 결과값:1317.62$, 예측값 :2060.57$
# 결과값:2895.53$, 예측값 :8783.68$
# 결과값:7247.40$, 예측값 :9554.94$
# 결과값:2123.50$, 예측값 :2310.74$
# 결과값:1973.74$, 예측값 :2300.51$
# 결과값:2024.70$, 예측값 :1867.36$
# 결과값:1290.74$, 예측값 :1502.96$
# 결과값:1185.32$, 예측값 :1599.50$
# 결과값:994.18$, 예측값 :1118.94$
# 결과값:1598.46$, 예측값 :2184.90$
# 결과값:2166.14$, 예측값 :1854.07$
# 결과값:6072.07$, 예측값 :6736.05$
# 결과값:2094.68$, 예측값 :3020.67$
# 결과값:1131.52$, 예측값 :1489.93$
# 결과값:1000.72$, 예측값 :1902.24$
# 결과값:1036.88$, 예측값 :1309.47$
# 결과값:2568.78$, 예측값 :2797.97$
# 결과값:1270.22$, 예측값 :1941.65$
# 결과값:2319.73$, 예측값 :2030.00$
# 결과값:1289.35$, 예측값 :1506.52$
# 결과값:2969.47$, 예측값 :5668.39$
# 결과값:1133.31$, 예측값 :1137.92$
# 결과값:5961.15$, 예측값 :10545.58$
# 결과값:4420.96$, 예측값 :3221.50$
# 결과값:968.78$, 예측값 :1572.15$
# 결과값:2059.79$, 예측값 :3782.76$
# 결과값:1991.02$, 예측값 :2337.25$
# 결과값:1717.94$, 예측값 :2065.37$
# 결과값:9504.07$, 예측값 :19605.72$
# 결과값:2067.92$, 예측값 :1774.97$
# 결과값:1339.58$, 예측값 :2116.63$
# 결과값:2337.69$, 예측값 :2337.03$
# 결과값:1720.93$, 예측값 :1255.99$
# 결과값:1587.81$, 예측값 :1810.64$
# 결과값:1738.38$, 예측값 :1843.34$
# 결과값:1481.75$, 예측값 :1960.35$
# 결과값:2075.87$, 예측값 :4047.47$
# 결과값:2453.10$, 예측값 :4440.54$
# 결과값:1984.26$, 예측값 :5386.93$
# 결과값:1679.27$, 예측값 :1567.35$
# 결과값:1556.58$, 예측값 :798.78$
# 결과값:2034.00$, 예측값 :2611.03$
# 결과값:2078.47$, 예측값 :1868.63$
# 결과값:4545.71$, 예측값 :1996.68$
# 결과값:2085.19$, 예측값 :2252.51$
# 결과값:846.74$, 예측값 :1399.49$
# 결과값:2403.31$, 예측값 :2703.60$
# 결과값:1514.71$, 예측값 :2380.35$
# 결과값:1003.72$, 예측값 :1918.96$
# 결과값:3067.51$, 예측값 :3577.07$
# 결과값:1401.30$, 예측값 :1695.19$
# 결과값:1524.65$, 예측값 :2292.36$
# 결과값:1497.14$, 예측값 :1812.62$
# 결과값:2061.87$, 예측값 :5578.67$
# 결과값:4958.89$, 예측값 :4792.44$
# 결과값:13410.72$, 예측값 :13457.12$
# 결과값:1785.62$, 예측값 :1306.39$
# 결과값:2370.80$, 예측값 :2202.57$
# 결과값:3389.88$, 예측값 :2932.10$
# 결과값:1987.22$, 예측값 :2516.86$
# 결과값:6493.52$, 예측값 :14857.56$
# 결과값:948.46$, 예측값 :1213.29$
# 결과값:1273.65$, 예측값 :1389.00$
# 결과값:1750.96$, 예측값 :1719.71$
# 결과값:2038.04$, 예측값 :4914.51$
# 결과값:2939.19$, 예측값 :11149.36$
# 결과값:2452.64$, 예측값 :3525.84$
# 결과값:1537.90$, 예측값 :1599.70$
# 결과값:791.33$, 예측값 :1650.39$
# 결과값:2200.67$, 예측값 :1477.24$
# 결과값:928.62$, 예측값 :1462.18$
# 결과값:2568.78$, 예측값 :2387.69$
# 결과값:834.91$, 예측값 :1330.78$
# 결과값:963.82$, 예측값 :1242.54$
# 결과값:1040.04$, 예측값 :1985.47$
# 결과값:1796.39$, 예측값 :1597.79$
# 결과값:2094.76$, 예측값 :6178.08$
# 결과값:1464.42$, 예측값 :2231.39$
# 결과값:1119.46$, 예측값 :1505.80$
# 결과값:1277.75$, 예측값 :770.88$
# 결과값:2533.68$, 예측값 :2533.70$
# 결과값:1093.23$, 예측값 :1683.91$
# 결과값:2062.70$, 예측값 :2874.78$
# 결과값:1516.44$, 예측값 :2220.76$
# 결과값:2368.35$, 예측값 :5363.00$
# 결과값:3043.26$, 예측값 :2458.07$
# 결과값:2028.27$, 예측값 :2305.53$
# 결과값:837.48$, 예측값 :939.13$
# 결과값:1873.45$, 예측값 :1998.64$
# 결과값:2048.08$, 예측값 :2094.92$
# 결과값:1348.76$, 예측값 :1461.19$
# 결과값:1134.40$, 예측값 :1557.17$
# 결과값:16216.19$, 예측값 :19964.35$
# 결과값:1968.43$, 예측값 :2733.91$
# 결과값:1108.29$, 예측값 :906.36$
# 결과값:2116.52$, 예측값 :3344.01$
# 결과값:4116.79$, 예측값 :3621.99$
# 결과값:3031.80$, 예측값 :6303.78$
# 결과값:1136.53$, 예측값 :1569.37$
# 결과값:2480.15$, 예측값 :2591.32$
# 결과값:3122.16$, 예측값 :2676.74$
# 결과값:1148.96$, 예측값 :2060.44$
# 결과값:2057.03$, 예측값 :1999.92$
# 결과값:922.64$, 예측값 :1182.80$
# 결과값:1058.95$, 예측값 :1267.49$
# 결과값:2467.91$, 예측값 :3051.59$
# 결과값:2187.06$, 예측값 :2496.65$
# 결과값:2079.23$, 예측값 :2268.78$
# 결과값:1383.13$, 예측값 :4904.93$
# 결과값:2099.93$, 예측값 :2624.96$
# 결과값:1324.27$, 예측값 :1616.01$
# 결과값:1481.29$, 예측값 :2136.38$
# 결과값:1012.33$, 예측값 :1631.23$
# 결과값:2106.75$, 예측값 :3256.92$
# 결과값:1970.49$, 예측값 :1736.12$
# 결과값:1161.67$, 예측값 :1549.02$
# 결과값:1352.82$, 예측값 :1568.89$
# 결과값:3642.69$, 예측값 :2851.76$
# 결과값:1095.73$, 예측값 :1841.34$
# 결과값:2352.55$, 예측값 :2534.55$
# 결과값:1124.88$, 예측값 :1378.91$
# 결과값:9518.21$, 예측값 :8620.54$
# 결과값:1472.19$, 예측값 :5240.46$
# 결과값:6096.99$, 예측값 :5690.39$
# 결과값:2031.82$, 예측값 :1837.46$
# 결과값:5309.69$, 예측값 :3728.99$
# 결과값:2279.60$, 예측값 :2826.12$
# 결과값:2052.56$, 예측값 :2963.97$
# Accuracy: 80.47   RMSE : 1997.24

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)

fig, axes = plt.subplots(1, 2,figsize = (12, 7), sharey = True)

prediction1 = prediction[prediction['label'] < 10000]
axes[0].plot(prediction1.index, prediction1['pred'],label='Prediction',        
        linestyle = '--',)
axes[0].plot(prediction1.index, prediction1['label'], label = 'Truth',
        linestyle = '--',)
axes[0].set_xticks([])
axes[0].legend()
axes[0].set_title("Price under 10000$")
prediction2 = prediction[prediction['label'] > 10000]
axes[1].plot(prediction2.index, prediction2['pred'],label='Prediction',        
        linestyle = '--',)
axes[1].plot(prediction2.index, prediction2['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
axes[1].set_xticks([])
axes[1].legend()
axes[1].set_title("Price over 10000$")
plt.ylabel('prices')
plt.show()
