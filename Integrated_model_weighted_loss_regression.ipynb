# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import random
import albumentations as A
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/'YAI 봄학기 Toy Project'
# Out:
# /content/drive/MyDrive/YAI 봄학기 Toy Project

# %%
csv_train_path = "train.csv"
csv_test_path = "test.csv"
csv_val_path = "val.csv"
image_path = "./images"
batch_size = 128
epochs = 100
learning_rate = 1e-3
seed = 42

# %%
csv_train_path = "train.csv"
csv_test_path = "test.csv"
csv_val_path = "val.csv"
image_path = "./images"
batch_size = 128
epochs = 100
learning_rate = 1e-3
seed = 42

# %%
trainset = pd.read_csv(csv_train_path)
weightmap = [1 / np.sum((np.array(np.log(trainset['Price']) - 6).astype(int) // 2) == i) for i in range(3)]
cutline = [np.exp(i) for i in range(8, 12, 2)]

# %%
class AllDataset(Dataset):
    def __init__(self, csv_path, image_path, image_transform=transforms.Compose([transforms.ToTensor()])):
        super(AllDataset).__init__()
        csv = pd.read_csv(csv_path).iloc[:, [0, 1, 2, 3, 4, 7, 12]]
        csv_np = csv.to_numpy()
        

        self.image_transform = image_transform
        self.ids = list(map(str, csv['Id']))
        self.image_path = image_path
        
        for i in [1, 3, 4, 5]:
            wordset = {word: idx for idx, word in enumerate(np.unique(csv_np[:,i]))}
            for row in range(len(csv_np)):
                csv_np[row][i] = wordset[csv_np[row][i]]
        self.ints = torch.from_numpy(np.array(csv_np[:,[1,3,4,5]], dtype="int"))
        self.floats = torch.from_numpy(np.array(csv_np[:,[2]], dtype="float")).float()
        self.target = torch.from_numpy(np.array(csv_np[:,[6]], dtype="float")).float()
    
    
    def __getitem__(self,idx):
        return self.image_transform(Image.open(self.image_path+'/'+self.ids[idx]+'.jpg')), self.ints[idx],self.floats[idx], self.target[idx]
    
    
    def __len__(self):
        return len(self.ints)

# %%
image_transform = transforms.Compose([transforms.ToTensor()
                                     ])
train_dataset = AllDataset(csv_train_path, image_path, image_transform)
test_dataset = AllDataset(csv_test_path, image_path, image_transform)
val_dataset = AllDataset(csv_val_path, image_path, image_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Sequential(nn.Linear(512, 4096),
                                         nn.BatchNorm1d(4096),
                                         nn.ReLU(),
                                         nn.Dropout()
                                        )
        self.resenet18 = self.resnet18.to(device)
        
        self.emb1 = torch.nn.Embedding(8, 20)
        self.emb2 = torch.nn.Embedding(11, 20)
        self.emb3 = torch.nn.Embedding(20, 20)
        self.emb4 = torch.nn.Embedding(4, 20)
        self.act = nn.ReLU()
        self.fc = nn.Linear(1, 20)
        self.csvbn = nn.BatchNorm1d(20)
        self.csvfc1 = nn.Linear(100, 8192)
        self.csvfc2 = nn.Linear(8192, 8192)
        self.csvfc3 = nn.Linear(8192, 4096)
        self.csvbn1 = nn.BatchNorm1d(8192)
        self.csvbn2 = nn.BatchNorm1d(8192)
        self.csvbn3 = nn.BatchNorm1d(4096)
        
        self.fc1 = nn.Linear(8192, 4096)
        self.fc2 = nn.Linear(4096, 1)
        self.bn1 = nn.BatchNorm1d(4096)
        self.dropout = nn.Dropout()
    
    def forward(self, image, x, y):
        image = self.resnet18(image)
        
        x1 = self.emb1(x[:,0])
        x2 = self.emb2(x[:,1])
        x3 = self.emb3(x[:,2])
        x4 = self.emb4(x[:,3])
        y = self.csvbn(self.fc(y))
        x = torch.cat((x1, x2, x3, x4, y), dim=1)
        
        x = self.dropout(self.act(self.csvbn1(self.csvfc1(x))))
        x = self.dropout(self.act(self.csvbn2(self.csvfc2(x))))
        x = self.dropout(self.act(self.csvbn3(self.csvfc3(x))))
        x = torch.cat((x, image), dim=1)
        
        x = self.dropout(self.act(self.bn1(self.fc1(x))))
        return self.fc2(x)

# %%
def WRMSE(pred, target):
    weight = []
    for i in target:
        weight.append(weightmap[(torch.log(i[0])- 6).int() // 2])
    weight = torch.from_numpy(np.array(weight)).float().to(device)
    x = torch.sum(weight * (pred - target) ** 2)
    x /= torch.sum(weight) * len(target)
    return torch.sqrt(x)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
model = Net().to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

gc.collect()
torch.cuda.empty_cache()

# %%
for epoch in range(epochs):
    model.train()
    criterion.train()
    
    avg_loss = 0

    for Img, X1, X2, Y in train_loader:
        Img = Img.to(device)
        X1 = X1.to(device)
        X2 = X2.to(device)
        Y = Y.to(device)

        model.zero_grad()
        prediction = model(Img, X1, X2)
        loss = WRMSE(prediction, Y).to(device)
        loss.backward()
        optimizer.step()
        avg_loss += loss / len(train_loader)
    print(f'[Epoch: {epoch+1:>2}] Average loss: {avg_loss:.4f}, ', end='')
    
    model.eval()
    criterion.eval()
    with torch.no_grad():
        val_avg_loss = 0.
        for Image_val, X1_val, X2_val, Y_val in val_loader:
            Image_val = Image_val.to(device)
            X1_val = X1_val.to(device)
            X2_val = X2_val.to(device)
            Y_val = Y_val.to(device)
            val_prediction = model(Image_val, X1_val, X2_val)
            val_loss = WRMSE(val_prediction, Y_val).to(device)
            val_avg_loss += val_loss / len(val_loader)
        
        print(f"val_loss: {val_avg_loss:.4f}")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   after removing the cwd from sys.path.
# [Epoch:  1] Average loss: 4356.8315, val_loss: 4151.0674
# [Epoch:  2] Average loss: 4242.7065, val_loss: 4218.6123
# [Epoch:  3] Average loss: 4099.8140, val_loss: 4062.7451
# [Epoch:  4] Average loss: 4150.2539, val_loss: 4130.0898
# [Epoch:  5] Average loss: 3997.0195, val_loss: 3836.7070
# [Epoch:  6] Average loss: 3910.5337, val_loss: 3428.6843
# [Epoch:  7] Average loss: 3754.4944, val_loss: 3647.8481
# [Epoch:  8] Average loss: 3679.5676, val_loss: 3886.8015
# [Epoch:  9] Average loss: 3677.1160, val_loss: 3287.5215
# [Epoch: 10] Average loss: 3310.2229, val_loss: 3139.0132
# [Epoch: 11] Average loss: 3274.3569, val_loss: 2916.1895
# [Epoch: 12] Average loss: 3087.2529, val_loss: 3192.6165
# [Epoch: 13] Average loss: 2951.8420, val_loss: 3270.2146
# [Epoch: 14] Average loss: 3212.5754, val_loss: 2670.4492
# [Epoch: 15] Average loss: 2651.7219, val_loss: 2550.5386
# [Epoch: 16] Average loss: 2609.2539, val_loss: 2161.2700
# [Epoch: 17] Average loss: 2432.5708, val_loss: 2005.0690
# [Epoch: 18] Average loss: 2333.1096, val_loss: 1981.3859
# [Epoch: 19] Average loss: 2263.3630, val_loss: 2011.8214
# [Epoch: 20] Average loss: 2099.4644, val_loss: 1769.0603
# [Epoch: 21] Average loss: 2046.4727, val_loss: 1496.8551
# [Epoch: 22] Average loss: 1895.9589, val_loss: 1541.4238
# [Epoch: 23] Average loss: 1891.0667, val_loss: 2052.5781
# [Epoch: 24] Average loss: 1895.2529, val_loss: 1662.9790
# [Epoch: 25] Average loss: 1818.4552, val_loss: 1635.8470
# [Epoch: 26] Average loss: 2012.1101, val_loss: 1854.4625
# [Epoch: 27] Average loss: 1734.3020, val_loss: 1300.6184
# [Epoch: 28] Average loss: 1767.3613, val_loss: 1430.1741
# [Epoch: 29] Average loss: 2429.0134, val_loss: 2331.5593
# [Epoch: 30] Average loss: 2423.6975, val_loss: 2010.8516
# [Epoch: 31] Average loss: 1586.1774, val_loss: 1058.4379
# [Epoch: 32] Average loss: 1517.5787, val_loss: 1532.6854
# [Epoch: 33] Average loss: 1714.1868, val_loss: 1545.5713
# [Epoch: 34] Average loss: 1585.7928, val_loss: 1496.5032
# [Epoch: 35] Average loss: 1585.8557, val_loss: 1251.0347
# [Epoch: 36] Average loss: 1411.2804, val_loss: 1346.2261
# [Epoch: 37] Average loss: 1465.5016, val_loss: 1574.5604
# [Epoch: 38] Average loss: 1440.3997, val_loss: 1597.4900
# [Epoch: 39] Average loss: 1581.7784, val_loss: 1250.8365
# [Epoch: 40] Average loss: 1346.3483, val_loss: 1098.5867
# [Epoch: 41] Average loss: 1390.8932, val_loss: 1295.4041
# [Epoch: 42] Average loss: 1444.1819, val_loss: 1134.1814
# [Epoch: 43] Average loss: 1410.5698, val_loss: 1338.5336
# [Epoch: 44] Average loss: 1550.6902, val_loss: 1570.7970
# [Epoch: 45] Average loss: 1500.8054, val_loss: 1258.8743
# [Epoch: 46] Average loss: 1409.0764, val_loss: 1512.6931
# [Epoch: 47] Average loss: 2158.9697, val_loss: 1498.0608
# [Epoch: 48] Average loss: 1398.8917, val_loss: 1432.8281
# [Epoch: 49] Average loss: 1402.6592, val_loss: 1197.0305
# [Epoch: 50] Average loss: 1287.8446, val_loss: 1261.9722
# [Epoch: 51] Average loss: 1423.8575, val_loss: 1273.1482
# [Epoch: 52] Average loss: 1311.9542, val_loss: 1186.8685
# [Epoch: 53] Average loss: 1313.7812, val_loss: 1510.5328
# [Epoch: 54] Average loss: 1330.8770, val_loss: 1248.4547
# [Epoch: 55] Average loss: 1235.5015, val_loss: 1607.6252
# [Epoch: 56] Average loss: 1323.6949, val_loss: 1107.4492
# [Epoch: 57] Average loss: 1289.1898, val_loss: 1276.2458
# [Epoch: 58] Average loss: 1365.5857, val_loss: 1317.1193
# [Epoch: 59] Average loss: 1449.9744, val_loss: 1651.0957
# [Epoch: 60] Average loss: 1399.9899, val_loss: 1401.6213
# [Epoch: 61] Average loss: 1258.3724, val_loss: 1244.7158
# [Epoch: 62] Average loss: 1357.5629, val_loss: 1149.3269
# [Epoch: 63] Average loss: 1305.7837, val_loss: 1211.5032
# [Epoch: 64] Average loss: 1293.0896, val_loss: 1182.8549
# [Epoch: 65] Average loss: 1312.9633, val_loss: 1259.3680
# [Epoch: 66] Average loss: 1187.4240, val_loss: 1519.5530
# [Epoch: 67] Average loss: 1439.5123, val_loss: 1216.7947
# [Epoch: 68] Average loss: 1417.7853, val_loss: 1678.8385
# [Epoch: 69] Average loss: 1142.4222, val_loss: 1462.0592
# [Epoch: 70] Average loss: 1251.6349, val_loss: 1575.3923
# [Epoch: 71] Average loss: 1166.1744, val_loss: 1880.9893
# [Epoch: 72] Average loss: 1295.4542, val_loss: 1216.6418
# [Epoch: 73] Average loss: 1569.0120, val_loss: 1440.1005
# [Epoch: 74] Average loss: 1267.6073, val_loss: 1361.4524
# [Epoch: 75] Average loss: 1179.7650, val_loss: 1587.7676
# [Epoch: 76] Average loss: 1237.3468, val_loss: 1071.1738
# [Epoch: 77] Average loss: 1236.3947, val_loss: 1211.6018
# [Epoch: 78] Average loss: 2173.6411, val_loss: 2014.1488
# [Epoch: 79] Average loss: 1134.3850, val_loss: 1669.8290
# [Epoch: 80] Average loss: 1181.5996, val_loss: 1279.9969
# [Epoch: 81] Average loss: 1158.6025, val_loss: 1386.2703
# [Epoch: 82] Average loss: 1173.7603, val_loss: 1546.7996
# [Epoch: 83] Average loss: 1142.2764, val_loss: 1322.9384
# [Epoch: 84] Average loss: 1360.0153, val_loss: 1363.8197
# [Epoch: 85] Average loss: 1208.5352, val_loss: 1690.6080
# [Epoch: 86] Average loss: 1292.8086, val_loss: 1416.0385
# [Epoch: 87] Average loss: 1205.1985, val_loss: 1428.3083
# [Epoch: 88] Average loss: 1100.0760, val_loss: 1476.8824
# [Epoch: 89] Average loss: 1284.0571, val_loss: 1450.5884
# [Epoch: 90] Average loss: 1171.1884, val_loss: 1887.3379
# [Epoch: 91] Average loss: 1285.8290, val_loss: 1213.0968
# [Epoch: 92] Average loss: 1160.9692, val_loss: 1243.6399
# [Epoch: 93] Average loss: 1117.5211, val_loss: 1426.5392
# [Epoch: 94] Average loss: 1272.6082, val_loss: 1441.5079
# [Epoch: 95] Average loss: 1103.0925, val_loss: 1289.2256
# [Epoch: 96] Average loss: 1215.1764, val_loss: 1339.3246
# [Epoch: 97] Average loss: 1198.3623, val_loss: 1831.6715
# [Epoch: 98] Average loss: 1231.9113, val_loss: 1421.2870
# [Epoch: 99] Average loss: 1215.4705, val_loss: 1539.0563
# [Epoch: 100] Average loss: 1213.0250, val_loss: 1838.2705

# %%
try :
    Name = './model_weighted_loss.pt'
    torch.save(model.state_dict(), Name)
except :
    pass

# %%
RMSEs = []
accuracys = []

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 20000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    accuracys.append(accuracy)
    RMSEs.append(RMSE)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}",)
# Out:
# 결과값:41719.09$, 예측값 :37098.29$
# 결과값:37753.27$, 예측값 :16496.22$
# 결과값:70749.53$, 예측값 :27649.89$
# 결과값:49075.34$, 예측값 :26247.94$
# 결과값:49865.46$, 예측값 :16248.78$
# 결과값:55408.52$, 예측값 :22643.97$
# Accuracy: -648.14   RMSE : 29027.23

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 20,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 15000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:41719.09$, 예측값 :37098.29$
# 결과값:15379.60$, 예측값 :10853.04$
# 결과값:16186.73$, 예측값 :8057.86$
# 결과값:16480.38$, 예측값 :15209.08$
# 결과값:37753.27$, 예측값 :16496.22$
# 결과값:18729.27$, 예측값 :4299.24$
# 결과값:15476.93$, 예측값 :12689.23$
# 결과값:17875.20$, 예측값 :9245.76$
# 결과값:16067.35$, 예측값 :5433.04$
# 결과값:49865.46$, 예측값 :16248.78$
# 결과값:55408.52$, 예측값 :22643.97$
# 결과값:49075.34$, 예측값 :26247.94$
# 결과값:70749.53$, 예측값 :27649.89$
# 결과값:18681.64$, 예측값 :9034.13$
# 결과값:16216.19$, 예측값 :14490.85$
# 결과값:18439.82$, 예측값 :6507.01$
# Accuracy: -16.22   RMSE : 19015.88

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 15,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 10000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:49075.34$, 예측값 :26247.94$
# 결과값:17875.20$, 예측값 :9245.76$
# 결과값:18681.64$, 예측값 :9034.13$
# 결과값:15476.93$, 예측값 :12689.23$
# 결과값:13336.86$, 예측값 :7137.82$
# 결과값:70749.53$, 예측값 :27649.89$
# 결과값:11755.98$, 예측값 :4284.22$
# 결과값:13328.09$, 예측값 :5491.03$
# 결과값:13326.63$, 예측값 :6866.15$
# 결과값:15379.60$, 예측값 :10853.04$
# 결과값:16067.35$, 예측값 :5433.04$
# 결과값:16216.19$, 예측값 :14490.85$
# 결과값:13410.72$, 예측값 :5955.74$
# 결과값:13500.16$, 예측값 :14119.29$
# 결과값:37753.27$, 예측값 :16496.22$
# 결과값:13262.90$, 예측값 :7017.53$
# 결과값:18439.82$, 예측값 :6507.01$
# 결과값:41719.09$, 예측값 :37098.29$
# 결과값:12627.71$, 예측값 :6556.88$
# 결과값:18729.27$, 예측값 :4299.24$
# 결과값:49865.46$, 예측값 :16248.78$
# 결과값:12996.87$, 예측값 :4898.55$
# 결과값:13490.76$, 예측값 :13226.41$
# 결과값:16186.73$, 예측값 :8057.86$
# 결과값:16480.38$, 예측값 :15209.08$
# 결과값:55408.52$, 예측값 :22643.97$
# Accuracy: 7.22   RMSE : 15417.95

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 10,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:1036.97$, 예측값 :1317.05$
# 결과값:1185.32$, 예측값 :1320.48$
# 결과값:2067.92$, 예측값 :1318.70$
# 결과값:2088.91$, 예측값 :2056.62$
# 결과값:2157.27$, 예측값 :1932.85$
# 결과값:2304.45$, 예측값 :2267.35$
# 결과값:2075.87$, 예측값 :2518.85$
# 결과값:2036.90$, 예측값 :1844.41$
# 결과값:1270.22$, 예측값 :1394.18$
# 결과값:1250.19$, 예측값 :1201.59$
# 결과값:1133.31$, 예측값 :1524.33$
# 결과값:2304.07$, 예측값 :1867.87$
# 결과값:1030.65$, 예측값 :773.21$
# 결과값:4833.72$, 예측값 :2881.08$
# 결과값:2292.07$, 예측값 :750.98$
# 결과값:1292.93$, 예측값 :1431.66$
# 결과값:1530.31$, 예측값 :1620.54$
# 결과값:2086.97$, 예측값 :2115.29$
# 결과값:1582.45$, 예측값 :2165.59$
# 결과값:2054.93$, 예측값 :5481.28$
# 결과값:1042.26$, 예측값 :964.65$
# 결과값:1114.81$, 예측값 :1438.23$
# 결과값:1040.25$, 예측값 :811.24$
# 결과값:1453.33$, 예측값 :1684.33$
# 결과값:4158.33$, 예측값 :2301.75$
# 결과값:1951.16$, 예측값 :2108.79$
# 결과값:1191.85$, 예측값 :1153.89$
# 결과값:2044.36$, 예측값 :2029.90$
# 결과값:1790.94$, 예측값 :1697.90$
# 결과값:2126.49$, 예측값 :1507.55$
# 결과값:1310.83$, 예측값 :1023.64$
# 결과값:2350.82$, 예측값 :3230.28$
# 결과값:2112.20$, 예측값 :2134.02$
# 결과값:926.91$, 예측값 :894.74$
# 결과값:1199.71$, 예측값 :1287.21$
# 결과값:3456.76$, 예측값 :1473.99$
# 결과값:1837.89$, 예측값 :1624.19$
# 결과값:1119.46$, 예측값 :1219.53$
# 결과값:55408.52$, 예측값 :22643.97$
# 결과값:1997.86$, 예측값 :2016.32$
# 결과값:2934.68$, 예측값 :3495.96$
# 결과값:1290.74$, 예측값 :1202.34$
# 결과값:16216.19$, 예측값 :14490.85$
# 결과값:839.64$, 예측값 :890.97$
# 결과값:2062.70$, 예측값 :2109.17$
# 결과값:2090.55$, 예측값 :2060.03$
# 결과값:1093.23$, 예측값 :1744.09$
# 결과값:1132.50$, 예측값 :685.71$
# 결과값:2179.02$, 예측값 :2085.62$
# 결과값:1400.63$, 예측값 :1391.28$
# 결과값:1107.02$, 예측값 :1712.21$
# 결과값:1702.84$, 예측값 :1588.63$
# 결과값:1697.76$, 예측값 :1827.75$
# 결과값:2089.62$, 예측값 :2202.45$
# 결과값:2024.70$, 예측값 :1676.99$
# 결과값:2056.00$, 예측값 :2009.28$
# 결과값:2062.01$, 예측값 :2207.60$
# 결과값:1997.77$, 예측값 :1821.40$
# 결과값:1738.38$, 예측값 :1570.68$
# 결과값:1986.07$, 예측값 :1767.48$
# 결과값:1993.12$, 예측값 :1753.74$
# 결과값:1822.60$, 예측값 :1597.72$
# 결과값:2508.64$, 예측값 :3464.44$
# 결과값:2448.26$, 예측값 :2127.90$
# 결과값:2080.06$, 예측값 :2040.54$
# 결과값:1204.23$, 예측값 :1227.82$
# 결과값:2282.33$, 예측값 :1723.45$
# 결과값:5991.94$, 예측값 :3855.95$
# 결과값:1922.98$, 예측값 :1920.20$
# 결과값:1199.98$, 예측값 :1080.41$
# 결과값:1696.00$, 예측값 :1878.16$
# 결과값:1277.72$, 예측값 :1263.07$
# 결과값:2075.91$, 예측값 :2139.14$
# 결과값:2052.56$, 예측값 :2544.38$
# 결과값:18729.27$, 예측값 :4299.24$
# 결과값:2104.05$, 예측값 :2141.85$
# 결과값:1880.97$, 예측값 :1590.14$
# 결과값:863.25$, 예측값 :1187.61$
# 결과값:4856.94$, 예측값 :3095.81$
# 결과값:1765.71$, 예측값 :1927.71$
# 결과값:2062.70$, 예측값 :2182.67$
# 결과값:4443.40$, 예측값 :15948.92$
# 결과값:1088.97$, 예측값 :2128.32$
# 결과값:1682.12$, 예측값 :1816.71$
# 결과값:974.54$, 예측값 :979.51$
# 결과값:1562.27$, 예측값 :1312.55$
# 결과값:2006.01$, 예측값 :1761.55$
# 결과값:3709.10$, 예측값 :8452.70$
# 결과값:16480.38$, 예측값 :15209.08$
# 결과값:2081.37$, 예측값 :2175.67$
# 결과값:3815.09$, 예측값 :4365.52$
# 결과값:2802.83$, 예측값 :1777.74$
# 결과값:1474.41$, 예측값 :1980.59$
# 결과값:2273.98$, 예측값 :1928.71$
# 결과값:70749.53$, 예측값 :27649.89$
# 결과값:1348.76$, 예측값 :792.70$
# 결과값:1329.03$, 예측값 :1156.85$
# 결과값:1997.75$, 예측값 :2598.43$
# 결과값:1012.33$, 예측값 :1398.44$
# 결과값:1884.69$, 예측값 :1627.16$
# 결과값:1720.93$, 예측값 :1235.37$
# 결과값:1997.22$, 예측값 :2036.18$
# 결과값:1839.55$, 예측값 :1681.56$
# 결과값:1124.70$, 예측값 :1909.44$
# 결과값:1532.76$, 예측값 :1352.06$
# 결과값:2029.39$, 예측값 :1780.98$
# 결과값:2014.75$, 예측값 :2113.42$
# 결과값:1041.16$, 예측값 :922.13$
# 결과값:3655.62$, 예측값 :2034.75$
# 결과값:2079.23$, 예측값 :1921.97$
# 결과값:1032.64$, 예측값 :1006.83$
# 결과값:1311.52$, 예측값 :1146.64$
# 결과값:9348.54$, 예측값 :5125.45$
# 결과값:2061.87$, 예측값 :2555.18$
# 결과값:1339.58$, 예측값 :1712.59$
# 결과값:1048.37$, 예측값 :808.85$
# 결과값:846.74$, 예측값 :672.38$
# 결과값:1508.36$, 예측값 :1477.21$
# 결과값:1149.58$, 예측값 :1636.73$
# 결과값:1030.68$, 예측값 :875.71$
# 결과값:1679.17$, 예측값 :1766.60$
# 결과값:1124.88$, 예측값 :1244.46$
# 결과값:3054.69$, 예측값 :2340.55$
# 결과값:922.64$, 예측값 :806.38$
# 결과값:2246.26$, 예측값 :2261.03$
# 결과값:1985.94$, 예측값 :2560.46$
# 결과값:2452.64$, 예측값 :2300.68$
# 결과값:9598.23$, 예측값 :8875.96$
# 결과값:1061.40$, 예측값 :1186.32$
# 결과값:1012.99$, 예측값 :1280.85$
# 결과값:1773.89$, 예측값 :2446.45$
# 결과값:2070.39$, 예측값 :1863.02$
# 결과값:2583.82$, 예측값 :1619.62$
# 결과값:1428.12$, 예측값 :1443.53$
# 결과값:1534.45$, 예측값 :846.14$
# 결과값:1310.14$, 예측값 :1419.79$
# 결과값:3001.29$, 예측값 :4346.73$
# 결과값:1882.12$, 예측값 :1607.57$
# 결과값:1624.52$, 예측값 :1214.70$
# 결과값:877.68$, 예측값 :1336.18$
# 결과값:1103.49$, 예측값 :671.57$
# 결과값:1276.32$, 예측값 :1381.95$
# 결과값:2318.26$, 예측값 :2123.17$
# 결과값:1040.08$, 예측값 :857.65$
# 결과값:1580.00$, 예측값 :1670.21$
# 결과값:1965.55$, 예측값 :1944.04$
# 결과값:2102.50$, 예측값 :1872.28$
# 결과값:2034.78$, 예측값 :1568.25$
# 결과값:2064.42$, 예측값 :1750.82$
# 결과값:49075.34$, 예측값 :26247.94$
# 결과값:1131.52$, 예측값 :1089.46$
# 결과값:1739.94$, 예측값 :1796.11$
# 결과값:893.71$, 예측값 :1480.67$
# 결과값:2727.75$, 예측값 :1495.01$
# 결과값:7258.54$, 예측값 :13136.47$
# 결과값:1544.19$, 예측값 :1688.58$
# 결과값:13410.72$, 예측값 :5955.74$
# 결과값:2459.12$, 예측값 :4095.66$
# 결과값:1598.08$, 예측값 :1917.19$
# 결과값:1658.90$, 예측값 :1514.38$
# 결과값:1463.08$, 예측값 :1345.20$
# 결과값:2448.26$, 예측값 :2019.68$
# 결과값:1540.60$, 예측값 :1895.81$
# 결과값:3233.01$, 예측값 :2050.63$
# 결과값:924.62$, 예측값 :632.26$
# 결과값:2094.68$, 예측값 :1840.53$
# 결과값:1968.43$, 예측값 :2242.61$
# 결과값:1031.12$, 예측값 :1034.88$
# 결과값:1155.32$, 예측값 :1151.50$
# 결과값:2059.52$, 예측값 :2382.16$
# 결과값:1986.00$, 예측값 :1872.76$
# 결과값:2098.19$, 예측값 :2148.86$
# 결과값:2187.15$, 예측값 :3735.57$
# 결과값:974.57$, 예측값 :629.24$
# 결과값:1786.96$, 예측값 :1398.93$
# 결과값:1672.80$, 예측값 :1918.29$
# 결과값:2099.93$, 예측값 :2158.64$
# 결과값:2061.11$, 예측값 :1990.82$
# 결과값:1538.81$, 예측값 :2091.74$
# 결과값:1504.71$, 예측값 :1754.30$
# 결과값:829.54$, 예측값 :919.75$
# 결과값:1018.38$, 예측값 :1067.52$
# 결과값:1650.45$, 예측값 :1683.99$
# 결과값:1538.85$, 예측값 :1500.74$
# 결과값:898.08$, 예측값 :923.48$
# 결과값:1675.74$, 예측값 :1965.27$
# 결과값:838.36$, 예측값 :776.32$
# 결과값:15379.60$, 예측값 :10853.04$
# 결과값:1091.99$, 예측값 :1136.49$
# 결과값:1425.61$, 예측값 :1236.56$
# 결과값:1885.25$, 예측값 :1764.88$
# 결과값:2053.38$, 예측값 :2516.51$
# 결과값:1746.93$, 예측값 :4258.08$
# 결과값:2149.05$, 예측값 :2112.04$
# 결과값:2043.45$, 예측값 :2058.77$
# 결과값:1349.89$, 예측값 :1403.95$
# 결과값:1972.43$, 예측값 :1664.49$
# 결과값:1056.32$, 예측값 :1365.45$
# 결과값:2031.45$, 예측값 :2055.70$
# 결과값:2028.32$, 예측값 :1988.99$
# 결과값:1473.78$, 예측값 :2222.29$
# 결과값:1401.03$, 예측값 :1814.85$
# 결과값:868.34$, 예측값 :746.44$
# 결과값:1497.14$, 예측값 :1677.56$
# 결과값:6493.52$, 예측값 :8566.46$
# 결과값:1291.97$, 예측값 :1444.85$
# 결과값:1423.71$, 예측값 :1375.53$
# 결과값:1038.49$, 예측값 :963.20$
# 결과값:2068.73$, 예측값 :2543.14$
# 결과값:2508.85$, 예측값 :2185.91$
# 결과값:11755.98$, 예측값 :4284.22$
# 결과값:1093.95$, 예측값 :636.33$
# 결과값:2480.15$, 예측값 :1936.19$
# 결과값:9518.21$, 예측값 :5542.60$
# 결과값:1400.94$, 예측값 :1436.79$
# 결과값:3460.94$, 예측값 :2390.45$
# 결과값:2263.49$, 예측값 :1695.75$
# 결과값:958.73$, 예측값 :978.58$
# 결과값:866.33$, 예측값 :1039.66$
# 결과값:2200.67$, 예측값 :1528.85$
# 결과값:2337.05$, 예측값 :2076.74$
# 결과값:2125.23$, 예측값 :1758.74$
# 결과값:2736.71$, 예측값 :2120.37$
# 결과값:1326.87$, 예측값 :1191.58$
# 결과값:2969.47$, 예측값 :3445.91$
# 결과값:1786.33$, 예측값 :1841.76$
# 결과값:898.56$, 예측값 :1194.73$
# 결과값:1581.86$, 예측값 :1502.74$
# 결과값:2002.90$, 예측값 :1818.15$
# 결과값:2757.79$, 예측값 :3386.06$
# 결과값:2062.41$, 예측값 :1727.32$
# 결과값:1598.58$, 예측값 :1929.89$
# 결과값:1161.67$, 예측값 :1437.76$
# 결과값:1799.85$, 예측값 :1739.48$
# 결과값:1057.50$, 예측값 :817.59$
# 결과값:1101.12$, 예측값 :842.35$
# 결과값:2049.90$, 예측값 :2074.45$
# 결과값:2060.18$, 예측값 :2162.69$
# 결과값:1283.79$, 예측값 :1116.49$
# 결과값:753.77$, 예측값 :813.17$
# 결과값:2145.16$, 예측값 :2592.91$
# 결과값:1034.60$, 예측값 :1190.24$
# 결과값:1465.45$, 예측값 :1610.84$
# 결과값:2817.63$, 예측값 :2013.15$
# 결과값:1537.92$, 예측값 :869.78$
# 결과값:2724.90$, 예측값 :1920.45$
# 결과값:1582.79$, 예측값 :1851.88$
# 결과값:1697.10$, 예측값 :1581.97$
# 결과값:1184.12$, 예측값 :536.32$
# 결과값:1162.92$, 예측값 :915.24$
# 결과값:1212.10$, 예측값 :839.11$
# 결과값:1752.72$, 예측값 :2887.81$
# 결과값:1986.62$, 예측값 :1794.07$
# 결과값:9640.53$, 예측값 :4779.43$
# 결과값:1452.83$, 예측값 :1331.47$
# 결과값:1332.09$, 예측값 :962.79$
# 결과값:1990.53$, 예측값 :1921.02$
# 결과값:1424.23$, 예측값 :1053.06$
# 결과값:974.35$, 예측값 :860.09$
# 결과값:1587.41$, 예측값 :1646.23$
# 결과값:1303.33$, 예측값 :1375.11$
# 결과값:1018.39$, 예측값 :1203.87$
# 결과값:821.61$, 예측값 :852.16$
# 결과값:969.38$, 예측값 :1283.64$
# 결과값:2324.68$, 예측값 :2073.52$
# 결과값:3135.82$, 예측값 :2088.80$
# 결과값:2067.68$, 예측값 :1831.03$
# 결과값:2079.38$, 예측값 :1835.02$
# 결과값:4379.77$, 예측값 :4899.25$
# 결과값:2337.00$, 예측값 :2128.97$
# 결과값:1669.15$, 예측값 :2164.44$
# 결과값:2034.00$, 예측값 :1958.41$
# 결과값:947.09$, 예측값 :1724.46$
# 결과값:834.91$, 예측값 :614.99$
# 결과값:37753.27$, 예측값 :16496.22$
# 결과값:1622.57$, 예측값 :1708.86$
# 결과값:1679.27$, 예측값 :1384.30$
# 결과값:2088.91$, 예측값 :2024.41$
# 결과값:904.35$, 예측값 :923.07$
# 결과값:2154.96$, 예측값 :2033.06$
# 결과값:2421.52$, 예측값 :1825.38$
# 결과값:3521.16$, 예측값 :1471.56$
# 결과값:2192.54$, 예측값 :1849.76$
# 결과값:3068.11$, 예측값 :2094.64$
# 결과값:1731.02$, 예측값 :1959.18$
# 결과값:1149.54$, 예측값 :1251.07$
# 결과값:4545.71$, 예측값 :1475.91$
# 결과값:2083.80$, 예측값 :2263.50$
# 결과값:2319.73$, 예측값 :1805.58$
# 결과값:1658.74$, 예측값 :1467.70$
# 결과값:1481.75$, 예측값 :1552.13$
# 결과값:3784.61$, 예측값 :4296.36$
# 결과값:3908.68$, 예측값 :2496.81$
# 결과값:1120.39$, 예측값 :709.37$
# 결과값:946.42$, 예측값 :719.41$
# 결과값:2508.02$, 예측값 :2171.86$
# 결과값:6096.99$, 예측값 :4027.55$
# 결과값:1720.61$, 예측값 :1370.27$
# 결과값:1188.42$, 예측값 :1249.95$
# 결과값:2045.64$, 예측값 :1906.07$
# 결과값:2077.89$, 예측값 :1974.99$
# 결과값:2073.70$, 예측값 :2555.76$
# 결과값:1836.29$, 예측값 :1558.32$
# 결과값:974.29$, 예측값 :1087.56$
# 결과값:5961.15$, 예측값 :6745.31$
# 결과값:3173.68$, 예측값 :2117.40$
# 결과값:1524.67$, 예측값 :1643.46$
# 결과값:1740.29$, 예측값 :2066.37$
# 결과값:2030.54$, 예측값 :2675.34$
# 결과값:1876.75$, 예측값 :1473.03$
# 결과값:2399.71$, 예측값 :2415.74$
# 결과값:1472.19$, 예측값 :2336.92$
# 결과값:1124.10$, 예측값 :1225.56$
# 결과값:3650.11$, 예측값 :2414.57$
# 결과값:1183.00$, 예측값 :1569.88$
# 결과값:1135.92$, 예측값 :1428.31$
# 결과값:2412.96$, 예측값 :1788.24$
# 결과값:1180.68$, 예측값 :1298.91$
# 결과값:2106.18$, 예측값 :1888.78$
# 결과값:1950.75$, 예측값 :1950.23$
# 결과값:1407.85$, 예측값 :1481.61$
# 결과값:4115.50$, 예측값 :2658.10$
# 결과값:1166.56$, 예측값 :1264.80$
# 결과값:1325.28$, 예측값 :1390.05$
# 결과값:1028.04$, 예측값 :1227.80$
# 결과값:4430.27$, 예측값 :5776.26$
# 결과값:2036.90$, 예측값 :1830.37$
# 결과값:2040.22$, 예측값 :2005.36$
# 결과값:1867.55$, 예측값 :1685.33$
# 결과값:2249.55$, 예측값 :1345.13$
# 결과값:4521.00$, 예측값 :3021.12$
# 결과값:1539.35$, 예측값 :1854.50$
# 결과값:1854.94$, 예측값 :1846.61$
# 결과값:1514.71$, 예측값 :1908.93$
# 결과값:1864.54$, 예측값 :1775.16$
# 결과값:1173.20$, 예측값 :1357.89$
# 결과값:1972.16$, 예측값 :1772.06$
# 결과값:1788.78$, 예측값 :1574.41$
# 결과값:2078.78$, 예측값 :2584.14$
# 결과값:2045.06$, 예측값 :2054.60$
# 결과값:1328.98$, 예측값 :1587.75$
# 결과값:1277.73$, 예측값 :1447.77$
# 결과값:1324.27$, 예측값 :1295.28$
# 결과값:895.73$, 예측값 :823.89$
# 결과값:3067.51$, 예측값 :2121.01$
# 결과값:1430.75$, 예측값 :1558.51$
# 결과값:2021.49$, 예측값 :1702.57$
# 결과값:1114.96$, 예측값 :720.55$
# 결과값:1968.26$, 예측값 :1668.27$
# 결과값:12996.87$, 예측값 :4898.55$
# 결과값:954.65$, 예측값 :1153.72$
# 결과값:1066.07$, 예측값 :937.58$
# 결과값:2040.00$, 예측값 :2557.31$
# 결과값:981.38$, 예측값 :1129.97$
# 결과값:1164.15$, 예측값 :1151.03$
# 결과값:1576.77$, 예측값 :1715.85$
# 결과값:1532.39$, 예측값 :1645.10$
# 결과값:1993.46$, 예측값 :2531.49$
# 결과값:968.78$, 예측값 :1451.54$
# 결과값:1659.72$, 예측값 :1679.06$
# 결과값:1843.82$, 예측값 :1562.53$
# 결과값:994.18$, 예측값 :1119.20$
# 결과값:1094.00$, 예측값 :770.38$
# 결과값:2048.08$, 예측값 :1736.44$
# 결과값:2242.06$, 예측값 :1535.05$
# 결과값:1028.53$, 예측값 :884.13$
# 결과값:1516.44$, 예측값 :1773.44$
# 결과값:1134.40$, 예측값 :828.67$
# 결과값:2031.06$, 예측값 :3257.50$
# 결과값:1164.21$, 예측값 :1207.72$
# 결과값:1822.02$, 예측값 :1776.36$
# 결과값:1055.41$, 예측값 :968.02$
# 결과값:1929.08$, 예측값 :1910.24$
# 결과값:1141.31$, 예측값 :1312.30$
# 결과값:2082.03$, 예측값 :1999.06$
# 결과값:1597.90$, 예측값 :1923.49$
# 결과값:1040.04$, 예측값 :1787.63$
# 결과값:1134.51$, 예측값 :780.54$
# 결과값:954.02$, 예측값 :1068.75$
# 결과값:1309.02$, 예측값 :1983.72$
# 결과값:2070.33$, 예측값 :1816.80$
# 결과값:2362.83$, 예측값 :3610.08$
# 결과값:969.79$, 예측값 :1234.48$
# 결과값:1785.62$, 예측값 :1332.00$
# 결과값:1032.69$, 예측값 :1143.43$
# 결과값:2111.79$, 예측값 :2567.66$
# 결과값:819.30$, 예측값 :689.24$
# 결과값:4161.25$, 예측값 :6829.38$
# 결과값:1135.48$, 예측값 :1197.66$
# 결과값:1354.57$, 예측값 :1222.25$
# 결과값:1255.25$, 예측값 :973.12$
# 결과값:4327.67$, 예측값 :3489.34$
# 결과값:2452.64$, 예측값 :2296.12$
# 결과값:1172.15$, 예측값 :1370.98$
# 결과값:1993.46$, 예측값 :2493.24$
# 결과값:1604.91$, 예측값 :1574.97$
# 결과값:2435.56$, 예측값 :1877.97$
# 결과값:2074.51$, 예측값 :1800.41$
# 결과값:3442.51$, 예측값 :4222.42$
# 결과값:2262.98$, 예측값 :1850.48$
# 결과값:16067.35$, 예측값 :5433.04$
# 결과값:1347.34$, 예측값 :1089.26$
# 결과값:1085.42$, 예측값 :797.52$
# 결과값:2122.91$, 예측값 :3572.97$
# 결과값:3018.02$, 예측값 :4573.40$
# 결과값:2053.49$, 예측값 :1963.46$
# 결과값:2187.19$, 예측값 :2050.96$
# 결과값:1615.89$, 예측값 :1191.28$
# 결과값:750.97$, 예측값 :973.61$
# 결과값:1401.30$, 예측값 :1381.69$
# 결과값:1606.66$, 예측값 :1530.38$
# 결과값:2370.80$, 예측값 :2033.36$
# 결과값:1126.24$, 예측값 :1190.59$
# 결과값:1010.79$, 예측값 :1168.87$
# 결과값:945.76$, 예측값 :1252.43$
# 결과값:2048.36$, 예측값 :1541.02$
# 결과값:2313.96$, 예측값 :1852.64$
# 결과값:1000.72$, 예측값 :971.02$
# 결과값:2061.80$, 예측값 :2071.97$
# 결과값:2060.62$, 예측값 :2086.44$
# 결과값:1256.24$, 예측값 :1320.97$
# 결과값:944.85$, 예측값 :1276.97$
# 결과값:1447.35$, 예측값 :1515.30$
# 결과값:2304.43$, 예측값 :2016.76$
# 결과값:1992.91$, 예측값 :2051.85$
# 결과값:1095.73$, 예측값 :1464.16$
# 결과값:1861.10$, 예측값 :2197.40$
# 결과값:2023.78$, 예측값 :2649.76$
# 결과값:13328.09$, 예측값 :5491.03$
# 결과값:2099.04$, 예측값 :2903.97$
# 결과값:2350.82$, 예측값 :2071.81$
# 결과값:2113.97$, 예측값 :1994.79$
# 결과값:1136.53$, 예측값 :834.86$
# 결과값:1972.58$, 예측값 :2516.84$
# 결과값:1346.68$, 예측값 :1210.33$
# 결과값:1039.70$, 예측값 :837.02$
# 결과값:2080.00$, 예측값 :1986.91$
# 결과값:1417.83$, 예측값 :1198.14$
# 결과값:2080.46$, 예측값 :2205.66$
# 결과값:2123.50$, 예측값 :2124.66$
# 결과값:826.78$, 예측값 :1050.08$
# 결과값:2002.26$, 예측값 :1697.10$
# 결과값:2066.92$, 예측값 :2567.98$
# 결과값:1140.06$, 예측값 :1240.73$
# 결과값:1036.26$, 예측값 :922.19$
# 결과값:2048.45$, 예측값 :2462.72$
# 결과값:1176.27$, 예측값 :1554.42$
# 결과값:1348.62$, 예측값 :2001.73$
# 결과값:4007.88$, 예측값 :3883.09$
# 결과값:1498.35$, 예측값 :1527.72$
# 결과값:1498.19$, 예측값 :1294.90$
# 결과값:4011.70$, 예측값 :2648.91$
# 결과값:2104.08$, 예측값 :2793.63$
# 결과값:2063.52$, 예측값 :1910.84$
# 결과값:1554.79$, 예측값 :1137.76$
# 결과값:1279.25$, 예측값 :1042.05$
# 결과값:1862.80$, 예측값 :1999.27$
# 결과값:1031.66$, 예측값 :1126.26$
# 결과값:3267.15$, 예측값 :1805.94$
# 결과값:2904.99$, 예측값 :3657.31$
# 결과값:2353.97$, 예측값 :2085.30$
# 결과값:2315.11$, 예측값 :1850.33$
# 결과값:1996.74$, 예측값 :1478.41$
# 결과값:2453.69$, 예측값 :1951.90$
# 결과값:2079.61$, 예측값 :2605.35$
# 결과값:1973.83$, 예측값 :2028.56$
# 결과값:1473.04$, 예측값 :1712.26$
# 결과값:2105.76$, 예측값 :2096.37$
# 결과값:1404.00$, 예측값 :1874.55$
# 결과값:838.41$, 예측값 :1196.75$
# 결과값:2480.77$, 예측값 :1724.25$
# 결과값:1973.74$, 예측값 :1910.39$
# 결과값:1273.65$, 예측값 :982.64$
# 결과값:1660.49$, 예측값 :1445.67$
# 결과값:18439.82$, 예측값 :6507.01$
# 결과값:13500.16$, 예측값 :14119.29$
# 결과값:3327.44$, 예측값 :2364.30$
# 결과값:2166.14$, 예측값 :1504.25$
# 결과값:3172.28$, 예측값 :2288.55$
# 결과값:2403.31$, 예측값 :1854.43$
# 결과값:1423.83$, 예측값 :1261.06$
# 결과값:2516.77$, 예측값 :1920.53$
# 결과값:2011.25$, 예측값 :2560.78$
# 결과값:2030.57$, 예측값 :2796.15$
# 결과값:2077.11$, 예측값 :2058.88$
# 결과값:2471.39$, 예측값 :4082.70$
# 결과값:1015.23$, 예측값 :1082.74$
# 결과값:2097.46$, 예측값 :3096.15$
# 결과값:1143.64$, 예측값 :839.99$
# 결과값:3260.31$, 예측값 :2096.36$
# 결과값:3031.80$, 예측값 :4596.21$
# 결과값:2895.53$, 예측값 :3069.66$
# 결과값:1329.81$, 예측값 :1018.21$
# 결과값:1289.35$, 예측값 :1305.49$
# 결과값:18681.64$, 예측값 :9034.13$
# 결과값:2082.67$, 예측값 :1897.56$
# 결과값:1022.80$, 예측값 :1067.71$
# 결과값:1368.98$, 예측값 :1347.97$
# 결과값:2086.21$, 예측값 :2246.49$
# 결과값:4148.72$, 예측값 :4752.97$
# 결과값:2187.06$, 예측값 :2251.61$
# 결과값:1282.57$, 예측값 :1408.02$
# 결과값:17875.20$, 예측값 :9245.76$
# 결과값:837.48$, 예측값 :1122.86$
# 결과값:1427.29$, 예측값 :1437.40$
# 결과값:1872.54$, 예측값 :1510.52$
# 결과값:2015.41$, 예측값 :1693.20$
# 결과값:2354.34$, 예측값 :1748.33$
# 결과값:2296.93$, 예측값 :1869.28$
# 결과값:1260.79$, 예측값 :1000.81$
# 결과값:1418.06$, 예측값 :1687.38$
# 결과값:2197.80$, 예측값 :2107.36$
# 결과값:1057.31$, 예측값 :1217.49$
# 결과값:1963.28$, 예측값 :2145.39$
# 결과값:2041.08$, 예측값 :1803.90$
# 결과값:1090.42$, 예측값 :1073.22$
# 결과값:1141.09$, 예측값 :721.83$
# 결과값:1529.59$, 예측값 :2113.08$
# 결과값:1105.87$, 예측값 :1324.12$
# 결과값:1382.34$, 예측값 :2069.21$
# 결과값:2071.48$, 예측값 :1825.92$
# 결과값:12627.71$, 예측값 :6556.88$
# 결과값:1683.22$, 예측값 :1580.49$
# 결과값:1968.02$, 예측값 :1896.78$
# 결과값:2048.36$, 예측값 :2041.17$
# 결과값:1383.13$, 예측값 :2002.58$
# 결과값:2078.36$, 예측값 :3242.72$
# 결과값:2059.79$, 예측값 :2355.36$
# 결과값:2953.85$, 예측값 :5405.24$
# 결과값:2104.09$, 예측값 :1863.29$
# 결과값:1991.83$, 예측값 :2712.42$
# 결과값:1528.57$, 예측값 :1448.38$
# 결과값:1426.55$, 예측값 :1485.54$
# 결과값:2069.61$, 예측값 :1940.13$
# 결과값:3389.88$, 예측값 :2212.91$
# 결과값:2568.78$, 예측값 :2140.96$
# 결과값:2304.07$, 예측값 :1835.31$
# 결과값:1983.47$, 예측값 :1739.96$
# 결과값:1738.11$, 예측값 :1369.05$
# 결과값:1534.57$, 예측값 :1695.88$
# 결과값:1424.77$, 예측값 :1172.40$
# 결과값:1293.26$, 예측값 :980.70$
# 결과값:2118.77$, 예측값 :1894.94$
# 결과값:1470.58$, 예측값 :2271.37$
# 결과값:2078.47$, 예측값 :1772.65$
# 결과값:1935.25$, 예측값 :2115.36$
# 결과값:49865.46$, 예측값 :16248.78$
# 결과값:1432.39$, 예측값 :1313.10$
# 결과값:2015.34$, 예측값 :2031.22$
# 결과값:1403.95$, 예측값 :1741.75$
# 결과값:2304.07$, 예측값 :1979.41$
# 결과값:1650.38$, 예측값 :1270.97$
# 결과값:1327.11$, 예측값 :1576.69$
# 결과값:1142.87$, 예측값 :1894.96$
# 결과값:1739.96$, 예측값 :1876.04$
# 결과값:3480.49$, 예측값 :2897.26$
# 결과값:1973.14$, 예측값 :2075.71$
# 결과값:1159.37$, 예측값 :943.63$
# 결과값:1524.65$, 예측값 :1740.94$
# 결과값:1164.88$, 예측값 :1510.47$
# 결과값:13336.86$, 예측값 :7137.82$
# 결과값:1140.55$, 예측값 :770.65$
# 결과값:3642.69$, 예측값 :2558.06$
# 결과값:2448.32$, 예측값 :2011.00$
# 결과값:3129.89$, 예측값 :4851.53$
# 결과값:1354.03$, 예측값 :1328.57$
# 결과값:1429.00$, 예측값 :1202.19$
# 결과값:1027.01$, 예측값 :1096.23$
# 결과값:1796.39$, 예측값 :1508.25$
# 결과값:3632.78$, 예측값 :2145.34$
# 결과값:945.34$, 예측값 :1074.18$
# 결과값:2290.68$, 예측값 :1749.81$
# 결과값:2337.00$, 예측값 :3008.62$
# 결과값:2106.37$, 예측값 :1879.31$
# 결과값:2527.87$, 예측값 :2093.74$
# 결과값:1096.51$, 예측값 :1192.13$
# 결과값:2061.99$, 예측값 :2035.30$
# 결과값:1881.17$, 예측값 :1699.01$
# 결과값:1583.70$, 예측값 :1413.68$
# 결과값:930.75$, 예측값 :750.45$
# 결과값:2551.35$, 예측값 :2161.17$
# 결과값:4420.96$, 예측값 :2408.23$
# 결과값:1058.89$, 예측값 :1138.38$
# 결과값:4958.89$, 예측값 :3752.03$
# 결과값:16186.73$, 예측값 :8057.86$
# 결과값:974.35$, 예측값 :808.77$
# 결과값:1722.11$, 예측값 :3563.07$
# 결과값:1473.19$, 예측값 :7459.29$
# 결과값:2568.80$, 예측값 :2079.70$
# 결과값:1024.19$, 예측값 :915.07$
# 결과값:1302.80$, 예측값 :1977.36$
# 결과값:1267.50$, 예측값 :1165.74$
# 결과값:2337.35$, 예측값 :2244.31$
# 결과값:2249.20$, 예측값 :1658.76$
# 결과값:1854.92$, 예측값 :1310.80$
# 결과값:2775.23$, 예측값 :4365.49$
# 결과값:1819.29$, 예측값 :1539.33$
# 결과값:2074.89$, 예측값 :2115.72$
# 결과값:2471.36$, 예측값 :2110.52$
# 결과값:1056.49$, 예측값 :806.36$
# 결과값:2071.45$, 예측값 :2847.45$
# 결과값:1599.11$, 예측값 :2380.37$
# 결과값:975.06$, 예측값 :1203.27$
# 결과값:1799.78$, 예측값 :1656.88$
# 결과값:1205.93$, 예측값 :1076.10$
# 결과값:2100.82$, 예측값 :1896.09$
# 결과값:1277.75$, 예측값 :1070.21$
# 결과값:2139.78$, 예측값 :2293.96$
# 결과값:1699.36$, 예측값 :1667.51$
# 결과값:992.57$, 예측값 :1041.83$
# 결과값:2241.65$, 예측값 :1815.12$
# 결과값:2213.67$, 예측값 :1795.70$
# 결과값:3049.30$, 예측값 :1910.61$
# 결과값:2055.01$, 예측값 :1889.52$
# 결과값:1006.26$, 예측값 :704.81$
# 결과값:1322.54$, 예측값 :1014.59$
# 결과값:2245.14$, 예측값 :2574.44$
# 결과값:1403.12$, 예측값 :1781.72$
# 결과값:4408.70$, 예측값 :3089.44$
# 결과값:846.08$, 예측값 :1230.52$
# 결과값:1965.55$, 예측값 :1922.23$
# 결과값:1743.35$, 예측값 :1508.21$
# 결과값:1750.96$, 예측값 :1665.53$
# 결과값:1191.82$, 예측값 :1058.22$
# 결과값:1163.62$, 예측값 :1418.02$
# 결과값:1555.63$, 예측값 :1401.62$
# 결과값:1603.42$, 예측값 :1273.22$
# 결과값:902.12$, 예측값 :1033.56$
# 결과값:2568.78$, 예측값 :2222.90$
# 결과값:886.62$, 예측값 :1115.41$
# 결과값:1604.70$, 예측값 :2185.50$
# 결과값:1970.54$, 예측값 :2542.20$
# 결과값:1153.26$, 예측값 :1418.98$
# 결과값:2105.01$, 예측값 :1821.22$
# 결과값:1063.62$, 예측값 :1222.29$
# 결과값:963.82$, 예측값 :929.13$
# 결과값:3021.19$, 예측값 :2180.10$
# 결과값:1212.63$, 예측값 :1028.18$
# 결과값:1031.20$, 예측값 :1187.32$
# 결과값:13326.63$, 예측값 :6866.15$
# 결과값:2092.25$, 예측값 :2536.77$
# 결과값:1030.06$, 예측값 :1201.76$
# 결과값:3650.16$, 예측값 :2276.78$
# 결과값:764.56$, 예측값 :746.95$
# 결과값:2352.55$, 예측값 :1943.61$
# 결과값:2031.70$, 예측값 :2655.63$
# 결과값:1003.72$, 예측값 :963.05$
# 결과값:1036.88$, 예측값 :1135.77$
# 결과값:2263.09$, 예측값 :1960.94$
# 결과값:1403.68$, 예측값 :1538.89$
# 결과값:3229.56$, 예측값 :2177.38$
# 결과값:1211.61$, 예측값 :1399.82$
# 결과값:2180.03$, 예측값 :905.84$
# 결과값:969.79$, 예측값 :694.48$
# 결과값:2057.03$, 예측값 :1487.47$
# 결과값:1650.73$, 예측값 :2005.49$
# 결과값:2453.10$, 예측값 :2416.66$
# 결과값:3483.07$, 예측값 :2357.04$
# 결과값:2619.85$, 예측값 :1902.21$
# 결과값:2109.20$, 예측값 :1857.38$
# 결과값:2665.60$, 예측값 :1753.96$
# 결과값:2028.20$, 예측값 :2525.22$
# 결과값:2018.71$, 예측값 :1871.83$
# 결과값:2152.82$, 예측값 :2560.07$
# 결과값:1335.20$, 예측값 :1261.91$
# 결과값:1660.54$, 예측값 :1114.74$
# 결과값:1681.61$, 예측값 :1552.96$
# 결과값:945.96$, 예측값 :645.93$
# 결과값:2028.12$, 예측값 :1773.37$
# 결과값:1379.74$, 예측값 :1041.79$
# 결과값:1991.02$, 예측값 :1823.27$
# 결과값:1645.60$, 예측값 :1539.09$
# 결과값:2094.05$, 예측값 :1835.12$
# 결과값:1093.01$, 예측값 :1205.54$
# 결과값:2356.77$, 예측값 :1620.33$
# 결과값:3514.31$, 예측값 :2254.19$
# 결과값:1742.54$, 예측값 :1521.51$
# 결과값:1093.73$, 예측값 :690.59$
# 결과값:1701.95$, 예측값 :1331.10$
# 결과값:1973.23$, 예측값 :1580.23$
# 결과값:2368.35$, 예측값 :2502.14$
# 결과값:2105.05$, 예측값 :2001.22$
# 결과값:1985.97$, 예측값 :2747.98$
# 결과값:2987.55$, 예측값 :3790.36$
# 결과값:943.90$, 예측값 :890.81$
# 결과값:2074.80$, 예측값 :1967.41$
# 결과값:853.18$, 예측값 :1063.83$
# 결과값:1086.84$, 예측값 :1097.65$
# 결과값:2993.13$, 예측값 :2416.01$
# 결과값:4352.31$, 예측값 :3448.16$
# 결과값:1988.78$, 예측값 :1758.10$
# 결과값:1093.95$, 예측값 :601.87$
# 결과값:1148.96$, 예측값 :1408.18$
# 결과값:901.80$, 예측값 :828.89$
# 결과값:1328.93$, 예측값 :1466.76$
# 결과값:1242.86$, 예측값 :1057.62$
# 결과값:2061.92$, 예측값 :2067.96$
# 결과값:2040.00$, 예측값 :2533.59$
# 결과값:1751.37$, 예측값 :1926.48$
# 결과값:2304.05$, 예측값 :2086.56$
# 결과값:805.98$, 예측값 :755.90$
# 결과값:1446.08$, 예측값 :1465.00$
# 결과값:1463.57$, 예측값 :1463.62$
# 결과값:1598.46$, 예측값 :1748.47$
# 결과값:1123.55$, 예측값 :1744.35$
# 결과값:1763.52$, 예측값 :1507.66$
# 결과값:1973.70$, 예측값 :1890.15$
# 결과값:2035.49$, 예측값 :1702.17$
# 결과값:3519.28$, 예측값 :2446.01$
# 결과값:808.48$, 예측값 :842.84$
# 결과값:1428.81$, 예측값 :1448.24$
# 결과값:1717.94$, 예측값 :1367.47$
# 결과값:3043.26$, 예측값 :2102.85$
# 결과값:4116.79$, 예측값 :2338.19$
# 결과값:2067.92$, 예측값 :3061.95$
# 결과값:6072.07$, 예측값 :4145.52$
# 결과값:943.90$, 예측값 :885.86$
# 결과값:1462.04$, 예측값 :714.58$
# 결과값:2028.27$, 예측값 :1923.17$
# 결과값:1196.50$, 예측값 :1222.70$
# 결과값:2631.11$, 예측값 :1706.55$
# 결과값:944.20$, 예측값 :1293.84$
# 결과값:2070.35$, 예측값 :2587.46$
# 결과값:928.62$, 예측값 :811.71$
# 결과값:875.42$, 예측값 :742.56$
# 결과값:2696.13$, 예측값 :2208.28$
# 결과값:2851.75$, 예측값 :1805.57$
# 결과값:853.01$, 예측값 :1070.88$
# 결과값:2353.56$, 예측값 :2097.37$
# 결과값:948.46$, 예측값 :726.16$
# 결과값:1805.77$, 예측값 :1885.67$
# 결과값:926.34$, 예측값 :1133.47$
# 결과값:1462.03$, 예측값 :1496.97$
# 결과값:2085.19$, 예측값 :2177.25$
# 결과값:1145.23$, 예측값 :1110.26$
# 결과값:2008.35$, 예측값 :1589.18$
# 결과값:904.91$, 예측값 :987.02$
# 결과값:1030.22$, 예측값 :1381.00$
# 결과값:1042.12$, 예측값 :1131.87$
# 결과값:2762.91$, 예측값 :1982.35$
# 결과값:1091.99$, 예측값 :683.58$
# 결과값:2027.51$, 예측값 :2035.80$
# 결과값:1698.83$, 예측값 :1534.26$
# 결과값:2544.90$, 예측값 :1811.73$
# 결과값:2084.78$, 예측값 :2023.55$
# 결과값:1556.58$, 예측값 :1182.59$
# 결과값:1122.50$, 예측값 :2065.44$
# 결과값:1768.87$, 예측값 :1769.59$
# 결과값:2161.39$, 예측값 :1835.09$
# 결과값:4092.84$, 예측값 :2479.46$
# 결과값:2055.02$, 예측값 :1885.76$
# 결과값:2087.09$, 예측값 :2527.69$
# 결과값:1281.14$, 예측값 :1487.17$
# 결과값:791.33$, 예측값 :830.08$
# 결과값:1291.89$, 예측값 :1344.38$
# 결과값:1565.85$, 예측값 :1136.89$
# 결과값:1873.45$, 예측값 :1909.76$
# 결과값:1188.76$, 예측값 :1171.71$
# 결과값:2723.69$, 예측값 :2058.79$
# 결과값:2247.53$, 예측값 :1677.03$
# 결과값:1150.70$, 예측값 :1057.77$
# 결과값:1139.13$, 예측값 :1188.56$
# 결과값:1326.33$, 예측값 :1356.91$
# 결과값:1430.74$, 예측값 :2076.19$
# 결과값:1623.88$, 예측값 :2321.85$
# 결과값:1371.84$, 예측값 :1485.49$
# 결과값:2259.29$, 예측값 :2426.67$
# 결과값:2279.60$, 예측값 :2030.93$
# 결과값:2051.69$, 예측값 :2529.87$
# 결과값:1680.03$, 예측값 :1992.05$
# 결과값:9504.07$, 예측값 :13473.98$
# 결과값:2299.43$, 예측값 :1859.19$
# 결과값:1358.27$, 예측값 :1492.30$
# 결과값:901.78$, 예측값 :753.12$
# 결과값:2078.35$, 예측값 :2038.07$
# 결과값:1481.29$, 예측값 :1543.74$
# 결과값:41719.09$, 예측값 :37098.29$
# 결과값:1096.64$, 예측값 :967.99$
# 결과값:1428.42$, 예측값 :1516.51$
# 결과값:1978.08$, 예측값 :1999.94$
# 결과값:1784.47$, 예측값 :1597.99$
# 결과값:15476.93$, 예측값 :12689.23$
# 결과값:2116.52$, 예측값 :2831.53$
# 결과값:1800.96$, 예측값 :1735.03$
# 결과값:974.29$, 예측값 :1069.00$
# 결과값:2528.27$, 예측값 :821.20$
# 결과값:1118.85$, 예측값 :846.28$
# 결과값:1358.39$, 예측값 :994.43$
# 결과값:4782.45$, 예측값 :3129.97$
# 결과값:2680.62$, 예측값 :2002.12$
# 결과값:1790.38$, 예측값 :1827.40$
# 결과값:2364.87$, 예측값 :2091.00$
# 결과값:2752.50$, 예측값 :1657.92$
# 결과값:2055.21$, 예측값 :1786.05$
# 결과값:2062.70$, 예측값 :2313.65$
# 결과값:1984.26$, 예측값 :2563.26$
# 결과값:6006.28$, 예측값 :3048.23$
# 결과값:959.62$, 예측값 :1179.84$
# 결과값:1537.90$, 예측값 :1821.42$
# 결과값:1058.95$, 예측값 :1069.31$
# 결과값:1044.12$, 예측값 :840.41$
# 결과값:1317.62$, 예측값 :1737.96$
# 결과값:1474.59$, 예측값 :1637.12$
# 결과값:1464.42$, 예측값 :2069.21$
# 결과값:2033.31$, 예측값 :2208.61$
# 결과값:1011.55$, 예측값 :1631.44$
# 결과값:977.83$, 예측값 :854.26$
# 결과값:1135.71$, 예측값 :1208.53$
# 결과값:1199.98$, 예측값 :970.14$
# 결과값:6829.35$, 예측값 :9913.18$
# 결과값:1366.28$, 예측값 :1716.48$
# 결과값:927.64$, 예측값 :1185.26$
# 결과값:1093.02$, 예측값 :1525.82$
# 결과값:1108.29$, 예측값 :1015.05$
# 결과값:1532.04$, 예측값 :568.81$
# 결과값:1473.68$, 예측값 :1638.41$
# 결과값:902.31$, 예측값 :1097.31$
# 결과값:2038.04$, 예측값 :2358.80$
# 결과값:1156.91$, 예측값 :920.52$
# 결과값:1460.31$, 예측값 :2466.84$
# 결과값:2095.89$, 예측값 :2244.66$
# 결과값:2939.19$, 예측값 :6918.33$
# 결과값:1347.34$, 예측값 :1248.02$
# 결과값:2322.22$, 예측값 :1462.36$
# 결과값:2123.38$, 예측값 :1922.09$
# 결과값:4861.95$, 예측값 :4877.49$
# 결과값:2596.11$, 예측값 :4122.80$
# 결과값:1624.24$, 예측값 :1749.81$
# 결과값:1115.81$, 예측값 :1085.81$
# 결과값:1399.57$, 예측값 :1618.12$
# 결과값:1969.80$, 예측값 :2108.06$
# 결과값:1041.72$, 예측값 :563.10$
# 결과값:1794.04$, 예측값 :1785.49$
# 결과값:1702.71$, 예측값 :1543.94$
# 결과값:2043.65$, 예측값 :2106.71$
# 결과값:1030.65$, 예측값 :1066.84$
# 결과값:1533.62$, 예측값 :1751.89$
# 결과값:1445.34$, 예측값 :1636.53$
# 결과값:3829.74$, 예측값 :4402.64$
# 결과값:1948.11$, 예측값 :3223.77$
# 결과값:2106.75$, 예측값 :2408.70$
# 결과값:848.80$, 예측값 :1089.64$
# 결과값:1170.83$, 예측값 :690.75$
# 결과값:1281.80$, 예측값 :1479.56$
# 결과값:1799.85$, 예측값 :1485.39$
# 결과값:1012.26$, 예측값 :1284.11$
# 결과값:2113.04$, 예측값 :2792.42$
# 결과값:1175.14$, 예측값 :1312.29$
# 결과값:1022.52$, 예측값 :816.96$
# 결과값:2069.41$, 예측값 :1870.95$
# 결과값:2014.73$, 예측값 :1835.86$
# 결과값:3122.16$, 예측값 :2128.60$
# 결과값:5309.69$, 예측값 :2793.48$
# 결과값:1165.41$, 예측값 :1073.28$
# 결과값:2101.62$, 예측값 :2546.64$
# 결과값:4029.32$, 예측값 :3257.51$
# 결과값:1537.39$, 예측값 :1771.31$
# 결과값:1987.22$, 예측값 :1886.98$
# 결과값:2047.47$, 예측값 :2420.90$
# 결과값:2274.17$, 예측값 :1545.07$
# 결과값:1970.49$, 예측값 :1683.55$
# 결과값:1474.41$, 예측값 :1843.50$
# 결과값:2551.39$, 예측값 :2294.55$
# 결과값:4510.98$, 예측값 :3294.95$
# 결과값:2533.68$, 예측값 :1976.69$
# 결과값:7247.40$, 예측값 :5844.47$
# 결과값:2223.08$, 예측값 :1749.32$
# 결과값:1660.49$, 예측값 :1198.95$
# 결과값:1717.94$, 예측값 :1500.29$
# 결과값:1504.10$, 예측값 :2601.04$
# 결과값:1718.73$, 예측값 :1877.16$
# 결과값:1723.88$, 예측값 :1626.25$
# 결과값:940.86$, 예측값 :1160.14$
# 결과값:1145.90$, 예측값 :833.61$
# 결과값:926.68$, 예측값 :1132.04$
# 결과값:1147.78$, 예측값 :984.12$
# 결과값:1352.82$, 예측값 :1268.91$
# 결과값:1587.81$, 예측값 :1541.35$
# 결과값:2784.33$, 예측값 :2248.75$
# 결과값:2066.16$, 예측값 :1958.67$
# 결과값:2044.11$, 예측값 :2519.51$
# 결과값:6086.00$, 예측값 :7858.45$
# 결과값:1698.05$, 예측값 :1727.39$
# 결과값:808.01$, 예측값 :729.22$
# 결과값:2057.27$, 예측값 :2851.45$
# 결과값:3664.60$, 예측값 :2678.27$
# 결과값:1972.37$, 예측값 :1420.20$
# 결과값:1116.82$, 예측값 :1079.97$
# 결과값:1445.15$, 예측값 :1389.08$
# 결과값:1444.09$, 예측값 :1361.54$
# 결과값:2568.78$, 예측값 :2350.55$
# 결과값:2204.14$, 예측값 :2806.59$
# 결과값:2785.64$, 예측값 :2197.42$
# 결과값:2179.32$, 예측값 :2138.12$
# 결과값:1672.34$, 예측값 :1647.58$
# 결과값:1931.92$, 예측값 :1594.91$
# 결과값:1063.04$, 예측값 :563.13$
# 결과값:2331.52$, 예측값 :2007.55$
# 결과값:1381.79$, 예측값 :1559.17$
# 결과값:2331.76$, 예측값 :2052.94$
# 결과값:2337.69$, 예측값 :2110.98$
# 결과값:13490.76$, 예측값 :13226.41$
# 결과값:2048.45$, 예측값 :2520.46$
# 결과값:1063.64$, 예측값 :1220.87$
# 결과값:4861.95$, 예측값 :4242.06$
# 결과값:1463.57$, 예측값 :1216.02$
# 결과값:1789.73$, 예측값 :1500.71$
# 결과값:2031.58$, 예측값 :1753.87$
# 결과값:6150.68$, 예측값 :3908.39$
# 결과값:1273.41$, 예측값 :1551.88$
# 결과값:1184.83$, 예측값 :1455.03$
# 결과값:2006.40$, 예측값 :1998.69$
# 결과값:2094.76$, 예측값 :2586.78$
# 결과값:2874.53$, 예측값 :2379.10$
# 결과값:1056.25$, 예측값 :675.73$
# 결과값:1424.92$, 예측값 :1515.08$
# 결과값:6087.33$, 예측값 :6499.01$
# 결과값:946.40$, 예측값 :732.79$
# 결과값:1034.69$, 예측값 :815.25$
# 결과값:2028.98$, 예측값 :2621.31$
# 결과값:2031.82$, 예측값 :1799.76$
# 결과값:994.18$, 예측값 :836.66$
# 결과값:2021.84$, 예측값 :2226.33$
# 결과값:2351.54$, 예측값 :2151.84$
# 결과값:2112.84$, 예측값 :1918.34$
# 결과값:962.18$, 예측값 :1095.37$
# 결과값:2080.00$, 예측값 :1969.61$
# 결과값:13262.90$, 예측값 :7017.53$
# 결과값:1752.65$, 예측값 :1629.53$
# 결과값:2033.24$, 예측값 :8568.63$
# 결과값:1960.82$, 예측값 :3180.55$
# 결과값:1063.09$, 예측값 :1371.00$
# 결과값:1526.62$, 예측값 :1734.31$
# 결과값:1100.09$, 예측값 :1229.33$
# 결과값:2076.53$, 예측값 :3209.02$
# 결과값:1751.48$, 예측값 :1417.65$
# 결과값:2018.05$, 예측값 :1975.22$
# 결과값:1169.51$, 예측값 :1521.77$
# 결과값:2467.91$, 예측값 :2151.29$
# 결과값:2044.65$, 예측값 :2221.95$
# 결과값:1975.64$, 예측값 :2086.77$
# 결과값:2070.48$, 예측값 :1941.89$
# Accuracy: 64.35   RMSE : 2698.42

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)

fig, axes = plt.subplots(1, 2,figsize = (12, 7), sharey = True)

prediction1 = prediction[prediction['label'] < 10000]
axes[0].plot(prediction1.index, prediction1['pred'],label='Prediction',        
        linestyle = '--',)
axes[0].plot(prediction1.index, prediction1['label'], label = 'Truth',
        linestyle = '--',)
axes[0].set_xticks([])
axes[0].legend()
axes[0].set_title("Price under 10000$")
prediction2 = prediction[prediction['label'] > 10000]
axes[1].plot(prediction2.index, prediction2['pred'],label='Prediction',        
        linestyle = '--',)
axes[1].plot(prediction2.index, prediction2['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
axes[1].set_xticks([])
axes[1].legend()
axes[1].set_title("Price over 10000$")
plt.ylabel('prices')
plt.show()
