# %%
import numpy as np

# %%
file = open("total.csv", 'r')
output = open("total_revised.csv", 'w')
data = file.readlines()
print(data)
# Out:
# ['Id,Shape,Weight,Clarity,Colour,Cut,Polish,Symmetry,Fluorescence,Length,Width,Depth,Price\n', '1638147,CUSHION,0.55,SI2,E,EX,EX,VG,N,5.05,4.35,2.94,1378.65\n', '1630155,CUSHION,0.5,VVS1,FANCY,EX,EX,VG,F,4.6,4.31,2.92,1379.74\n', '1612606,CUSHION,0.51,VS2,H,EX,EX,VG,N,4.71,4.35,2.94,1380.19\n', '1638140,CUSHION,0.5,VS2,H,EX,EX,VG,N,4.91,4.26,2.88,1380.61\n', '1536093,CUSHION,0.53,SI1,D,EX,VG,VG,N,4.7,4.46,3.01,1383.13\n', '1643527,CUSHION,0.52,VVS1,I,EX,EX,VG,N,4.76,4.42,2.99,1384.24\n', '1636092,CUSHION,0.5,SI1,E,VG,EX,VG,N,4.91,4.17,2.9,1385.91\n', '1648845,CUSHION,0.5,SI1,D,EX,EX,GD,N,4.89,4.24,2.84,1389.25\n', '1631332,CUSHION,0.55,VVS1,I,EX,EX,VG,N,4.69,4.5,3.04,1391.02\n', '1639565,CUSHION,0.55,VS1,H,EX,EX,EX,ST,4.78,4.52,3.04,1392.9\n', '1608375,CUSHION,0.91,SI1,M,EX,EX,EX,F,6.09,5.11,3.47,1393.76\n', '1623506,CUSHION,0.52,VS1,H,EX,EX,VG,M,4.64,4.48,3.03,1319.56\n', '1593561,CUSHION,0.5,VVS1,I,EX,EX,VG,N,4.63,4.33,2.92,1320.14\n', '1612588,CUSHION,0.71,VS1,K,EX,EX,VG,N,5.73,4.
# ...

# %%
output.write(data[0])
data = np.array(data[1:])
print(data)
# Out:
# ['1638147,CUSHION,0.55,SI2,E,EX,EX,VG,N,5.05,4.35,2.94,1378.65\n'
#  '1630155,CUSHION,0.5,VVS1,FANCY,EX,EX,VG,F,4.6,4.31,2.92,1379.74\n'
#  '1612606,CUSHION,0.51,VS2,H,EX,EX,VG,N,4.71,4.35,2.94,1380.19\n' ...
#  '1773024,ROUND,0.5,SI1,E,EX,EX,EX,N,5.03,5.06,3.16,2453.1\n'
#  '1774887,ROUND,0.52,SI1,H,EX,EX,EX,N,5.11,5.13,3.2,2453.41\n'
#  '1630512,ROUND,0.5,VS1,H,EX,EX,VG,N,5.09,5.13,3.12,2453.69\n']

# %%
data.sort()

# %%
print(data)
print(len(data))
# Out:
# ['111000-5962,CUSHION,1.01,I2,FANCY,EX,VG,VG,N,5.89,5.63,3.53,1155.27\n'
#  '111000-6281,CUSHION,1.19,I2,FANCY,EX,VG,GD,M,5.97,5.59,3.8,3638.36\n'
#  '111000-6305,OVAL,1.0,SI2,U-V,EX,EX,VG,M,8.47,5.39,3.42,2237.73\n' ...
#  '213090-252,PEAR,1.0,SI2,E,EX,VG,EX,N,8.7,5.58,3.46,5375.5\n'
#  '213129-141,PEAR,1.0,SI2,E,VG,VG,VG,N,8.5,5.43,3.39,4447.63\n'
#  'NY180424-54,CUSHION,4.0,VS2,H,EX,EX,EX,N,9.21,8.61,5.84,74875.06\n']
# 5063

# %%
data = np.unique(data)

# %%
print(len(data))
# Out:
# 4801

# %%
for line in data:
    output.write(line)
file.close()
output.close()
