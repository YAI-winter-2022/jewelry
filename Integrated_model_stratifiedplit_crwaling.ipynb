# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import random
import albumentations as A
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/'YAI 봄학기 Toy Project'
# Out:
# /content/drive/MyDrive/YAI 봄학기 Toy Project

# %%
csv_train_path = "train_append_re.csv"
csv_test_path = "test_append_re.csv"
csv_val_path = "val_append_re.csv"
image_path = "./images"
batch_size = 128 # CUDA out of memory로 인해 256 ~> 128 수정
epochs = 50 # 여러번 시도 했는데 50 근처에서 자꾸 런타임이 초기화 되네요...
learning_rate = 1e-3
seed = 42

# %%
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
class AllDataset(Dataset):
    def __init__(self, csv_path, image_path, image_transform=transforms.Compose([transforms.ToTensor()])):
        super(AllDataset).__init__()
        csv = pd.read_csv(csv_path)
        csv_np = csv.to_numpy()
        
        self.image_transform = image_transform
        self.ids = list(map(str, csv['Id']))
        self.image_path = image_path
        
        for i in [1, 3, 4, 5, 6, 7, 8]:
            wordset = {word: idx for idx, word in enumerate(np.unique(csv_np[:,i]))}
            for row in range(len(csv_np)):
                csv_np[row][i] = wordset[csv_np[row][i]]
        self.ints = torch.from_numpy(np.array(csv_np[:,[1,3,4,5,6,7,8]], dtype="int"))
        self.floats = torch.from_numpy(np.array(csv_np[:,[2,9,10,11]], dtype="float")).float()
        self.target = torch.from_numpy(np.array(csv_np[:,[12]], dtype="float")).float()
    
    
    def __getitem__(self,idx):
        return self.image_transform(Image.open(self.image_path+'/'+self.ids[idx]+'.jpg')), self.ints[idx],self.floats[idx], self.target[idx]
    
    
    def __len__(self):
        return len(self.ints)

# %%
image_transform = transforms.Compose([transforms.ToTensor()
                                     ])
train_dataset = AllDataset(csv_train_path, image_path, image_transform)
test_dataset = AllDataset(csv_test_path, image_path, image_transform)
val_dataset = AllDataset(csv_val_path, image_path, image_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Sequential(nn.Linear(512, 4096),
                                         nn.BatchNorm1d(4096),
                                         nn.ReLU(),
                                         nn.Dropout()
                                        )
        self.resenet18 = self.resnet18.to(device)
        
        self.emb1 = torch.nn.Embedding(8, 20)
        self.emb2 = torch.nn.Embedding(11, 20)
        self.emb3 = torch.nn.Embedding(20, 20)
        self.emb4 = torch.nn.Embedding(4, 20)
        self.emb5 = torch.nn.Embedding(4, 20)
        self.emb6 = torch.nn.Embedding(4, 20)
        self.emb7 = torch.nn.Embedding(7, 20)
        self.act = nn.ReLU()
        self.fc = nn.Linear(4, 80)
        self.csvbn = nn.BatchNorm1d(80)
        self.csvfc1 = nn.Linear(220, 8192)
        self.csvfc2 = nn.Linear(8192, 8192)
        self.csvfc3 = nn.Linear(8192, 4096)
        self.csvbn1 = nn.BatchNorm1d(8192)
        self.csvbn2 = nn.BatchNorm1d(8192)
        self.csvbn3 = nn.BatchNorm1d(4096)
        
        self.fc1 = nn.Linear(8192, 4096)
        self.fc2 = nn.Linear(4096, 1)
        self.bn1 = nn.BatchNorm1d(4096)
        self.dropout = nn.Dropout()
    
    def forward(self, image, x, y):
        image = self.resnet18(image)
        
        x1 = self.emb1(x[:,0])
        x2 = self.emb2(x[:,1])
        x3 = self.emb3(x[:,2])
        x4 = self.emb4(x[:,3])
        x5 = self.emb5(x[:,4])
        x6 = self.emb6(x[:,5])
        x7 = self.emb7(x[:,6])
        y = self.csvbn(self.fc(y))
        x = torch.cat((x1, x2, x3, x4, x5, x6, x7, y), dim=1)
        
        x = self.dropout(self.act(self.csvbn1(self.csvfc1(x))))
        x = self.dropout(self.act(self.csvbn2(self.csvfc2(x))))
        x = self.dropout(self.act(self.csvbn3(self.csvfc3(x))))
        x = torch.cat((x, image), dim=1)
        
        x = self.dropout(self.act(self.bn1(self.fc1(x))))
        return self.fc2(x)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
model = Net().to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

gc.collect()
torch.cuda.empty_cache()

# %%
for epoch in range(epochs):
    model.train()
    criterion.train()
    
    avg_loss = 0

    for Img, X1, X2, Y in train_loader:
        Img = Img.to(device)
        X1 = X1.to(device)
        X2 = X2.to(device)
        Y = Y.to(device)

        model.zero_grad()
        prediction = model(Img, X1, X2)
        loss = torch.sqrt(criterion(prediction, Y)).to(device)
        loss.backward()
        optimizer.step()
        avg_loss += loss / len(train_loader)
    print(f'[Epoch: {epoch+1:>2}] Average loss: {avg_loss:.4f}, ', end='')
    
    model.eval()
    criterion.eval()
    with torch.no_grad():
        val_avg_loss = 0.
        for Image_val, X1_val, X2_val, Y_val in val_loader:
            Image_val = Image_val.to(device)
            X1_val = X1_val.to(device)
            X2_val = X2_val.to(device)
            Y_val = Y_val.to(device)
            val_prediction = model(Image_val, X1_val, X2_val)
            val_loss = torch.sqrt(criterion(val_prediction, Y_val)).to(device)
            val_avg_loss += val_loss / len(val_loader)
        
        print(f"val_loss: {val_avg_loss:.4f}")
# Out:
# [Epoch:  1] Average loss: 20541.8105, val_loss: 18185.6152
# [Epoch:  2] Average loss: 20441.5020, val_loss: 18049.1055
# [Epoch:  3] Average loss: 20289.6660, val_loss: 17708.9727
# [Epoch:  4] Average loss: 20089.0508, val_loss: 17798.3438
# [Epoch:  5] Average loss: 19908.1680, val_loss: 17646.3965
# [Epoch:  6] Average loss: 19652.0547, val_loss: 17339.4004
# [Epoch:  7] Average loss: 19401.2617, val_loss: 17421.5352
# [Epoch:  8] Average loss: 19100.3496, val_loss: 16844.9355
# [Epoch:  9] Average loss: 18835.0098, val_loss: 16947.7812
# [Epoch: 10] Average loss: 18505.1660, val_loss: 16488.2500
# [Epoch: 11] Average loss: 18154.7617, val_loss: 16095.3350
# [Epoch: 12] Average loss: 17798.5000, val_loss: 15959.0615
# [Epoch: 13] Average loss: 17388.8105, val_loss: 15338.6406
# [Epoch: 14] Average loss: 16961.9141, val_loss: 15174.6270
# [Epoch: 15] Average loss: 16506.7930, val_loss: 14558.5615
# [Epoch: 16] Average loss: 16041.2744, val_loss: 15253.3232
# [Epoch: 17] Average loss: 15496.9326, val_loss: 14286.7715
# [Epoch: 18] Average loss: 14991.6494, val_loss: 13630.8945
# [Epoch: 19] Average loss: 14452.6855, val_loss: 13696.5957
# [Epoch: 20] Average loss: 13891.8877, val_loss: 12508.7832
# [Epoch: 21] Average loss: 13297.8428, val_loss: 11884.5957
# [Epoch: 22] Average loss: 12699.8701, val_loss: 12457.4268
# [Epoch: 23] Average loss: 12066.3213, val_loss: 10896.8066
# [Epoch: 24] Average loss: 11429.3408, val_loss: 10627.6377
# [Epoch: 25] Average loss: 10721.8955, val_loss: 9590.6943
# [Epoch: 26] Average loss: 10043.5000, val_loss: 9604.0742
# [Epoch: 27] Average loss: 9326.9150, val_loss: 10662.1592
# [Epoch: 28] Average loss: 8575.2812, val_loss: 8273.7656
# [Epoch: 29] Average loss: 7828.7803, val_loss: 7993.6641
# [Epoch: 30] Average loss: 7133.5044, val_loss: 6337.0474
# [Epoch: 31] Average loss: 6377.1484, val_loss: 7354.7222
# [Epoch: 32] Average loss: 5729.7759, val_loss: 7193.7388
# [Epoch: 33] Average loss: 5008.5757, val_loss: 7418.4395
# [Epoch: 34] Average loss: 4514.9209, val_loss: 5408.9927
# [Epoch: 35] Average loss: 4079.2981, val_loss: 5959.5483
# [Epoch: 36] Average loss: 3552.7834, val_loss: 4316.1885
# [Epoch: 37] Average loss: 3294.4531, val_loss: 4009.9761
# [Epoch: 38] Average loss: 3284.6741, val_loss: 4000.8975
# [Epoch: 39] Average loss: 3074.0544, val_loss: 5565.3408
# [Epoch: 40] Average loss: 2699.1846, val_loss: 3879.6411
# [Epoch: 41] Average loss: 2541.3970, val_loss: 4042.1191
# [Epoch: 42] Average loss: 2443.2449, val_loss: 4147.2427
# [Epoch: 43] Average loss: 2291.9644, val_loss: 4174.7832
# [Epoch: 44] Average loss: 2523.2261, val_loss: 4280.9487
# [Epoch: 45] Average loss: 2384.0364, val_loss: 3697.8701
# [Epoch: 46] Average loss: 2262.8840, val_loss: 3949.5659
# [Epoch: 47] Average loss: 2199.8042, val_loss: 5061.4854
# [Epoch: 48] Average loss: 2550.7722, val_loss: 3804.4094
# [Epoch: 49] Average loss: 2154.7546, val_loss: 4336.6621
# [Epoch: 50] Average loss: 2287.2620, val_loss: 3563.4795

# %%
PATH = './'
Name = 'model_stfsplit_crwaling.pt'
torch.save(model.state_dict(), PATH+Name)

# %%
RMSEs = []
accuracys = []

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 20000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    accuracys.append(accuracy)
    RMSEs.append(RMSE)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}",)
# Out:
# 결과값:27591.72$, 예측값 :26141.65$
# 결과값:29369.75$, 예측값 :34155.71$
# 결과값:27314.91$, 예측값 :29939.36$
# 결과값:23349.63$, 예측값 :18476.91$
# 결과값:34211.50$, 예측값 :34625.83$
# 결과값:20068.89$, 예측값 :26177.23$
# 결과값:43612.11$, 예측값 :43805.11$
# 결과값:20280.75$, 예측값 :24212.47$
# 결과값:35410.46$, 예측값 :42775.67$
# 결과값:29117.12$, 예측값 :37552.50$
# 결과값:23207.22$, 예측값 :12999.92$
# 결과값:45052.80$, 예측값 :24028.07$
# 결과값:31911.25$, 예측값 :33387.61$
# 결과값:34346.46$, 예측값 :31442.74$
# 결과값:51524.24$, 예측값 :68921.63$
# 결과값:52848.73$, 예측값 :30864.24$
# 결과값:42905.79$, 예측값 :18572.60$
# 결과값:22188.46$, 예측값 :20963.46$
# 결과값:33397.60$, 예측값 :30975.05$
# 결과값:61536.29$, 예측값 :72237.87$
# 결과값:28308.82$, 예측값 :32114.80$
# 결과값:32885.75$, 예측값 :28602.76$
# 결과값:45024.69$, 예측값 :22290.29$
# 결과값:25577.43$, 예측값 :29833.26$
# 결과값:26746.08$, 예측값 :33546.86$
# 결과값:68659.03$, 예측값 :25363.80$
# 결과값:26625.14$, 예측값 :33478.31$
# 결과값:40999.92$, 예측값 :24099.75$
# 결과값:57498.09$, 예측값 :55470.55$
# 결과값:37042.20$, 예측값 :19403.54$
# 결과값:26308.95$, 예측값 :18072.89$
# 결과값:36908.43$, 예측값 :21086.98$
# 결과값:23028.91$, 예측값 :28810.66$
# 결과값:66986.79$, 예측값 :49297.07$
# 결과값:49105.46$, 예측값 :22703.77$
# 결과값:38007.72$, 예측값 :48505.21$
# 결과값:36709.39$, 예측값 :22488.63$
# 결과값:41079.67$, 예측값 :26196.50$
# 결과값:22917.52$, 예측값 :33953.95$
# 결과값:43849.17$, 예측값 :19222.30$
# 결과값:21725.54$, 예측값 :25638.14$
# 결과값:58437.60$, 예측값 :59078.93$
# 결과값:23901.09$, 예측값 :15762.32$
# 결과값:38667.58$, 예측값 :46506.12$
# 결과값:40852.38$, 예측값 :51676.94$
# 결과값:22295.68$, 예측값 :31933.82$
# 결과값:21170.51$, 예측값 :26028.31$
# 결과값:30959.82$, 예측값 :17372.99$
# 결과값:22023.28$, 예측값 :30080.50$
# 결과값:55489.43$, 예측값 :22004.50$
# 결과값:27119.82$, 예측값 :15832.47$
# 결과값:55121.16$, 예측값 :54731.38$
# 결과값:41077.42$, 예측값 :19385.95$
# 결과값:27950.91$, 예측값 :23825.22$
# 결과값:53764.84$, 예측값 :23938.19$
# 결과값:64372.54$, 예측값 :36631.15$
# 결과값:21631.88$, 예측값 :17929.96$
# 결과값:30920.20$, 예측값 :34858.37$
# 결과값:25055.64$, 예측값 :17776.18$
# 결과값:38599.92$, 예측값 :37914.39$
# 결과값:21597.14$, 예측값 :9252.42$
# 결과값:30493.40$, 예측값 :23630.68$
# 결과값:54628.83$, 예측값 :23933.43$
# 결과값:26351.57$, 예측값 :16796.46$
# 결과값:33980.23$, 예측값 :16790.03$
# 결과값:50279.42$, 예측값 :43425.57$
# 결과값:21823.85$, 예측값 :14667.10$
# 결과값:48878.47$, 예측값 :49775.21$
# 결과값:44591.90$, 예측값 :19660.52$
# 결과값:26256.28$, 예측값 :42308.63$
# 결과값:31533.98$, 예측값 :35240.77$
# 결과값:70749.53$, 예측값 :45726.54$
# 결과값:58291.08$, 예측값 :54311.74$
# 결과값:36516.67$, 예측값 :43257.18$
# 결과값:26926.69$, 예측값 :10841.53$
# 결과값:33543.70$, 예측값 :13935.24$
# 결과값:25135.50$, 예측값 :27668.16$
# 결과값:26863.06$, 예측값 :39435.13$
# 결과값:58468.02$, 예측값 :25421.41$
# 결과값:21269.26$, 예측값 :45259.94$
# 결과값:37187.48$, 예측값 :41748.13$
# 결과값:56175.76$, 예측값 :29200.31$
# 결과값:28995.88$, 예측값 :37865.34$
# 결과값:41613.86$, 예측값 :52125.08$
# 결과값:50439.17$, 예측값 :59853.81$
# 결과값:46774.57$, 예측값 :23256.90$
# 결과값:21341.85$, 예측값 :21390.51$
# 결과값:29978.80$, 예측값 :42652.18$
# 결과값:20647.68$, 예측값 :24254.16$
# 결과값:24718.20$, 예측값 :15998.43$
# 결과값:42250.88$, 예측값 :23581.91$
# 결과값:37633.44$, 예측값 :38349.58$
# 결과값:26160.00$, 예측값 :38894.52$
# 결과값:34948.31$, 예측값 :26602.57$
# 결과값:30428.44$, 예측값 :41171.50$
# 결과값:33248.83$, 예측값 :36341.79$
# 결과값:35524.48$, 예측값 :33405.70$
# 결과값:49865.46$, 예측값 :31131.90$
# 결과값:37005.07$, 예측값 :23923.34$
# 결과값:24688.75$, 예측값 :34924.32$
# 결과값:69297.88$, 예측값 :24665.99$
# 결과값:20295.30$, 예측값 :38966.50$
# 결과값:24389.96$, 예측값 :16982.25$
# 결과값:50569.24$, 예측값 :20565.46$
# 결과값:25383.84$, 예측값 :27927.89$
# 결과값:25612.14$, 예측값 :35436.47$
# 결과값:31098.54$, 예측값 :25526.15$
# 결과값:23199.27$, 예측값 :26081.83$
# 결과값:23679.82$, 예측값 :38554.16$
# 결과값:21268.81$, 예측값 :18270.83$
# 결과값:26064.87$, 예측값 :27895.56$
# 결과값:28864.68$, 예측값 :19328.67$
# 결과값:47297.70$, 예측값 :24290.74$
# 결과값:28335.84$, 예측값 :18739.93$
# 결과값:22499.57$, 예측값 :20045.72$
# 결과값:57017.00$, 예측값 :25526.61$
# 결과값:28291.89$, 예측값 :24011.70$
# 결과값:41953.28$, 예측값 :48763.34$
# 결과값:64620.82$, 예측값 :22290.24$
# 결과값:40078.74$, 예측값 :24082.95$
# 결과값:47167.24$, 예측값 :18167.66$
# 결과값:20139.90$, 예측값 :25343.95$
# 결과값:39855.05$, 예측값 :43988.96$
# 결과값:21273.74$, 예측값 :38295.68$
# 결과값:41870.40$, 예측값 :29677.47$
# 결과값:64608.96$, 예측값 :66149.20$
# 결과값:61111.33$, 예측값 :22356.90$
# 결과값:28861.48$, 예측값 :13734.46$
# 결과값:34571.88$, 예측값 :23716.28$
# 결과값:21864.34$, 예측값 :36165.77$
# 결과값:27909.02$, 예측값 :37297.65$
# 결과값:49596.35$, 예측값 :46449.47$
# 결과값:39042.12$, 예측값 :39774.61$
# 결과값:27551.75$, 예측값 :16988.84$
# 결과값:28881.90$, 예측값 :17695.52$
# 결과값:43204.90$, 예측값 :18855.44$
# 결과값:27424.80$, 예측값 :17321.95$
# 결과값:34225.71$, 예측값 :27802.14$
# 결과값:63873.39$, 예측값 :35234.00$
# 결과값:33864.78$, 예측값 :37244.12$
# 결과값:43603.15$, 예측값 :23182.65$
# 결과값:30836.52$, 예측값 :21146.77$
# 결과값:26130.53$, 예측값 :35035.00$
# 결과값:23972.19$, 예측값 :14745.42$
# 결과값:20507.17$, 예측값 :23298.82$
# 결과값:61698.95$, 예측값 :22367.60$
# 결과값:55834.65$, 예측값 :22675.71$
# 결과값:62259.60$, 예측값 :61095.58$
# 결과값:41719.09$, 예측값 :46729.96$
# 결과값:20612.37$, 예측값 :17923.03$
# 결과값:27628.26$, 예측값 :20476.37$
# 결과값:27505.31$, 예측값 :32044.48$
# 결과값:25617.52$, 예측값 :26366.76$
# 결과값:33085.57$, 예측값 :38721.36$
# 결과값:27068.73$, 예측값 :15651.20$
# 결과값:20676.24$, 예측값 :13547.79$
# 결과값:26932.46$, 예측값 :19124.62$
# 결과값:64294.39$, 예측값 :48508.59$
# 결과값:20920.19$, 예측값 :26111.25$
# 결과값:21931.09$, 예측값 :24205.95$
# 결과값:32102.37$, 예측값 :37842.36$
# 결과값:33296.64$, 예측값 :38605.64$
# 결과값:40003.27$, 예측값 :17385.60$
# 결과값:22009.90$, 예측값 :13483.23$
# 결과값:20586.85$, 예측값 :32173.24$
# 결과값:30774.12$, 예측값 :29961.67$
# 결과값:23495.78$, 예측값 :14041.67$
# 결과값:68617.96$, 예측값 :26955.56$
# 결과값:40273.43$, 예측값 :40808.77$
# 결과값:61631.84$, 예측값 :34740.80$
# 결과값:63271.35$, 예측값 :54475.66$
# 결과값:31859.88$, 예측값 :51492.87$
# 결과값:26611.96$, 예측값 :28707.44$
# 결과값:34746.72$, 예측값 :37486.40$
# 결과값:21570.62$, 예측값 :26381.43$
# 결과값:22571.78$, 예측값 :12609.53$
# 결과값:24578.10$, 예측값 :13640.23$
# 결과값:50554.25$, 예측값 :29203.38$
# 결과값:33530.73$, 예측값 :21374.98$
# 결과값:35055.12$, 예측값 :42326.94$
# 결과값:33859.16$, 예측값 :47840.43$
# 결과값:35983.13$, 예측값 :49205.62$
# 결과값:27205.50$, 예측값 :31333.22$
# 결과값:23700.97$, 예측값 :31522.23$
# 결과값:32303.92$, 예측값 :31130.06$
# 결과값:20344.27$, 예측값 :30937.87$
# 결과값:64372.54$, 예측값 :26528.93$
# 결과값:27922.66$, 예측값 :41652.98$
# 결과값:20419.78$, 예측값 :30932.90$
# 결과값:47252.40$, 예측값 :45174.49$
# 결과값:25244.54$, 예측값 :16782.79$
# 결과값:22167.26$, 예측값 :38094.85$
# 결과값:29562.00$, 예측값 :38081.34$
# 결과값:49964.93$, 예측값 :22798.48$
# 결과값:36689.98$, 예측값 :48928.86$
# 결과값:22980.98$, 예측값 :10040.47$
# 결과값:21277.73$, 예측값 :23563.74$
# 결과값:24460.13$, 예측값 :19596.90$
# 결과값:55408.52$, 예측값 :40784.84$
# 결과값:22799.87$, 예측값 :27647.22$
# 결과값:25034.76$, 예측값 :21075.69$
# 결과값:20483.38$, 예측값 :26560.40$
# 결과값:23272.44$, 예측값 :27074.67$
# 결과값:32951.72$, 예측값 :38725.87$
# 결과값:28350.11$, 예측값 :33206.20$
# 결과값:23504.41$, 예측값 :23397.98$
# 결과값:54478.32$, 예측값 :51907.41$
# 결과값:25346.44$, 예측값 :29970.64$
# 결과값:38190.98$, 예측값 :24300.90$
# 결과값:25202.39$, 예측값 :17721.38$
# 결과값:44832.26$, 예측값 :44731.35$
# 결과값:21068.75$, 예측값 :24696.74$
# 결과값:29581.89$, 예측값 :19500.96$
# 결과값:37297.65$, 예측값 :27127.31$
# 결과값:20633.28$, 예측값 :17833.67$
# 결과값:23887.50$, 예측값 :31290.36$
# 결과값:20425.49$, 예측값 :26139.06$
# 결과값:34184.09$, 예측값 :46674.84$
# 결과값:43216.40$, 예측값 :50138.29$
# 결과값:20418.11$, 예측값 :21013.91$
# 결과값:22801.15$, 예측값 :15267.51$
# 결과값:52687.05$, 예측값 :62560.17$
# 결과값:33785.08$, 예측값 :39550.45$
# 결과값:25441.10$, 예측값 :27858.38$
# 결과값:63065.18$, 예측값 :23302.86$
# 결과값:24901.69$, 예측값 :17361.03$
# 결과값:29107.42$, 예측값 :19441.66$
# 결과값:46884.32$, 예측값 :43274.66$
# 결과값:47478.60$, 예측값 :51474.07$
# 결과값:64839.84$, 예측값 :48298.39$
# 결과값:32800.56$, 예측값 :24991.44$
# 결과값:29651.08$, 예측값 :29479.15$
# 결과값:53998.15$, 예측값 :30127.76$
# 결과값:46719.55$, 예측값 :17951.26$
# 결과값:20158.59$, 예측값 :25932.14$
# 결과값:41917.20$, 예측값 :48394.71$
# 결과값:49075.34$, 예측값 :45338.61$
# 결과값:21735.81$, 예측값 :15306.40$
# 결과값:63965.99$, 예측값 :32455.44$
# 결과값:22106.31$, 예측값 :23224.35$
# 결과값:38379.10$, 예측값 :16367.73$
# 결과값:31337.89$, 예측값 :44003.33$
# 결과값:45657.41$, 예측값 :28671.53$
# 결과값:41371.20$, 예측값 :33987.30$
# 결과값:24146.99$, 예측값 :39828.64$
# 결과값:21091.67$, 예측값 :12314.49$
# 결과값:49340.63$, 예측값 :22443.56$
# 결과값:25091.01$, 예측값 :31374.81$
# 결과값:20568.97$, 예측값 :22353.19$
# 결과값:29512.98$, 예측값 :30498.27$
# 결과값:32632.75$, 예측값 :36407.62$
# 결과값:38389.60$, 예측값 :27551.16$
# 결과값:33370.94$, 예측값 :16852.76$
# 결과값:24656.52$, 예측값 :33444.56$
# 결과값:36431.97$, 예측값 :52243.67$
# 결과값:40466.40$, 예측값 :46832.22$
# 결과값:29871.82$, 예측값 :28941.26$
# 결과값:20148.51$, 예측값 :27576.12$
# 결과값:63530.73$, 예측값 :48529.79$
# 결과값:38149.61$, 예측값 :15842.14$
# 결과값:35719.12$, 예측값 :47299.94$
# 결과값:25038.87$, 예측값 :23633.71$
# 결과값:56407.68$, 예측값 :26615.94$
# 결과값:26213.40$, 예측값 :29655.37$
# 결과값:31369.32$, 예측값 :38927.38$
# 결과값:23325.59$, 예측값 :17531.10$
# 결과값:49799.86$, 예측값 :20465.00$
# 결과값:20128.93$, 예측값 :12585.60$
# 결과값:69759.86$, 예측값 :57068.81$
# 결과값:20929.08$, 예측값 :26211.26$
# 결과값:23169.18$, 예측값 :26883.68$
# 결과값:20173.51$, 예측값 :13554.11$
# 결과값:67290.13$, 예측값 :67886.40$
# 결과값:41660.11$, 예측값 :48825.07$
# 결과값:20568.60$, 예측값 :27800.19$
# 결과값:45322.82$, 예측값 :49163.23$
# 결과값:31056.48$, 예측값 :14776.54$
# 결과값:29596.65$, 예측값 :43628.12$
# 결과값:30834.02$, 예측값 :17889.42$
# 결과값:62247.12$, 예측값 :63694.19$
# 결과값:35863.89$, 예측값 :41619.54$
# 결과값:38225.91$, 예측값 :19255.11$
# 결과값:49484.99$, 예측값 :21670.85$
# 결과값:34232.64$, 예측값 :45567.77$
# 결과값:51362.03$, 예측값 :22123.41$
# 결과값:20860.01$, 예측값 :11575.01$
# 결과값:49397.98$, 예측값 :61319.11$
# 결과값:44619.79$, 예측값 :46527.15$
# 결과값:23382.75$, 예측값 :34813.83$
# 결과값:30082.42$, 예측값 :24543.20$
# 결과값:26450.86$, 예측값 :14061.26$
# 결과값:31199.25$, 예측값 :32647.18$
# 결과값:68574.48$, 예측값 :22308.80$
# 결과값:26083.82$, 예측값 :27403.18$
# 결과값:27634.20$, 예측값 :36813.43$
# 결과값:52699.97$, 예측값 :57399.63$
# 결과값:20965.96$, 예측값 :9786.39$
# 결과값:21579.42$, 예측값 :22528.81$
# 결과값:41953.98$, 예측값 :28300.58$
# 결과값:30273.44$, 예측값 :29716.26$
# 결과값:45836.54$, 예측값 :27895.68$
# 결과값:59670.09$, 예측값 :25626.77$
# 결과값:22891.14$, 예측값 :12740.08$
# 결과값:49176.27$, 예측값 :15940.03$
# 결과값:45057.48$, 예측값 :35978.48$
# 결과값:38228.78$, 예측값 :15897.54$
# 결과값:47296.08$, 예측값 :27354.02$
# 결과값:28005.62$, 예측값 :17121.55$
# 결과값:25659.50$, 예측값 :18408.43$
# 결과값:60768.12$, 예측값 :61030.92$
# 결과값:27946.11$, 예측값 :34490.12$
# 결과값:22399.73$, 예측값 :21603.50$
# 결과값:22235.62$, 예측값 :16996.61$
# 결과값:30895.80$, 예측값 :20797.36$
# 결과값:20564.19$, 예측값 :24090.11$
# 결과값:45801.04$, 예측값 :33300.83$
# 결과값:52137.95$, 예측값 :47763.28$
# 결과값:21132.06$, 예측값 :13536.89$
# 결과값:67738.23$, 예측값 :51795.37$
# 결과값:25892.41$, 예측값 :36532.34$
# 결과값:31780.32$, 예측값 :18172.88$
# 결과값:24933.36$, 예측값 :15925.22$
# 결과값:57439.15$, 예측값 :62195.07$
# 결과값:25334.40$, 예측값 :38550.34$
# 결과값:39034.32$, 예측값 :44235.73$
# 결과값:35416.68$, 예측값 :25828.94$
# 결과값:27902.71$, 예측값 :36746.84$
# 결과값:41928.12$, 예측값 :21302.74$
# 결과값:29404.60$, 예측값 :15483.00$
# 결과값:31342.97$, 예측값 :24535.06$
# 결과값:20398.14$, 예측값 :24319.71$
# 결과값:35880.23$, 예측값 :39636.80$
# 결과값:40836.71$, 예측값 :29214.62$
# 결과값:24027.79$, 예측값 :27373.05$
# 결과값:25017.10$, 예측값 :13567.83$
# 결과값:41407.39$, 예측값 :28262.28$
# 결과값:20455.34$, 예측값 :23339.90$
# 결과값:27388.00$, 예측값 :28808.53$
# 결과값:42306.20$, 예측값 :25667.57$
# 결과값:30784.37$, 예측값 :36325.47$
# 결과값:28443.36$, 예측값 :34997.87$
# 결과값:67065.04$, 예측값 :69720.34$
# 결과값:57991.13$, 예측값 :31188.26$
# 결과값:31817.76$, 예측값 :35740.52$
# 결과값:55114.43$, 예측값 :52281.01$
# 결과값:34002.34$, 예측값 :44907.01$
# 결과값:24964.93$, 예측값 :26565.47$
# 결과값:26046.90$, 예측값 :35259.75$
# 결과값:41085.99$, 예측값 :47037.42$
# 결과값:40550.62$, 예측값 :45910.50$
# 결과값:27413.43$, 예측값 :38849.36$
# 결과값:44632.77$, 예측값 :21271.85$
# 결과값:49931.34$, 예측값 :44089.87$
# 결과값:29551.97$, 예측값 :33885.94$
# 결과값:39604.91$, 예측값 :17279.12$
# 결과값:66413.49$, 예측값 :46433.79$
# 결과값:61067.60$, 예측값 :25963.81$
# 결과값:20560.96$, 예측값 :11154.81$
# 결과값:25584.00$, 예측값 :17069.80$
# 결과값:32381.79$, 예측값 :33416.60$
# 결과값:46999.18$, 예측값 :22318.89$
# 결과값:28482.54$, 예측값 :33858.20$
# 결과값:32098.84$, 예측값 :33368.72$
# 결과값:20503.13$, 예측값 :35014.30$
# 결과값:24041.22$, 예측값 :16380.41$
# 결과값:55856.35$, 예측값 :58767.81$
# 결과값:44230.99$, 예측값 :48003.63$
# 결과값:23814.90$, 예측값 :18159.18$
# 결과값:34268.68$, 예측값 :24111.59$
# 결과값:20141.22$, 예측값 :18243.30$
# 결과값:26632.32$, 예측값 :18356.27$
# 결과값:40908.44$, 예측값 :46307.34$
# 결과값:34224.76$, 예측값 :25920.23$
# 결과값:33490.42$, 예측값 :21858.00$
# 결과값:21648.12$, 예측값 :19761.15$
# 결과값:45075.72$, 예측값 :47568.10$
# 결과값:30234.83$, 예측값 :30601.16$
# 결과값:21155.78$, 예측값 :13827.21$
# 결과값:26153.60$, 예측값 :10747.91$
# 결과값:21089.69$, 예측값 :26592.29$
# 결과값:43163.33$, 예측값 :44194.01$
# 결과값:27122.16$, 예측값 :13715.53$
# 결과값:26685.53$, 예측값 :10884.00$
# 결과값:20656.12$, 예측값 :25560.67$
# 결과값:20734.32$, 예측값 :16701.18$
# 결과값:63276.72$, 예측값 :61810.24$
# 결과값:49707.29$, 예측값 :54130.71$
# 결과값:63577.08$, 예측값 :36790.14$
# 결과값:31103.12$, 예측값 :16154.20$
# 결과값:56131.02$, 예측값 :53818.07$
# 결과값:37753.27$, 예측값 :31699.80$
# 결과값:50138.79$, 예측값 :52930.11$
# 결과값:37691.55$, 예측값 :14734.04$
# 결과값:29260.48$, 예측값 :18807.74$
# 결과값:21547.23$, 예측값 :26470.83$
# 결과값:21292.03$, 예측값 :11044.52$
# 결과값:36331.53$, 예측값 :36268.36$
# 결과값:57774.21$, 예측값 :68805.65$
# 결과값:20500.37$, 예측값 :26093.41$
# 결과값:27329.64$, 예측값 :13263.59$
# 결과값:39880.62$, 예측값 :23998.38$
# 결과값:52930.41$, 예측값 :42601.99$
# 결과값:36866.22$, 예측값 :45406.70$
# 결과값:29652.40$, 예측값 :21467.86$
# 결과값:22785.34$, 예측값 :21411.09$
# 결과값:48094.80$, 예측값 :46680.34$
# 결과값:21373.06$, 예측값 :28824.29$
# 결과값:23587.59$, 예측값 :24182.97$
# 결과값:50907.51$, 예측값 :24926.98$
# 결과값:42906.55$, 예측값 :50315.46$
# 결과값:39272.56$, 예측값 :56650.57$
# 결과값:66450.93$, 예측값 :58351.82$
# 결과값:58721.83$, 예측값 :61941.54$
# 결과값:34039.04$, 예측값 :38817.01$
# 결과값:41684.93$, 예측값 :25150.29$
# 결과값:49595.52$, 예측값 :57366.11$
# 결과값:42701.88$, 예측값 :15356.35$
# 결과값:25803.49$, 예측값 :29330.21$
# 결과값:27705.68$, 예측값 :27796.29$
# 결과값:61082.46$, 예측값 :55298.93$
# 결과값:52363.90$, 예측값 :25040.54$
# 결과값:33084.11$, 예측값 :37828.55$
# 결과값:67113.49$, 예측값 :66546.35$
# 결과값:47515.73$, 예측값 :48212.61$
# 결과값:20166.87$, 예측값 :22964.67$
# 결과값:43148.04$, 예측값 :25091.79$
# 결과값:22582.79$, 예측값 :30129.60$
# Accuracy: -7.96   RMSE : 13964.04

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 20,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 15000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:57774.21$, 예측값 :68805.65$
# 결과값:36516.67$, 예측값 :43257.18$
# 결과값:37005.07$, 예측값 :23923.34$
# 결과값:45657.41$, 예측값 :28671.53$
# 결과값:51362.03$, 예측값 :22123.41$
# 결과값:31369.32$, 예측값 :38927.38$
# 결과값:21648.12$, 예측값 :19761.15$
# 결과값:64839.84$, 예측값 :48298.39$
# 결과값:35863.89$, 예측값 :41619.54$
# 결과값:21579.42$, 예측값 :22528.81$
# 결과값:36866.22$, 예측값 :45406.70$
# 결과값:43163.33$, 예측값 :44194.01$
# 결과값:39880.62$, 예측값 :23998.38$
# 결과값:22891.14$, 예측값 :12740.08$
# 결과값:24389.96$, 예측값 :16982.25$
# 결과값:44230.99$, 예측값 :48003.63$
# 결과값:16186.73$, 예측값 :22953.72$
# 결과값:20503.13$, 예측값 :35014.30$
# 결과값:40852.38$, 예측값 :51676.94$
# 결과값:21931.09$, 예측값 :24205.95$
# 결과값:25659.50$, 예측값 :18408.43$
# 결과값:23587.59$, 예측값 :24182.97$
# 결과값:18681.64$, 예측값 :20734.49$
# 결과값:23199.27$, 예측값 :26081.83$
# 결과값:22582.79$, 예측값 :30129.60$
# 결과값:23207.22$, 예측값 :12999.92$
# 결과값:66986.79$, 예측값 :49297.07$
# 결과값:21864.34$, 예측값 :36165.77$
# 결과값:33980.23$, 예측값 :16790.03$
# 결과값:20158.59$, 예측값 :25932.14$
# 결과값:20483.38$, 예측값 :26560.40$
# 결과값:20586.85$, 예측값 :32173.24$
# 결과값:28443.36$, 예측값 :34997.87$
# 결과값:43216.40$, 예측값 :50138.29$
# 결과값:45836.54$, 예측값 :27895.68$
# 결과값:46719.55$, 예측값 :17951.26$
# 결과값:20128.93$, 예측값 :12585.60$
# 결과값:16216.19$, 예측값 :22206.17$
# 결과값:33785.08$, 예측값 :39550.45$
# 결과값:48878.47$, 예측값 :49775.21$
# 결과값:25346.44$, 예측값 :29970.64$
# 결과값:40908.44$, 예측값 :46307.34$
# 결과값:29581.89$, 예측값 :19500.96$
# 결과값:40466.40$, 예측값 :46832.22$
# 결과값:26685.53$, 예측값 :10884.00$
# 결과값:20507.17$, 예측값 :23298.82$
# 결과값:26064.87$, 예측값 :27895.56$
# 결과값:24460.13$, 예측값 :19596.90$
# 결과값:55408.52$, 예측값 :40784.84$
# 결과값:26625.14$, 예측값 :33478.31$
# 결과값:39604.91$, 예측값 :17279.12$
# 결과값:30428.44$, 예측값 :41171.50$
# 결과값:56175.76$, 예측값 :29200.31$
# 결과값:24933.36$, 예측값 :15925.22$
# 결과값:41917.20$, 예측값 :48394.71$
# 결과값:34225.71$, 예측값 :27802.14$
# 결과값:29551.97$, 예측값 :33885.94$
# 결과값:22295.68$, 예측값 :31933.82$
# 결과값:23814.90$, 예측값 :18159.18$
# 결과값:21170.51$, 예측값 :26028.31$
# 결과값:21269.26$, 예측값 :45259.94$
# 결과값:34211.50$, 예측값 :34625.83$
# 결과값:30082.42$, 예측값 :24543.20$
# 결과값:33490.42$, 예측값 :21858.00$
# 결과값:26213.40$, 예측값 :29655.37$
# 결과값:58437.60$, 예측값 :59078.93$
# 결과값:63965.99$, 예측값 :32455.44$
# 결과값:64620.82$, 예측값 :22290.24$
# 결과값:26308.95$, 예측값 :18072.89$
# 결과값:38389.60$, 예측값 :27551.16$
# 결과값:26863.06$, 예측값 :39435.13$
# 결과값:25334.40$, 예측값 :38550.34$
# 결과값:31199.25$, 예측값 :32647.18$
# 결과값:61536.29$, 예측값 :72237.87$
# 결과값:30774.12$, 예측값 :29961.67$
# 결과값:60768.12$, 예측값 :61030.92$
# 결과값:57991.13$, 예측값 :31188.26$
# 결과값:23887.50$, 예측값 :31290.36$
# 결과값:39042.12$, 예측값 :39774.61$
# 결과값:57439.15$, 예측값 :62195.07$
# 결과값:36709.39$, 예측값 :22488.63$
# 결과값:38599.92$, 예측값 :37914.39$
# 결과값:33248.83$, 예측값 :36341.79$
# 결과값:23169.18$, 예측값 :26883.68$
# 결과값:37691.55$, 예측값 :14734.04$
# 결과값:25038.87$, 예측값 :23633.71$
# 결과값:44632.77$, 예측값 :21271.85$
# 결과값:38667.58$, 예측값 :46506.12$
# 결과값:20398.14$, 예측값 :24319.71$
# 결과값:49799.86$, 예측값 :20465.00$
# 결과값:27922.66$, 예측값 :41652.98$
# 결과값:55121.16$, 예측값 :54731.38$
# 결과값:34746.72$, 예측값 :37486.40$
# 결과값:26611.96$, 예측값 :28707.44$
# 결과값:22399.73$, 예측값 :21603.50$
# 결과값:29978.80$, 예측값 :42652.18$
# 결과값:23495.78$, 예측값 :14041.67$
# 결과값:45057.48$, 예측값 :35978.48$
# 결과값:20418.11$, 예측값 :21013.91$
# 결과값:38379.10$, 예측값 :16367.73$
# 결과값:23349.63$, 예측값 :18476.91$
# 결과값:24901.69$, 예측값 :17361.03$
# 결과값:49176.27$, 예측값 :15940.03$
# 결과값:27122.16$, 예측값 :13715.53$
# 결과값:49964.93$, 예측값 :22798.48$
# 결과값:26926.69$, 예측값 :10841.53$
# 결과값:20139.90$, 예측값 :25343.95$
# 결과값:41870.40$, 예측값 :29677.47$
# 결과값:25577.43$, 예측값 :29833.26$
# 결과값:52363.90$, 예측값 :25040.54$
# 결과값:43849.17$, 예측값 :19222.30$
# 결과값:32102.37$, 예측값 :37842.36$
# 결과값:49340.63$, 예측값 :22443.56$
# 결과값:34571.88$, 예측값 :23716.28$
# 결과값:21597.14$, 예측값 :9252.42$
# 결과값:47478.60$, 예측값 :51474.07$
# 결과값:21268.81$, 예측값 :18270.83$
# 결과값:52137.95$, 예측값 :47763.28$
# 결과값:40003.27$, 예측값 :17385.60$
# 결과값:28881.90$, 예측값 :17695.52$
# 결과값:48094.80$, 예측값 :46680.34$
# 결과값:45801.04$, 예측값 :33300.83$
# 결과값:30895.80$, 예측값 :20797.36$
# 결과값:33397.60$, 예측값 :30975.05$
# 결과값:43603.15$, 예측값 :23182.65$
# 결과값:22106.31$, 예측값 :23224.35$
# 결과값:22023.28$, 예측값 :30080.50$
# 결과값:67065.04$, 예측값 :69720.34$
# 결과값:47252.40$, 예측값 :45174.49$
# 결과값:29596.65$, 예측값 :43628.12$
# 결과값:34039.04$, 예측값 :38817.01$
# 결과값:50439.17$, 예측값 :59853.81$
# 결과값:20647.68$, 예측값 :24254.16$
# 결과값:45322.82$, 예측값 :49163.23$
# 결과값:35416.68$, 예측값 :25828.94$
# 결과값:40078.74$, 예측값 :24082.95$
# 결과값:28482.54$, 예측값 :33858.20$
# 결과값:39272.56$, 예측값 :56650.57$
# 결과값:50554.25$, 예측값 :29203.38$
# 결과값:28335.84$, 예측값 :18739.93$
# 결과값:31533.98$, 예측값 :35240.77$
# 결과값:59670.09$, 예측값 :25626.77$
# 결과값:67738.23$, 예측값 :51795.37$
# 결과값:33085.57$, 예측값 :38721.36$
# 결과값:21341.85$, 예측값 :21390.51$
# 결과값:21725.54$, 예측값 :25638.14$
# 결과값:20068.89$, 예측값 :26177.23$
# 결과값:28864.68$, 예측값 :19328.67$
# 결과값:22801.15$, 예측값 :15267.51$
# 결과값:21373.06$, 예측값 :28824.29$
# 결과값:29512.98$, 예측값 :30498.27$
# 결과값:63065.18$, 예측값 :23302.86$
# 결과값:27634.20$, 예측값 :36813.43$
# 결과값:41953.28$, 예측값 :48763.34$
# 결과값:35983.13$, 예측값 :49205.62$
# 결과값:25617.52$, 예측값 :26366.76$
# 결과값:41719.09$, 예측값 :46729.96$
# 결과값:23679.82$, 예측값 :38554.16$
# 결과값:20568.97$, 예측값 :22353.19$
# 결과값:23028.91$, 예측값 :28810.66$
# 결과값:64294.39$, 예측값 :48508.59$
# 결과값:33543.70$, 예측값 :13935.24$
# 결과값:41079.67$, 예측값 :26196.50$
# 결과값:33530.73$, 예측값 :21374.98$
# 결과값:20419.78$, 예측값 :30932.90$
# 결과값:69759.86$, 예측값 :57068.81$
# 결과값:20148.51$, 예측값 :27576.12$
# 결과값:26046.90$, 예측값 :35259.75$
# 결과값:47167.24$, 예측값 :18167.66$
# 결과값:22235.62$, 예측값 :16996.61$
# 결과값:36689.98$, 예측값 :48928.86$
# 결과값:40836.71$, 예측값 :29214.62$
# 결과값:20173.51$, 예측값 :13554.11$
# 결과값:54628.83$, 예측값 :23933.43$
# 결과값:70749.53$, 예측값 :45726.54$
# 결과값:20425.49$, 예측값 :26139.06$
# 결과값:27551.75$, 예측값 :16988.84$
# 결과값:44832.26$, 예측값 :44731.35$
# 결과값:49596.35$, 예측값 :46449.47$
# 결과값:52848.73$, 예측값 :30864.24$
# 결과값:30959.82$, 예측값 :17372.99$
# 결과값:32800.56$, 예측값 :24991.44$
# 결과값:15476.93$, 예측값 :18830.40$
# 결과값:32098.84$, 예측값 :33368.72$
# 결과값:25441.10$, 예측값 :27858.38$
# 결과값:49865.46$, 예측값 :31131.90$
# 결과값:68574.48$, 예측값 :22308.80$
# 결과값:31911.25$, 예측값 :33387.61$
# 결과값:21570.62$, 예측값 :26381.43$
# 결과값:28005.62$, 예측값 :17121.55$
# 결과값:27950.91$, 예측값 :23825.22$
# 결과값:31817.76$, 예측값 :35740.52$
# 결과값:50569.24$, 예측값 :20565.46$
# 결과값:32381.79$, 예측값 :33416.60$
# 결과값:50279.42$, 예측값 :43425.57$
# 결과값:21277.73$, 예측값 :23563.74$
# 결과값:42701.88$, 예측값 :15356.35$
# 결과값:40999.92$, 예측값 :24099.75$
# 결과값:49595.52$, 예측값 :57366.11$
# 결과값:29107.42$, 예측값 :19441.66$
# 결과값:22571.78$, 예측값 :12609.53$
# 결과값:64372.54$, 예측값 :26528.93$
# 결과값:21132.06$, 예측값 :13536.89$
# 결과값:42906.55$, 예측값 :50315.46$
# 결과값:18439.82$, 예측값 :9422.87$
# 결과값:21631.88$, 예측값 :17929.96$
# 결과값:30836.52$, 예측값 :21146.77$
# 결과값:66413.49$, 예측값 :46433.79$
# 결과값:25017.10$, 예측값 :13567.83$
# 결과값:30493.40$, 예측값 :23630.68$
# 결과값:33859.16$, 예측값 :47840.43$
# 결과값:37753.27$, 예측값 :31699.80$
# 결과값:64372.54$, 예측값 :36631.15$
# 결과값:20656.12$, 예측값 :25560.67$
# 결과값:27388.00$, 예측값 :28808.53$
# 결과값:21068.75$, 예측값 :24696.74$
# 결과값:27205.50$, 예측값 :31333.22$
# 결과값:36331.53$, 예측값 :36268.36$
# 결과값:33370.94$, 예측값 :16852.76$
# 결과값:32885.75$, 예측값 :28602.76$
# 결과값:47515.73$, 예측값 :48212.61$
# 결과값:68617.96$, 예측값 :26955.56$
# 결과값:67113.49$, 예측값 :66546.35$
# 결과값:53998.15$, 예측값 :30127.76$
# 결과값:26932.46$, 예측값 :19124.62$
# 결과값:55114.43$, 예측값 :52281.01$
# 결과값:30920.20$, 예측값 :34858.37$
# 결과값:30273.44$, 예측값 :29716.26$
# 결과값:31342.97$, 예측값 :24535.06$
# 결과값:36908.43$, 예측값 :21086.98$
# 결과값:56407.68$, 예측값 :26615.94$
# 결과값:41660.11$, 예측값 :48825.07$
# 결과값:26632.32$, 예측값 :18356.27$
# 결과값:26450.86$, 예측값 :14061.26$
# 결과값:25034.76$, 예측값 :21075.69$
# 결과값:32951.72$, 예측값 :38725.87$
# 결과값:49707.29$, 예측값 :54130.71$
# 결과값:41928.12$, 예측값 :21302.74$
# 결과값:38149.61$, 예측값 :15842.14$
# 결과값:34268.68$, 예측값 :24111.59$
# 결과값:28308.82$, 예측값 :32114.80$
# 결과값:37042.20$, 예측값 :19403.54$
# 결과값:31098.54$, 예측값 :25526.15$
# 결과값:35719.12$, 예측값 :47299.94$
# 결과값:31337.89$, 예측값 :44003.33$
# 결과값:43204.90$, 예측값 :18855.44$
# 결과값:49931.34$, 예측값 :44089.87$
# 결과값:27119.82$, 예측값 :15832.47$
# 결과값:27329.64$, 예측값 :13263.59$
# 결과값:58721.83$, 예측값 :61941.54$
# 결과값:29652.40$, 예측값 :21467.86$
# 결과값:31780.32$, 예측값 :18172.88$
# 결과값:22980.98$, 예측값 :10040.47$
# 결과값:27424.80$, 예측값 :17321.95$
# 결과값:22785.34$, 예측값 :21411.09$
# 결과값:25612.14$, 예측값 :35436.47$
# 결과값:23972.19$, 예측값 :14745.42$
# 결과값:68659.03$, 예측값 :25363.80$
# 결과값:30234.83$, 예측값 :30601.16$
# 결과값:69297.88$, 예측값 :24665.99$
# 결과값:42905.79$, 예측값 :18572.60$
# 결과값:31859.88$, 예측값 :51492.87$
# 결과값:35410.46$, 예측값 :42775.67$
# 결과값:25244.54$, 예측값 :16782.79$
# 결과값:49105.46$, 예측값 :22703.77$
# 결과값:22799.87$, 예측값 :27647.22$
# 결과값:26351.57$, 예측값 :16796.46$
# 결과값:46999.18$, 예측값 :22318.89$
# 결과값:34232.64$, 예측값 :45567.77$
# 결과값:46774.57$, 예측값 :23256.90$
# 결과값:34346.46$, 예측값 :31442.74$
# 결과값:32632.75$, 예측값 :36407.62$
# 결과값:30834.02$, 예측값 :17889.42$
# 결과값:23901.09$, 예측값 :15762.32$
# 결과값:27705.68$, 예측값 :27796.29$
# 결과값:27909.02$, 예측값 :37297.65$
# 결과값:26083.82$, 예측값 :27403.18$
# 결과값:21823.85$, 예측값 :14667.10$
# 결과값:51524.24$, 예측값 :68921.63$
# 결과값:20564.19$, 예측값 :24090.11$
# 결과값:29117.12$, 예측값 :37552.50$
# 결과값:31056.48$, 예측값 :14776.54$
# 결과값:20295.30$, 예측값 :38966.50$
# 결과값:55856.35$, 예측값 :58767.81$
# 결과값:52699.97$, 예측값 :57399.63$
# 결과값:24718.20$, 예측값 :15998.43$
# 결과값:25135.50$, 예측값 :27668.16$
# 결과값:16480.38$, 예측값 :21311.26$
# 결과값:21273.74$, 예측값 :38295.68$
# 결과값:20920.19$, 예측값 :26111.25$
# 결과값:42250.88$, 예측값 :23581.91$
# 결과값:43148.04$, 예측값 :25091.79$
# 결과값:39034.32$, 예측값 :44235.73$
# 결과값:55489.43$, 예측값 :22004.50$
# 결과값:37633.44$, 예측값 :38349.58$
# 결과값:28995.88$, 예측값 :37865.34$
# 결과값:29562.00$, 예측값 :38081.34$
# 결과값:29871.82$, 예측값 :28941.26$
# 결과값:38228.78$, 예측값 :15897.54$
# 결과값:20568.60$, 예측값 :27800.19$
# 결과값:28350.11$, 예측값 :33206.20$
# 결과값:27068.73$, 예측값 :15651.20$
# 결과값:25803.49$, 예측값 :29330.21$
# 결과값:49484.99$, 예측값 :21670.85$
# 결과값:26130.53$, 예측값 :35035.00$
# 결과값:25584.00$, 예측값 :17069.80$
# 결과값:35055.12$, 예측값 :42326.94$
# 결과값:32303.92$, 예측값 :31130.06$
# 결과값:20141.22$, 예측값 :18243.30$
# 결과값:25383.84$, 예측값 :27927.89$
# 결과값:44619.79$, 예측값 :46527.15$
# 결과값:61082.46$, 예측값 :55298.93$
# 결과값:22009.90$, 예측값 :13483.23$
# 결과값:24146.99$, 예측값 :39828.64$
# 결과값:20280.75$, 예측값 :24212.47$
# 결과값:21155.78$, 예측값 :13827.21$
# 결과값:20166.87$, 예측값 :22964.67$
# 결과값:29260.48$, 예측값 :18807.74$
# 결과값:20455.34$, 예측값 :23339.90$
# 결과값:31103.12$, 예측값 :16154.20$
# 결과값:21735.81$, 예측값 :15306.40$
# 결과값:41371.20$, 예측값 :33987.30$
# 결과값:50907.51$, 예측값 :24926.98$
# 결과값:43612.11$, 예측값 :43805.11$
# 결과값:20560.96$, 예측값 :11154.81$
# 결과값:22499.57$, 예측값 :20045.72$
# 결과값:35524.48$, 예측값 :33405.70$
# 결과값:41684.93$, 예측값 :25150.29$
# 결과값:55834.65$, 예측값 :22675.71$
# 결과값:38190.98$, 예측값 :24300.90$
# 결과값:34224.76$, 예측값 :25920.23$
# 결과값:20929.08$, 예측값 :26211.26$
# 결과값:53764.84$, 예측값 :23938.19$
# 결과값:56131.02$, 예측값 :53818.07$
# 결과값:33084.11$, 예측값 :37828.55$
# 결과값:24656.52$, 예측값 :33444.56$
# 결과값:44591.90$, 예측값 :19660.52$
# 결과값:23325.59$, 예측값 :17531.10$
# 결과값:61631.84$, 예측값 :34740.80$
# 결과값:41953.98$, 예측값 :28300.58$
# 결과값:63873.39$, 예측값 :35234.00$
# 결과값:29651.08$, 예측값 :29479.15$
# 결과값:34948.31$, 예측값 :26602.57$
# 결과값:23700.97$, 예측값 :31522.23$
# 결과값:61698.95$, 예측값 :22367.60$
# 결과값:61067.60$, 예측값 :25963.81$
# 결과값:23272.44$, 예측값 :27074.67$
# 결과값:22917.52$, 예측값 :33953.95$
# 결과값:45052.80$, 예측값 :24028.07$
# 결과값:63276.72$, 예측값 :61810.24$
# 결과값:67290.13$, 예측값 :67886.40$
# 결과값:26256.28$, 예측값 :42308.63$
# 결과값:66450.93$, 예측값 :58351.82$
# 결과값:20500.37$, 예측값 :26093.41$
# 결과값:38225.91$, 예측값 :19255.11$
# 결과값:38007.72$, 예측값 :48505.21$
# 결과값:27628.26$, 예측값 :20476.37$
# 결과값:62247.12$, 예측값 :63694.19$
# 결과값:36431.97$, 예측값 :52243.67$
# 결과값:42306.20$, 예측값 :25667.57$
# 결과값:20612.37$, 예측값 :17923.03$
# 결과값:58468.02$, 예측값 :25421.41$
# 결과값:37187.48$, 예측값 :41748.13$
# 결과값:40550.62$, 예측값 :45910.50$
# 결과값:41077.42$, 예측값 :19385.95$
# 결과값:27946.11$, 예측값 :34490.12$
# 결과값:46884.32$, 예측값 :43274.66$
# 결과값:24578.10$, 예측값 :13640.23$
# 결과값:34002.34$, 예측값 :44907.01$
# 결과값:37297.65$, 예측값 :27127.31$
# 결과값:49075.34$, 예측값 :45338.61$
# 결과값:27591.72$, 예측값 :26141.65$
# 결과값:34184.09$, 예측값 :46674.84$
# 결과값:41613.86$, 예측값 :52125.08$
# 결과값:27314.91$, 예측값 :29939.36$
# 결과값:64608.96$, 예측값 :66149.20$
# 결과값:52687.05$, 예측값 :62560.17$
# 결과값:20860.01$, 예측값 :11575.01$
# 결과값:63271.35$, 예측값 :54475.66$
# 결과값:18729.27$, 예측값 :11171.58$
# 결과값:24027.79$, 예측값 :27373.05$
# 결과값:27413.43$, 예측값 :38849.36$
# 결과값:52930.41$, 예측값 :42601.99$
# 결과값:33864.78$, 예측값 :37244.12$
# 결과값:47297.70$, 예측값 :24290.74$
# 결과값:24688.75$, 예측값 :34924.32$
# 결과값:20633.28$, 예측값 :17833.67$
# 결과값:23504.41$, 예측값 :23397.98$
# 결과값:15379.60$, 예측값 :20447.88$
# 결과값:61111.33$, 예측값 :22356.90$
# 결과값:24041.22$, 예측값 :16380.41$
# 결과값:25091.01$, 예측값 :31374.81$
# 결과값:41085.99$, 예측값 :47037.42$
# 결과값:20344.27$, 예측값 :30937.87$
# 결과값:20965.96$, 예측값 :9786.39$
# 결과값:29404.60$, 예측값 :15483.00$
# 결과값:21091.67$, 예측값 :12314.49$
# 결과값:22188.46$, 예측값 :20963.46$
# 결과값:54478.32$, 예측값 :51907.41$
# 결과값:63577.08$, 예측값 :36790.14$
# 결과값:21547.23$, 예측값 :26470.83$
# 결과값:41407.39$, 예측값 :28262.28$
# 결과값:16067.35$, 예측값 :8896.84$
# 결과값:27505.31$, 예측값 :32044.48$
# 결과값:27902.71$, 예측값 :36746.84$
# 결과값:17875.20$, 예측값 :34901.44$
# 결과값:62259.60$, 예측값 :61095.58$
# 결과값:28861.48$, 예측값 :13734.46$
# 결과값:20734.32$, 예측값 :16701.18$
# 결과값:45024.69$, 예측값 :22290.29$
# 결과값:25055.64$, 예측값 :17776.18$
# 결과값:21292.03$, 예측값 :11044.52$
# 결과값:25202.39$, 예측값 :17721.38$
# 결과값:47296.08$, 예측값 :27354.02$
# 결과값:39855.05$, 예측값 :43988.96$
# 결과값:58291.08$, 예측값 :54311.74$
# 결과값:20676.24$, 예측값 :13547.79$
# 결과값:33296.64$, 예측값 :38605.64$
# 결과값:26160.00$, 예측값 :38894.52$
# 결과값:57498.09$, 예측값 :55470.55$
# 결과값:23382.75$, 예측값 :34813.83$
# 결과값:50138.79$, 예측값 :52930.11$
# 결과값:26153.60$, 예측값 :10747.91$
# 결과값:22167.26$, 예측값 :38094.85$
# 결과값:30784.37$, 예측값 :36325.47$
# 결과값:21089.69$, 예측값 :26592.29$
# 결과값:40273.43$, 예측값 :40808.77$
# 결과값:24964.93$, 예측값 :26565.47$
# 결과값:28291.89$, 예측값 :24011.70$
# 결과값:45075.72$, 예측값 :47568.10$
# 결과값:25892.41$, 예측값 :36532.34$
# 결과값:26746.08$, 예측값 :33546.86$
# 결과값:63530.73$, 예측값 :48529.79$
# 결과값:35880.23$, 예측값 :39636.80$
# 결과값:49397.98$, 예측값 :61319.11$
# 결과값:57017.00$, 예측값 :25526.61$
# 결과값:29369.75$, 예측값 :34155.71$
# Accuracy: -3.99   RMSE : 13855.12

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 15,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 10000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:26213.40$, 예측값 :29655.37$
# 결과값:49595.52$, 예측값 :57366.11$
# 결과값:27122.16$, 예측값 :13715.53$
# 결과값:30428.44$, 예측값 :41171.50$
# 결과값:13326.63$, 예측값 :17327.74$
# 결과값:34039.04$, 예측값 :38817.01$
# 결과값:43603.15$, 예측값 :23182.65$
# 결과값:28861.48$, 예측값 :13734.46$
# 결과값:40003.27$, 예측값 :17385.60$
# 결과값:22295.68$, 예측값 :31933.82$
# 결과값:25441.10$, 예측값 :27858.38$
# 결과값:38225.91$, 예측값 :19255.11$
# 결과값:66413.49$, 예측값 :46433.79$
# 결과값:27329.64$, 예측값 :13263.59$
# 결과값:31369.32$, 예측값 :38927.38$
# 결과값:16186.73$, 예측값 :22953.72$
# 결과값:30273.44$, 예측값 :29716.26$
# 결과값:51362.03$, 예측값 :22123.41$
# 결과값:55114.43$, 예측값 :52281.01$
# 결과값:33980.23$, 예측값 :16790.03$
# 결과값:40852.38$, 예측값 :51676.94$
# 결과값:52137.95$, 예측값 :47763.28$
# 결과값:66450.93$, 예측값 :58351.82$
# 결과값:27424.80$, 예측값 :17321.95$
# 결과값:52699.97$, 예측값 :57399.63$
# 결과값:68659.03$, 예측값 :25363.80$
# 결과값:20507.17$, 예측값 :23298.82$
# 결과값:24688.75$, 예측값 :34924.32$
# 결과값:30784.37$, 예측값 :36325.47$
# 결과값:21068.75$, 예측값 :24696.74$
# 결과값:32381.79$, 예측값 :33416.60$
# 결과값:53764.84$, 예측값 :23938.19$
# 결과값:34746.72$, 예측값 :37486.40$
# 결과값:63577.08$, 예측값 :36790.14$
# 결과값:20166.87$, 예측값 :22964.67$
# 결과값:40908.44$, 예측값 :46307.34$
# 결과값:24146.99$, 예측값 :39828.64$
# 결과값:22801.15$, 예측값 :15267.51$
# 결과값:20295.30$, 예측값 :38966.50$
# 결과값:68574.48$, 예측값 :22308.80$
# 결과값:41953.98$, 예측값 :28300.58$
# 결과값:41719.09$, 예측값 :46729.96$
# 결과값:43204.90$, 예측값 :18855.44$
# 결과값:23169.18$, 예측값 :26883.68$
# 결과값:32800.56$, 예측값 :24991.44$
# 결과값:25244.54$, 예측값 :16782.79$
# 결과값:43849.17$, 예측값 :19222.30$
# 결과값:33543.70$, 예측값 :13935.24$
# 결과값:58291.08$, 예측값 :54311.74$
# 결과값:25577.43$, 예측값 :29833.26$
# 결과값:35863.89$, 예측값 :41619.54$
# 결과값:31056.48$, 예측값 :14776.54$
# 결과값:29978.80$, 예측값 :42652.18$
# 결과값:21292.03$, 예측값 :11044.52$
# 결과값:28005.62$, 예측값 :17121.55$
# 결과값:12627.71$, 예측값 :20749.56$
# 결과값:28881.90$, 예측값 :17695.52$
# 결과값:45836.54$, 예측값 :27895.68$
# 결과값:57498.09$, 예측값 :55470.55$
# 결과값:20418.11$, 예측값 :21013.91$
# 결과값:27628.26$, 예측값 :20476.37$
# 결과값:38667.58$, 예측값 :46506.12$
# 결과값:63276.72$, 예측값 :61810.24$
# 결과값:55834.65$, 예측값 :22675.71$
# 결과값:68617.96$, 예측값 :26955.56$
# 결과값:21597.14$, 예측값 :9252.42$
# 결과값:30234.83$, 예측값 :30601.16$
# 결과값:49865.46$, 예측값 :31131.90$
# 결과값:50138.79$, 예측값 :52930.11$
# 결과값:26632.32$, 예측값 :18356.27$
# 결과값:36431.97$, 예측값 :52243.67$
# 결과값:26685.53$, 예측값 :10884.00$
# 결과값:28350.11$, 예측값 :33206.20$
# 결과값:44832.26$, 예측값 :44731.35$
# 결과값:45075.72$, 예측값 :47568.10$
# 결과값:33248.83$, 예측값 :36341.79$
# 결과값:40550.62$, 예측값 :45910.50$
# 결과값:42701.88$, 예측값 :15356.35$
# 결과값:37633.44$, 예측값 :38349.58$
# 결과값:40466.40$, 예측값 :46832.22$
# 결과값:39604.91$, 예측값 :17279.12$
# 결과값:30493.40$, 예측값 :23630.68$
# 결과값:13490.76$, 예측값 :16622.07$
# 결과값:35055.12$, 예측값 :42326.94$
# 결과값:25803.49$, 예측값 :29330.21$
# 결과값:22499.57$, 예측값 :20045.72$
# 결과값:57991.13$, 예측값 :31188.26$
# 결과값:21132.06$, 예측값 :13536.89$
# 결과값:27909.02$, 예측값 :37297.65$
# 결과값:22399.73$, 예측값 :21603.50$
# 결과값:31103.12$, 예측값 :16154.20$
# 결과값:20419.78$, 예측값 :30932.90$
# 결과값:26308.95$, 예측값 :18072.89$
# 결과값:21341.85$, 예측값 :21390.51$
# 결과값:37187.48$, 예측값 :41748.13$
# 결과값:24041.22$, 예측값 :16380.41$
# 결과값:47478.60$, 예측값 :51474.07$
# 결과값:30834.02$, 예측값 :17889.42$
# 결과값:49596.35$, 예측값 :46449.47$
# 결과값:27551.75$, 예측값 :16988.84$
# 결과값:34002.34$, 예측값 :44907.01$
# 결과값:43148.04$, 예측값 :25091.79$
# 결과값:55856.35$, 예측값 :58767.81$
# 결과값:23504.41$, 예측값 :23397.98$
# 결과값:64294.39$, 예측값 :48508.59$
# 결과값:41917.20$, 예측값 :48394.71$
# 결과값:27205.50$, 예측값 :31333.22$
# 결과값:21273.74$, 예측값 :38295.68$
# 결과값:50279.42$, 예측값 :43425.57$
# 결과값:32951.72$, 예측값 :38725.87$
# 결과값:33864.78$, 예측값 :37244.12$
# 결과값:42905.79$, 예측값 :18572.60$
# 결과값:28443.36$, 예측값 :34997.87$
# 결과값:42906.55$, 예측값 :50315.46$
# 결과값:28335.84$, 예측값 :18739.93$
# 결과값:27705.68$, 예측값 :27796.29$
# 결과값:13336.86$, 예측값 :15658.61$
# 결과값:62247.12$, 예측값 :63694.19$
# 결과값:69297.88$, 예측값 :24665.99$
# 결과값:44591.90$, 예측값 :19660.52$
# 결과값:27388.00$, 예측값 :28808.53$
# 결과값:21268.81$, 예측값 :18270.83$
# 결과값:34225.71$, 예측값 :27802.14$
# 결과값:34211.50$, 예측값 :34625.83$
# 결과값:25659.50$, 예측값 :18408.43$
# 결과값:63271.35$, 예측값 :54475.66$
# 결과값:38007.72$, 예측값 :48505.21$
# 결과값:50569.24$, 예측값 :20565.46$
# 결과값:30774.12$, 예측값 :29961.67$
# 결과값:21648.12$, 예측값 :19761.15$
# 결과값:23349.63$, 예측값 :18476.91$
# 결과값:64608.96$, 예측값 :66149.20$
# 결과값:24964.93$, 예측값 :26565.47$
# 결과값:32098.84$, 예측값 :33368.72$
# 결과값:47252.40$, 예측값 :45174.49$
# 결과값:43163.33$, 예측값 :44194.01$
# 결과값:32102.37$, 예측값 :37842.36$
# 결과값:22188.46$, 예측값 :20963.46$
# 결과값:32303.92$, 예측값 :31130.06$
# 결과값:23587.59$, 예측값 :24182.97$
# 결과값:26130.53$, 예측값 :35035.00$
# 결과값:27413.43$, 예측값 :38849.36$
# 결과값:27314.91$, 예측값 :29939.36$
# 결과값:41079.67$, 예측값 :26196.50$
# 결과값:25383.84$, 예측값 :27927.89$
# 결과값:46774.57$, 예측값 :23256.90$
# 결과값:23382.75$, 예측값 :34813.83$
# 결과값:22167.26$, 예측값 :38094.85$
# 결과값:23700.97$, 예측값 :31522.23$
# 결과값:26153.60$, 예측값 :10747.91$
# 결과값:20503.13$, 예측값 :35014.30$
# 결과값:25892.41$, 예측값 :36532.34$
# 결과값:64839.84$, 예측값 :48298.39$
# 결과값:54628.83$, 예측값 :23933.43$
# 결과값:15476.93$, 예측값 :18830.40$
# 결과값:21725.54$, 예측값 :25638.14$
# 결과값:24901.69$, 예측값 :17361.03$
# 결과값:21089.69$, 예측값 :26592.29$
# 결과값:23495.78$, 예측값 :14041.67$
# 결과값:49799.86$, 예측값 :20465.00$
# 결과값:47296.08$, 예측값 :27354.02$
# 결과값:55489.43$, 예측값 :22004.50$
# 결과값:58437.60$, 예측값 :59078.93$
# 결과값:40999.92$, 예측값 :24099.75$
# 결과값:18681.64$, 예측값 :20734.49$
# 결과값:20568.60$, 예측값 :27800.19$
# 결과값:21373.06$, 예측값 :28824.29$
# 결과값:47515.73$, 예측값 :48212.61$
# 결과값:25135.50$, 예측값 :27668.16$
# 결과값:26450.86$, 예측값 :14061.26$
# 결과값:53998.15$, 예측값 :30127.76$
# 결과값:35880.23$, 예측값 :39636.80$
# 결과값:38379.10$, 예측값 :16367.73$
# 결과값:40078.74$, 예측값 :24082.95$
# 결과값:41371.20$, 예측값 :33987.30$
# 결과값:23887.50$, 예측값 :31290.36$
# 결과값:30920.20$, 예측값 :34858.37$
# 결과값:20612.37$, 예측값 :17923.03$
# 결과값:29369.75$, 예측값 :34155.71$
# 결과값:21864.34$, 예측값 :36165.77$
# 결과값:46884.32$, 예측값 :43274.66$
# 결과값:64372.54$, 예측값 :36631.15$
# 결과값:49931.34$, 예측값 :44089.87$
# 결과값:41684.93$, 예측값 :25150.29$
# 결과값:30082.42$, 예측값 :24543.20$
# 결과값:31859.88$, 예측값 :51492.87$
# 결과값:43612.11$, 예측값 :43805.11$
# 결과값:37753.27$, 예측값 :31699.80$
# 결과값:20280.75$, 예측값 :24212.47$
# 결과값:31342.97$, 예측값 :24535.06$
# 결과값:24656.52$, 예측값 :33444.56$
# 결과값:37042.20$, 예측값 :19403.54$
# 결과값:26926.69$, 예측값 :10841.53$
# 결과값:22106.31$, 예측값 :23224.35$
# 결과값:36908.43$, 예측값 :21086.98$
# 결과값:28308.82$, 예측값 :32114.80$
# 결과값:33490.42$, 예측값 :21858.00$
# 결과값:45052.80$, 예측값 :24028.07$
# 결과값:24578.10$, 예측값 :13640.23$
# 결과값:41085.99$, 예측값 :47037.42$
# 결과값:49105.46$, 예측값 :22703.77$
# 결과값:27119.82$, 예측값 :15832.47$
# 결과값:34224.76$, 예측값 :25920.23$
# 결과값:50907.51$, 예측값 :24926.98$
# 결과값:29652.40$, 예측값 :21467.86$
# 결과값:39042.12$, 예측값 :39774.61$
# 결과값:29651.08$, 예측값 :29479.15$
# 결과값:69759.86$, 예측값 :57068.81$
# 결과값:35524.48$, 예측값 :33405.70$
# 결과값:29117.12$, 예측값 :37552.50$
# 결과값:35983.13$, 예측값 :49205.62$
# 결과값:22799.87$, 예측값 :27647.22$
# 결과값:33084.11$, 예측값 :37828.55$
# 결과값:52848.73$, 예측값 :30864.24$
# 결과값:26046.90$, 예측값 :35259.75$
# 결과값:20676.24$, 예측값 :13547.79$
# 결과값:40273.43$, 예측값 :40808.77$
# 결과값:20141.22$, 예측값 :18243.30$
# 결과값:39855.05$, 예측값 :43988.96$
# 결과값:25091.01$, 예측값 :31374.81$
# 결과값:42306.20$, 예측값 :25667.57$
# 결과값:63965.99$, 예측값 :32455.44$
# 결과값:55121.16$, 예측값 :54731.38$
# 결과값:21931.09$, 예측값 :24205.95$
# 결과값:41870.40$, 예측값 :29677.47$
# 결과값:29562.00$, 예측값 :38081.34$
# 결과값:49397.98$, 예측값 :61319.11$
# 결과값:34184.09$, 예측값 :46674.84$
# 결과값:21631.88$, 예측값 :17929.96$
# 결과값:20068.89$, 예측값 :26177.23$
# 결과값:23901.09$, 예측값 :15762.32$
# 결과값:29512.98$, 예측값 :30498.27$
# 결과값:23814.90$, 예측값 :18159.18$
# 결과값:25038.87$, 예측값 :23633.71$
# 결과값:63530.73$, 예측값 :48529.79$
# 결과값:31199.25$, 예측값 :32647.18$
# 결과값:27946.11$, 예측값 :34490.12$
# 결과값:41077.42$, 예측값 :19385.95$
# 결과값:33397.60$, 예측값 :30975.05$
# 결과값:25612.14$, 예측값 :35436.47$
# 결과값:21091.67$, 예측값 :12314.49$
# 결과값:63873.39$, 예측값 :35234.00$
# 결과값:11755.98$, 예측값 :12018.74$
# 결과값:20344.27$, 예측값 :30937.87$
# 결과값:28864.68$, 예측값 :19328.67$
# 결과값:24389.96$, 예측값 :16982.25$
# 결과값:26160.00$, 예측값 :38894.52$
# 결과값:43216.40$, 예측값 :50138.29$
# 결과값:45024.69$, 예측값 :22290.29$
# 결과값:36331.53$, 예측값 :36268.36$
# 결과값:34232.64$, 예측값 :45567.77$
# 결과값:29551.97$, 예측값 :33885.94$
# 결과값:21277.73$, 예측값 :23563.74$
# 결과값:35416.68$, 예측값 :25828.94$
# 결과값:20560.96$, 예측값 :11154.81$
# 결과값:61067.60$, 예측값 :25963.81$
# 결과값:36516.67$, 예측값 :43257.18$
# 결과값:29404.60$, 예측값 :15483.00$
# 결과값:49176.27$, 예측값 :15940.03$
# 결과값:62259.60$, 예측값 :61095.58$
# 결과값:50439.17$, 예측값 :59853.81$
# 결과값:20139.90$, 예측값 :25343.95$
# 결과값:17875.20$, 예측값 :34901.44$
# 결과값:61082.46$, 예측값 :55298.93$
# 결과값:26256.28$, 예측값 :42308.63$
# 결과값:31533.98$, 예측값 :35240.77$
# 결과값:50554.25$, 예측값 :29203.38$
# 결과값:26064.87$, 예측값 :27895.56$
# 결과값:25202.39$, 예측값 :17721.38$
# 결과값:38389.60$, 예측값 :27551.16$
# 결과값:37005.07$, 예측값 :23923.34$
# 결과값:39272.56$, 예측값 :56650.57$
# 결과값:28291.89$, 예측값 :24011.70$
# 결과값:36689.98$, 예측값 :48928.86$
# 결과값:23199.27$, 예측값 :26081.83$
# 결과값:39034.32$, 예측값 :44235.73$
# 결과값:47297.70$, 예측값 :24290.74$
# 결과값:27922.66$, 예측값 :41652.98$
# 결과값:35410.46$, 예측값 :42775.67$
# 결과값:20920.19$, 예측값 :26111.25$
# 결과값:21170.51$, 예측값 :26028.31$
# 결과값:27634.20$, 예측값 :36813.43$
# 결과값:28995.88$, 예측값 :37865.34$
# 결과값:22009.90$, 예측값 :13483.23$
# 결과값:61631.84$, 예측값 :34740.80$
# 결과값:33859.16$, 예측값 :47840.43$
# 결과값:66986.79$, 예측값 :49297.07$
# 결과값:31780.32$, 예측값 :18172.88$
# 결과값:26083.82$, 예측값 :27403.18$
# 결과값:20455.34$, 예측값 :23339.90$
# 결과값:44619.79$, 예측값 :46527.15$
# 결과값:21735.81$, 예측값 :15306.40$
# 결과값:61698.95$, 예측값 :22367.60$
# 결과값:25334.40$, 예측값 :38550.34$
# 결과값:29581.89$, 예측값 :19500.96$
# 결과값:33085.57$, 예측값 :38721.36$
# 결과값:20586.85$, 예측값 :32173.24$
# 결과값:55408.52$, 예측값 :40784.84$
# 결과값:41928.12$, 예측값 :21302.74$
# 결과값:27950.91$, 예측값 :23825.22$
# 결과값:27068.73$, 예측값 :15651.20$
# 결과값:59670.09$, 예측값 :25626.77$
# 결과값:33530.73$, 예측값 :21374.98$
# 결과값:27505.31$, 예측값 :32044.48$
# 결과값:58468.02$, 예측값 :25421.41$
# 결과값:36866.22$, 예측값 :45406.70$
# 결과값:20483.38$, 예측값 :26560.40$
# 결과값:20734.32$, 예측값 :16701.18$
# 결과값:20656.12$, 예측값 :25560.67$
# 결과값:18439.82$, 예측값 :9422.87$
# 결과값:67113.49$, 예측값 :66546.35$
# 결과값:25034.76$, 예측값 :21075.69$
# 결과값:22023.28$, 예측값 :30080.50$
# 결과값:33785.08$, 예측값 :39550.45$
# 결과값:29260.48$, 예측값 :18807.74$
# 결과값:49340.63$, 예측값 :22443.56$
# 결과값:20965.96$, 예측값 :9786.39$
# 결과값:24460.13$, 예측값 :19596.90$
# 결과값:52930.41$, 예측값 :42601.99$
# 결과값:37691.55$, 예측값 :14734.04$
# 결과값:38149.61$, 예측값 :15842.14$
# 결과값:41613.86$, 예측값 :52125.08$
# 결과값:21269.26$, 예측값 :45259.94$
# 결과값:34948.31$, 예측값 :26602.57$
# 결과값:22980.98$, 예측값 :10040.47$
# 결과값:26746.08$, 예측값 :33546.86$
# 결과값:34571.88$, 예측값 :23716.28$
# 결과값:27591.72$, 예측값 :26141.65$
# 결과값:61111.33$, 예측값 :22356.90$
# 결과값:13262.90$, 예측값 :10529.04$
# 결과값:16480.38$, 예측값 :21311.26$
# 결과값:23972.19$, 예측값 :14745.42$
# 결과값:44632.77$, 예측값 :21271.85$
# 결과값:29871.82$, 예측값 :28941.26$
# 결과값:20860.01$, 예측값 :11575.01$
# 결과값:24933.36$, 예측값 :15925.22$
# 결과값:26932.46$, 예측값 :19124.62$
# 결과값:45657.41$, 예측값 :28671.53$
# 결과값:20647.68$, 예측값 :24254.16$
# 결과값:20500.37$, 예측값 :26093.41$
# 결과값:47167.24$, 예측값 :18167.66$
# 결과값:25055.64$, 예측값 :17776.18$
# 결과값:48094.80$, 예측값 :46680.34$
# 결과값:67065.04$, 예측값 :69720.34$
# 결과값:22571.78$, 예측값 :12609.53$
# 결과값:70749.53$, 예측값 :45726.54$
# 결과값:40836.71$, 예측값 :29214.62$
# 결과값:60768.12$, 예측값 :61030.92$
# 결과값:21547.23$, 예측값 :26470.83$
# 결과값:25584.00$, 예측값 :17069.80$
# 결과값:44230.99$, 예측값 :48003.63$
# 결과값:33370.94$, 예측값 :16852.76$
# 결과값:28482.54$, 예측값 :33858.20$
# 결과값:26611.96$, 예측값 :28707.44$
# 결과값:29107.42$, 예측값 :19441.66$
# 결과값:25617.52$, 예측값 :26366.76$
# 결과값:45801.04$, 예측값 :33300.83$
# 결과값:12996.87$, 예측값 :12099.37$
# 결과값:13410.72$, 예측값 :14691.13$
# 결과값:20173.51$, 예측값 :13554.11$
# 결과값:56407.68$, 예측값 :26615.94$
# 결과값:67290.13$, 예측값 :67886.40$
# 결과값:20633.28$, 예측값 :17833.67$
# 결과값:30836.52$, 예측값 :21146.77$
# 결과값:46999.18$, 예측값 :22318.89$
# 결과값:57017.00$, 예측값 :25526.61$
# 결과값:34346.46$, 예측값 :31442.74$
# 결과값:20128.93$, 예측값 :12585.60$
# 결과값:58721.83$, 예측값 :61941.54$
# 결과값:26351.57$, 예측값 :16796.46$
# 결과값:30959.82$, 예측값 :17372.99$
# 결과값:42250.88$, 예측값 :23581.91$
# 결과값:20398.14$, 예측값 :24319.71$
# 결과값:51524.24$, 예측값 :68921.63$
# 결과값:21823.85$, 예측값 :14667.10$
# 결과값:31911.25$, 예측값 :33387.61$
# 결과값:63065.18$, 예측값 :23302.86$
# 결과값:20564.19$, 예측값 :24090.11$
# 결과값:56175.76$, 예측값 :29200.31$
# 결과값:33296.64$, 예측값 :38605.64$
# 결과값:45057.48$, 예측값 :35978.48$
# 결과값:49707.29$, 예측값 :54130.71$
# 결과값:27902.71$, 예측값 :36746.84$
# 결과값:25346.44$, 예측값 :29970.64$
# 결과값:41407.39$, 예측값 :28262.28$
# 결과값:23028.91$, 예측값 :28810.66$
# 결과값:20425.49$, 예측값 :26139.06$
# 결과값:36709.39$, 예측값 :22488.63$
# 결과값:35719.12$, 예측값 :47299.94$
# 결과값:21155.78$, 예측값 :13827.21$
# 결과값:13500.16$, 예측값 :16430.66$
# 결과값:48878.47$, 예측값 :49775.21$
# 결과값:31337.89$, 예측값 :44003.33$
# 결과값:61536.29$, 예측값 :72237.87$
# 결과값:64620.82$, 예측값 :22290.24$
# 결과값:22235.62$, 예측값 :16996.61$
# 결과값:64372.54$, 예측값 :26528.93$
# 결과값:22582.79$, 예측값 :30129.60$
# 결과값:18729.27$, 예측값 :11171.58$
# 결과값:20148.51$, 예측값 :27576.12$
# 결과값:22917.52$, 예측값 :33953.95$
# 결과값:46719.55$, 예측값 :17951.26$
# 결과값:20929.08$, 예측값 :26211.26$
# 결과값:56131.02$, 예측값 :53818.07$
# 결과값:52687.05$, 예측값 :62560.17$
# 결과값:67738.23$, 예측값 :51795.37$
# 결과값:24718.20$, 예측값 :15998.43$
# 결과값:54478.32$, 예측값 :51907.41$
# 결과값:24027.79$, 예측값 :27373.05$
# 결과값:32885.75$, 예측값 :28602.76$
# 결과값:20158.59$, 예측값 :25932.14$
# 결과값:32632.75$, 예측값 :36407.62$
# 결과값:57774.21$, 예측값 :68805.65$
# 결과값:38228.78$, 예측값 :15897.54$
# 결과값:22785.34$, 예측값 :21411.09$
# 결과값:15379.60$, 예측값 :20447.88$
# 결과값:49075.34$, 예측값 :45338.61$
# 결과값:23679.82$, 예측값 :38554.16$
# 결과값:31817.76$, 예측값 :35740.52$
# 결과값:37297.65$, 예측값 :27127.31$
# 결과값:30895.80$, 예측값 :20797.36$
# 결과값:52363.90$, 예측값 :25040.54$
# 결과값:57439.15$, 예측값 :62195.07$
# 결과값:22891.14$, 예측값 :12740.08$
# 결과값:16216.19$, 예측값 :22206.17$
# 결과값:20568.97$, 예측값 :22353.19$
# 결과값:41953.28$, 예측값 :48763.34$
# 결과값:38599.92$, 예측값 :37914.39$
# 결과값:41660.11$, 예측값 :48825.07$
# 결과값:49964.93$, 예측값 :22798.48$
# 결과값:26625.14$, 예측값 :33478.31$
# 결과값:45322.82$, 예측값 :49163.23$
# 결과값:34268.68$, 예측값 :24111.59$
# 결과값:23325.59$, 예측값 :17531.10$
# 결과값:26863.06$, 예측값 :39435.13$
# 결과값:21579.42$, 예측값 :22528.81$
# 결과값:25017.10$, 예측값 :13567.83$
# 결과값:38190.98$, 예측값 :24300.90$
# 결과값:21570.62$, 예측값 :26381.43$
# 결과값:31098.54$, 예측값 :25526.15$
# 결과값:16067.35$, 예측값 :8896.84$
# 결과값:13328.09$, 예측값 :12307.70$
# 결과값:23207.22$, 예측값 :12999.92$
# 결과값:49484.99$, 예측값 :21670.85$
# 결과값:39880.62$, 예측값 :23998.38$
# 결과값:29596.65$, 예측값 :43628.12$
# 결과값:23272.44$, 예측값 :27074.67$
# Accuracy: 1.85   RMSE : 13708.80

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 10,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:1018.39$, 예측값 :986.61$
# 결과값:3908.68$, 예측값 :1895.39$
# 결과값:1088.97$, 예측값 :1621.86$
# 결과값:1134.40$, 예측값 :754.49$
# 결과값:2044.36$, 예측값 :1725.06$
# 결과값:1751.48$, 예측값 :898.50$
# 결과값:1292.93$, 예측값 :1662.08$
# 결과값:47297.70$, 예측값 :24290.74$
# 결과값:1993.46$, 예측값 :1469.86$
# 결과값:1032.69$, 예측값 :1140.85$
# 결과값:1743.35$, 예측값 :1129.05$
# 결과값:1463.57$, 예측값 :1100.05$
# 결과값:1169.51$, 예측값 :1202.57$
# 결과값:2062.70$, 예측값 :3035.82$
# 결과값:49105.46$, 예측값 :22703.77$
# 결과값:1164.21$, 예측값 :1466.45$
# 결과값:23028.91$, 예측값 :28810.66$
# 결과값:975.06$, 예측값 :1345.56$
# 결과값:1404.00$, 예측값 :1786.61$
# 결과값:2245.14$, 예측값 :3082.33$
# 결과값:34039.04$, 예측값 :38817.01$
# 결과값:2078.36$, 예측값 :3252.86$
# 결과값:47167.24$, 예측값 :18167.66$
# 결과값:1970.54$, 예측값 :1951.25$
# 결과값:2453.69$, 예측값 :1740.90$
# 결과값:1327.11$, 예측값 :1034.91$
# 결과값:877.68$, 예측값 :1338.37$
# 결과값:1399.57$, 예측값 :1523.32$
# 결과값:1191.85$, 예측값 :346.51$
# 결과값:1682.12$, 예측값 :1995.54$
# 결과값:1040.25$, 예측값 :1202.36$
# 결과값:1093.95$, 예측값 :1281.99$
# 결과값:2551.39$, 예측값 :3501.90$
# 결과값:50554.25$, 예측값 :29203.38$
# 결과값:2106.18$, 예측값 :2601.58$
# 결과값:57774.21$, 예측값 :68805.65$
# 결과값:43849.17$, 예측값 :19222.30$
# 결과값:1048.37$, 예측값 :1215.08$
# 결과값:3233.01$, 예측값 :1729.64$
# 결과값:1790.38$, 예측값 :5194.60$
# 결과값:3068.11$, 예측값 :3019.51$
# 결과값:2097.46$, 예측값 :2091.62$
# 결과값:1465.45$, 예측값 :2179.96$
# 결과값:25017.10$, 예측값 :13567.83$
# 결과값:29107.42$, 예측값 :19441.66$
# 결과값:42250.88$, 예측값 :23581.91$
# 결과값:2086.21$, 예측값 :6130.37$
# 결과값:2331.52$, 예측값 :1656.60$
# 결과값:50569.24$, 예측값 :20565.46$
# 결과값:926.91$, 예측값 :993.16$
# 결과값:1539.35$, 예측값 :1681.50$
# 결과값:64839.84$, 예측값 :48298.39$
# 결과값:1135.71$, 예측값 :1260.93$
# 결과값:2480.77$, 예측값 :3611.54$
# 결과값:1122.50$, 예측값 :1722.65$
# 결과값:1650.38$, 예측값 :1341.48$
# 결과값:1028.53$, 예측값 :1091.97$
# 결과값:1529.59$, 예측값 :3343.35$
# 결과값:1968.02$, 예측값 :1256.08$
# 결과값:1036.26$, 예측값 :1731.89$
# 결과값:41077.42$, 예측값 :19385.95$
# 결과값:2568.78$, 예측값 :2036.77$
# 결과값:1864.54$, 예측값 :1677.80$
# 결과값:37187.48$, 예측값 :41748.13$
# 결과값:33084.11$, 예측값 :37828.55$
# 결과값:1968.26$, 예측값 :1447.40$
# 결과값:1929.08$, 예측값 :1220.00$
# 결과값:4861.95$, 예측값 :6816.21$
# 결과값:1472.19$, 예측값 :2087.32$
# 결과값:1534.45$, 예측값 :819.96$
# 결과값:2161.39$, 예측값 :3949.88$
# 결과값:7258.54$, 예측값 :12849.13$
# 결과값:853.18$, 예측값 :1406.47$
# 결과값:764.56$, 예측값 :899.81$
# 결과값:33490.42$, 예측값 :21858.00$
# 결과값:1090.42$, 예측값 :1561.94$
# 결과값:20295.30$, 예측값 :38966.50$
# 결과값:1645.60$, 예측값 :1459.54$
# 결과값:1140.55$, 예측값 :1723.86$
# 결과값:2059.52$, 예측값 :2271.01$
# 결과값:40852.38$, 예측값 :51676.94$
# 결과값:3664.60$, 예측값 :3324.36$
# 결과값:1516.44$, 예측값 :2058.15$
# 결과값:1534.57$, 예측값 :1530.84$
# 결과값:39880.62$, 예측값 :23998.38$
# 결과값:32303.92$, 예측값 :31130.06$
# 결과값:1034.69$, 예측값 :376.60$
# 결과값:1040.04$, 예측값 :1179.19$
# 결과값:2304.43$, 예측값 :3836.15$
# 결과값:946.42$, 예측값 :1788.92$
# 결과값:2021.84$, 예측값 :1912.26$
# 결과값:2337.05$, 예측값 :2572.40$
# 결과값:1335.20$, 예측값 :748.21$
# 결과값:958.73$, 예측값 :173.06$
# 결과값:27705.68$, 예측값 :27796.29$
# 결과값:1303.33$, 예측값 :1259.27$
# 결과값:2053.38$, 예측값 :2435.25$
# 결과값:898.08$, 예측값 :975.66$
# 결과값:64608.96$, 예측값 :66149.20$
# 결과값:3031.80$, 예측값 :4562.67$
# 결과값:992.57$, 예측값 :1002.92$
# 결과값:18681.64$, 예측값 :20734.49$
# 결과값:49595.52$, 예측값 :57366.11$
# 결과값:1034.60$, 예측값 :1346.49$
# 결과값:1031.12$, 예측값 :1212.61$
# 결과값:1010.79$, 예측값 :485.27$
# 결과값:1615.89$, 예측값 :1102.64$
# 결과값:47515.73$, 예측값 :48212.61$
# 결과값:2074.89$, 예측값 :2177.57$
# 결과값:13336.86$, 예측값 :15658.61$
# 결과값:1524.67$, 예측값 :1328.61$
# 결과값:21597.14$, 예측값 :9252.42$
# 결과값:2031.70$, 예측값 :2073.97$
# 결과값:2055.21$, 예측값 :2126.21$
# 결과값:1011.55$, 예측값 :658.32$
# 결과값:5961.15$, 예측값 :6096.56$
# 결과값:1185.32$, 예측값 :715.92$
# 결과값:41928.12$, 예측값 :21302.74$
# 결과값:24718.20$, 예측값 :15998.43$
# 결과값:926.68$, 예측값 :1362.81$
# 결과값:28335.84$, 예측값 :18739.93$
# 결과값:1131.52$, 예측값 :1344.48$
# 결과값:46884.32$, 예측값 :43274.66$
# 결과값:2070.48$, 예측값 :2222.95$
# 결과값:12996.87$, 예측값 :12099.37$
# 결과값:2087.09$, 예측값 :2941.49$
# 결과값:23504.41$, 예측값 :23397.98$
# 결과값:1044.12$, 예측값 :782.07$
# 결과값:1597.90$, 예측값 :1741.35$
# 결과값:51362.03$, 예측값 :22123.41$
# 결과값:35416.68$, 예측값 :25828.94$
# 결과값:2088.91$, 예측값 :2487.23$
# 결과값:928.62$, 예측값 :1422.41$
# 결과값:2157.27$, 예측값 :1541.32$
# 결과값:2179.32$, 예측값 :2240.01$
# 결과값:52848.73$, 예측값 :30864.24$
# 결과값:43216.40$, 예측값 :50138.29$
# 결과값:28995.88$, 예측값 :37865.34$
# 결과값:1273.65$, 예측값 :777.69$
# 결과값:1159.37$, 예측값 :874.81$
# 결과값:2049.90$, 예측값 :2010.47$
# 결과값:940.86$, 예측값 :1070.34$
# 결과값:20128.93$, 예측값 :12585.60$
# 결과값:21089.69$, 예측값 :26592.29$
# 결과값:2851.75$, 예측값 :1494.66$
# 결과값:1650.45$, 예측값 :1777.36$
# 결과값:2197.80$, 예측값 :1809.23$
# 결과값:22582.79$, 예측값 :30129.60$
# 결과값:1184.12$, 예측값 :962.28$
# 결과값:60768.12$, 예측값 :61030.92$
# 결과값:1273.41$, 예측값 :1870.76$
# 결과값:27068.73$, 예측값 :15651.20$
# 결과값:927.64$, 예측값 :1141.22$
# 결과값:2111.79$, 예측값 :1975.00$
# 결과값:948.46$, 예측값 :1180.22$
# 결과값:32381.79$, 예측값 :33416.60$
# 결과값:50138.79$, 예측값 :52930.11$
# 결과값:25244.54$, 예측값 :16782.79$
# 결과값:1056.49$, 예측값 :2453.51$
# 결과값:28350.11$, 예측값 :33206.20$
# 결과값:30920.20$, 예측값 :34858.37$
# 결과값:32098.84$, 예측값 :33368.72$
# 결과값:25659.50$, 예측값 :18408.43$
# 결과값:3054.69$, 예측값 :4592.66$
# 결과값:20418.11$, 예측값 :21013.91$
# 결과값:3514.31$, 예측값 :3263.45$
# 결과값:20148.51$, 예측값 :27576.12$
# 결과값:1427.29$, 예측값 :961.65$
# 결과값:3642.69$, 예측값 :2735.57$
# 결과값:3049.30$, 예측값 :1615.78$
# 결과값:2082.67$, 예측값 :2692.28$
# 결과값:994.18$, 예측값 :803.90$
# 결과값:1997.75$, 예측값 :2119.51$
# 결과값:28308.82$, 예측값 :32114.80$
# 결과값:34746.72$, 예측값 :37486.40$
# 결과값:2249.20$, 예측값 :2016.21$
# 결과값:2154.96$, 예측값 :1937.95$
# 결과값:66986.79$, 예측값 :49297.07$
# 결과값:2014.73$, 예측값 :2290.16$
# 결과값:1242.86$, 예측값 :1244.13$
# 결과값:3067.51$, 예측값 :4445.83$
# 결과값:28443.36$, 예측값 :34997.87$
# 결과값:1988.78$, 예측값 :1051.23$
# 결과값:1658.90$, 예측값 :1373.13$
# 결과값:2242.06$, 예측값 :1112.26$
# 결과값:27413.43$, 예측값 :38849.36$
# 결과값:1975.64$, 예측값 :2283.02$
# 결과값:974.29$, 예측값 :994.38$
# 결과값:21269.26$, 예측값 :45259.94$
# 결과값:21273.74$, 예측값 :38295.68$
# 결과값:27946.11$, 예측값 :34490.12$
# 결과값:1101.12$, 예측값 :675.68$
# 결과값:29581.89$, 예측값 :19500.96$
# 결과값:1623.88$, 예측값 :2122.38$
# 결과값:49865.46$, 예측값 :31131.90$
# 결과값:2054.93$, 예측값 :2505.90$
# 결과값:1794.04$, 예측값 :1300.95$
# 결과값:57439.15$, 예측값 :62195.07$
# 결과값:7247.40$, 예측값 :5238.14$
# 결과값:6087.33$, 예측값 :9053.42$
# 결과값:974.57$, 예측값 :437.08$
# 결과값:1556.58$, 예측값 :748.49$
# 결과값:2480.15$, 예측값 :3915.52$
# 결과값:21735.81$, 예측값 :15306.40$
# 결과값:2304.07$, 예측값 :1508.73$
# 결과값:2757.79$, 예측값 :4114.03$
# 결과값:1199.71$, 예측값 :939.27$
# 결과값:969.38$, 예측값 :1181.79$
# 결과값:2784.33$, 예측값 :4614.42$
# 결과값:2337.00$, 예측값 :2041.93$
# 결과값:38599.92$, 예측값 :37914.39$
# 결과값:1997.22$, 예측값 :1908.31$
# 결과값:1464.42$, 예측값 :1891.54$
# 결과값:945.96$, 예측값 :795.73$
# 결과값:808.01$, 예측값 :1063.96$
# 결과값:1407.85$, 예측값 :1727.51$
# 결과값:1576.77$, 예측값 :2597.79$
# 결과값:44632.77$, 예측값 :21271.85$
# 결과값:1424.23$, 예측값 :798.31$
# 결과값:1063.04$, 예측값 :1021.11$
# 결과값:27205.50$, 예측값 :31333.22$
# 결과값:9348.54$, 예측값 :5468.27$
# 결과값:1085.42$, 예측값 :1210.81$
# 결과값:922.64$, 예측값 :2249.64$
# 결과값:31911.25$, 예측값 :33387.61$
# 결과값:1371.84$, 예측값 :1673.92$
# 결과값:1063.62$, 예측값 :1156.97$
# 결과값:34002.34$, 예측값 :44907.01$
# 결과값:1880.97$, 예측값 :1130.06$
# 결과값:2351.54$, 예측값 :2734.23$
# 결과값:3043.26$, 예측값 :1356.60$
# 결과값:28482.54$, 예측값 :33858.20$
# 결과값:20647.68$, 예측값 :24254.16$
# 결과값:902.12$, 예측값 :1059.03$
# 결과값:22571.78$, 예측값 :12609.53$
# 결과값:2059.79$, 예측값 :5233.40$
# 결과값:56175.76$, 예측값 :29200.31$
# 결과값:64620.82$, 예측값 :22290.24$
# 결과값:1583.70$, 예측값 :1037.15$
# 결과값:39034.32$, 예측값 :44235.73$
# 결과값:2070.33$, 예측값 :1259.59$
# 결과값:2038.04$, 예측값 :2605.69$
# 결과값:2048.36$, 예측값 :1961.83$
# 결과값:37297.65$, 예측값 :27127.31$
# 결과값:1752.72$, 예측값 :2017.25$
# 결과값:2071.48$, 예측값 :1545.24$
# 결과값:1963.28$, 예측값 :1932.33$
# 결과값:1702.71$, 예측값 :1883.54$
# 결과값:2353.56$, 예측값 :2711.94$
# 결과값:1114.81$, 예측값 :1298.00$
# 결과값:1022.80$, 예측값 :1197.37$
# 결과값:2533.68$, 예측값 :1320.57$
# 결과값:2048.45$, 예측값 :2228.92$
# 결과값:2067.68$, 예측값 :2229.17$
# 결과값:2246.26$, 예측값 :2294.97$
# 결과값:1291.89$, 예측값 :1444.95$
# 결과값:1164.15$, 예측값 :1314.68$
# 결과값:2061.80$, 예측값 :2185.73$
# 결과값:893.71$, 예측값 :1339.98$
# 결과값:1276.32$, 예측값 :616.13$
# 결과값:20141.22$, 예측값 :18243.30$
# 결과값:1401.03$, 예측값 :2307.51$
# 결과값:33543.70$, 예측값 :13935.24$
# 결과값:2086.97$, 예측값 :1950.50$
# 결과값:1675.74$, 예측값 :1651.17$
# 결과값:48094.80$, 예측값 :46680.34$
# 결과값:20483.38$, 예측값 :26560.40$
# 결과값:28864.68$, 예측값 :19328.67$
# 결과값:4116.79$, 예측값 :2803.72$
# 결과값:1103.49$, 예측값 :1130.91$
# 결과값:1788.78$, 예측값 :1146.17$
# 결과값:1738.38$, 예측값 :1140.91$
# 결과값:2568.78$, 예측값 :1783.00$
# 결과값:1118.85$, 예측값 :1216.06$
# 결과값:45052.80$, 예측값 :24028.07$
# 결과값:20676.24$, 예측값 :13547.79$
# 결과값:2043.65$, 예측값 :2019.46$
# 결과값:3267.15$, 예측값 :1833.72$
# 결과값:2079.38$, 예측값 :2171.11$
# 결과값:26685.53$, 예측값 :10884.00$
# 결과값:35863.89$, 예측값 :41619.54$
# 결과값:2073.70$, 예측값 :2364.24$
# 결과값:1603.42$, 예측값 :916.34$
# 결과값:1681.61$, 예측값 :1169.03$
# 결과값:33296.64$, 예측값 :38605.64$
# 결과값:2085.19$, 예측값 :2718.91$
# 결과값:2078.47$, 예측값 :1035.32$
# 결과값:2292.07$, 예측값 :818.19$
# 결과값:2736.71$, 예측값 :1360.15$
# 결과값:1188.42$, 예측값 :1056.40$
# 결과값:31056.48$, 예측값 :14776.54$
# 결과값:1447.35$, 예측값 :1041.44$
# 결과값:2070.39$, 예측값 :1359.09$
# 결과값:2105.76$, 예측값 :2563.12$
# 결과값:23325.59$, 예측값 :17531.10$
# 결과값:2043.45$, 예측값 :2629.19$
# 결과값:1750.96$, 예측값 :1826.72$
# 결과값:1997.77$, 예측값 :1315.75$
# 결과값:2080.06$, 예측값 :3089.71$
# 결과값:1659.72$, 예측값 :1348.20$
# 결과값:2112.20$, 예측값 :1231.35$
# 결과값:2070.35$, 예측값 :1894.10$
# 결과값:1997.86$, 예측값 :1777.66$
# 결과값:1401.30$, 예측값 :1563.20$
# 결과값:27388.00$, 예측값 :28808.53$
# 결과값:1786.96$, 예측값 :1216.07$
# 결과값:16067.35$, 예측값 :8896.84$
# 결과값:2104.09$, 예측값 :1509.17$
# 결과값:2061.92$, 예측값 :2641.72$
# 결과값:24933.36$, 예측값 :15925.22$
# 결과값:41953.28$, 예측값 :48763.34$
# 결과값:954.02$, 예측값 :1027.41$
# 결과값:1452.83$, 예측값 :1205.11$
# 결과값:61111.33$, 예측값 :22356.90$
# 결과값:2527.87$, 예측값 :1951.24$
# 결과값:1473.78$, 예측값 :1443.52$
# 결과값:2033.24$, 예측값 :3894.85$
# 결과값:2101.62$, 예측값 :2535.55$
# 결과값:20564.19$, 예측값 :24090.11$
# 결과값:1039.70$, 예측값 :1217.44$
# 결과값:1126.24$, 예측값 :633.99$
# 결과값:974.29$, 예측값 :975.08$
# 결과값:2105.01$, 예측값 :1513.84$
# 결과값:2074.51$, 예측값 :1624.24$
# 결과값:2680.62$, 예측값 :2450.42$
# 결과값:20560.96$, 예측값 :11154.81$
# 결과값:2051.69$, 예측값 :2342.79$
# 결과값:2080.46$, 예측값 :2349.07$
# 결과값:42905.79$, 예측값 :18572.60$
# 결과값:30784.37$, 예측값 :36325.47$
# 결과값:1003.72$, 예측값 :989.82$
# 결과값:1124.88$, 예측값 :1177.43$
# 결과값:27551.75$, 예측값 :16988.84$
# 결과값:21931.09$, 예측값 :24205.95$
# 결과값:839.64$, 예측값 :494.31$
# 결과값:1504.10$, 예측값 :1630.17$
# 결과값:20965.96$, 예측값 :9786.39$
# 결과값:1381.79$, 예측값 :1237.45$
# 결과값:1474.41$, 예측값 :3437.44$
# 결과값:1027.01$, 예측값 :1203.20$
# 결과값:2100.82$, 예측값 :1435.43$
# 결과값:2724.90$, 예측값 :1795.62$
# 결과값:1184.83$, 예측값 :1704.39$
# 결과값:1015.23$, 예측값 :1461.86$
# 결과값:24688.75$, 예측값 :34924.32$
# 결과값:45024.69$, 예측값 :22290.29$
# 결과값:1514.71$, 예측값 :1497.41$
# 결과값:21579.42$, 예측값 :22528.81$
# 결과값:1352.82$, 예측값 :1111.52$
# 결과값:1114.96$, 예측값 :1245.70$
# 결과값:1679.27$, 예측값 :1522.16$
# 결과값:1279.25$, 예측값 :584.59$
# 결과값:1096.51$, 예측값 :1406.22$
# 결과값:2324.68$, 예측값 :2957.99$
# 결과값:25334.40$, 예측값 :38550.34$
# 결과값:36689.98$, 예측값 :48928.86$
# 결과값:37753.27$, 예측값 :31699.80$
# 결과값:1290.74$, 예측값 :993.67$
# 결과값:55114.43$, 예측값 :52281.01$
# 결과값:25091.01$, 예측값 :31374.81$
# 결과값:1765.71$, 예측값 :1609.66$
# 결과값:2053.49$, 예측값 :1881.65$
# 결과값:2055.02$, 예측값 :1634.75$
# 결과값:61082.46$, 예측값 :55298.93$
# 결과값:32951.72$, 예측값 :38725.87$
# 결과값:1311.52$, 예측값 :795.52$
# 결과값:24041.22$, 예측값 :16380.41$
# 결과값:2353.97$, 예측값 :2403.41$
# 결과값:1347.34$, 예측값 :1412.69$
# 결과값:13490.76$, 예측값 :16622.07$
# 결과값:43148.04$, 예측값 :25091.79$
# 결과값:55856.35$, 예측값 :58767.81$
# 결과값:1030.65$, 예측값 :952.50$
# 결과값:49075.34$, 예측값 :45338.61$
# 결과값:37005.07$, 예측값 :23923.34$
# 결과값:31103.12$, 예측값 :16154.20$
# 결과값:1582.79$, 예측값 :1896.05$
# 결과값:1165.41$, 예측값 :1141.14$
# 결과값:2508.64$, 예측값 :2478.06$
# 결과값:1986.62$, 예측값 :2009.64$
# 결과값:47296.08$, 예측값 :27354.02$
# 결과값:1598.46$, 예측값 :1891.67$
# 결과값:26308.95$, 예측값 :18072.89$
# 결과값:2078.78$, 예측값 :2301.08$
# 결과값:15476.93$, 예측값 :18830.40$
# 결과값:22235.62$, 예측값 :16996.61$
# 결과값:1031.20$, 예측값 :1141.49$
# 결과값:24146.99$, 예측값 :39828.64$
# 결과값:20425.49$, 예측값 :26139.06$
# 결과값:1498.35$, 예측값 :2081.44$
# 결과값:1093.01$, 예측값 :1290.03$
# 결과값:63965.99$, 예측값 :32455.44$
# 결과값:1683.22$, 예측값 :1674.71$
# 결과값:3327.44$, 예측값 :5443.40$
# 결과값:39042.12$, 예측값 :39774.61$
# 결과값:66450.93$, 예측값 :58351.82$
# 결과값:2403.31$, 예측값 :3317.17$
# 결과값:52363.90$, 예측값 :25040.54$
# 결과값:22980.98$, 예측값 :10040.47$
# 결과값:40466.40$, 예측값 :46832.22$
# 결과값:2048.08$, 예측값 :1369.16$
# 결과값:753.77$, 예측값 :689.13$
# 결과값:29404.60$, 예측값 :15483.00$
# 결과값:1533.62$, 예측값 :2960.73$
# 결과값:1310.83$, 예측값 :1188.05$
# 결과값:1867.55$, 예측값 :1638.58$
# 결과값:28291.89$, 예측값 :24011.70$
# 결과값:24460.13$, 예측값 :19596.90$
# 결과값:3815.09$, 예측값 :4052.38$
# 결과값:1281.14$, 예측값 :1820.75$
# 결과값:2076.53$, 예측값 :4168.22$
# 결과값:47478.60$, 예측값 :51474.07$
# 결과값:1660.49$, 예측값 :1300.86$
# 결과값:20158.59$, 예측값 :25932.14$
# 결과값:53998.15$, 예측값 :30127.76$
# 결과값:25577.43$, 예측값 :29833.26$
# 결과값:2299.43$, 예측값 :2906.69$
# 결과값:21132.06$, 예측값 :13536.89$
# 결과값:4430.27$, 예측값 :6186.87$
# 결과값:2035.49$, 예측값 :932.38$
# 결과값:1972.58$, 예측값 :2174.52$
# 결과값:1141.31$, 예측값 :1480.38$
# 결과값:2104.08$, 예측값 :2250.84$
# 결과값:4545.71$, 예측값 :1290.11$
# 결과값:2062.70$, 예측값 :2074.61$
# 결과값:1973.83$, 예측값 :4885.98$
# 결과값:1530.31$, 예측값 :1676.75$
# 결과값:33248.83$, 예측값 :36341.79$
# 결과값:25803.49$, 예측값 :29330.21$
# 결과값:20920.19$, 예측값 :26111.25$
# 결과값:2094.68$, 예측값 :2598.59$
# 결과값:23814.90$, 예측값 :18159.18$
# 결과값:40999.92$, 예측값 :24099.75$
# 결과값:1537.90$, 예측값 :1911.42$
# 결과값:1738.11$, 예측값 :1136.49$
# 결과값:21631.88$, 예측값 :17929.96$
# 결과값:1057.50$, 예측값 :762.67$
# 결과값:1030.68$, 예측값 :1360.00$
# 결과값:6006.28$, 예측값 :2259.76$
# 결과값:1058.89$, 예측값 :858.48$
# 결과값:1172.15$, 예측값 :1012.71$
# 결과값:49596.35$, 예측값 :46449.47$
# 결과값:2092.25$, 예측값 :3427.14$
# 결과값:41684.93$, 예측값 :25150.29$
# 결과값:1786.33$, 예측값 :1458.63$
# 결과값:1094.00$, 예측값 :1312.61$
# 결과값:1277.72$, 예측값 :1079.48$
# 결과값:45075.72$, 예측값 :47568.10$
# 결과값:64294.39$, 예측값 :48508.59$
# 결과값:26926.69$, 예측값 :10841.53$
# 결과값:2125.23$, 예측값 :3768.62$
# 결과값:1876.75$, 예측값 :1383.54$
# 결과값:31098.54$, 예측값 :25526.15$
# 결과값:2313.96$, 예측값 :3707.09$
# 결과값:22917.52$, 예측값 :33953.95$
# 결과값:2370.80$, 예측값 :2809.94$
# 결과값:45657.41$, 예측값 :28671.53$
# 결과값:63276.72$, 예측값 :61810.24$
# 결과값:21570.62$, 예측값 :26381.43$
# 결과값:2030.57$, 예측값 :2324.74$
# 결과값:29651.08$, 예측값 :29479.15$
# 결과값:2099.93$, 예측값 :2496.99$
# 결과값:52699.97$, 예측값 :57399.63$
# 결과값:1965.55$, 예측값 :2179.25$
# 결과값:1030.65$, 예측값 :938.98$
# 결과값:2274.17$, 예측값 :1724.70$
# 결과값:2934.68$, 예측값 :2979.45$
# 결과값:1969.80$, 예측값 :2565.47$
# 결과값:1537.92$, 예측값 :1299.51$
# 결과값:2040.00$, 예측값 :2585.56$
# 결과값:1180.68$, 예측값 :1601.47$
# 결과값:1680.03$, 예측값 :2251.02$
# 결과값:1282.57$, 예측값 :1323.42$
# 결과값:1432.39$, 예측값 :581.52$
# 결과값:1881.17$, 예측값 :1315.41$
# 결과값:1135.92$, 예측값 :1087.00$
# 결과값:2063.52$, 예측값 :2312.49$
# 결과값:2031.06$, 예측값 :2365.25$
# 결과값:1329.03$, 예측값 :1547.69$
# 결과값:1862.80$, 예측값 :1551.09$
# 결과값:63065.18$, 예측값 :23302.86$
# 결과값:1773.89$, 예측값 :1823.72$
# 결과값:2074.80$, 예측값 :2151.08$
# 결과값:1882.12$, 예측값 :1724.43$
# 결과값:2060.62$, 예측값 :2343.02$
# 결과값:875.42$, 예측값 :1287.61$
# 결과값:20929.08$, 예측값 :26211.26$
# 결과값:2723.69$, 예측값 :1047.16$
# 결과값:2775.23$, 예측값 :3617.42$
# 결과값:16480.38$, 예측값 :21311.26$
# 결과값:49176.27$, 예측값 :15940.03$
# 결과값:2969.47$, 예측값 :3644.91$
# 결과값:1091.99$, 예측값 :1492.73$
# 결과값:1056.25$, 예측값 :1024.60$
# 결과값:3389.88$, 예측값 :1646.03$
# 결과값:63530.73$, 예측값 :48529.79$
# 결과값:2062.41$, 예측값 :2043.57$
# 결과값:1984.26$, 예측값 :2303.26$
# 결과값:1063.64$, 예측값 :1326.59$
# 결과값:1108.29$, 예측값 :760.38$
# 결과값:2066.92$, 예측값 :1984.66$
# 결과값:1996.74$, 예측값 :985.25$
# 결과값:1417.83$, 예측값 :697.31$
# 결과값:26632.32$, 예측값 :18356.27$
# 결과값:25346.44$, 예측값 :29970.64$
# 결과값:1140.06$, 예측값 :1562.21$
# 결과값:1508.36$, 예측값 :1068.67$
# 결과값:2448.26$, 예측값 :1209.44$
# 결과값:4958.89$, 예측값 :4981.96$
# 결과값:27329.64$, 예측값 :13263.59$
# 결과값:2105.05$, 예측값 :1448.35$
# 결과값:1599.11$, 예측값 :1698.01$
# 결과값:26046.90$, 예측값 :35259.75$
# 결과값:1093.02$, 예측값 :1586.40$
# 결과값:26083.82$, 예측값 :27403.18$
# 결과값:2263.09$, 예측값 :3917.80$
# 결과값:2259.29$, 예측값 :1656.15$
# 결과값:1446.08$, 예측값 :1502.42$
# 결과값:1861.10$, 예측값 :1994.51$
# 결과값:1289.35$, 예측값 :1254.04$
# 결과값:46719.55$, 예측값 :17951.26$
# 결과값:68617.96$, 예측값 :26955.56$
# 결과값:974.54$, 예측값 :1431.97$
# 결과값:1973.74$, 예측값 :2271.54$
# 결과값:36908.43$, 예측값 :21086.98$
# 결과값:2241.65$, 예측값 :1463.36$
# 결과값:4115.50$, 예측값 :6207.06$
# 결과값:6072.07$, 예측값 :10163.93$
# 결과값:1528.57$, 예측값 :2030.05$
# 결과값:30834.02$, 예측값 :17889.42$
# 결과값:902.31$, 예측값 :1248.30$
# 결과값:27424.80$, 예측값 :17321.95$
# 결과값:20173.51$, 예측값 :13554.11$
# 결과값:38389.60$, 예측값 :27551.16$
# 결과값:2544.90$, 예측값 :1799.35$
# 결과값:1183.00$, 예측값 :1512.05$
# 결과값:15379.60$, 예측값 :20447.88$
# 결과값:2452.64$, 예측값 :4651.24$
# 결과값:2080.00$, 예측값 :2284.96$
# 결과값:1018.38$, 예측값 :581.38$
# 결과값:1149.54$, 예측값 :1316.72$
# 결과값:1532.76$, 예측값 :1027.12$
# 결과값:2139.78$, 예측값 :1922.84$
# 결과값:27628.26$, 예측값 :20476.37$
# 결과값:1211.61$, 예측값 :1479.65$
# 결과값:58468.02$, 예측값 :25421.41$
# 결과값:1199.98$, 예측값 :1217.51$
# 결과값:1332.09$, 예측값 :1383.08$
# 결과값:3521.16$, 예측값 :1164.40$
# 결과값:2296.93$, 예측값 :1455.60$
# 결과값:2002.90$, 예측값 :911.81$
# 결과값:1142.87$, 예측값 :1844.77$
# 결과값:1784.47$, 예측값 :1228.48$
# 결과값:32632.75$, 예측값 :36407.62$
# 결과값:1418.06$, 예측값 :1539.07$
# 결과값:22188.46$, 예측값 :20963.46$
# 결과값:846.08$, 예측값 :1168.62$
# 결과값:54628.83$, 예측값 :23933.43$
# 결과값:4861.95$, 예측값 :10001.93$
# 결과값:57017.00$, 예측값 :25526.61$
# 결과값:27122.16$, 예측값 :13715.53$
# 결과값:3135.82$, 예측값 :1993.34$
# 결과값:2247.53$, 예측값 :2045.43$
# 결과값:2090.55$, 예측값 :1554.91$
# 결과값:904.91$, 예측값 :878.20$
# 결과값:1055.41$, 예측값 :1181.21$
# 결과값:1799.85$, 예측값 :2129.13$
# 결과값:2048.36$, 예측값 :1746.68$
# 결과값:56407.68$, 예측값 :26615.94$
# 결과값:1133.31$, 예측값 :2195.98$
# 결과값:2290.68$, 예측값 :431.60$
# 결과값:1739.96$, 예측값 :2471.34$
# 결과값:2061.87$, 예측값 :2094.88$
# 결과값:49964.93$, 예측값 :22798.48$
# 결과값:20503.13$, 예측값 :35014.30$
# 결과값:2077.11$, 예측값 :2381.93$
# 결과값:1066.07$, 예측값 :524.50$
# 결과값:1400.63$, 예측값 :1028.19$
# 결과값:1339.58$, 예측값 :1963.14$
# 결과값:41660.11$, 예측값 :48825.07$
# 결과값:29512.98$, 예측값 :30498.27$
# 결과값:901.78$, 예측값 :732.06$
# 결과값:1277.75$, 예측값 :866.26$
# 결과값:863.25$, 예측값 :1158.44$
# 결과값:2354.34$, 예측값 :1311.97$
# 결과값:20398.14$, 예측값 :24319.71$
# 결과값:3829.74$, 예측값 :4953.17$
# 결과값:64372.54$, 예측값 :36631.15$
# 결과값:33785.08$, 예측값 :39550.45$
# 결과값:2337.35$, 예측값 :2212.87$
# 결과값:63271.35$, 예측값 :54475.66$
# 결과값:21725.54$, 예측값 :25638.14$
# 결과값:2015.34$, 예측값 :2066.74$
# 결과값:1354.57$, 예측값 :1259.61$
# 결과값:1698.83$, 예측값 :1827.76$
# 결과값:1526.62$, 예측값 :1715.88$
# 결과값:50279.42$, 예측값 :43425.57$
# 결과값:2069.41$, 예측값 :1431.29$
# 결과값:1317.62$, 예측값 :1685.53$
# 결과값:1119.46$, 예측값 :735.66$
# 결과값:47252.40$, 예측값 :45174.49$
# 결과값:35524.48$, 예측값 :33405.70$
# 결과값:27314.91$, 예측값 :29939.36$
# 결과값:1100.09$, 예측값 :1407.13$
# 결과값:25135.50$, 예측값 :27668.16$
# 결과값:59670.09$, 예측값 :25626.77$
# 결과값:24656.52$, 예측값 :33444.56$
# 결과값:2471.39$, 예측값 :5855.74$
# 결과값:32102.37$, 예측값 :37842.36$
# 결과값:2516.77$, 예측값 :3746.07$
# 결과값:1740.29$, 예측값 :2802.23$
# 결과값:2448.32$, 예측값 :2485.82$
# 결과값:1036.97$, 예측값 :1200.71$
# 결과값:42701.88$, 예측값 :15356.35$
# 결과값:9504.07$, 예측값 :25400.27$
# 결과값:2187.19$, 예측값 :2608.49$
# 결과값:926.34$, 예측값 :732.01$
# 결과값:1885.25$, 예측값 :1096.85$
# 결과값:2029.39$, 예측값 :1733.31$
# 결과값:1423.71$, 예측값 :1091.49$
# 결과값:38225.91$, 예측값 :19255.11$
# 결과값:2027.51$, 예측값 :939.96$
# 결과값:2055.01$, 예측값 :2010.53$
# 결과값:1987.22$, 예측값 :3747.26$
# 결과값:1948.11$, 예측값 :1795.53$
# 결과값:4158.33$, 예측값 :2345.68$
# 결과값:4510.98$, 예측값 :3873.18$
# 결과값:1031.66$, 예측값 :670.34$
# 결과값:2018.05$, 예측값 :1908.91$
# 결과값:24901.69$, 예측값 :17361.03$
# 결과값:27591.72$, 예측값 :26141.65$
# 결과값:2448.26$, 예측값 :1635.95$
# 결과값:4007.88$, 예측값 :5138.25$
# 결과값:1012.33$, 예측값 :1389.10$
# 결과값:901.80$, 예측값 :601.65$
# 결과값:1212.10$, 예측값 :1354.32$
# 결과값:2568.80$, 예측값 :1547.29$
# 결과값:69759.86$, 예측값 :57068.81$
# 결과값:1800.96$, 예측값 :1750.16$
# 결과값:33085.57$, 예측값 :38721.36$
# 결과값:2508.85$, 예측값 :1941.92$
# 결과값:1162.92$, 예측값 :1025.82$
# 결과값:49931.34$, 예측값 :44089.87$
# 결과값:66413.49$, 예측값 :46433.79$
# 결과값:33397.60$, 예측값 :30975.05$
# 결과값:2631.11$, 예측값 :1589.48$
# 결과값:1147.78$, 예측값 :595.64$
# 결과값:886.62$, 예측값 :1286.85$
# 결과값:1884.69$, 예측값 :1277.00$
# 결과값:49484.99$, 예측값 :21670.85$
# 결과값:46774.57$, 예측값 :23256.90$
# 결과값:36866.22$, 예측값 :45406.70$
# 결과값:1720.93$, 예측값 :1397.55$
# 결과값:2467.91$, 예측값 :3016.51$
# 결과값:4092.84$, 예측값 :1812.75$
# 결과값:2802.83$, 예측값 :1111.60$
# 결과값:1991.83$, 예측값 :2272.14$
# 결과값:945.76$, 예측값 :694.41$
# 결과값:1326.33$, 예측값 :1466.59$
# 결과값:2067.92$, 예측값 :2080.44$
# 결과값:4029.32$, 예측값 :5829.08$
# 결과값:2113.97$, 예측값 :2490.93$
# 결과값:21068.75$, 예측값 :24696.74$
# 결과값:31342.97$, 예측값 :24535.06$
# 결과값:1012.26$, 예측값 :1029.53$
# 결과값:2044.11$, 예측값 :2134.88$
# 결과값:31199.25$, 예측값 :32647.18$
# 결과값:2362.83$, 예측값 :3446.35$
# 결과값:61067.60$, 예측값 :25963.81$
# 결과값:2596.11$, 예측값 :4091.28$
# 결과값:31859.88$, 예측값 :51492.87$
# 결과값:3456.76$, 예측값 :1374.74$
# 결과값:43163.33$, 예측값 :44194.01$
# 결과값:20455.34$, 예측값 :23339.90$
# 결과값:33859.16$, 예측값 :47840.43$
# 결과값:2052.56$, 예측값 :1867.94$
# 결과값:1790.94$, 예측값 :1255.12$
# 결과값:2062.70$, 예측값 :2117.02$
# 결과값:2282.33$, 예측값 :3519.08$
# 결과값:1991.02$, 예측값 :2103.23$
# 결과값:977.83$, 예측값 :817.87$
# 결과값:23887.50$, 예측값 :31290.36$
# 결과값:1403.68$, 예측값 :857.30$
# 결과값:895.73$, 예측값 :1006.61$
# 결과값:1972.43$, 예측값 :1537.37$
# 결과값:1960.82$, 예측값 :2854.52$
# 결과값:1012.99$, 예측값 :1063.29$
# 결과값:1161.67$, 예측값 :1105.59$
# 결과값:1580.00$, 예측값 :1803.94$
# 결과값:930.75$, 예측값 :1302.64$
# 결과값:30895.80$, 예측값 :20797.36$
# 결과값:1679.17$, 예측값 :1958.22$
# 결과값:1107.02$, 예측값 :1126.69$
# 결과값:1445.34$, 예측값 :1303.00$
# 결과값:35410.46$, 예측값 :42775.67$
# 결과값:1255.25$, 예측값 :1209.39$
# 결과값:40003.27$, 예측값 :17385.60$
# 결과값:2528.27$, 예측값 :1560.17$
# 결과값:2993.13$, 예측값 :1985.36$
# 결과값:2014.75$, 예측값 :3185.55$
# 결과값:1444.09$, 예측값 :773.40$
# 결과값:43204.90$, 예측값 :18855.44$
# 결과값:2075.87$, 예측값 :2334.82$
# 결과값:67738.23$, 예측값 :51795.37$
# 결과값:1746.93$, 예측값 :3363.84$
# 결과값:3460.94$, 예측값 :2674.02$
# 결과값:1328.98$, 예측값 :1643.45$
# 결과값:25441.10$, 예측값 :27858.38$
# 결과값:63873.39$, 예측값 :35234.00$
# 결과값:21091.67$, 예측값 :12314.49$
# 결과값:1366.28$, 예측값 :1748.49$
# 결과값:1096.64$, 예측값 :766.52$
# 결과값:1473.04$, 예측값 :1588.40$
# 결과값:23272.44$, 예측값 :27074.67$
# 결과값:2322.22$, 예측값 :1362.82$
# 결과값:1836.29$, 예측값 :1385.82$
# 결과값:45836.54$, 예측값 :27895.68$
# 결과값:1145.90$, 예측값 :396.12$
# 결과값:2104.05$, 예측값 :2501.36$
# 결과값:23901.09$, 예측값 :15762.32$
# 결과값:1839.55$, 예측값 :1626.87$
# 결과값:2180.03$, 예측값 :2074.57$
# 결과값:24964.93$, 예측값 :26565.47$
# 결과값:2006.40$, 예측값 :1817.75$
# 결과값:1164.88$, 예측값 :831.42$
# 결과값:22801.15$, 예측값 :15267.51$
# 결과값:1277.73$, 예측값 :1449.96$
# 결과값:1041.72$, 예측값 :1137.04$
# 결과값:1030.22$, 예측값 :902.63$
# 결과값:70749.53$, 예측값 :45726.54$
# 결과값:2987.55$, 예측값 :3534.79$
# 결과값:969.79$, 예측값 :663.50$
# 결과값:23207.22$, 예측값 :12999.92$
# 결과값:26625.14$, 예측값 :33478.31$
# 결과값:1041.16$, 예측값 :966.70$
# 결과값:2081.37$, 예측값 :3146.22$
# 결과값:26746.08$, 예측값 :33546.86$
# 결과값:1970.49$, 예측값 :1225.09$
# 결과값:2036.90$, 예측값 :1353.05$
# 결과값:2304.45$, 예측값 :2550.50$
# 결과값:2083.80$, 예측값 :2389.03$
# 결과값:22399.73$, 예측값 :21603.50$
# 결과값:1175.14$, 예측값 :831.95$
# 결과값:4521.00$, 예측값 :3001.61$
# 결과값:1462.04$, 예측값 :1086.21$
# 결과값:1348.76$, 예측값 :871.59$
# 결과값:1346.68$, 예측값 :977.38$
# 결과값:1555.63$, 예측값 :1741.84$
# 결과값:1968.43$, 예측값 :1528.11$
# 결과값:22106.31$, 예측값 :23224.35$
# 결과값:1309.02$, 예측값 :1114.38$
# 결과값:4833.72$, 예측값 :2041.17$
# 결과값:1532.04$, 예측값 :2949.25$
# 결과값:1030.06$, 예측값 :934.45$
# 결과값:1095.73$, 예측값 :1113.52$
# 결과값:20500.37$, 예측값 :26093.41$
# 결과값:2031.58$, 예측값 :1670.17$
# 결과값:20419.78$, 예측값 :30932.90$
# 결과값:1873.45$, 예측값 :2138.60$
# 결과값:1699.36$, 예측값 :1239.49$
# 결과값:2034.00$, 예측값 :2563.84$
# 결과값:2094.76$, 예측값 :2162.54$
# 결과값:58437.60$, 예측값 :59078.93$
# 결과값:2024.70$, 예측값 :1412.81$
# 결과값:1581.86$, 예측값 :1628.86$
# 결과값:2095.89$, 예측값 :1791.83$
# 결과값:30428.44$, 예측값 :41171.50$
# 결과값:9598.23$, 예측값 :11985.54$
# 결과값:1105.87$, 예측값 :2207.44$
# 결과값:829.54$, 예측값 :1086.21$
# 결과값:1382.34$, 예측값 :2215.16$
# 결과값:1554.79$, 예측값 :1717.68$
# 결과값:5309.69$, 예측값 :2106.23$
# 결과값:1722.11$, 예측값 :2434.14$
# 결과값:1000.72$, 예측값 :791.99$
# 결과값:40078.74$, 예측값 :24082.95$
# 결과값:2350.82$, 예측값 :2269.31$
# 결과값:1063.09$, 예측값 :1138.50$
# 결과값:21648.12$, 예측값 :19761.15$
# 결과값:55408.52$, 예측값 :40784.84$
# 결과값:1582.45$, 예측값 :1950.67$
# 결과값:1028.04$, 예측값 :975.65$
# 결과값:45801.04$, 예측값 :33300.83$
# 결과값:38190.98$, 예측값 :24300.90$
# 결과값:834.91$, 예측값 :1373.07$
# 결과값:1524.65$, 예측값 :1775.51$
# 결과값:2061.99$, 예측값 :2224.22$
# 결과값:25038.87$, 예측값 :23633.71$
# 결과값:1135.48$, 예측값 :811.23$
# 결과값:2082.03$, 예측값 :1855.20$
# 결과값:1965.55$, 예측값 :2166.07$
# 결과값:1562.27$, 예측값 :1302.54$
# 결과값:2047.47$, 예측값 :1969.85$
# 결과값:2874.53$, 예측값 :4284.07$
# 결과값:1430.74$, 예측값 :1428.29$
# 결과값:1768.87$, 예측값 :1625.35$
# 결과값:1445.15$, 예측값 :809.15$
# 결과값:16186.73$, 예측값 :22953.72$
# 결과값:838.36$, 예측값 :1345.98$
# 결과값:1805.77$, 예측값 :1751.43$
# 결과값:2453.10$, 예측값 :2458.85$
# 결과값:38667.58$, 예측값 :46506.12$
# 결과값:26064.87$, 예측값 :27895.56$
# 결과값:1424.92$, 예측값 :1705.57$
# 결과값:2304.05$, 예측값 :2616.96$
# 결과값:26611.96$, 예측값 :28707.44$
# 결과값:23587.59$, 예측값 :24182.97$
# 결과값:2179.02$, 예측값 :2597.10$
# 결과값:34571.88$, 예측값 :23716.28$
# 결과값:1763.52$, 예측값 :1582.20$
# 결과값:1731.02$, 예측값 :2128.07$
# 결과값:1196.50$, 예측값 :1223.98$
# 결과값:1624.24$, 예측값 :2027.25$
# 결과값:866.33$, 예측값 :984.94$
# 결과값:2045.64$, 예측값 :1562.34$
# 결과값:2279.60$, 예측값 :2462.22$
# 결과값:1042.12$, 예측값 :1370.96$
# 결과값:41917.20$, 예측값 :48394.71$
# 결과값:2331.76$, 예측값 :1533.69$
# 결과값:1854.94$, 예측값 :1755.51$
# 결과값:2028.20$, 예측값 :2321.58$
# 결과값:946.40$, 예측값 :1369.35$
# 결과값:2318.26$, 예측값 :1359.66$
# 결과값:22295.68$, 예측값 :31933.82$
# 결과값:2106.75$, 예측값 :2281.10$
# 결과값:1538.85$, 예측값 :1628.38$
# 결과값:56131.02$, 예측값 :53818.07$
# 결과값:1697.10$, 예측값 :909.91$
# 결과값:1537.39$, 예측값 :1210.93$
# 결과값:1267.50$, 예측값 :1248.90$
# 결과값:1538.81$, 예측값 :1448.54$
# 결과값:44832.26$, 예측값 :44731.35$
# 결과값:26450.86$, 예측값 :14061.26$
# 결과값:898.56$, 예측값 :1161.44$
# 결과값:2064.42$, 예측값 :1730.67$
# 결과값:50439.17$, 예측값 :59853.81$
# 결과값:1972.37$, 예측값 :1712.11$
# 결과값:42306.20$, 예측값 :25667.57$
# 결과값:26153.60$, 예측값 :10747.91$
# 결과값:974.35$, 예측값 :684.33$
# 결과값:1604.70$, 예측값 :2565.35$
# 결과값:3229.56$, 예측값 :4346.35$
# 결과값:1973.23$, 예측값 :3483.51$
# 결과값:20568.60$, 예측값 :27800.19$
# 결과값:2062.01$, 예측값 :2633.35$
# 결과값:1134.51$, 예측값 :428.06$
# 결과값:49340.63$, 예측값 :22443.56$
# 결과값:34211.50$, 예측값 :34625.83$
# 결과값:68659.03$, 예측값 :25363.80$
# 결과값:25612.14$, 예측값 :35436.47$
# 결과값:35719.12$, 예측값 :47299.94$
# 결과값:33864.78$, 예측값 :37244.12$
# 결과값:3655.62$, 예측값 :2314.92$
# 결과값:44619.79$, 예측값 :46527.15$
# 결과값:1426.55$, 예측값 :792.90$
# 결과값:1354.03$, 예측값 :1665.12$
# 결과값:20166.87$, 예측값 :22964.67$
# 결과값:30082.42$, 예측값 :24543.20$
# 결과값:3483.07$, 예측값 :3586.77$
# 결과값:25383.84$, 예측값 :27927.89$
# 결과값:1720.61$, 예측값 :1494.89$
# 결과값:2034.78$, 예측값 :2229.59$
# 결과값:1148.96$, 예측값 :1360.94$
# 결과값:1256.24$, 예측값 :1067.51$
# 결과값:1854.92$, 예측값 :1108.34$
# 결과값:1403.12$, 예측값 :1323.30$
# 결과값:25034.76$, 예측값 :21075.69$
# 결과값:18729.27$, 예측값 :11171.58$
# 결과값:1310.14$, 예측값 :1080.51$
# 결과값:41407.39$, 예측값 :28262.28$
# 결과값:49397.98$, 예측값 :61319.11$
# 결과값:1032.64$, 예측값 :699.14$
# 결과값:26932.46$, 예측값 :19124.62$
# 결과값:6086.00$, 예측값 :7665.38$
# 결과값:29562.00$, 예측값 :38081.34$
# 결과값:1199.98$, 예측값 :811.08$
# 결과값:848.80$, 예측값 :3836.19$
# 결과값:1698.05$, 예측값 :1931.67$
# 결과값:838.41$, 예측값 :610.02$
# 결과값:2028.12$, 예측값 :2085.10$
# 결과값:27902.71$, 예측값 :36746.84$
# 결과값:12627.71$, 예측값 :20749.56$
# 결과값:3018.02$, 예측값 :4591.66$
# 결과값:1038.49$, 예측값 :819.55$
# 결과값:49799.86$, 예측값 :20465.00$
# 결과값:20280.75$, 예측값 :24212.47$
# 결과값:1669.15$, 예측값 :1677.22$
# 결과값:40273.43$, 예측값 :40808.77$
# 결과값:43612.11$, 예측값 :43805.11$
# 결과값:2089.62$, 예측값 :1694.34$
# 결과값:808.48$, 예측값 :1380.30$
# 결과값:1789.73$, 예측값 :1605.36$
# 결과값:27909.02$, 예측값 :37297.65$
# 결과값:4011.70$, 예측값 :4286.91$
# 결과값:2953.85$, 예측값 :7181.97$
# 결과값:1058.95$, 예측값 :1402.03$
# 결과값:2040.00$, 예측값 :2179.08$
# 결과값:1086.84$, 예측값 :1021.53$
# 결과값:1145.23$, 예측값 :1243.13$
# 결과값:1124.70$, 예측값 :1702.95$
# 결과값:2551.35$, 예측값 :2266.68$
# 결과값:1951.16$, 예측값 :1583.87$
# 결과값:853.01$, 예측값 :1053.04$
# 결과값:2213.67$, 예측값 :3034.84$
# 결과값:3650.11$, 예측값 :5719.13$
# 결과값:49707.29$, 예측값 :54130.71$
# 결과값:2187.15$, 예측값 :2379.64$
# 결과값:962.18$, 예측값 :524.22$
# 결과값:3173.68$, 예측값 :4128.76$
# 결과값:2166.14$, 예측값 :597.31$
# 결과값:1983.47$, 예측값 :1262.97$
# 결과값:3519.28$, 예측값 :4492.69$
# 결과값:44591.90$, 예측값 :19660.52$
# 결과값:1173.20$, 예측값 :867.73$
# 결과값:29596.65$, 예측값 :43628.12$
# 결과값:2421.52$, 예측값 :3447.26$
# 결과값:41953.98$, 예측값 :28300.58$
# 결과값:947.09$, 예측값 :2087.19$
# 결과값:846.74$, 예측값 :745.76$
# 결과값:58291.08$, 예측값 :54311.74$
# 결과값:1752.65$, 예측값 :873.72$
# 결과값:34346.46$, 예측값 :31442.74$
# 결과값:974.35$, 예측값 :1197.78$
# 결과값:63577.08$, 예측값 :36790.14$
# 결과값:40550.62$, 예측값 :45910.50$
# 결과값:1056.32$, 예측값 :1070.28$
# 결과값:1950.75$, 예측값 :2054.96$
# 결과값:2665.60$, 예측값 :1402.03$
# 결과값:1328.93$, 예측값 :1378.96$
# 결과값:1116.82$, 예측값 :1050.01$
# 결과값:1358.39$, 예측값 :837.43$
# 결과값:1470.58$, 예측값 :1515.54$
# 결과값:23199.27$, 예측값 :26081.83$
# 결과값:1260.79$, 예측값 :1148.93$
# 결과값:2057.03$, 예측값 :720.55$
# 결과값:2036.90$, 예측값 :1639.74$
# 결과값:1115.81$, 예측값 :932.18$
# 결과값:52137.95$, 예측값 :47763.28$
# 결과값:1481.29$, 예측값 :1887.27$
# 결과값:1718.73$, 예측값 :1804.79$
# 결과값:1379.74$, 예측값 :1219.38$
# 결과값:4379.77$, 예측값 :4238.88$
# 결과값:1155.32$, 예측값 :850.01$
# 결과값:2030.54$, 예측값 :2095.63$
# 결과값:30493.40$, 예측값 :23630.68$
# 결과값:1606.66$, 예측값 :1199.23$
# 결과값:1819.29$, 예측값 :1178.19$
# 결과값:55489.43$, 예측값 :22004.50$
# 결과값:1329.81$, 예측값 :1059.24$
# 결과값:40908.44$, 예측값 :46307.34$
# 결과값:2262.98$, 예측값 :1900.33$
# 결과값:1368.98$, 예측값 :1173.44$
# 결과값:31817.76$, 예측값 :35740.52$
# 결과값:1660.54$, 예측값 :581.41$
# 결과값:1473.19$, 예측값 :1755.29$
# 결과값:1462.03$, 예측값 :1648.57$
# 결과값:1163.62$, 예측값 :1566.45$
# 결과값:27119.82$, 예측값 :15832.47$
# 결과값:29652.40$, 예측값 :21467.86$
# 결과값:26213.40$, 예측값 :29655.37$
# 결과값:31337.89$, 예측값 :44003.33$
# 결과값:1922.98$, 예측값 :1322.08$
# 결과값:1429.00$, 예측값 :1122.37$
# 결과값:837.48$, 예측값 :656.39$
# 결과값:1205.93$, 예측값 :942.43$
# 결과값:1660.49$, 예측값 :1184.36$
# 결과값:27505.31$, 예측값 :32044.48$
# 결과값:1093.73$, 예측값 :582.60$
# 결과값:1723.88$, 예측값 :1421.95$
# 결과값:2088.91$, 예측값 :1818.61$
# 결과값:2031.45$, 예측값 :1853.49$
# 결과값:2060.18$, 예측값 :3926.53$
# 결과값:943.90$, 예측값 :1249.02$
# 결과값:2028.32$, 예측값 :3331.75$
# 결과값:1739.94$, 예측값 :1436.64$
# 결과값:2304.07$, 예측값 :1815.80$
# 결과값:55834.65$, 예측값 :22675.71$
# 결과값:1697.76$, 예측값 :2681.52$
# 결과값:36516.67$, 예측값 :43257.18$
# 결과값:2041.08$, 예측값 :1681.57$
# 결과값:58721.83$, 예측값 :61941.54$
# 결과값:1188.76$, 예측값 :1157.68$
# 결과값:20656.12$, 예측값 :25560.67$
# 결과값:1504.71$, 예측값 :2405.83$
# 결과값:924.62$, 예측값 :755.97$
# 결과값:2084.78$, 예측값 :2596.21$
# 결과값:2364.87$, 예측값 :1537.93$
# 결과값:1212.63$, 예측값 :1410.56$
# 결과값:23349.63$, 예측값 :18476.91$
# 결과값:34224.76$, 예측값 :25920.23$
# 결과값:41079.67$, 예측값 :26196.50$
# 결과값:52930.41$, 예측값 :42601.99$
# 결과값:2568.78$, 예측값 :2727.93$
# 결과값:2126.49$, 예측값 :2408.70$
# 결과값:38149.61$, 예측값 :15842.14$
# 결과값:2122.91$, 예측값 :2520.67$
# 결과값:1986.00$, 예측값 :3741.99$
# 결과값:28861.48$, 예측값 :13734.46$
# 결과값:2337.69$, 예측값 :2322.56$
# 결과값:6150.68$, 예측값 :6012.67$
# 결과값:2356.77$, 예측값 :3079.61$
# 결과값:2696.13$, 예측값 :4960.24$
# 결과값:30234.83$, 예측값 :30601.16$
# 결과값:67290.13$, 예측값 :67886.40$
# 결과값:37691.55$, 예측값 :14734.04$
# 결과값:4420.96$, 예측값 :2320.66$
# 결과값:9640.53$, 예측값 :14644.51$
# 결과값:1176.27$, 예측값 :1671.57$
# 결과값:2077.89$, 예측값 :2555.07$
# 결과값:1799.85$, 예측값 :665.00$
# 결과값:1424.77$, 예측값 :1167.16$
# 결과값:2895.53$, 예측값 :4512.50$
# 결과값:57498.09$, 예측값 :55470.55$
# 결과값:34225.71$, 예측값 :27802.14$
# 결과값:22009.90$, 예측값 :13483.23$
# 결과값:3632.78$, 예측값 :1580.92$
# 결과값:1348.62$, 예측값 :1303.66$
# 결과값:2045.06$, 예측값 :2451.62$
# 결과값:21373.06$, 예측값 :28824.29$
# 결과값:1123.55$, 예측값 :1895.33$
# 결과값:41371.20$, 예측값 :33987.30$
# 결과값:819.30$, 예측값 :555.90$
# 결과값:1293.26$, 예측값 :1353.73$
# 결과값:2057.27$, 예측값 :2334.07$
# 결과값:1702.84$, 예측값 :1729.76$
# 결과값:1544.19$, 예측값 :1015.31$
# 결과값:22499.57$, 예측값 :20045.72$
# 결과값:2263.49$, 예측값 :1873.14$
# 결과값:1042.26$, 예측값 :1268.42$
# 결과값:26351.57$, 예측값 :16796.46$
# 결과값:2904.99$, 예측값 :3598.03$
# 결과값:1696.00$, 예측값 :1873.76$
# 결과값:1463.57$, 예측값 :1560.12$
# 결과값:1822.60$, 예측값 :1421.47$
# 결과값:2785.64$, 예측값 :6019.72$
# 결과값:26256.28$, 예측값 :42308.63$
# 결과값:22785.34$, 예측값 :21411.09$
# 결과값:2015.41$, 예측값 :1523.62$
# 결과값:54478.32$, 예측값 :51907.41$
# 결과값:1291.97$, 예측값 :777.40$
# 결과값:2099.04$, 예측값 :2311.36$
# 결과값:2079.23$, 예측값 :1645.71$
# 결과값:1837.89$, 예측값 :1158.88$
# 결과값:2249.55$, 예측값 :1677.43$
# 결과값:37633.44$, 예측값 :38349.58$
# 결과값:38228.78$, 예측값 :15897.54$
# 결과값:3709.10$, 예측값 :15795.09$
# 결과값:38007.72$, 예측값 :48505.21$
# 결과값:61536.29$, 예측값 :72237.87$
# 결과값:2412.96$, 예측값 :1589.64$
# 결과값:1985.94$, 예측값 :3149.07$
# 결과값:1717.94$, 예측값 :1432.48$
# 결과값:4408.70$, 예측값 :3888.38$
# 결과값:1993.12$, 예측값 :1617.04$
# 결과값:2123.38$, 예측값 :1730.82$
# 결과값:1672.80$, 예측값 :1523.45$
# 결과값:3442.51$, 예측값 :4779.55$
# 결과값:20586.85$, 예측값 :32173.24$
# 결과값:4352.31$, 예측값 :6663.34$
# 결과값:2273.98$, 예측값 :2201.75$
# 결과값:53764.84$, 예측값 :23938.19$
# 결과값:1428.42$, 예측값 :1357.52$
# 결과값:2098.19$, 예측값 :2171.07$
# 결과값:2028.27$, 예측값 :2675.59$
# 결과값:20860.01$, 예측값 :11575.01$
# 결과값:33980.23$, 예측값 :16790.03$
# 결과값:1281.80$, 예측값 :1403.28$
# 결과값:45057.48$, 예측값 :35978.48$
# 결과값:69297.88$, 예측값 :24665.99$
# 결과값:1474.59$, 예측값 :1818.94$
# 결과값:981.38$, 예측값 :1229.30$
# 결과값:2399.71$, 예측값 :4340.82$
# 결과값:3784.61$, 예측값 :4773.67$
# 결과값:1006.26$, 예측값 :1566.06$
# 결과값:51524.24$, 예측값 :68921.63$
# 결과값:18439.82$, 예측값 :9422.87$
# 결과값:1430.75$, 예측값 :2046.99$
# 결과값:2112.84$, 예측값 :1029.87$
# 결과값:22167.26$, 예측값 :38094.85$
# 결과값:3260.31$, 예측값 :1662.75$
# 결과값:1990.53$, 예측값 :2388.32$
# 결과값:1872.54$, 예측값 :1258.73$
# 결과값:30273.44$, 예측값 :29716.26$
# 결과값:1473.68$, 예측값 :1430.74$
# 결과값:1141.09$, 예측값 :1005.90$
# 결과값:1153.26$, 예측값 :1447.94$
# 결과값:1587.41$, 예측값 :1770.13$
# 결과값:2106.37$, 예측값 :1867.86$
# 결과값:4782.45$, 예측값 :3833.14$
# 결과값:1598.08$, 예측값 :1555.66$
# 결과값:2187.06$, 예측값 :2238.06$
# 결과값:1322.54$, 예측값 :1063.60$
# 결과값:28005.62$, 예측값 :17121.55$
# 결과값:1124.10$, 예측값 :1070.79$
# 결과값:64372.54$, 예측값 :26528.93$
# 결과값:944.85$, 예측값 :1038.12$
# 결과값:29871.82$, 예측값 :28941.26$
# 결과값:62259.60$, 예측값 :61095.58$
# 결과값:963.82$, 예측값 :899.61$
# 결과값:2102.50$, 예측값 :1366.48$
# 결과값:31780.32$, 예측값 :18172.88$
# 결과값:13500.16$, 예측값 :16430.66$
# 결과값:21268.81$, 예측값 :18270.83$
# 결과값:41870.40$, 예측값 :29677.47$
# 결과값:28881.90$, 예측값 :17695.52$
# 결과값:1040.08$, 예측값 :1048.78$
# 결과값:35880.23$, 예측값 :39636.80$
# 결과값:2113.04$, 예측값 :1920.17$
# 결과값:34948.31$, 예측값 :26602.57$
# 결과값:1992.91$, 예측값 :1603.22$
# 결과값:2094.05$, 예측값 :1605.13$
# 결과값:21277.73$, 예측값 :23563.74$
# 결과값:1498.19$, 예측값 :1565.90$
# 결과값:1036.88$, 예측값 :470.48$
# 결과값:1428.81$, 예측값 :2779.82$
# 결과값:39855.05$, 예측값 :43988.96$
# 결과값:2508.02$, 예측값 :2354.38$
# 결과값:1799.78$, 예측값 :1921.89$
# 결과값:25584.00$, 예측값 :17069.80$
# 결과값:1751.37$, 예측값 :4462.00$
# 결과값:1093.23$, 예측값 :1693.06$
# 결과값:68574.48$, 예측값 :22308.80$
# 결과값:2033.31$, 예측값 :1999.14$
# 결과값:1658.74$, 예측값 :1416.17$
# 결과값:23495.78$, 예측값 :14041.67$
# 결과값:25892.41$, 예측값 :36532.34$
# 결과값:2352.55$, 예측값 :1892.35$
# 결과값:2056.00$, 예측값 :2046.90$
# 결과값:11755.98$, 예측값 :12018.74$
# 결과값:4856.94$, 예측값 :7863.89$
# 결과값:32800.56$, 예측값 :24991.44$
# 결과값:1532.39$, 예측값 :1544.32$
# 결과값:1136.53$, 예측값 :717.53$
# 결과값:1986.07$, 예측값 :2204.08$
# 결과값:34232.64$, 예측값 :45567.77$
# 결과값:1400.94$, 예측값 :1365.95$
# 결과값:943.90$, 예측값 :938.31$
# 결과값:2350.82$, 예측값 :3365.90$
# 결과값:20633.28$, 예측값 :17833.67$
# 결과값:1170.83$, 예측값 :1015.54$
# 결과값:36431.97$, 예측값 :52243.67$
# 결과값:32885.75$, 예측값 :28602.76$
# 결과값:1463.08$, 예측값 :2244.90$
# 결과값:2048.45$, 예측값 :2236.03$
# 결과값:27950.91$, 예측값 :23825.22$
# 결과값:1604.91$, 예측값 :1499.21$
# 결과값:40836.71$, 예측값 :29214.62$
# 결과값:57991.13$, 예측값 :31188.26$
# 결과값:2067.92$, 예측값 :1028.32$
# 결과값:2071.45$, 예측값 :2041.52$
# 결과값:23169.18$, 예측값 :26883.68$
# 결과값:67065.04$, 예측값 :69720.34$
# 결과값:41719.09$, 예측값 :46729.96$
# 결과값:2368.35$, 예측값 :1864.02$
# 결과값:1325.28$, 예측값 :1281.76$
# 결과값:3172.28$, 예측값 :5105.49$
# 결과값:25202.39$, 예측값 :17721.38$
# 결과값:29117.12$, 예측값 :37552.50$
# 결과값:21547.23$, 예측값 :26470.83$
# 결과값:1672.34$, 예측값 :1490.48$
# 결과값:26863.06$, 예측값 :39435.13$
# 결과값:6829.35$, 예측값 :12539.02$
# 결과값:2939.19$, 예측값 :2113.12$
# 결과값:30774.12$, 예측값 :29961.67$
# 결과값:1191.82$, 예측값 :1370.45$
# 결과값:13410.72$, 예측값 :14691.13$
# 결과값:2204.14$, 예측값 :2689.68$
# 결과값:1326.87$, 예측값 :1923.43$
# 결과값:2452.64$, 예측값 :3254.11$
# 결과값:2021.49$, 예측값 :3571.69$
# 결과값:31533.98$, 예측값 :35240.77$
# 결과값:2459.12$, 예측값 :3376.91$
# 결과값:2583.82$, 예측값 :1022.35$
# 결과값:2118.77$, 예측값 :2147.34$
# 결과값:1347.34$, 예측값 :1258.86$
# 결과값:2031.82$, 예측값 :1430.18$
# 결과값:2109.20$, 예측값 :1591.45$
# 결과값:1022.52$, 예측값 :1115.26$
# 결과값:2304.07$, 예측값 :1139.15$
# 결과값:5991.94$, 예측값 :3194.75$
# 결과값:1166.56$, 예측값 :1538.85$
# 결과값:6096.99$, 예측값 :3873.87$
# 결과값:4327.67$, 예측값 :6663.87$
# 결과값:13262.90$, 예측값 :10529.04$
# 결과값:2061.11$, 예측값 :1924.84$
# 결과값:22891.14$, 예측값 :12740.08$
# 결과값:1701.95$, 예측값 :750.75$
# 결과값:2752.50$, 예측값 :1949.34$
# 결과값:1270.22$, 예측값 :1992.94$
# 결과값:3129.89$, 예측값 :3974.03$
# 결과값:1428.12$, 예측값 :1481.09$
# 결과값:4161.25$, 예측값 :6442.45$
# 결과값:1822.02$, 예측값 :1448.26$
# 결과값:20068.89$, 예측값 :26177.23$
# 결과값:23700.97$, 예측값 :31522.23$
# 결과값:21292.03$, 예측값 :11044.52$
# 결과값:2619.85$, 예측값 :2872.28$
# 결과값:26130.53$, 예측값 :35035.00$
# 결과값:39604.91$, 예측값 :17279.12$
# 결과값:23382.75$, 예측값 :34813.83$
# 결과값:1972.16$, 예측값 :1835.27$
# 결과값:1717.94$, 예측값 :2539.78$
# 결과값:67113.49$, 예측값 :66546.35$
# 결과값:1742.54$, 예측값 :1321.53$
# 결과값:1973.14$, 예측값 :2118.20$
# 결과값:2727.75$, 예측값 :994.27$
# 결과값:29551.97$, 예측값 :33885.94$
# 결과값:1460.31$, 예측값 :2354.93$
# 결과값:33370.94$, 예측값 :16852.76$
# 결과값:1425.61$, 예측값 :1066.38$
# 결과값:2008.35$, 예측값 :778.50$
# 결과값:821.61$, 예측값 :1330.76$
# 결과값:41085.99$, 예측값 :47037.42$
# 결과값:36331.53$, 예측값 :36268.36$
# 결과값:61631.84$, 예측값 :34740.80$
# 결과값:791.33$, 예측값 :979.44$
# 결과값:2149.05$, 예측값 :1798.82$
# 결과값:2223.08$, 예측값 :984.45$
# 결과값:1453.33$, 예측값 :1327.53$
# 결과값:55121.16$, 예측값 :54731.38$
# 결과값:2123.50$, 예측값 :1882.75$
# 결과값:2337.00$, 예측값 :3805.96$
# 결과값:24578.10$, 예측값 :13640.23$
# 결과값:2192.54$, 예측값 :2027.29$
# 결과값:29978.80$, 예측값 :42652.18$
# 결과값:50907.51$, 예측값 :24926.98$
# 결과값:29369.75$, 예측값 :34155.71$
# 결과값:26160.00$, 예측값 :38894.52$
# 결과값:1250.19$, 예측값 :1351.76$
# 결과값:1283.79$, 예측값 :695.59$
# 결과값:904.35$, 예측값 :1127.17$
# 결과값:23972.19$, 예측값 :14745.42$
# 결과값:3122.16$, 예측값 :3265.50$
# 결과값:30836.52$, 예측값 :21146.77$
# 결과값:9518.21$, 예측값 :11812.96$
# 결과값:34268.68$, 예측값 :24111.59$
# 결과값:21170.51$, 예측값 :26028.31$
# 결과값:1598.58$, 예측값 :1638.52$
# 결과값:2040.22$, 예측값 :2035.97$
# 결과값:1024.19$, 예측값 :885.42$
# 결과값:1061.40$, 예측값 :1519.70$
# 결과값:2044.65$, 예측값 :2039.23$
# 결과값:25055.64$, 예측값 :17776.18$
# 결과값:1093.95$, 예측값 :885.71$
# 결과값:42906.55$, 예측값 :50315.46$
# 결과값:1149.58$, 예측값 :946.04$
# 결과값:1091.99$, 예측값 :1485.08$
# 결과값:21864.34$, 예측값 :36165.77$
# 결과값:41613.86$, 예측값 :52125.08$
# 결과값:959.62$, 예측값 :1192.72$
# 결과값:61698.95$, 예측값 :22367.60$
# 결과값:30959.82$, 예측값 :17372.99$
# 결과값:1324.27$, 예측값 :710.58$
# 결과값:2028.98$, 예측값 :2310.79$
# 결과값:3480.49$, 예측값 :3713.42$
# 결과값:35983.13$, 예측값 :49205.62$
# 결과값:2066.16$, 예측값 :1865.99$
# 결과값:968.78$, 예측값 :1152.23$
# 결과값:21341.85$, 예측값 :21390.51$
# 결과값:944.20$, 예측값 :959.13$
# 결과값:2435.56$, 예측값 :2092.50$
# 결과값:1481.75$, 예측값 :1830.68$
# 결과값:36709.39$, 예측값 :22488.63$
# 결과값:35055.12$, 예측값 :42326.94$
# 결과값:805.98$, 예측값 :829.04$
# 결과값:1931.92$, 예측값 :1798.27$
# 결과값:2762.91$, 예측값 :2067.00$
# 결과값:1540.60$, 예측값 :1759.61$
# 결과값:43603.15$, 예측값 :23182.65$
# 결과값:34184.09$, 예측값 :46674.84$
# 결과값:1843.82$, 예측값 :1150.03$
# 결과값:20568.97$, 예측값 :22353.19$
# 결과값:2319.73$, 예측값 :2464.18$
# 결과값:4148.72$, 예측값 :5287.07$
# 결과값:24027.79$, 예측값 :27373.05$
# 결과값:52687.05$, 예측값 :62560.17$
# 결과값:6493.52$, 예측값 :11923.68$
# 결과값:1120.39$, 예측값 :1209.63$
# 결과값:44230.99$, 예측값 :48003.63$
# 결과값:2080.00$, 예측값 :2642.92$
# 결과값:1057.31$, 예측값 :936.33$
# 결과값:16216.19$, 예측값 :22206.17$
# 결과값:1132.50$, 예측값 :1064.16$
# 결과값:1143.64$, 예측값 :650.61$
# 결과값:1622.57$, 예측값 :1867.56$
# 결과값:994.18$, 예측값 :634.09$
# 결과값:1150.70$, 예측값 :879.31$
# 결과값:750.97$, 예측값 :562.44$
# 결과값:20507.17$, 예측값 :23298.82$
# 결과값:1383.13$, 예측값 :1893.95$
# 결과값:1935.25$, 예측값 :1480.74$
# 결과값:2116.52$, 예측값 :2644.64$
# 결과값:954.65$, 예측값 :943.31$
# 결과값:22799.87$, 예측값 :27647.22$
# 결과값:1565.85$, 예측값 :1434.25$
# 결과값:1985.97$, 예측값 :1652.04$
# 결과값:24389.96$, 예측값 :16982.25$
# 결과값:29260.48$, 예측값 :18807.74$
# 결과값:27634.20$, 예측값 :36813.43$
# 결과값:1204.23$, 예측값 :1434.21$
# 결과값:13328.09$, 예측값 :12307.70$
# 결과값:1624.52$, 예측값 :2612.58$
# 결과값:46999.18$, 예측값 :22318.89$
# 결과값:1302.80$, 예측값 :1308.20$
# 결과값:2002.26$, 예측값 :1376.45$
# 결과값:2817.63$, 예측값 :4174.23$
# 결과값:20734.32$, 예측값 :16701.18$
# 결과값:2471.36$, 예측값 :1935.87$
# 결과값:2145.16$, 예측값 :2291.98$
# 결과값:62247.12$, 예측값 :63694.19$
# 결과값:1796.39$, 예측값 :1689.90$
# 결과값:21155.78$, 예측값 :13827.21$
# 결과값:2079.61$, 예측값 :2965.74$
# 결과값:39272.56$, 예측값 :56650.57$
# 결과값:969.79$, 예측값 :2357.19$
# 결과값:23679.82$, 예측값 :38554.16$
# 결과값:2152.82$, 예측값 :1928.04$
# 결과값:1785.62$, 예측값 :1328.94$
# 결과값:20344.27$, 예측값 :30937.87$
# 결과값:945.34$, 예측값 :1341.77$
# 결과값:33530.73$, 예측값 :21374.98$
# 결과값:2075.91$, 예측값 :2219.34$
# 결과값:3650.16$, 예측값 :2934.60$
# 결과값:20139.90$, 예측값 :25343.95$
# 결과값:17875.20$, 예측값 :34901.44$
# 결과값:2315.11$, 예측값 :5865.42$
# 결과값:1423.83$, 예측값 :1548.16$
# 결과값:868.34$, 예측값 :990.24$
# 결과값:2011.25$, 예측값 :2792.24$
# 결과값:826.78$, 예측값 :1258.88$
# 결과값:2200.67$, 예측값 :1625.52$
# 결과값:13326.63$, 예측값 :17327.74$
# 결과값:1403.95$, 예측값 :1777.43$
# 결과값:1993.46$, 예측값 :2209.54$
# 결과값:3001.29$, 예측값 :4088.29$
# 결과값:1349.89$, 예측값 :776.70$
# 결과값:1139.13$, 예측값 :1418.62$
# 결과값:45322.82$, 예측값 :49163.23$
# 결과값:1497.14$, 예측값 :933.98$
# 결과값:21823.85$, 예측값 :14667.10$
# 결과값:1978.08$, 예측값 :5180.85$
# 결과값:25617.52$, 예측값 :26366.76$
# 결과값:2018.71$, 예측값 :1678.82$
# 결과값:20612.37$, 예측값 :17923.03$
# 결과값:37042.20$, 예측값 :19403.54$
# 결과값:2023.78$, 예측값 :1832.80$
# 결과값:1650.73$, 예측값 :1457.12$
# 결과값:1973.70$, 예측값 :1795.62$
# 결과값:31369.32$, 예측값 :38927.38$
# 결과값:1156.91$, 예측값 :952.55$
# 결과값:3021.19$, 예측값 :2380.01$
# 결과값:22023.28$, 예측값 :30080.50$
# 결과값:48878.47$, 예측값 :49775.21$
# 결과값:1358.27$, 예측값 :1684.69$
# 결과값:2006.01$, 예측값 :2011.44$
# 결과값:2078.35$, 예측값 :2857.93$
# 결과값:2068.73$, 예측값 :1936.47$
# 결과값:1587.81$, 예측값 :1257.82$
# 결과값:38379.10$, 예측값 :16367.73$
# 결과값:27922.66$, 예측값 :41652.98$
# 결과값:4443.40$, 예측값 :5028.52$
# 결과값:1474.41$, 예측값 :1702.26$
# 결과값:2069.61$, 예측값 :1766.09$
# Accuracy: 79.51   RMSE : 7906.41

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)

fig, axes = plt.subplots(1, 2,figsize = (12, 7), sharey = True)

prediction1 = prediction[prediction['label'] < 10000]
axes[0].plot(prediction1.index, prediction1['pred'],label='Prediction',        
        linestyle = '--',)
axes[0].plot(prediction1.index, prediction1['label'], label = 'Truth',
        linestyle = '--',)
axes[0].set_xticks([])
axes[0].legend()
axes[0].set_title("Price under 10000$")
prediction2 = prediction[prediction['label'] > 10000]
axes[1].plot(prediction2.index, prediction2['pred'],label='Prediction',        
        linestyle = '--',)
axes[1].plot(prediction2.index, prediction2['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
axes[1].set_xticks([])
axes[1].legend()
axes[1].set_title("Price over 10000$")
plt.ylabel('prices')
plt.show()
