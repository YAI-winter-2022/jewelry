# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import random
import albumentations as A
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/'YAI 봄학기 Toy Project'
# Out:
# /content/drive/MyDrive/YAI 봄학기 Toy Project

# %%
csv_train_path = "trainx2.csv"
csv_test_path = "test_append_re.csv"
csv_val_path = "val_append_re.csv"
image_path = "./images"
batch_size = 128 # CUDA out of memory로 인해 256 ~> 128 수정
epochs = 100 # 여러번 시도 했는데 50 근처에서 자꾸 런타임이 초기화 되네요...
learning_rate = 1e-3
seed = 42

# %%
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
class AllDataset(Dataset):
    def __init__(self, csv_path, image_path, image_transform=transforms.Compose([transforms.ToTensor()])):
        super(AllDataset).__init__()
        csv = pd.read_csv(csv_path)
        csv_np = csv.to_numpy()
        
        self.image_transform = image_transform
        self.ids = list(map(str, csv['Id']))
        self.image_path = image_path
        
        for i in [1, 3, 4, 5, 6, 7, 8]:
            wordset = {word: idx for idx, word in enumerate(np.unique(csv_np[:,i]))}
            for row in range(len(csv_np)):
                csv_np[row][i] = wordset[csv_np[row][i]]
        self.ints = torch.from_numpy(np.array(csv_np[:,[1,3,4,5,6,7,8]], dtype="int"))
        self.floats = torch.from_numpy(np.array(csv_np[:,[2,9,10,11]], dtype="float")).float()
        self.target = torch.from_numpy(np.array(csv_np[:,[12]], dtype="float")).float()
    
    
    def __getitem__(self,idx):
        return self.image_transform(Image.open(self.image_path+'/'+self.ids[idx]+'.jpg')), self.ints[idx],self.floats[idx], self.target[idx]
    
    
    def __len__(self):
        return len(self.ints)

# %%
image_transform = transforms.Compose([transforms.ToTensor()
                                     ])
train_dataset = AllDataset(csv_train_path, image_path, image_transform)
test_dataset = AllDataset(csv_test_path, image_path, image_transform)
val_dataset = AllDataset(csv_val_path, image_path, image_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Sequential(nn.Linear(512, 4096),
                                         nn.BatchNorm1d(4096),
                                         nn.ReLU(),
                                         nn.Dropout()
                                        )
        self.resenet18 = self.resnet18.to(device)
        
        self.emb1 = torch.nn.Embedding(8, 20)
        self.emb2 = torch.nn.Embedding(11, 20)
        self.emb3 = torch.nn.Embedding(20, 20)
        self.emb4 = torch.nn.Embedding(4, 20)
        self.emb5 = torch.nn.Embedding(4, 20)
        self.emb6 = torch.nn.Embedding(4, 20)
        self.emb7 = torch.nn.Embedding(7, 20)
        self.act = nn.ReLU()
        self.fc = nn.Linear(4, 80)
        self.csvbn = nn.BatchNorm1d(80)
        self.csvfc1 = nn.Linear(220, 8192)
        self.csvfc2 = nn.Linear(8192, 8192)
        self.csvfc3 = nn.Linear(8192, 4096)
        self.csvbn1 = nn.BatchNorm1d(8192)
        self.csvbn2 = nn.BatchNorm1d(8192)
        self.csvbn3 = nn.BatchNorm1d(4096)
        
        self.fc1 = nn.Linear(8192, 4096)
        self.fc2 = nn.Linear(4096, 1)
        self.bn1 = nn.BatchNorm1d(4096)
        self.dropout = nn.Dropout()
    
    def forward(self, image, x, y):
        image = self.resnet18(image)
        
        x1 = self.emb1(x[:,0])
        x2 = self.emb2(x[:,1])
        x3 = self.emb3(x[:,2])
        x4 = self.emb4(x[:,3])
        x5 = self.emb5(x[:,4])
        x6 = self.emb6(x[:,5])
        x7 = self.emb7(x[:,6])
        y = self.csvbn(self.fc(y))
        x = torch.cat((x1, x2, x3, x4, x5, x6, x7, y), dim=1)
        
        x = self.dropout(self.act(self.csvbn1(self.csvfc1(x))))
        x = self.dropout(self.act(self.csvbn2(self.csvfc2(x))))
        x = self.dropout(self.act(self.csvbn3(self.csvfc3(x))))
        x = torch.cat((x, image), dim=1)
        
        x = self.dropout(self.act(self.bn1(self.fc1(x))))
        return self.fc2(x)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
model = Net().to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

gc.collect()
torch.cuda.empty_cache()

# %%
for epoch in range(epochs):
    model.train()
    criterion.train()
    
    avg_loss = 0

    for Img, X1, X2, Y in train_loader:
        Img = Img.to(device)
        X1 = X1.to(device)
        X2 = X2.to(device)
        Y = Y.to(device)

        model.zero_grad()
        prediction = model(Img, X1, X2)
        loss = torch.sqrt(criterion(prediction, Y)).to(device)
        loss.backward()
        optimizer.step()
        avg_loss += loss / len(train_loader)
    print(f'[Epoch: {epoch+1:>2}] Average loss: {avg_loss:.4f}, ', end='')
    
    model.eval()
    criterion.eval()
    with torch.no_grad():
        val_avg_loss = 0.
        for Image_val, X1_val, X2_val, Y_val in val_loader:
            Image_val = Image_val.to(device)
            X1_val = X1_val.to(device)
            X2_val = X2_val.to(device)
            Y_val = Y_val.to(device)
            val_prediction = model(Image_val, X1_val, X2_val)
            val_loss = torch.sqrt(criterion(val_prediction, Y_val)).to(device)
            val_avg_loss += val_loss / len(val_loader)
        
        print(f"val_loss: {val_avg_loss:.4f}")
# Out:
# [Epoch:  1] Average loss: 25325.6738, val_loss: 18224.7793
# [Epoch:  2] Average loss: 25132.4766, val_loss: 17987.3750
# [Epoch:  3] Average loss: 24958.2422, val_loss: 17853.5645
# [Epoch:  4] Average loss: 24693.9199, val_loss: 17882.4688
# [Epoch:  5] Average loss: 24387.7363, val_loss: 17792.1855
# [Epoch:  6] Average loss: 24078.3281, val_loss: 17405.4297
# [Epoch:  7] Average loss: 23661.9727, val_loss: 17172.3574
# [Epoch:  8] Average loss: 23248.5293, val_loss: 16621.1152
# [Epoch:  9] Average loss: 22759.1387, val_loss: 16703.2871
# [Epoch: 10] Average loss: 22256.9629, val_loss: 16157.1133
# [Epoch: 11] Average loss: 21677.3184, val_loss: 15830.0938
# [Epoch: 12] Average loss: 21072.8984, val_loss: 15435.3184
# [Epoch: 13] Average loss: 20395.2773, val_loss: 14862.9619
# [Epoch: 14] Average loss: 19709.9219, val_loss: 14798.8516
# [Epoch: 15] Average loss: 18964.3008, val_loss: 13723.4473
# [Epoch: 16] Average loss: 18188.8301, val_loss: 13339.5986
# [Epoch: 17] Average loss: 17358.3828, val_loss: 13591.3965
# [Epoch: 18] Average loss: 16482.0020, val_loss: 12016.5459
# [Epoch: 19] Average loss: 15558.8564, val_loss: 12507.2100
# [Epoch: 20] Average loss: 14625.3379, val_loss: 11133.9951
# [Epoch: 21] Average loss: 13647.0176, val_loss: 10498.3115
# [Epoch: 22] Average loss: 12616.2715, val_loss: 9583.0996
# [Epoch: 23] Average loss: 11557.6699, val_loss: 8724.1201
# [Epoch: 24] Average loss: 10447.8740, val_loss: 8743.9277
# [Epoch: 25] Average loss: 9369.3379, val_loss: 7011.8418
# [Epoch: 26] Average loss: 8256.0420, val_loss: 6139.6084
# [Epoch: 27] Average loss: 7162.6499, val_loss: 6022.2861
# [Epoch: 28] Average loss: 6106.0947, val_loss: 6108.1973
# [Epoch: 29] Average loss: 5213.1880, val_loss: 4959.7876
# [Epoch: 30] Average loss: 4253.5000, val_loss: 5782.8521
# [Epoch: 31] Average loss: 3620.5063, val_loss: 4332.1768
# [Epoch: 32] Average loss: 3197.4307, val_loss: 4271.9136
# [Epoch: 33] Average loss: 2937.7883, val_loss: 4389.9438
# [Epoch: 34] Average loss: 2894.4136, val_loss: 3610.9407
# [Epoch: 35] Average loss: 2625.0000, val_loss: 3467.3250
# [Epoch: 36] Average loss: 2622.9246, val_loss: 3436.8489
# [Epoch: 37] Average loss: 2756.2319, val_loss: 4432.0967
# [Epoch: 38] Average loss: 2403.9453, val_loss: 3245.4099
# [Epoch: 39] Average loss: 2487.5615, val_loss: 4249.6108
# [Epoch: 40] Average loss: 2373.1316, val_loss: 3552.6670
# [Epoch: 41] Average loss: 2219.7783, val_loss: 3966.3203
# [Epoch: 42] Average loss: 2077.6714, val_loss: 4053.6604
# [Epoch: 43] Average loss: 2133.5403, val_loss: 3430.6816
# [Epoch: 44] Average loss: 2262.1548, val_loss: 3434.1162
# [Epoch: 45] Average loss: 2035.5636, val_loss: 3511.7651
# [Epoch: 46] Average loss: 2150.0154, val_loss: 3301.7747
# [Epoch: 47] Average loss: 2375.3755, val_loss: 3502.7749
# [Epoch: 48] Average loss: 2232.7634, val_loss: 3692.4321
# [Epoch: 49] Average loss: 2120.7197, val_loss: 3228.8950
# [Epoch: 50] Average loss: 2071.1313, val_loss: 3318.4563
# [Epoch: 51] Average loss: 2226.9604, val_loss: 3547.5349
# [Epoch: 52] Average loss: 1921.6348, val_loss: 3877.8684
# [Epoch: 53] Average loss: 2088.0100, val_loss: 3010.2725
# [Epoch: 54] Average loss: 2060.5432, val_loss: 3171.6831
# [Epoch: 55] Average loss: 1786.9335, val_loss: 3563.6055
# [Epoch: 56] Average loss: 2040.5980, val_loss: 3119.8525
# [Epoch: 57] Average loss: 1833.7554, val_loss: 3295.0093
# [Epoch: 58] Average loss: 1967.4374, val_loss: 3237.0896
# [Epoch: 59] Average loss: 2008.9688, val_loss: 3051.9282
# [Epoch: 60] Average loss: 1821.2594, val_loss: 3269.0674
# [Epoch: 61] Average loss: 2021.9042, val_loss: 3168.9363
# [Epoch: 62] Average loss: 1728.7881, val_loss: 3150.0002
# [Epoch: 63] Average loss: 2185.2957, val_loss: 3128.5598
# [Epoch: 64] Average loss: 1851.0782, val_loss: 3331.4194
# [Epoch: 65] Average loss: 1934.9922, val_loss: 3825.2966
# [Epoch: 66] Average loss: 1885.6766, val_loss: 3089.9236
# [Epoch: 67] Average loss: 2072.9883, val_loss: 4043.9292
# [Epoch: 68] Average loss: 1947.0886, val_loss: 3339.4590
# [Epoch: 69] Average loss: 1897.4128, val_loss: 3223.7168
# [Epoch: 70] Average loss: 1896.9542, val_loss: 3482.7197
# [Epoch: 71] Average loss: 1889.9072, val_loss: 3064.1360
# [Epoch: 72] Average loss: 1944.5201, val_loss: 3259.0571
# [Epoch: 73] Average loss: 2101.5439, val_loss: 3307.9861
# [Epoch: 74] Average loss: 1955.6057, val_loss: 3286.5605
# [Epoch: 75] Average loss: 1829.3627, val_loss: 3256.0039
# [Epoch: 76] Average loss: 1954.5273, val_loss: 3217.5920
# [Epoch: 77] Average loss: 2002.1536, val_loss: 3451.1440
# [Epoch: 78] Average loss: 1722.2767, val_loss: 3295.8125
# [Epoch: 79] Average loss: 1910.9991, val_loss: 3238.8271
# [Epoch: 80] Average loss: 1838.4368, val_loss: 3065.2559
# [Epoch: 81] Average loss: 1786.6362, val_loss: 3755.6167
# [Epoch: 82] Average loss: 1736.1271, val_loss: 3217.1672
# [Epoch: 83] Average loss: 1850.6847, val_loss: 3434.1990
# [Epoch: 84] Average loss: 1822.5157, val_loss: 3429.9202
# [Epoch: 85] Average loss: 1775.3639, val_loss: 3411.8804
# [Epoch: 86] Average loss: 1723.5134, val_loss: 3474.9143
# [Epoch: 87] Average loss: 1852.4988, val_loss: 3289.1160
# [Epoch: 88] Average loss: 1683.8065, val_loss: 3350.4160
# [Epoch: 89] Average loss: 2086.1238, val_loss: 3253.2139
# [Epoch: 90] Average loss: 1859.9836, val_loss: 3317.2563
# [Epoch: 91] Average loss: 1622.8395, val_loss: 3079.4966
# [Epoch: 92] Average loss: 1838.3302, val_loss: 3460.2942
# [Epoch: 93] Average loss: 1693.4326, val_loss: 3237.9751
# [Epoch: 94] Average loss: 2089.0042, val_loss: 3436.8306
# [Epoch: 95] Average loss: 1834.4059, val_loss: 3742.2031
# [Epoch: 96] Average loss: 1783.6935, val_loss: 3519.4785
# [Epoch: 97] Average loss: 1563.7587, val_loss: 3497.0112
# [Epoch: 98] Average loss: 1749.3445, val_loss: 3175.3008
# [Epoch: 99] Average loss: 1544.0000, val_loss: 3319.2104
# [Epoch: 100] Average loss: 1749.4319, val_loss: 3508.1624

# %%
PATH = './'
Name = 'model_stfsplit_crwaling_x2.pt'
torch.save(model.state_dict(), PATH+Name)

# %%
RMSEs = []
accuracys = []

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 20000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    accuracys.append(accuracy)
    RMSEs.append(RMSE)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}",)
# Out:
# 결과값:20860.01$, 예측값 :9918.90$
# 결과값:27122.16$, 예측값 :15179.05$
# 결과값:20173.51$, 예측값 :13676.49$
# 결과값:45075.72$, 예측값 :51412.91$
# 결과값:27205.50$, 예측값 :31926.10$
# 결과값:24901.69$, 예측값 :18437.65$
# 결과값:32303.92$, 예측값 :26080.50$
# 결과값:23382.75$, 예측값 :37432.28$
# 결과값:49707.29$, 예측값 :48308.25$
# 결과값:21292.03$, 예측값 :9038.40$
# 결과값:25803.49$, 예측값 :27854.13$
# 결과값:22980.98$, 예측값 :8129.32$
# 결과값:25892.41$, 예측값 :38110.07$
# 결과값:31337.89$, 예측값 :49348.59$
# 결과값:28350.11$, 예측값 :27299.23$
# 결과값:61111.33$, 예측값 :25575.19$
# 결과값:36709.39$, 예측값 :19007.53$
# 결과값:25659.50$, 예측값 :17541.71$
# 결과값:35719.12$, 예측값 :47277.25$
# 결과값:24027.79$, 예측값 :25048.17$
# 결과값:36689.98$, 예측값 :44993.75$
# 결과값:34224.76$, 예측값 :23313.71$
# 결과값:41077.42$, 예측값 :20134.96$
# 결과값:49176.27$, 예측값 :16919.13$
# 결과값:27634.20$, 예측값 :32285.80$
# 결과값:30493.40$, 예측값 :26961.61$
# 결과값:56131.02$, 예측값 :50080.76$
# 결과값:27329.64$, 예측값 :9075.16$
# 결과값:51524.24$, 예측값 :65097.44$
# 결과값:40273.43$, 예측값 :39658.61$
# 결과값:33084.11$, 예측값 :41275.10$
# 결과값:59670.09$, 예측값 :25952.24$
# 결과값:24964.93$, 예측값 :27695.17$
# 결과값:32632.75$, 예측값 :32008.02$
# 결과값:38389.60$, 예측값 :25799.29$
# 결과값:47296.08$, 예측값 :24473.46$
# 결과값:45322.82$, 예측값 :46891.98$
# 결과값:61536.29$, 예측값 :66529.61$
# 결과값:62247.12$, 예측값 :60736.12$
# 결과값:35863.89$, 예측값 :39506.01$
# 결과값:52930.41$, 예측값 :40527.15$
# 결과값:63065.18$, 예측값 :25557.02$
# 결과값:27119.82$, 예측값 :16397.18$
# 결과값:20483.38$, 예측값 :25964.15$
# 결과값:25034.76$, 예측값 :21145.92$
# 결과값:40852.38$, 예측값 :50951.61$
# 결과값:49799.86$, 예측값 :18889.59$
# 결과값:28335.84$, 예측값 :20715.85$
# 결과값:33859.16$, 예측값 :46030.53$
# 결과값:22167.26$, 예측값 :38743.47$
# 결과값:27505.31$, 예측값 :29364.08$
# 결과값:21132.06$, 예측값 :12820.77$
# 결과값:49075.34$, 예측값 :49788.47$
# 결과값:40550.62$, 예측값 :37933.23$
# 결과값:26932.46$, 예측값 :21377.72$
# 결과값:26213.40$, 예측값 :30227.71$
# 결과값:42701.88$, 예측값 :15862.96$
# 결과값:30082.42$, 예측값 :22913.86$
# 결과값:45057.48$, 예측값 :33507.23$
# 결과값:35416.68$, 예측값 :21785.25$
# 결과값:40836.71$, 예측값 :26941.91$
# 결과값:34268.68$, 예측값 :27550.34$
# 결과값:30428.44$, 예측값 :39390.76$
# 결과값:49964.93$, 예측값 :20691.99$
# 결과값:21579.42$, 예측값 :21363.46$
# 결과값:26064.87$, 예측값 :27486.48$
# 결과값:48878.47$, 예측값 :48957.85$
# 결과값:41917.20$, 예측값 :44426.02$
# 결과값:20158.59$, 예측값 :29406.05$
# 결과값:23169.18$, 예측값 :20135.78$
# 결과값:30273.44$, 예측값 :29010.43$
# 결과값:35880.23$, 예측값 :41269.85$
# 결과값:27902.71$, 예측값 :32062.26$
# 결과값:30784.37$, 예측값 :36279.18$
# 결과값:55121.16$, 예측값 :51905.25$
# 결과값:24688.75$, 예측값 :31843.93$
# 결과값:54628.83$, 예측값 :23355.80$
# 결과값:43216.40$, 예측값 :47590.49$
# 결과값:34746.72$, 예측값 :38295.25$
# 결과값:22785.34$, 예측값 :21409.93$
# 결과값:27946.11$, 예측값 :36762.39$
# 결과값:21091.67$, 예측값 :12767.58$
# 결과값:42250.88$, 예측값 :25742.03$
# 결과값:44832.26$, 예측값 :45284.14$
# 결과값:29551.97$, 예측값 :35380.30$
# 결과값:49105.46$, 예측값 :19017.52$
# 결과값:64294.39$, 예측값 :47211.05$
# 결과값:56407.68$, 예측값 :24655.22$
# 결과값:31533.98$, 예측값 :33170.91$
# 결과값:27922.66$, 예측값 :38945.64$
# 결과값:21269.26$, 예측값 :42633.95$
# 결과값:23587.59$, 예측값 :20772.69$
# 결과값:53764.84$, 예측값 :25615.73$
# 결과값:55114.43$, 예측값 :50202.70$
# 결과값:45836.54$, 예측값 :31829.80$
# 결과값:35410.46$, 예측값 :41724.82$
# 결과값:31342.97$, 예측값 :22489.01$
# 결과값:26351.57$, 예측값 :18871.65$
# 결과값:20068.89$, 예측값 :22211.98$
# 결과값:21648.12$, 예측값 :16306.90$
# 결과값:25346.44$, 예측값 :30725.84$
# 결과값:47167.24$, 예측값 :17748.25$
# 결과값:52363.90$, 예측값 :26942.55$
# 결과값:39880.62$, 예측값 :22561.98$
# 결과값:52848.73$, 예측값 :31619.59$
# 결과값:55834.65$, 예측값 :22640.60$
# 결과값:28482.54$, 예측값 :33368.85$
# 결과값:64620.82$, 예측값 :23174.58$
# 결과값:37753.27$, 예측값 :26831.69$
# 결과값:26160.00$, 예측값 :33171.38$
# 결과값:20676.24$, 예측값 :17095.94$
# 결과값:52137.95$, 예측값 :45821.79$
# 결과값:21931.09$, 예측값 :23694.73$
# 결과값:21735.81$, 예측값 :15998.37$
# 결과값:38190.98$, 예측값 :27211.44$
# 결과값:21341.85$, 예측값 :21637.16$
# 결과값:70749.53$, 예측값 :46815.26$
# 결과값:40466.40$, 예측값 :52233.82$
# 결과값:40908.44$, 예측값 :45458.52$
# 결과값:20280.75$, 예측값 :26303.01$
# 결과값:61082.46$, 예측값 :54576.81$
# 결과값:63965.99$, 예측값 :36381.27$
# 결과값:31911.25$, 예측값 :32244.76$
# 결과값:55408.52$, 예측값 :35893.25$
# 결과값:28291.89$, 예측값 :23589.52$
# 결과값:34232.64$, 예측값 :41043.93$
# 결과값:63873.39$, 예측값 :33018.40$
# 결과값:41719.09$, 예측값 :44369.23$
# 결과값:30920.20$, 예측값 :39637.22$
# 결과값:45657.41$, 예측값 :25634.78$
# 결과값:33530.73$, 예측값 :18458.28$
# 결과값:21155.78$, 예측값 :16861.69$
# 결과값:40999.92$, 예측값 :18556.16$
# 결과값:24146.99$, 예측값 :31342.12$
# 결과값:28861.48$, 예측값 :13657.18$
# 결과값:28881.90$, 예측값 :17117.07$
# 결과값:23199.27$, 예측값 :25069.71$
# 결과값:27950.91$, 예측값 :21621.76$
# 결과값:28005.62$, 예측값 :19333.78$
# 결과값:22023.28$, 예측값 :26102.25$
# 결과값:50554.25$, 예측값 :28917.76$
# 결과값:20344.27$, 예측값 :32834.87$
# 결과값:33397.60$, 예측값 :30871.31$
# 결과값:29581.89$, 예측값 :20017.33$
# 결과값:20418.11$, 예측값 :23907.03$
# 결과값:22571.78$, 예측값 :15283.46$
# 결과값:63276.72$, 예측값 :57295.07$
# 결과값:66450.93$, 예측값 :52626.34$
# 결과값:27413.43$, 예측값 :33619.71$
# 결과값:62259.60$, 예측값 :54375.56$
# 결과값:48094.80$, 예측값 :47708.82$
# 결과값:34571.88$, 예측값 :24829.72$
# 결과값:41684.93$, 예측값 :23451.04$
# 결과값:26685.53$, 예측값 :13020.80$
# 결과값:38228.78$, 예측값 :16243.26$
# 결과값:33490.42$, 예측값 :20432.53$
# 결과값:32800.56$, 예측값 :24883.28$
# 결과값:26632.32$, 예측값 :20629.54$
# 결과값:20734.32$, 예측값 :16921.01$
# 결과값:57498.09$, 예측값 :48347.38$
# 결과값:20920.19$, 예측값 :28272.70$
# 결과값:34184.09$, 예측값 :48830.10$
# 결과값:39604.91$, 예측값 :15715.27$
# 결과값:21277.73$, 예측값 :24066.12$
# 결과값:35524.48$, 예측값 :31999.65$
# 결과값:50439.17$, 예측값 :56468.07$
# 결과값:22295.68$, 예측값 :32266.04$
# 결과값:20295.30$, 예측값 :40331.93$
# 결과값:36516.67$, 예측값 :39006.18$
# 결과값:28864.68$, 예측값 :18440.07$
# 결과값:27591.72$, 예측값 :23870.74$
# 결과값:44230.99$, 예측값 :46042.71$
# 결과값:38599.92$, 예측값 :39814.63$
# 결과값:35983.13$, 예측값 :50991.43$
# 결과값:32885.75$, 예측값 :27040.33$
# 결과값:55856.35$, 예측값 :55781.25$
# 결과값:29404.60$, 예측값 :13763.76$
# 결과값:24389.96$, 예측값 :16901.23$
# 결과값:30834.02$, 예측값 :16683.01$
# 결과값:26083.82$, 예측값 :24110.98$
# 결과값:20633.28$, 예측값 :14544.98$
# 결과값:43148.04$, 예측값 :22965.41$
# 결과값:21864.34$, 예측값 :34608.55$
# 결과값:29512.98$, 예측값 :30695.06$
# 결과값:25017.10$, 예측값 :11614.52$
# 결과값:57991.13$, 예측값 :32519.28$
# 결과값:20455.34$, 예측값 :23209.45$
# 결과값:22801.15$, 예측값 :15025.41$
# 결과값:30836.52$, 예측값 :22311.68$
# 결과값:25612.14$, 예측값 :28966.20$
# 결과값:47478.60$, 예측값 :52305.66$
# 결과값:67738.23$, 예측값 :48620.82$
# 결과값:29107.42$, 예측값 :20321.81$
# 결과값:64608.96$, 예측값 :63902.78$
# 결과값:34346.46$, 예측값 :31571.21$
# 결과값:40003.27$, 예측값 :16705.43$
# 결과값:66413.49$, 예측값 :47235.56$
# 결과값:25202.39$, 예측값 :14730.42$
# 결과값:41371.20$, 예측값 :30795.63$
# 결과값:22799.87$, 예측값 :27625.43$
# 결과값:30774.12$, 예측값 :27280.73$
# 결과값:41660.11$, 예측값 :49310.91$
# 결과값:66986.79$, 예측값 :45410.37$
# 결과값:41079.67$, 예측값 :28452.86$
# 결과값:61698.95$, 예측값 :21280.53$
# 결과값:21268.81$, 예측값 :14593.04$
# 결과값:25038.87$, 예측값 :22132.33$
# 결과값:41928.12$, 예측값 :20588.22$
# 결과값:49595.52$, 예측값 :52209.73$
# 결과값:60768.12$, 예측값 :59902.27$
# 결과값:31103.12$, 예측값 :14457.40$
# 결과값:32098.84$, 예측값 :35921.01$
# 결과값:34002.34$, 예측값 :43016.96$
# 결과값:44632.77$, 예측값 :16668.96$
# 결과값:33248.83$, 예측값 :35819.71$
# 결과값:20398.14$, 예측값 :21245.55$
# 결과값:44591.90$, 예측값 :18608.34$
# 결과값:32951.72$, 예측값 :32752.50$
# 결과값:34948.31$, 예측값 :20804.37$
# 결과값:49484.99$, 예측값 :21540.14$
# 결과값:25383.84$, 예측값 :27767.81$
# 결과값:38225.91$, 예측값 :17284.47$
# 결과값:52687.05$, 예측값 :56275.25$
# 결과값:25055.64$, 예측값 :17704.22$
# 결과값:49596.35$, 예측값 :48113.53$
# 결과값:38149.61$, 예측값 :15009.72$
# 결과값:27388.00$, 예측값 :23991.08$
# 결과값:33980.23$, 예측값 :18914.11$
# 결과값:57439.15$, 예측값 :56637.20$
# 결과값:25135.50$, 예측값 :25953.68$
# 결과값:20507.17$, 예측값 :23413.51$
# 결과값:41953.98$, 예측값 :25571.15$
# 결과값:40078.74$, 예측값 :23721.65$
# 결과값:50138.79$, 예측값 :51878.17$
# 결과값:34039.04$, 예측값 :38553.36$
# 결과값:26256.28$, 예측값 :36984.36$
# 결과값:33370.94$, 예측값 :17872.10$
# 결과값:25441.10$, 예측값 :29289.50$
# 결과값:22891.14$, 예측값 :14506.26$
# 결과값:20128.93$, 예측값 :14481.72$
# 결과값:29369.75$, 예측값 :30779.54$
# 결과값:43204.90$, 예측값 :19882.87$
# 결과값:45052.80$, 예측값 :23174.04$
# 결과값:26153.60$, 예측값 :12775.50$
# 결과값:22188.46$, 예측값 :17191.37$
# 결과값:30895.80$, 예측값 :19415.62$
# 결과값:42906.55$, 예측값 :48923.54$
# 결과값:20500.37$, 예측값 :25913.95$
# 결과값:44619.79$, 예측값 :44118.40$
# 결과값:26926.69$, 예측값 :9799.22$
# 결과값:22106.31$, 예측값 :18839.95$
# 결과값:27424.80$, 예측값 :18482.71$
# 결과값:41407.39$, 예측값 :24815.55$
# 결과값:26130.53$, 예측값 :36845.00$
# 결과값:52699.97$, 예측값 :53543.36$
# 결과값:46719.55$, 예측값 :18244.30$
# 결과값:26625.14$, 예측값 :25657.25$
# 결과값:64839.84$, 예측값 :46716.68$
# 결과값:61631.84$, 예측값 :32873.21$
# 결과값:23504.41$, 예측값 :23246.45$
# 결과값:38379.10$, 예측값 :16076.23$
# 결과값:20139.90$, 예측값 :21216.79$
# 결과값:23887.50$, 예측값 :27891.65$
# 결과값:34225.71$, 예측값 :28878.18$
# 결과값:39034.32$, 예측값 :42325.42$
# 결과값:22235.62$, 예측값 :15538.96$
# 결과값:26308.95$, 예측값 :17121.28$
# 결과값:20612.37$, 예측값 :16235.75$
# 결과값:26046.90$, 예측값 :32616.16$
# 결과값:23814.90$, 예측값 :17460.71$
# 결과값:67065.04$, 예측값 :63374.05$
# 결과값:25584.00$, 예측값 :16460.56$
# 결과값:31817.76$, 예측값 :36058.43$
# 결과값:43612.11$, 예측값 :46461.68$
# 결과값:63271.35$, 예측값 :56872.40$
# 결과값:27314.91$, 예측값 :31154.79$
# 결과값:24656.52$, 예측값 :29768.60$
# 결과값:43603.15$, 예측값 :25185.94$
# 결과값:23901.09$, 예측값 :16839.62$
# 결과값:23272.44$, 예측값 :26971.31$
# 결과값:41953.28$, 예측값 :44231.63$
# 결과값:61067.60$, 예측값 :24354.75$
# 결과값:41870.40$, 예측값 :27325.31$
# 결과값:20656.12$, 예측값 :23574.10$
# 결과값:24578.10$, 예측값 :12156.96$
# 결과값:20647.68$, 예측값 :24061.51$
# 결과값:68617.96$, 예측값 :24586.12$
# 결과값:21068.75$, 예측값 :20384.00$
# 결과값:50907.51$, 예측값 :24213.97$
# 결과값:23972.19$, 예측값 :13930.18$
# 결과값:22009.90$, 예측값 :15444.76$
# 결과값:20965.96$, 예측값 :10734.27$
# 결과값:67113.49$, 예측값 :61205.96$
# 결과값:22917.52$, 예측값 :35231.10$
# 결과값:29651.08$, 예측값 :27624.62$
# 결과값:29260.48$, 예측값 :19271.24$
# 결과값:26450.86$, 예측값 :12016.52$
# 결과값:43849.17$, 예측값 :18032.28$
# 결과값:33296.64$, 예측값 :35527.46$
# 결과값:33785.08$, 예측값 :31597.26$
# 결과값:49397.98$, 예측값 :59893.57$
# 결과값:35055.12$, 예측값 :42343.61$
# 결과값:29978.80$, 예측값 :35729.85$
# 결과값:57017.00$, 예측값 :26156.72$
# 결과값:50279.42$, 예측값 :36606.12$
# 결과값:21273.74$, 예측값 :36411.26$
# 결과값:27628.26$, 예측값 :21967.49$
# 결과값:25617.52$, 예측값 :20297.20$
# 결과값:26611.96$, 예측값 :26181.39$
# 결과값:24933.36$, 예측값 :10572.64$
# 결과값:20419.78$, 예측값 :26651.77$
# 결과값:47252.40$, 예측값 :43830.64$
# 결과값:24041.22$, 예측값 :19847.70$
# 결과값:34211.50$, 예측값 :37613.32$
# 결과값:21170.51$, 예측값 :24508.98$
# 결과값:69297.88$, 예측값 :22805.11$
# 결과값:27909.02$, 예측값 :34910.33$
# 결과값:21570.62$, 예측값 :25158.43$
# 결과값:31098.54$, 예측값 :24008.13$
# 결과값:21823.85$, 예측값 :14078.41$
# 결과값:22582.79$, 예측값 :25261.61$
# 결과값:42306.20$, 예측값 :25337.12$
# 결과값:29871.82$, 예측값 :26091.65$
# 결과값:23028.91$, 예측값 :27219.54$
# 결과값:67290.13$, 예측값 :65050.97$
# 결과값:58721.83$, 예측값 :61374.45$
# 결과값:28995.88$, 예측값 :31512.53$
# 결과값:68659.03$, 예측값 :28765.95$
# 결과값:31780.32$, 예측값 :17726.05$
# 결과값:37042.20$, 예측값 :16500.71$
# 결과값:45024.69$, 예측값 :21536.24$
# 결과값:20564.19$, 예측값 :20582.21$
# 결과값:37633.44$, 예측값 :38248.86$
# 결과값:29652.40$, 예측값 :18393.68$
# 결과값:38007.72$, 예측값 :46660.77$
# 결과값:30234.83$, 예측값 :33079.46$
# 결과값:30959.82$, 예측값 :15618.84$
# 결과값:49931.34$, 예측값 :42354.17$
# 결과값:69759.86$, 예측값 :51983.24$
# 결과값:23679.82$, 예측값 :34749.66$
# 결과값:33085.57$, 예측값 :39642.04$
# 결과값:23349.63$, 예측값 :12642.18$
# 결과값:32102.37$, 예측값 :38838.41$
# 결과값:31369.32$, 예측값 :38790.78$
# 결과값:21725.54$, 예측값 :21906.99$
# 결과값:36331.53$, 예측값 :32906.06$
# 결과값:29596.65$, 예측값 :34712.63$
# 결과값:54478.32$, 예측값 :52217.08$
# 결과값:45801.04$, 예측값 :28981.04$
# 결과값:55489.43$, 예측값 :19549.91$
# 결과값:64372.54$, 예측값 :23307.83$
# 결과값:37297.65$, 예측값 :26337.65$
# 결과값:21547.23$, 예측값 :29436.88$
# 결과값:20568.60$, 예측값 :26281.29$
# 결과값:20141.22$, 예측값 :16866.48$
# 결과값:25577.43$, 예측값 :28602.15$
# 결과값:49340.63$, 예측값 :21007.93$
# 결과값:39272.56$, 예측값 :57315.09$
# 결과값:29117.12$, 예측값 :37448.14$
# 결과값:63530.73$, 예측값 :49621.47$
# 결과값:46774.57$, 예측값 :22972.81$
# 결과값:64372.54$, 예측값 :38490.81$
# 결과값:20425.49$, 예측값 :24568.28$
# 결과값:37187.48$, 예측값 :42951.25$
# 결과값:28443.36$, 예측값 :33852.38$
# 결과값:29562.00$, 예측값 :32834.48$
# 결과값:68574.48$, 예측값 :20003.39$
# 결과값:21089.69$, 예측값 :25948.77$
# 결과값:51362.03$, 예측값 :21094.57$
# 결과값:20166.87$, 예측값 :22548.11$
# 결과값:24460.13$, 예측값 :19421.94$
# 결과값:31056.48$, 예측값 :16547.27$
# 결과값:27551.75$, 예측값 :18881.25$
# 결과값:31859.88$, 예측값 :46598.39$
# 결과값:46884.32$, 예측값 :44979.12$
# 결과값:49865.46$, 예측값 :34973.88$
# 결과값:22499.57$, 예측값 :18917.60$
# 결과값:21631.88$, 예측값 :18096.94$
# 결과값:26863.06$, 예측값 :42988.72$
# 결과값:43163.33$, 예측값 :44260.33$
# 결과값:37005.07$, 예측값 :21876.82$
# 결과값:23325.59$, 예측값 :18578.79$
# 결과값:38667.58$, 예측값 :42130.07$
# 결과값:26746.08$, 예측값 :27562.67$
# 결과값:41085.99$, 예측값 :48068.09$
# 결과값:39855.05$, 예측값 :42266.30$
# 결과값:58468.02$, 예측값 :27398.65$
# 결과값:39042.12$, 예측값 :35093.07$
# 결과값:20586.85$, 예측값 :29868.94$
# 결과값:33543.70$, 예측값 :13143.94$
# 결과값:58291.08$, 예측값 :54361.43$
# 결과값:24718.20$, 예측값 :16817.65$
# 결과값:21373.06$, 예측값 :28487.28$
# 결과값:21597.14$, 예측값 :7990.32$
# 결과값:22399.73$, 예측값 :21405.35$
# 결과값:20560.96$, 예측값 :8433.02$
# 결과값:46999.18$, 예측값 :24146.18$
# 결과값:20503.13$, 예측값 :40138.39$
# 결과값:23700.97$, 예측값 :23195.67$
# 결과값:36908.43$, 예측값 :19439.17$
# 결과값:25244.54$, 예측값 :15708.30$
# 결과값:56175.76$, 예측값 :27849.52$
# 결과값:25334.40$, 예측값 :37239.30$
# 결과값:25091.01$, 예측값 :31269.09$
# 결과값:53998.15$, 예측값 :33184.50$
# 결과값:20568.97$, 예측값 :21903.64$
# 결과값:27068.73$, 예측값 :15372.48$
# 결과값:36431.97$, 예측값 :49813.52$
# 결과값:20148.51$, 예측값 :28815.03$
# 결과값:37691.55$, 예측값 :15429.92$
# 결과값:57774.21$, 예측값 :61914.18$
# 결과값:32381.79$, 예측값 :34030.35$
# 결과값:47515.73$, 예측값 :46032.01$
# 결과값:31199.25$, 예측값 :30485.25$
# 결과값:23207.22$, 예측값 :17888.36$
# 결과값:63577.08$, 예측값 :35974.71$
# 결과값:41613.86$, 예측값 :48888.43$
# 결과값:27705.68$, 예측값 :34495.77$
# 결과값:33864.78$, 예측값 :34293.07$
# 결과값:42905.79$, 예측값 :18958.78$
# 결과값:28308.82$, 예측값 :31263.22$
# 결과값:23495.78$, 예측값 :13219.85$
# 결과값:47297.70$, 예측값 :23153.15$
# 결과값:36866.22$, 예측값 :44525.62$
# 결과값:58437.60$, 예측값 :56917.83$
# 결과값:20929.08$, 예측값 :21832.38$
# 결과값:50569.24$, 예측값 :19272.64$
# Accuracy: -10.00   RMSE : 14095.30

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 20,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 15000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:20860.01$, 예측값 :9918.90$
# 결과값:49075.34$, 예측값 :49788.47$
# 결과값:23700.97$, 예측값 :23195.67$
# 결과값:50439.17$, 예측값 :56468.07$
# 결과값:21931.09$, 예측값 :23694.73$
# 결과값:33296.64$, 예측값 :35527.46$
# 결과값:23382.75$, 예측값 :37432.28$
# 결과값:24389.96$, 예측값 :16901.23$
# 결과값:20965.96$, 예측값 :10734.27$
# 결과값:37691.55$, 예측값 :15429.92$
# 결과값:43148.04$, 예측값 :22965.41$
# 결과값:51362.03$, 예측값 :21094.57$
# 결과값:49931.34$, 예측값 :42354.17$
# 결과값:35416.68$, 예측값 :21785.25$
# 결과값:68617.96$, 예측값 :24586.12$
# 결과값:69297.88$, 예측값 :22805.11$
# 결과값:42250.88$, 예측값 :25742.03$
# 결과값:31817.76$, 예측값 :36058.43$
# 결과값:20633.28$, 예측값 :14544.98$
# 결과값:61082.46$, 예측값 :54576.81$
# 결과값:27122.16$, 예측값 :15179.05$
# 결과값:23814.90$, 예측값 :17460.71$
# 결과값:46774.57$, 예측값 :22972.81$
# 결과값:21269.26$, 예측값 :42633.95$
# 결과값:39272.56$, 예측값 :57315.09$
# 결과값:26351.57$, 예측값 :18871.65$
# 결과값:69759.86$, 예측값 :51983.24$
# 결과값:31533.98$, 예측값 :33170.91$
# 결과값:32800.56$, 예측값 :24883.28$
# 결과값:41077.42$, 예측값 :20134.96$
# 결과값:26083.82$, 예측값 :24110.98$
# 결과값:44832.26$, 예측값 :45284.14$
# 결과값:20068.89$, 예측값 :22211.98$
# 결과값:21823.85$, 예측값 :14078.41$
# 결과값:33370.94$, 예측값 :17872.10$
# 결과값:40003.27$, 예측값 :16705.43$
# 결과값:63065.18$, 예측값 :25557.02$
# 결과값:21268.81$, 예측값 :14593.04$
# 결과값:33084.11$, 예측값 :41275.10$
# 결과값:21648.12$, 예측값 :16306.90$
# 결과값:21597.14$, 예측값 :7990.32$
# 결과값:29260.48$, 예측값 :19271.24$
# 결과값:21273.74$, 예측값 :36411.26$
# 결과값:28005.62$, 예측값 :19333.78$
# 결과값:15379.60$, 예측값 :15442.11$
# 결과값:47478.60$, 예측값 :52305.66$
# 결과값:52699.97$, 예측값 :53543.36$
# 결과값:47296.08$, 예측값 :24473.46$
# 결과값:52687.05$, 예측값 :56275.25$
# 결과값:27950.91$, 예측값 :21621.76$
# 결과값:26130.53$, 예측값 :36845.00$
# 결과값:16216.19$, 예측값 :24411.72$
# 결과값:25612.14$, 예측값 :28966.20$
# 결과값:31103.12$, 예측값 :14457.40$
# 결과값:22785.34$, 예측값 :21409.93$
# 결과값:20929.08$, 예측값 :21832.38$
# 결과값:39855.05$, 예측값 :42266.30$
# 결과값:33085.57$, 예측값 :39642.04$
# 결과값:66413.49$, 예측값 :47235.56$
# 결과값:37297.65$, 예측값 :26337.65$
# 결과값:49484.99$, 예측값 :21540.14$
# 결과값:45052.80$, 예측값 :23174.04$
# 결과값:31780.32$, 예측값 :17726.05$
# 결과값:23504.41$, 예측값 :23246.45$
# 결과값:16480.38$, 예측값 :16308.63$
# 결과값:21292.03$, 예측값 :9038.40$
# 결과값:20139.90$, 예측값 :21216.79$
# 결과값:16186.73$, 예측값 :21421.86$
# 결과값:23028.91$, 예측값 :27219.54$
# 결과값:56175.76$, 예측값 :27849.52$
# 결과값:24688.75$, 예측값 :31843.93$
# 결과값:23349.63$, 예측값 :12642.18$
# 결과값:20418.11$, 예측값 :23907.03$
# 결과값:45322.82$, 예측값 :46891.98$
# 결과값:59670.09$, 예측값 :25952.24$
# 결과값:32381.79$, 예측값 :34030.35$
# 결과값:27705.68$, 예측값 :34495.77$
# 결과값:49340.63$, 예측값 :21007.93$
# 결과값:39042.12$, 예측값 :35093.07$
# 결과값:36908.43$, 예측값 :19439.17$
# 결과값:40078.74$, 예측값 :23721.65$
# 결과값:20173.51$, 예측값 :13676.49$
# 결과값:31199.25$, 예측값 :30485.25$
# 결과값:63276.72$, 예측값 :57295.07$
# 결과값:34039.04$, 예측값 :38553.36$
# 결과값:47252.40$, 예측값 :43830.64$
# 결과값:25617.52$, 예측값 :20297.20$
# 결과값:22980.98$, 예측값 :8129.32$
# 결과값:35719.12$, 예측값 :47277.25$
# 결과값:21547.23$, 예측값 :29436.88$
# 결과값:58291.08$, 예측값 :54361.43$
# 결과값:21091.67$, 예측값 :12767.58$
# 결과값:20734.32$, 예측값 :16921.01$
# 결과값:49707.29$, 예측값 :48308.25$
# 결과값:20656.12$, 예측값 :23574.10$
# 결과값:67290.13$, 예측값 :65050.97$
# 결과값:61631.84$, 예측값 :32873.21$
# 결과값:22023.28$, 예측값 :26102.25$
# 결과값:66986.79$, 예측값 :45410.37$
# 결과값:20568.60$, 예측값 :26281.29$
# 결과값:27068.73$, 예측값 :15372.48$
# 결과값:20676.24$, 예측값 :17095.94$
# 결과값:58721.83$, 예측값 :61374.45$
# 결과값:57774.21$, 예측값 :61914.18$
# 결과값:28443.36$, 예측값 :33852.38$
# 결과값:27551.75$, 예측값 :18881.25$
# 결과값:23679.82$, 예측값 :34749.66$
# 결과값:31342.97$, 예측값 :22489.01$
# 결과값:21277.73$, 예측값 :24066.12$
# 결과값:41953.98$, 예측값 :25571.15$
# 결과값:26153.60$, 예측값 :12775.50$
# 결과값:55408.52$, 예측값 :35893.25$
# 결과값:21341.85$, 예측값 :21637.16$
# 결과값:20280.75$, 예측값 :26303.01$
# 결과값:25346.44$, 예측값 :30725.84$
# 결과값:38389.60$, 예측값 :25799.29$
# 결과값:25659.50$, 예측값 :17541.71$
# 결과값:63577.08$, 예측값 :35974.71$
# 결과값:25055.64$, 예측값 :17704.22$
# 결과값:22167.26$, 예측값 :38743.47$
# 결과값:35410.46$, 예측값 :41724.82$
# 결과값:21373.06$, 예측값 :28487.28$
# 결과값:50138.79$, 예측값 :51878.17$
# 결과값:41085.99$, 예측값 :48068.09$
# 결과값:24027.79$, 예측값 :25048.17$
# 결과값:46999.18$, 예측값 :24146.18$
# 결과값:22235.62$, 예측값 :15538.96$
# 결과값:64294.39$, 예측값 :47211.05$
# 결과값:35880.23$, 예측값 :41269.85$
# 결과값:31098.54$, 예측값 :24008.13$
# 결과값:20586.85$, 예측값 :29868.94$
# 결과값:20398.14$, 예측값 :21245.55$
# 결과값:37042.20$, 예측값 :16500.71$
# 결과값:21170.51$, 예측값 :24508.98$
# 결과값:29581.89$, 예측값 :20017.33$
# 결과값:25803.49$, 예측값 :27854.13$
# 결과값:34211.50$, 예측값 :37613.32$
# 결과값:32303.92$, 예측값 :26080.50$
# 결과값:46719.55$, 예측값 :18244.30$
# 결과값:25584.00$, 예측값 :16460.56$
# 결과값:21631.88$, 예측값 :18096.94$
# 결과값:38225.91$, 예측값 :17284.47$
# 결과값:35524.48$, 예측값 :31999.65$
# 결과값:24146.99$, 예측값 :31342.12$
# 결과값:40273.43$, 예측값 :39658.61$
# 결과값:31911.25$, 예측값 :32244.76$
# 결과값:29871.82$, 예측값 :26091.65$
# 결과값:41870.40$, 예측값 :27325.31$
# 결과값:40550.62$, 예측값 :37933.23$
# 결과값:18439.82$, 예측값 :9062.50$
# 결과값:20425.49$, 예측값 :24568.28$
# 결과값:25244.54$, 예측값 :15708.30$
# 결과값:30234.83$, 예측값 :33079.46$
# 결과값:55834.65$, 예측값 :22640.60$
# 결과값:20141.22$, 예측값 :16866.48$
# 결과값:33859.16$, 예측값 :46030.53$
# 결과값:20507.17$, 예측값 :23413.51$
# 결과값:18729.27$, 예측값 :8436.69$
# 결과값:24656.52$, 예측값 :29768.60$
# 결과값:31369.32$, 예측값 :38790.78$
# 결과값:63271.35$, 예측값 :56872.40$
# 결과값:29596.65$, 예측값 :34712.63$
# 결과값:21725.54$, 예측값 :21906.99$
# 결과값:46884.32$, 예측값 :44979.12$
# 결과값:34571.88$, 예측값 :24829.72$
# 결과값:22188.46$, 예측값 :17191.37$
# 결과값:44632.77$, 예측값 :16668.96$
# 결과값:64839.84$, 예측값 :46716.68$
# 결과값:21068.75$, 예측값 :20384.00$
# 결과값:26685.53$, 예측값 :13020.80$
# 결과값:44230.99$, 예측값 :46042.71$
# 결과값:41928.12$, 예측값 :20588.22$
# 결과값:26932.46$, 예측값 :21377.72$
# 결과값:32885.75$, 예측값 :27040.33$
# 결과값:43849.17$, 예측값 :18032.28$
# 결과값:50554.25$, 예측값 :28917.76$
# 결과값:21132.06$, 예측값 :12820.77$
# 결과값:23495.78$, 예측값 :13219.85$
# 결과값:52848.73$, 예측값 :31619.59$
# 결과값:64620.82$, 예측값 :23174.58$
# 결과값:27902.71$, 예측값 :32062.26$
# 결과값:22582.79$, 예측값 :25261.61$
# 결과값:17875.20$, 예측값 :32522.72$
# 결과값:26064.87$, 예측값 :27486.48$
# 결과값:29562.00$, 예측값 :32834.48$
# 결과값:45836.54$, 예측값 :31829.80$
# 결과값:31056.48$, 예측값 :16547.27$
# 결과값:29652.40$, 예측값 :18393.68$
# 결과값:20166.87$, 예측값 :22548.11$
# 결과값:61067.60$, 예측값 :24354.75$
# 결과값:21089.69$, 예측값 :25948.77$
# 결과값:41660.11$, 예측값 :49310.91$
# 결과값:43603.15$, 예측값 :25185.94$
# 결과값:67065.04$, 예측값 :63374.05$
# 결과값:43612.11$, 예측값 :46461.68$
# 결과값:41371.20$, 예측값 :30795.63$
# 결과값:57017.00$, 예측값 :26156.72$
# 결과값:25038.87$, 예측값 :22132.33$
# 결과값:61536.29$, 예측값 :66529.61$
# 결과값:48094.80$, 예측값 :47708.82$
# 결과값:42701.88$, 예측값 :15862.96$
# 결과값:25383.84$, 예측값 :27767.81$
# 결과값:26160.00$, 예측값 :33171.38$
# 결과값:22801.15$, 예측값 :15025.41$
# 결과값:29107.42$, 예측값 :20321.81$
# 결과값:24964.93$, 예측값 :27695.17$
# 결과값:20560.96$, 예측값 :8433.02$
# 결과값:27946.11$, 예측값 :36762.39$
# 결과값:21864.34$, 예측값 :34608.55$
# 결과값:50569.24$, 예측값 :19272.64$
# 결과값:24578.10$, 예측값 :12156.96$
# 결과값:26308.95$, 예측값 :17121.28$
# 결과값:34232.64$, 예측값 :41043.93$
# 결과값:28881.90$, 예측값 :17117.07$
# 결과값:33543.70$, 예측값 :13143.94$
# 결과값:23587.59$, 예측값 :20772.69$
# 결과값:41953.28$, 예측값 :44231.63$
# 결과값:48878.47$, 예측값 :48957.85$
# 결과값:27922.66$, 예측값 :38945.64$
# 결과값:26625.14$, 예측값 :25657.25$
# 결과값:20568.97$, 예측값 :21903.64$
# 결과값:39604.91$, 예측값 :15715.27$
# 결과값:36516.67$, 예측값 :39006.18$
# 결과값:23325.59$, 예측값 :18578.79$
# 결과값:35983.13$, 예측값 :50991.43$
# 결과값:28350.11$, 예측값 :27299.23$
# 결과값:64608.96$, 예측값 :63902.78$
# 결과값:33490.42$, 예측값 :20432.53$
# 결과값:55489.43$, 예측값 :19549.91$
# 결과값:33248.83$, 예측값 :35819.71$
# 결과값:20455.34$, 예측값 :23209.45$
# 결과값:27424.80$, 예측값 :18482.71$
# 결과값:34224.76$, 예측값 :23313.71$
# 결과값:31337.89$, 예측값 :49348.59$
# 결과값:25202.39$, 예측값 :14730.42$
# 결과값:62259.60$, 예측값 :54375.56$
# 결과값:67738.23$, 예측값 :48620.82$
# 결과값:20647.68$, 예측값 :24061.51$
# 결과값:63873.39$, 예측값 :33018.40$
# 결과값:38667.58$, 예측값 :42130.07$
# 결과값:21155.78$, 예측값 :16861.69$
# 결과값:29978.80$, 예측값 :35729.85$
# 결과값:24901.69$, 예측값 :18437.65$
# 결과값:38149.61$, 예측값 :15009.72$
# 결과값:36866.22$, 예측값 :44525.62$
# 결과값:40999.92$, 예측값 :18556.16$
# 결과값:34184.09$, 예측값 :48830.10$
# 결과값:66450.93$, 예측값 :52626.34$
# 결과값:32951.72$, 예측값 :32752.50$
# 결과값:34346.46$, 예측값 :31571.21$
# 결과값:32102.37$, 예측값 :38838.41$
# 결과값:23972.19$, 예측값 :13930.18$
# 결과값:37005.07$, 예측값 :21876.82$
# 결과값:28864.68$, 예측값 :18440.07$
# 결과값:22295.68$, 예측값 :32266.04$
# 결과값:20564.19$, 예측값 :20582.21$
# 결과값:34746.72$, 예측값 :38295.25$
# 결과값:26611.96$, 예측값 :26181.39$
# 결과값:26746.08$, 예측값 :27562.67$
# 결과값:27205.50$, 예측값 :31926.10$
# 결과값:25577.43$, 예측값 :28602.15$
# 결과값:20295.30$, 예측값 :40331.93$
# 결과값:33397.60$, 예측값 :30871.31$
# 결과값:54628.83$, 예측값 :23355.80$
# 결과값:25034.76$, 예측값 :21145.92$
# 결과값:45057.48$, 예측값 :33507.23$
# 결과값:45657.41$, 예측값 :25634.78$
# 결과값:30493.40$, 예측값 :26961.61$
# 결과값:57439.15$, 예측값 :56637.20$
# 결과값:20344.27$, 예측값 :32834.87$
# 결과값:27634.20$, 예측값 :32285.80$
# 결과값:35863.89$, 예측값 :39506.01$
# 결과값:28482.54$, 예측값 :33368.85$
# 결과값:55114.43$, 예측값 :50202.70$
# 결과값:20128.93$, 예측값 :14481.72$
# 결과값:20920.19$, 예측값 :28272.70$
# 결과값:41079.67$, 예측값 :28452.86$
# 결과값:23169.18$, 예측값 :20135.78$
# 결과값:20158.59$, 예측값 :29406.05$
# 결과값:58437.60$, 예측값 :56917.83$
# 결과값:23207.22$, 예측값 :17888.36$
# 결과값:33785.08$, 예측값 :31597.26$
# 결과값:52930.41$, 예측값 :40527.15$
# 결과값:30082.42$, 예측값 :22913.86$
# 결과값:25892.41$, 예측값 :38110.07$
# 결과값:49105.46$, 예측값 :19017.52$
# 결과값:55856.35$, 예측값 :55781.25$
# 결과값:47167.24$, 예측값 :17748.25$
# 결과값:39034.32$, 예측값 :42325.42$
# 결과값:37753.27$, 예측값 :26831.69$
# 결과값:23199.27$, 예측값 :25069.71$
# 결과값:22499.57$, 예측값 :18917.60$
# 결과값:42906.55$, 예측값 :48923.54$
# 결과값:20148.51$, 예측값 :28815.03$
# 결과값:30959.82$, 예측값 :15618.84$
# 결과값:45024.69$, 예측값 :21536.24$
# 결과값:16067.35$, 예측값 :5082.79$
# 결과값:39880.62$, 예측값 :22561.98$
# 결과값:27628.26$, 예측값 :21967.49$
# 결과값:29369.75$, 예측값 :30779.54$
# 결과값:26213.40$, 예측값 :30227.71$
# 결과값:27591.72$, 예측값 :23870.74$
# 결과값:30784.37$, 예측값 :36279.18$
# 결과값:27119.82$, 예측값 :16397.18$
# 결과값:34225.71$, 예측값 :28878.18$
# 결과값:20500.37$, 예측값 :25913.95$
# 결과값:49964.93$, 예측값 :20691.99$
# 결과값:38007.72$, 예측값 :46660.77$
# 결과값:61698.95$, 예측값 :21280.53$
# 결과값:29551.97$, 예측값 :35380.30$
# 결과값:47297.70$, 예측값 :23153.15$
# 결과값:32632.75$, 예측값 :32008.02$
# 결과값:64372.54$, 예측값 :23307.83$
# 결과값:63965.99$, 예측값 :36381.27$
# 결과값:68574.48$, 예측값 :20003.39$
# 결과값:30895.80$, 예측값 :19415.62$
# 결과값:57498.09$, 예측값 :48347.38$
# 결과값:38599.92$, 예측값 :39814.63$
# 결과값:21735.81$, 예측값 :15998.37$
# 결과값:53764.84$, 예측값 :25615.73$
# 결과값:22891.14$, 예측값 :14506.26$
# 결과값:30774.12$, 예측값 :27280.73$
# 결과값:42306.20$, 예측값 :25337.12$
# 결과값:36709.39$, 예측값 :19007.53$
# 결과값:22799.87$, 예측값 :27625.43$
# 결과값:40908.44$, 예측값 :45458.52$
# 결과값:41407.39$, 예측값 :24815.55$
# 결과값:24460.13$, 예측값 :19421.94$
# 결과값:22399.73$, 예측값 :21405.35$
# 결과값:49176.27$, 예측값 :16919.13$
# 결과값:26632.32$, 예측값 :20629.54$
# 결과값:23901.09$, 예측값 :16839.62$
# 결과값:27314.91$, 예측값 :31154.79$
# 결과값:54478.32$, 예측값 :52217.08$
# 결과값:44591.90$, 예측값 :18608.34$
# 결과값:49799.86$, 예측값 :18889.59$
# 결과값:49596.35$, 예측값 :48113.53$
# 결과값:32098.84$, 예측값 :35921.01$
# 결과값:33530.73$, 예측값 :18458.28$
# 결과값:30836.52$, 예측값 :22311.68$
# 결과값:58468.02$, 예측값 :27398.65$
# 결과값:27329.64$, 예측값 :9075.16$
# 결과값:35055.12$, 예측값 :42343.61$
# 결과값:25091.01$, 예측값 :31269.09$
# 결과값:28335.84$, 예측값 :20715.85$
# 결과값:25441.10$, 예측값 :29289.50$
# 결과값:33864.78$, 예측값 :34293.07$
# 결과값:60768.12$, 예측값 :59902.27$
# 결과값:27505.31$, 예측값 :29364.08$
# 결과값:50907.51$, 예측값 :24213.97$
# 결과값:22106.31$, 예측값 :18839.95$
# 결과값:36689.98$, 예측값 :44993.75$
# 결과값:26450.86$, 예측값 :12016.52$
# 결과값:20419.78$, 예측값 :26651.77$
# 결과값:28861.48$, 예측값 :13657.18$
# 결과값:23887.50$, 예측값 :27891.65$
# 결과값:49397.98$, 예측값 :59893.57$
# 결과값:27388.00$, 예측값 :23991.08$
# 결과값:24933.36$, 예측값 :10572.64$
# 결과값:41684.93$, 예측값 :23451.04$
# 결과값:40836.71$, 예측값 :26941.91$
# 결과값:49865.46$, 예측값 :34973.88$
# 결과값:52137.95$, 예측값 :45821.79$
# 결과값:34268.68$, 예측값 :27550.34$
# 결과값:28308.82$, 예측값 :31263.22$
# 결과값:45075.72$, 예측값 :51412.91$
# 결과값:23272.44$, 예측값 :26971.31$
# 결과값:38228.78$, 예측값 :16243.26$
# 결과값:62247.12$, 예측값 :60736.12$
# 결과값:18681.64$, 예측값 :17365.36$
# 결과값:30920.20$, 예측값 :39637.22$
# 결과값:55121.16$, 예측값 :51905.25$
# 결과값:68659.03$, 예측값 :28765.95$
# 결과값:31859.88$, 예측값 :46598.39$
# 결과값:27413.43$, 예측값 :33619.71$
# 결과값:52363.90$, 예측값 :26942.55$
# 결과값:51524.24$, 예측값 :65097.44$
# 결과값:53998.15$, 예측값 :33184.50$
# 결과값:61111.33$, 예측값 :25575.19$
# 결과값:25017.10$, 예측값 :11614.52$
# 결과값:57991.13$, 예측값 :32519.28$
# 결과값:67113.49$, 예측값 :61205.96$
# 결과값:47515.73$, 예측값 :46032.01$
# 결과값:30428.44$, 예측값 :39390.76$
# 결과값:24718.20$, 예측값 :16817.65$
# 결과값:26863.06$, 예측값 :42988.72$
# 결과값:20483.38$, 예측값 :25964.15$
# 결과값:37187.48$, 예측값 :42951.25$
# 결과값:37633.44$, 예측값 :38248.86$
# 결과값:34948.31$, 예측값 :20804.37$
# 결과값:22571.78$, 예측값 :15283.46$
# 결과값:40466.40$, 예측값 :52233.82$
# 결과값:38190.98$, 예측값 :27211.44$
# 결과값:41917.20$, 예측값 :44426.02$
# 결과값:25334.40$, 예측값 :37239.30$
# 결과값:26046.90$, 예측값 :32616.16$
# 결과값:21570.62$, 예측값 :25158.43$
# 결과값:64372.54$, 예측값 :38490.81$
# 결과값:27909.02$, 예측값 :34910.33$
# 결과값:43204.90$, 예측값 :19882.87$
# 결과값:28291.89$, 예측값 :23589.52$
# 결과값:41613.86$, 예측값 :48888.43$
# 결과값:29512.98$, 예측값 :30695.06$
# 결과값:26256.28$, 예측값 :36984.36$
# 결과값:25135.50$, 예측값 :25953.68$
# 결과값:41719.09$, 예측값 :44369.23$
# 결과값:33980.23$, 예측값 :18914.11$
# 결과값:70749.53$, 예측값 :46815.26$
# 결과값:45801.04$, 예측값 :28981.04$
# 결과값:24041.22$, 예측값 :19847.70$
# 결과값:49595.52$, 예측값 :52209.73$
# 결과값:30273.44$, 예측값 :29010.43$
# 결과값:15476.93$, 예측값 :18426.56$
# 결과값:56131.02$, 예측값 :50080.76$
# 결과값:50279.42$, 예측값 :36606.12$
# 결과값:36331.53$, 예측값 :32906.06$
# 결과값:34002.34$, 예측값 :43016.96$
# 결과값:21579.42$, 예측값 :21363.46$
# 결과값:20612.37$, 예측값 :16235.75$
# 결과값:22009.90$, 예측값 :15444.76$
# 결과값:43163.33$, 예측값 :44260.33$
# 결과값:42905.79$, 예측값 :18958.78$
# 결과값:40852.38$, 예측값 :50951.61$
# 결과값:26926.69$, 예측값 :9799.22$
# 결과값:28995.88$, 예측값 :31512.53$
# 결과값:29404.60$, 예측값 :13763.76$
# 결과값:44619.79$, 예측값 :44118.40$
# 결과값:29651.08$, 예측값 :27624.62$
# 결과값:29117.12$, 예측값 :37448.14$
# 결과값:43216.40$, 예측값 :47590.49$
# 결과값:20503.13$, 예측값 :40138.39$
# 결과값:22917.52$, 예측값 :35231.10$
# 결과값:36431.97$, 예측값 :49813.52$
# 결과값:30834.02$, 예측값 :16683.01$
# 결과값:56407.68$, 예측값 :24655.22$
# 결과값:63530.73$, 예측값 :49621.47$
# 결과값:38379.10$, 예측값 :16076.23$
# Accuracy: -5.95   RMSE : 13985.07

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 15,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 10000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:49397.98$, 예측값 :59893.57$
# 결과값:52699.97$, 예측값 :53543.36$
# 결과값:13500.16$, 예측값 :9131.17$
# 결과값:13490.76$, 예측값 :10382.18$
# 결과값:45801.04$, 예측값 :28981.04$
# 결과값:41613.86$, 예측값 :48888.43$
# 결과값:29404.60$, 예측값 :13763.76$
# 결과값:43216.40$, 예측값 :47590.49$
# 결과값:55114.43$, 예측값 :50202.70$
# 결과값:42250.88$, 예측값 :25742.03$
# 결과값:67290.13$, 예측값 :65050.97$
# 결과값:29117.12$, 예측값 :37448.14$
# 결과값:35410.46$, 예측값 :41724.82$
# 결과값:27946.11$, 예측값 :36762.39$
# 결과값:35880.23$, 예측값 :41269.85$
# 결과값:15476.93$, 예측값 :18426.56$
# 결과값:38599.92$, 예측값 :39814.63$
# 결과값:37753.27$, 예측값 :26831.69$
# 결과값:37297.65$, 예측값 :26337.65$
# 결과값:21648.12$, 예측값 :16306.90$
# 결과값:37187.48$, 예측값 :42951.25$
# 결과값:20280.75$, 예측값 :26303.01$
# 결과값:22399.73$, 예측값 :21405.35$
# 결과값:21735.81$, 예측값 :15998.37$
# 결과값:41719.09$, 예측값 :44369.23$
# 결과값:25892.41$, 예측값 :38110.07$
# 결과값:13336.86$, 예측값 :13549.64$
# 결과값:33397.60$, 예측값 :30871.31$
# 결과값:21373.06$, 예측값 :28487.28$
# 결과값:16480.38$, 예측값 :16308.63$
# 결과값:31780.32$, 예측값 :17726.05$
# 결과값:21089.69$, 예측값 :25948.77$
# 결과값:27909.02$, 예측값 :34910.33$
# 결과값:23972.19$, 예측값 :13930.18$
# 결과값:48094.80$, 예측값 :47708.82$
# 결과값:18681.64$, 예측값 :17365.36$
# 결과값:57991.13$, 예측값 :32519.28$
# 결과값:38190.98$, 예측값 :27211.44$
# 결과값:58437.60$, 예측값 :56917.83$
# 결과값:49865.46$, 예측값 :34973.88$
# 결과값:20507.17$, 예측값 :23413.51$
# 결과값:23495.78$, 예측값 :13219.85$
# 결과값:38007.72$, 예측값 :46660.77$
# 결과값:26153.60$, 예측값 :12775.50$
# 결과값:23169.18$, 예측값 :20135.78$
# 결과값:26625.14$, 예측값 :25657.25$
# 결과값:58291.08$, 예측값 :54361.43$
# 결과값:37633.44$, 예측값 :38248.86$
# 결과값:22582.79$, 예측값 :25261.61$
# 결과값:24027.79$, 예측값 :25048.17$
# 결과값:34948.31$, 예측값 :20804.37$
# 결과값:25135.50$, 예측값 :25953.68$
# 결과값:61536.29$, 예측값 :66529.61$
# 결과값:11755.98$, 예측값 :8721.74$
# 결과값:66450.93$, 예측값 :52626.34$
# 결과값:29551.97$, 예측값 :35380.30$
# 결과값:16067.35$, 예측값 :5082.79$
# 결과값:54478.32$, 예측값 :52217.08$
# 결과값:36431.97$, 예측값 :49813.52$
# 결과값:64372.54$, 예측값 :38490.81$
# 결과값:21268.81$, 예측값 :14593.04$
# 결과값:26308.95$, 예측값 :17121.28$
# 결과값:52930.41$, 예측값 :40527.15$
# 결과값:40273.43$, 예측값 :39658.61$
# 결과값:50439.17$, 예측값 :56468.07$
# 결과값:20560.96$, 예측값 :8433.02$
# 결과값:20173.51$, 예측값 :13676.49$
# 결과값:49105.46$, 예측값 :19017.52$
# 결과값:28443.36$, 예측값 :33852.38$
# 결과값:27591.72$, 예측값 :23870.74$
# 결과값:18439.82$, 예측값 :9062.50$
# 결과값:21068.75$, 예측값 :20384.00$
# 결과값:29512.98$, 예측값 :30695.06$
# 결과값:53998.15$, 예측값 :33184.50$
# 결과값:30774.12$, 예측값 :27280.73$
# 결과값:27551.75$, 예측값 :18881.25$
# 결과값:27329.64$, 예측값 :9075.16$
# 결과값:30428.44$, 예측값 :39390.76$
# 결과값:35055.12$, 예측값 :42343.61$
# 결과값:25017.10$, 예측값 :11614.52$
# 결과값:20568.60$, 예측값 :26281.29$
# 결과값:21823.85$, 예측값 :14078.41$
# 결과값:25055.64$, 예측값 :17704.22$
# 결과값:36331.53$, 예측값 :32906.06$
# 결과값:21597.14$, 예측값 :7990.32$
# 결과값:33530.73$, 예측값 :18458.28$
# 결과값:40908.44$, 예측값 :45458.52$
# 결과값:61631.84$, 예측값 :32873.21$
# 결과값:29369.75$, 예측값 :30779.54$
# 결과값:54628.83$, 예측값 :23355.80$
# 결과값:44619.79$, 예측값 :44118.40$
# 결과값:31056.48$, 예측값 :16547.27$
# 결과값:41085.99$, 예측값 :48068.09$
# 결과값:41407.39$, 예측값 :24815.55$
# 결과값:24688.75$, 예측값 :31843.93$
# 결과값:21155.78$, 예측값 :16861.69$
# 결과값:63065.18$, 예측값 :25557.02$
# 결과값:27505.31$, 예측값 :29364.08$
# 결과값:56407.68$, 예측값 :24655.22$
# 결과값:27902.71$, 예측값 :32062.26$
# 결과값:23272.44$, 예측값 :26971.31$
# 결과값:21341.85$, 예측값 :21637.16$
# 결과값:30082.42$, 예측값 :22913.86$
# 결과값:43163.33$, 예측값 :44260.33$
# 결과값:31533.98$, 예측값 :33170.91$
# 결과값:49964.93$, 예측값 :20691.99$
# 결과값:28308.82$, 예측값 :31263.22$
# 결과값:34225.71$, 예측값 :28878.18$
# 결과값:21273.74$, 예측값 :36411.26$
# 결과값:36516.67$, 예측값 :39006.18$
# 결과값:34184.09$, 예측값 :48830.10$
# 결과값:25091.01$, 예측값 :31269.09$
# 결과값:68574.48$, 예측값 :20003.39$
# 결과값:31911.25$, 예측값 :32244.76$
# 결과값:33543.70$, 예측값 :13143.94$
# 결과값:20128.93$, 예측값 :14481.72$
# 결과값:32381.79$, 예측값 :34030.35$
# 결과값:43603.15$, 예측값 :25185.94$
# 결과값:56131.02$, 예측값 :50080.76$
# 결과값:21132.06$, 예측값 :12820.77$
# 결과값:40550.62$, 예측값 :37933.23$
# 결과값:24718.20$, 예측값 :16817.65$
# 결과값:29652.40$, 예측값 :18393.68$
# 결과값:53764.84$, 예측값 :25615.73$
# 결과값:31337.89$, 예측값 :49348.59$
# 결과값:29581.89$, 예측값 :20017.33$
# 결과값:48878.47$, 예측값 :48957.85$
# 결과값:45657.41$, 예측값 :25634.78$
# 결과값:38389.60$, 예측값 :25799.29$
# 결과값:37042.20$, 예측값 :16500.71$
# 결과값:26046.90$, 예측값 :32616.16$
# 결과값:32303.92$, 예측값 :26080.50$
# 결과값:49075.34$, 예측값 :49788.47$
# 결과값:20586.85$, 예측값 :29868.94$
# 결과값:33085.57$, 예측값 :39642.04$
# 결과값:36908.43$, 예측값 :19439.17$
# 결과값:20860.01$, 예측값 :9918.90$
# 결과값:44591.90$, 예측값 :18608.34$
# 결과값:57017.00$, 예측값 :26156.72$
# 결과값:35983.13$, 예측값 :50991.43$
# 결과값:38225.91$, 예측값 :17284.47$
# 결과값:24460.13$, 예측값 :19421.94$
# 결과값:63965.99$, 예측값 :36381.27$
# 결과값:55834.65$, 예측값 :22640.60$
# 결과값:64620.82$, 예측값 :23174.58$
# 결과값:20656.12$, 예측값 :23574.10$
# 결과값:38228.78$, 예측값 :16243.26$
# 결과값:66986.79$, 예측값 :45410.37$
# 결과값:22188.46$, 예측값 :17191.37$
# 결과값:55489.43$, 예측값 :19549.91$
# 결과값:49340.63$, 예측값 :21007.93$
# 결과값:28350.11$, 예측값 :27299.23$
# 결과값:23382.75$, 예측값 :37432.28$
# 결과값:27950.91$, 예측값 :21621.76$
# 결과값:27634.20$, 예측값 :32285.80$
# 결과값:61111.33$, 예측값 :25575.19$
# 결과값:33785.08$, 예측값 :31597.26$
# 결과값:50554.25$, 예측값 :28917.76$
# 결과값:45057.48$, 예측값 :33507.23$
# 결과값:20965.96$, 예측값 :10734.27$
# 결과값:26160.00$, 예측값 :33171.38$
# 결과값:59670.09$, 예측값 :25952.24$
# 결과값:58721.83$, 예측값 :61374.45$
# 결과값:20148.51$, 예측값 :28815.03$
# 결과값:28864.68$, 예측값 :18440.07$
# 결과값:66413.49$, 예측값 :47235.56$
# 결과값:43612.11$, 예측값 :46461.68$
# 결과값:40836.71$, 예측값 :26941.91$
# 결과값:22023.28$, 예측값 :26102.25$
# 결과값:26450.86$, 예측값 :12016.52$
# 결과값:40078.74$, 예측값 :23721.65$
# 결과값:27388.00$, 예측값 :23991.08$
# 결과값:29562.00$, 예측값 :32834.48$
# 결과값:70749.53$, 예측값 :46815.26$
# 결과값:63873.39$, 예측값 :33018.40$
# 결과값:49176.27$, 예측값 :16919.13$
# 결과값:31098.54$, 예측값 :24008.13$
# 결과값:30234.83$, 예측값 :33079.46$
# 결과값:25334.40$, 예측값 :37239.30$
# 결과값:52137.95$, 예측값 :45821.79$
# 결과값:57774.21$, 예측값 :61914.18$
# 결과값:20455.34$, 예측값 :23209.45$
# 결과값:22980.98$, 예측값 :8129.32$
# 결과값:24964.93$, 예측값 :27695.17$
# 결과값:35863.89$, 예측값 :39506.01$
# 결과값:20734.32$, 예측값 :16921.01$
# 결과값:39604.91$, 예측값 :15715.27$
# 결과값:37005.07$, 예측값 :21876.82$
# 결과값:30493.40$, 예측값 :26961.61$
# 결과값:68659.03$, 예측값 :28765.95$
# 결과값:64608.96$, 예측값 :63902.78$
# 결과값:56175.76$, 예측값 :27849.52$
# 결과값:49707.29$, 예측값 :48308.25$
# 결과값:36866.22$, 예측값 :44525.62$
# 결과값:67113.49$, 예측값 :61205.96$
# 결과값:63276.72$, 예측값 :57295.07$
# 결과값:32951.72$, 예측값 :32752.50$
# 결과값:49595.52$, 예측값 :52209.73$
# 결과값:26685.53$, 예측값 :13020.80$
# 결과값:33370.94$, 예측값 :17872.10$
# 결과값:21091.67$, 예측값 :12767.58$
# 결과값:42906.55$, 예측값 :48923.54$
# 결과값:57498.09$, 예측값 :48347.38$
# 결과값:63530.73$, 예측값 :49621.47$
# 결과값:67065.04$, 예측값 :63374.05$
# 결과값:28291.89$, 예측값 :23589.52$
# 결과값:41660.11$, 예측값 :49310.91$
# 결과값:21269.26$, 예측값 :42633.95$
# 결과값:12996.87$, 예측값 :13384.17$
# 결과값:23325.59$, 예측값 :18578.79$
# 결과값:28861.48$, 예측값 :13657.18$
# 결과값:34571.88$, 예측값 :24829.72$
# 결과값:21931.09$, 예측값 :23694.73$
# 결과값:22235.62$, 예측값 :15538.96$
# 결과값:25038.87$, 예측값 :22132.33$
# 결과값:24389.96$, 예측값 :16901.23$
# 결과값:29260.48$, 예측값 :19271.24$
# 결과값:25577.43$, 예측값 :28602.15$
# 결과값:27122.16$, 예측값 :15179.05$
# 결과값:50279.42$, 예측값 :36606.12$
# 결과값:47515.73$, 예측값 :46032.01$
# 결과값:13262.90$, 예측값 :9204.46$
# 결과값:33296.64$, 예측값 :35527.46$
# 결과값:30920.20$, 예측값 :39637.22$
# 결과값:31817.76$, 예측값 :36058.43$
# 결과값:20647.68$, 예측값 :24061.51$
# 결과값:44632.77$, 예측값 :16668.96$
# 결과값:18729.27$, 예측값 :8436.69$
# 결과값:12627.71$, 예측값 :16577.28$
# 결과값:22499.57$, 예측값 :18917.60$
# 결과값:26351.57$, 예측값 :18871.65$
# 결과값:29107.42$, 예측값 :20321.81$
# 결과값:32102.37$, 예측값 :38838.41$
# 결과값:50569.24$, 예측값 :19272.64$
# 결과값:41917.20$, 예측값 :44426.02$
# 결과값:42905.79$, 예측값 :18958.78$
# 결과값:21292.03$, 예측값 :9038.40$
# 결과값:26932.46$, 예측값 :21377.72$
# 결과값:20676.24$, 예측값 :17095.94$
# 결과값:20068.89$, 예측값 :22211.98$
# 결과값:52363.90$, 예측값 :26942.55$
# 결과값:31199.25$, 예측값 :30485.25$
# 결과값:27119.82$, 예측값 :16397.18$
# 결과값:28482.54$, 예측값 :33368.85$
# 결과값:49931.34$, 예측값 :42354.17$
# 결과값:26926.69$, 예측값 :9799.22$
# 결과값:27413.43$, 예측값 :33619.71$
# 결과값:26746.08$, 예측값 :27562.67$
# 결과값:26611.96$, 예측값 :26181.39$
# 결과값:17875.20$, 예측값 :32522.72$
# 결과값:63577.08$, 예측값 :35974.71$
# 결과값:28881.90$, 예측값 :17117.07$
# 결과값:20929.08$, 예측값 :21832.38$
# 결과값:24656.52$, 예측값 :29768.60$
# 결과값:26083.82$, 예측값 :24110.98$
# 결과값:20503.13$, 예측값 :40138.39$
# 결과값:26064.87$, 예측값 :27486.48$
# 결과값:46774.57$, 예측값 :22972.81$
# 결과값:27068.73$, 예측값 :15372.48$
# 결과값:22571.78$, 예측값 :15283.46$
# 결과값:42701.88$, 예측값 :15862.96$
# 결과값:32098.84$, 예측값 :35921.01$
# 결과값:31859.88$, 예측값 :46598.39$
# 결과값:41953.98$, 예측값 :25571.15$
# 결과값:22801.15$, 예측값 :15025.41$
# 결과값:20500.37$, 예측값 :25913.95$
# 결과값:31369.32$, 예측값 :38790.78$
# 결과값:50907.51$, 예측값 :24213.97$
# 결과값:24901.69$, 예측값 :18437.65$
# 결과값:43204.90$, 예측값 :19882.87$
# 결과값:39880.62$, 예측값 :22561.98$
# 결과값:39034.32$, 예측값 :42325.42$
# 결과값:22785.34$, 예측값 :21409.93$
# 결과값:20166.87$, 예측값 :22548.11$
# 결과값:43148.04$, 예측값 :22965.41$
# 결과값:36709.39$, 예측값 :19007.53$
# 결과값:23700.97$, 예측값 :23195.67$
# 결과값:37691.55$, 예측값 :15429.92$
# 결과값:41684.93$, 예측값 :23451.04$
# 결과값:23679.82$, 예측값 :34749.66$
# 결과값:34039.04$, 예측값 :38553.36$
# 결과값:30273.44$, 예측값 :29010.43$
# 결과값:27314.91$, 예측값 :31154.79$
# 결과값:20612.37$, 예측값 :16235.75$
# 결과값:46884.32$, 예측값 :44979.12$
# 결과값:25612.14$, 예측값 :28966.20$
# 결과값:33859.16$, 예측값 :46030.53$
# 결과값:13326.63$, 예측값 :15792.03$
# 결과값:32800.56$, 예측값 :24883.28$
# 결과값:61698.95$, 예측값 :21280.53$
# 결과값:67738.23$, 예측값 :48620.82$
# 결과값:20139.90$, 예측값 :21216.79$
# 결과값:58468.02$, 예측값 :27398.65$
# 결과값:62259.60$, 예측값 :54375.56$
# 결과값:22891.14$, 예측값 :14506.26$
# 결과값:35719.12$, 예측값 :47277.25$
# 결과값:23901.09$, 예측값 :16839.62$
# 결과값:33248.83$, 예측값 :35819.71$
# 결과값:68617.96$, 예측값 :24586.12$
# 결과값:44230.99$, 예측값 :46042.71$
# 결과값:25383.84$, 예측값 :27767.81$
# 결과값:20920.19$, 예측값 :28272.70$
# 결과값:47252.40$, 예측값 :43830.64$
# 결과값:47296.08$, 예측값 :24473.46$
# 결과값:69759.86$, 예측값 :51983.24$
# 결과값:20141.22$, 예측값 :16866.48$
# 결과값:20295.30$, 예측값 :40331.93$
# 결과값:51362.03$, 예측값 :21094.57$
# 결과값:64372.54$, 예측값 :23307.83$
# 결과값:22917.52$, 예측값 :35231.10$
# 결과값:20633.28$, 예측값 :14544.98$
# 결과값:34002.34$, 예측값 :43016.96$
# 결과값:40852.38$, 예측값 :50951.61$
# 결과값:22167.26$, 예측값 :38743.47$
# 결과값:29871.82$, 예측값 :26091.65$
# 결과값:13328.09$, 예측값 :4467.73$
# 결과값:35416.68$, 예측값 :21785.25$
# 결과값:34346.46$, 예측값 :31571.21$
# 결과값:20344.27$, 예측값 :32834.87$
# 결과값:61082.46$, 예측값 :54576.81$
# 결과값:23587.59$, 예측값 :20772.69$
# 결과값:33980.23$, 예측값 :18914.11$
# 결과값:24933.36$, 예측값 :10572.64$
# 결과값:38149.61$, 예측값 :15009.72$
# 결과값:45075.72$, 예측값 :51412.91$
# 결과값:34232.64$, 예측값 :41043.93$
# 결과값:30895.80$, 예측값 :19415.62$
# 결과값:25803.49$, 예측값 :27854.13$
# 결과값:20483.38$, 예측값 :25964.15$
# 결과값:25441.10$, 예측값 :29289.50$
# 결과값:25202.39$, 예측값 :14730.42$
# 결과값:28335.84$, 예측값 :20715.85$
# 결과값:47478.60$, 예측값 :52305.66$
# 결과값:23887.50$, 예측값 :27891.65$
# 결과값:52848.73$, 예측값 :31619.59$
# 결과값:16186.73$, 예측값 :21421.86$
# 결과값:16216.19$, 예측값 :24411.72$
# 결과값:23349.63$, 예측값 :12642.18$
# 결과값:55856.35$, 예측값 :55781.25$
# 결과값:26213.40$, 예측값 :30227.71$
# 결과값:49799.86$, 예측값 :18889.59$
# 결과값:33084.11$, 예측값 :41275.10$
# 결과값:25346.44$, 예측값 :30725.84$
# 결과값:21570.62$, 예측값 :25158.43$
# 결과값:36689.98$, 예측값 :44993.75$
# 결과값:33864.78$, 예측값 :34293.07$
# 결과값:38379.10$, 예측값 :16076.23$
# 결과값:25244.54$, 예측값 :15708.30$
# 결과값:49596.35$, 예측값 :48113.53$
# 결과값:47297.70$, 예측값 :23153.15$
# 결과값:32632.75$, 예측값 :32008.02$
# 결과값:20418.11$, 예측값 :23907.03$
# 결과값:26256.28$, 예측값 :36984.36$
# 결과값:30784.37$, 예측값 :36279.18$
# 결과값:20564.19$, 예측값 :20582.21$
# 결과값:38667.58$, 예측값 :42130.07$
# 결과값:31342.97$, 예측값 :22489.01$
# 결과값:28995.88$, 예측값 :31512.53$
# 결과값:29596.65$, 예측값 :34712.63$
# 결과값:46999.18$, 예측값 :24146.18$
# 결과값:21579.42$, 예측값 :21363.46$
# 결과값:22799.87$, 예측값 :27625.43$
# 결과값:57439.15$, 예측값 :56637.20$
# 결과값:63271.35$, 예측값 :56872.40$
# 결과값:28005.62$, 예측값 :19333.78$
# 결과값:20398.14$, 예측값 :21245.55$
# 결과값:35524.48$, 예측값 :31999.65$
# 결과값:25617.52$, 예측값 :20297.20$
# 결과값:52687.05$, 예측값 :56275.25$
# 결과값:46719.55$, 예측값 :18244.30$
# 결과값:20568.97$, 예측값 :21903.64$
# 결과값:31103.12$, 예측값 :14457.40$
# 결과값:41077.42$, 예측값 :20134.96$
# 결과값:64839.84$, 예측값 :46716.68$
# 결과값:64294.39$, 예측값 :47211.05$
# 결과값:33490.42$, 예측값 :20432.53$
# 결과값:23504.41$, 예측값 :23246.45$
# 결과값:27705.68$, 예측값 :34495.77$
# 결과값:24146.99$, 예측값 :31342.12$
# 결과값:55408.52$, 예측값 :35893.25$
# 결과값:41079.67$, 예측값 :28452.86$
# 결과값:21864.34$, 예측값 :34608.55$
# 결과값:22106.31$, 예측값 :18839.95$
# 결과값:50138.79$, 예측값 :51878.17$
# 결과값:21631.88$, 예측값 :18096.94$
# 결과값:55121.16$, 예측값 :51905.25$
# 결과값:26863.06$, 예측값 :42988.72$
# 결과값:13410.72$, 예측값 :13114.44$
# 결과값:27922.66$, 예측값 :38945.64$
# 결과값:20425.49$, 예측값 :24568.28$
# 결과값:44832.26$, 예측값 :45284.14$
# 결과값:24041.22$, 예측값 :19847.70$
# 결과값:23207.22$, 예측값 :17888.36$
# 결과값:27628.26$, 예측값 :21967.49$
# 결과값:15379.60$, 예측값 :15442.11$
# 결과값:45836.54$, 예측값 :31829.80$
# 결과값:60768.12$, 예측값 :59902.27$
# 결과값:26632.32$, 예측값 :20629.54$
# 결과값:25659.50$, 예측값 :17541.71$
# 결과값:40466.40$, 예측값 :52233.82$
# 결과값:45322.82$, 예측값 :46891.98$
# 결과값:51524.24$, 예측값 :65097.44$
# 결과값:24578.10$, 예측값 :12156.96$
# 결과값:41928.12$, 예측값 :20588.22$
# 결과값:30836.52$, 예측값 :22311.68$
# 결과값:29651.08$, 예측값 :27624.62$
# 결과값:61067.60$, 예측값 :24354.75$
# 결과값:21277.73$, 예측값 :24066.12$
# 결과값:27205.50$, 예측값 :31926.10$
# 결과값:47167.24$, 예측값 :17748.25$
# 결과값:40003.27$, 예측값 :16705.43$
# 결과값:42306.20$, 예측값 :25337.12$
# 결과값:39855.05$, 예측값 :42266.30$
# 결과값:34211.50$, 예측값 :37613.32$
# 결과값:45024.69$, 예측값 :21536.24$
# 결과값:21170.51$, 예측값 :24508.98$
# 결과값:23028.91$, 예측값 :27219.54$
# 결과값:22295.68$, 예측값 :32266.04$
# 결과값:23199.27$, 예측값 :25069.71$
# 결과값:30959.82$, 예측값 :15618.84$
# 결과값:45052.80$, 예측값 :23174.04$
# 결과값:69297.88$, 예측값 :22805.11$
# 결과값:62247.12$, 예측값 :60736.12$
# 결과값:49484.99$, 예측값 :21540.14$
# 결과값:30834.02$, 예측값 :16683.01$
# 결과값:41953.28$, 예측값 :44231.63$
# 결과값:40999.92$, 예측값 :18556.16$
# 결과값:27424.80$, 예측값 :18482.71$
# 결과값:29978.80$, 예측값 :35729.85$
# 결과값:21725.54$, 예측값 :21906.99$
# 결과값:22009.90$, 예측값 :15444.76$
# 결과값:23814.90$, 예측값 :17460.71$
# 결과값:26130.53$, 예측값 :36845.00$
# 결과값:20419.78$, 예측값 :26651.77$
# 결과값:32885.75$, 예측값 :27040.33$
# 결과값:21547.23$, 예측값 :29436.88$
# 결과값:41371.20$, 예측값 :30795.63$
# 결과값:25584.00$, 예측값 :16460.56$
# 결과값:39042.12$, 예측값 :35093.07$
# 결과값:41870.40$, 예측값 :27325.31$
# 결과값:34224.76$, 예측값 :23313.71$
# 결과값:34746.72$, 예측값 :38295.25$
# 결과값:43849.17$, 예측값 :18032.28$
# 결과값:25034.76$, 예측값 :21145.92$
# 결과값:34268.68$, 예측값 :27550.34$
# 결과값:39272.56$, 예측값 :57315.09$
# 결과값:20158.59$, 예측값 :29406.05$
# Accuracy: -0.04   RMSE : 13840.28

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 10,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:2066.92$, 예측값 :1486.49$
# 결과값:1973.23$, 예측값 :1021.71$
# 결과값:1105.87$, 예측값 :783.10$
# 결과값:34232.64$, 예측값 :41043.93$
# 결과값:3173.68$, 예측값 :3618.15$
# 결과값:5991.94$, 예측값 :1575.18$
# 결과값:1212.63$, 예측값 :855.86$
# 결과값:1447.35$, 예측값 :841.05$
# 결과값:4011.70$, 예측값 :3148.41$
# 결과값:1985.94$, 예측값 :1578.17$
# 결과값:37691.55$, 예측값 :15429.92$
# 결과값:33248.83$, 예측값 :35819.71$
# 결과값:753.77$, 예측값 :858.77$
# 결과값:1347.34$, 예측값 :827.36$
# 결과값:926.68$, 예측값 :550.99$
# 결과값:1993.12$, 예측값 :1469.27$
# 결과값:2508.64$, 예측값 :2342.57$
# 결과값:33859.16$, 예측값 :46030.53$
# 결과값:2817.63$, 예측값 :3789.08$
# 결과값:2213.67$, 예측값 :2487.79$
# 결과값:55834.65$, 예측값 :22640.60$
# 결과값:1538.85$, 예측값 :1064.71$
# 결과값:1091.99$, 예측값 :703.72$
# 결과값:1624.24$, 예측값 :1415.79$
# 결과값:808.48$, 예측값 :990.34$
# 결과값:1173.20$, 예측값 :843.97$
# 결과값:31342.97$, 예측값 :22489.01$
# 결과값:24578.10$, 예측값 :12156.96$
# 결과값:1281.80$, 예측값 :691.98$
# 결과값:1463.57$, 예측값 :1358.22$
# 결과값:49964.93$, 예측값 :20691.99$
# 결과값:2044.65$, 예측값 :2425.25$
# 결과값:1427.29$, 예측값 :1187.32$
# 결과값:2059.52$, 예측값 :1808.24$
# 결과값:2100.82$, 예측값 :1028.36$
# 결과값:2987.55$, 예측값 :2957.00$
# 결과값:30493.40$, 예측값 :26961.61$
# 결과값:27205.50$, 예측값 :31926.10$
# 결과값:63965.99$, 예측값 :36381.27$
# 결과값:2048.36$, 예측값 :1084.53$
# 결과값:1430.75$, 예측값 :1591.12$
# 결과값:1429.00$, 예측값 :736.09$
# 결과값:20920.19$, 예측값 :28272.70$
# 결과값:1752.65$, 예측값 :635.84$
# 결과값:2337.35$, 예측값 :2382.94$
# 결과값:33864.78$, 예측값 :34293.07$
# 결과값:50569.24$, 예측값 :19272.64$
# 결과값:1990.53$, 예측값 :2475.95$
# 결과값:928.62$, 예측값 :1066.18$
# 결과값:1012.99$, 예측값 :762.46$
# 결과값:63577.08$, 예측값 :35974.71$
# 결과값:1796.39$, 예측값 :733.85$
# 결과값:18439.82$, 예측값 :9062.50$
# 결과값:20560.96$, 예측값 :8433.02$
# 결과값:2002.90$, 예측값 :774.54$
# 결과값:1328.98$, 예측값 :1330.51$
# 결과값:1379.74$, 예측값 :1215.42$
# 결과값:41079.67$, 예측값 :28452.86$
# 결과값:36331.53$, 예측값 :32906.06$
# 결과값:946.40$, 예측값 :1014.58$
# 결과값:2412.96$, 예측값 :811.80$
# 결과값:954.65$, 예측값 :751.35$
# 결과값:46884.32$, 예측값 :44979.12$
# 결과값:2092.25$, 예측값 :1516.86$
# 결과값:2014.75$, 예측값 :2188.19$
# 결과값:2038.04$, 예측값 :1757.20$
# 결과값:2061.80$, 예측값 :1895.38$
# 결과값:1139.13$, 예측값 :841.76$
# 결과값:20280.75$, 예측값 :26303.01$
# 결과값:3001.29$, 예측값 :2977.18$
# 결과값:2036.90$, 예측값 :739.19$
# 결과값:4092.84$, 예측값 :1966.08$
# 결과값:2775.23$, 예측값 :3079.25$
# 결과값:2596.11$, 예측값 :3520.85$
# 결과값:3650.16$, 예측값 :2078.82$
# 결과값:1418.06$, 예측값 :1542.56$
# 결과값:1424.77$, 예측값 :822.99$
# 결과값:1538.81$, 예측값 :1253.61$
# 결과값:1324.27$, 예측값 :628.37$
# 결과값:22917.52$, 예측값 :35231.10$
# 결과값:23679.82$, 예측값 :34749.66$
# 결과값:13410.72$, 예측값 :13114.44$
# 결과값:1141.09$, 예측값 :691.51$
# 결과값:2094.76$, 예측값 :1990.35$
# 결과값:1172.15$, 예측값 :797.26$
# 결과값:1996.74$, 예측값 :646.57$
# 결과값:1115.81$, 예측값 :665.18$
# 결과값:33397.60$, 예측값 :30871.31$
# 결과값:20507.17$, 예측값 :23413.51$
# 결과값:819.30$, 예측값 :707.66$
# 결과값:34224.76$, 예측값 :23313.71$
# 결과값:2533.68$, 예측값 :856.81$
# 결과값:3122.16$, 예측값 :741.55$
# 결과값:64620.82$, 예측값 :23174.58$
# 결과값:11755.98$, 예측값 :8721.74$
# 결과값:1180.68$, 예측값 :1740.40$
# 결과값:3018.02$, 예측값 :4053.05$
# 결과값:3049.30$, 예측값 :1045.32$
# 결과값:23814.90$, 예측값 :17460.71$
# 결과값:22582.79$, 예측값 :25261.61$
# 결과값:23207.22$, 예측값 :17888.36$
# 결과값:1799.85$, 예측값 :1571.20$
# 결과값:1978.08$, 예측값 :1577.71$
# 결과값:1042.26$, 예측값 :894.81$
# 결과값:1739.94$, 예측값 :1191.64$
# 결과값:1040.08$, 예측값 :797.38$
# 결과값:1132.50$, 예측값 :730.64$
# 결과값:969.79$, 예측값 :749.18$
# 결과값:23587.59$, 예측값 :20772.69$
# 결과값:1015.23$, 예측값 :710.62$
# 결과값:41684.93$, 예측값 :23451.04$
# 결과값:2031.70$, 예측값 :1578.34$
# 결과값:37297.65$, 예측값 :26337.65$
# 결과값:20425.49$, 예측값 :24568.28$
# 결과값:33085.57$, 예측값 :39642.04$
# 결과값:1424.23$, 예측값 :1080.93$
# 결과값:2934.68$, 예측값 :2206.90$
# 결과값:33490.42$, 예측값 :20432.53$
# 결과값:13326.63$, 예측값 :15792.03$
# 결과값:943.90$, 예측값 :814.61$
# 결과값:30784.37$, 예측값 :36279.18$
# 결과값:28864.68$, 예측값 :18440.07$
# 결과값:1556.58$, 예측값 :1220.43$
# 결과값:2024.70$, 예측값 :894.87$
# 결과값:23349.63$, 예측값 :12642.18$
# 결과값:1786.96$, 예측값 :729.64$
# 결과값:29562.00$, 예측값 :32834.48$
# 결과값:1058.89$, 예측값 :773.68$
# 결과값:1122.50$, 예측값 :1441.33$
# 결과값:1327.11$, 예측값 :1007.02$
# 결과값:1326.33$, 예측값 :755.21$
# 결과값:3021.19$, 예측값 :1807.52$
# 결과값:1260.79$, 예측값 :587.73$
# 결과값:20676.24$, 예측값 :17095.94$
# 결과값:1163.62$, 예측값 :818.66$
# 결과값:2762.91$, 예측값 :1607.90$
# 결과값:2752.50$, 예측값 :2524.88$
# 결과값:2055.02$, 예측값 :957.01$
# 결과값:2101.62$, 예측값 :1893.90$
# 결과값:1731.02$, 예측값 :1323.25$
# 결과값:821.61$, 예측값 :1020.78$
# 결과값:2048.36$, 예측값 :2042.61$
# 결과값:1785.62$, 예측값 :577.59$
# 결과값:926.34$, 예측값 :550.14$
# 결과값:2527.87$, 예측값 :1746.26$
# 결과값:67738.23$, 예측값 :48620.82$
# 결과값:64372.54$, 예측값 :38490.81$
# 결과값:1056.25$, 예측값 :1009.01$
# 결과값:2680.62$, 예측값 :2173.80$
# 결과값:2029.39$, 예측값 :755.81$
# 결과값:2471.39$, 예측값 :2456.42$
# 결과값:30895.80$, 예측값 :19415.62$
# 결과값:25055.64$, 예측값 :17704.22$
# 결과값:1604.70$, 예측값 :1804.90$
# 결과값:2062.41$, 예측값 :611.10$
# 결과값:26213.40$, 예측값 :30227.71$
# 결과값:54628.83$, 예측값 :23355.80$
# 결과값:1997.75$, 예측값 :1677.61$
# 결과값:22980.98$, 예측값 :8129.32$
# 결과값:2313.96$, 예측값 :3191.54$
# 결과값:23325.59$, 예측값 :18578.79$
# 결과값:1063.62$, 예측값 :889.31$
# 결과값:1030.06$, 예측값 :826.31$
# 결과값:1973.70$, 예측값 :2040.05$
# 결과값:20734.32$, 예측값 :16921.01$
# 결과값:58721.83$, 예측값 :61374.45$
# 결과값:3632.78$, 예측값 :731.92$
# 결과값:13500.16$, 예측값 :9131.17$
# 결과값:1532.04$, 예측값 :596.44$
# 결과값:992.57$, 예측값 :623.41$
# 결과값:1093.01$, 예측값 :976.50$
# 결과값:1199.98$, 예측값 :809.01$
# 결과값:25244.54$, 예측값 :15708.30$
# 결과값:61082.46$, 예측값 :54576.81$
# 결과값:61536.29$, 예측값 :66529.61$
# 결과값:2516.77$, 예측값 :3407.58$
# 결과값:2304.05$, 예측값 :2264.63$
# 결과값:20503.13$, 예측값 :40138.39$
# 결과값:1738.38$, 예측값 :786.50$
# 결과값:56131.02$, 예측값 :50080.76$
# 결과값:20965.96$, 예측값 :10734.27$
# 결과값:2031.58$, 예측값 :939.84$
# 결과값:1169.51$, 예측값 :920.60$
# 결과값:1470.58$, 예측값 :1386.19$
# 결과값:2104.05$, 예측값 :1226.17$
# 결과값:895.73$, 예측값 :955.34$
# 결과값:2528.27$, 예측값 :999.44$
# 결과값:2583.82$, 예측값 :1233.01$
# 결과값:2350.82$, 예측값 :2418.70$
# 결과값:1325.28$, 예측값 :710.92$
# 결과값:24389.96$, 예측값 :16901.23$
# 결과값:2125.23$, 예측값 :2745.31$
# 결과값:47297.70$, 예측값 :23153.15$
# 결과값:1603.42$, 예측값 :682.85$
# 결과값:41613.86$, 예측값 :48888.43$
# 결과값:1270.22$, 예측값 :1304.17$
# 결과값:1134.51$, 예측값 :707.26$
# 결과값:52699.97$, 예측값 :53543.36$
# 결과값:45024.69$, 예측값 :21536.24$
# 결과값:6150.68$, 예측값 :4902.01$
# 결과값:27329.64$, 예측값 :9075.16$
# 결과값:44632.77$, 예측값 :16668.96$
# 결과값:2028.98$, 예측값 :3282.86$
# 결과값:56175.76$, 예측값 :27849.52$
# 결과값:29369.75$, 예측값 :30779.54$
# 결과값:43603.15$, 예측값 :25185.94$
# 결과값:1516.44$, 예측값 :1476.78$
# 결과값:21341.85$, 예측값 :21637.16$
# 결과값:39042.12$, 예측값 :35093.07$
# 결과값:23901.09$, 예측값 :16839.62$
# 결과값:49865.46$, 예측값 :34973.88$
# 결과값:1140.06$, 예측값 :857.22$
# 결과값:49595.52$, 예측값 :52209.73$
# 결과값:1446.08$, 예측값 :1106.44$
# 결과값:2040.00$, 예측값 :2147.93$
# 결과값:26932.46$, 예측값 :21377.72$
# 결과값:1540.60$, 예측값 :1788.18$
# 결과값:1931.92$, 예측값 :1634.03$
# 결과값:2077.11$, 예측값 :2099.86$
# 결과값:1623.88$, 예측값 :1407.27$
# 결과값:52137.95$, 예측값 :45821.79$
# 결과값:2452.64$, 예측값 :2506.64$
# 결과값:1861.10$, 예측값 :1392.47$
# 결과값:838.36$, 예측값 :864.01$
# 결과값:1790.94$, 예측값 :667.88$
# 결과값:2149.05$, 예측값 :1631.24$
# 결과값:2021.84$, 예측값 :2458.69$
# 결과값:20068.89$, 예측값 :22211.98$
# 결과값:1107.02$, 예측값 :771.69$
# 결과값:2322.22$, 예측값 :2822.27$
# 결과값:1057.31$, 예측값 :749.44$
# 결과값:1164.88$, 예측값 :877.01$
# 결과값:3642.69$, 예측값 :2328.98$
# 결과값:1650.45$, 예측값 :1464.10$
# 결과값:32885.75$, 예측값 :27040.33$
# 결과값:37633.44$, 예측값 :38248.86$
# 결과값:1135.71$, 예측값 :1041.31$
# 결과값:1843.82$, 예측값 :801.52$
# 결과값:48878.47$, 예측값 :48957.85$
# 결과값:1382.34$, 예측값 :1358.67$
# 결과값:974.29$, 예측값 :714.35$
# 결과값:1003.72$, 예측값 :983.80$
# 결과값:39272.56$, 예측값 :57315.09$
# 결과값:26351.57$, 예측값 :18871.65$
# 결과값:27705.68$, 예측값 :34495.77$
# 결과값:2031.82$, 예측값 :945.79$
# 결과값:24718.20$, 예측값 :16817.65$
# 결과값:1196.50$, 예측값 :1337.30$
# 결과값:22499.57$, 예측값 :18917.60$
# 결과값:28291.89$, 예측값 :23589.52$
# 결과값:36516.67$, 예측값 :39006.18$
# 결과값:4116.79$, 예측값 :2177.25$
# 결과값:38149.61$, 예측값 :15009.72$
# 결과값:2060.62$, 예측값 :2343.68$
# 결과값:1161.67$, 예측값 :1325.22$
# 결과값:1862.80$, 예측값 :1585.88$
# 결과값:3456.76$, 예측값 :1993.10$
# 결과값:1882.12$, 예측값 :1252.96$
# 결과값:1250.19$, 예측값 :960.32$
# 결과값:23887.50$, 예측값 :27891.65$
# 결과값:2069.61$, 예측값 :911.79$
# 결과값:1445.34$, 예측값 :1158.54$
# 결과값:2245.14$, 예측값 :1905.95$
# 결과값:38667.58$, 예측값 :42130.07$
# 결과값:37042.20$, 예측값 :16500.71$
# 결과값:2354.34$, 예측값 :816.98$
# 결과값:2031.45$, 예측값 :1826.13$
# 결과값:1751.48$, 예측값 :757.40$
# 결과값:21648.12$, 예측값 :16306.90$
# 결과값:1972.37$, 예측값 :1603.69$
# 결과값:1742.54$, 예측값 :796.90$
# 결과값:2106.18$, 예측값 :2199.76$
# 결과값:2166.14$, 예측값 :747.29$
# 결과값:41953.98$, 예측값 :25571.15$
# 결과값:1935.25$, 예측값 :1290.18$
# 결과값:61631.84$, 예측값 :32873.21$
# 결과값:22785.34$, 예측값 :21409.93$
# 결과값:30082.42$, 예측값 :22913.86$
# 결과값:1143.64$, 예측값 :1036.59$
# 결과값:41371.20$, 예측값 :30795.63$
# 결과값:1149.54$, 예측값 :1071.55$
# 결과값:1683.22$, 예측값 :869.60$
# 결과값:1972.43$, 예측값 :841.93$
# 결과값:31337.89$, 예측값 :49348.59$
# 결과값:21864.34$, 예측값 :34608.55$
# 결과값:1463.08$, 예측값 :1854.57$
# 결과값:946.42$, 예측값 :806.31$
# 결과값:1717.94$, 예측값 :1799.56$
# 결과값:13336.86$, 예측값 :13549.64$
# 결과값:1950.75$, 예측값 :1551.19$
# 결과값:2044.11$, 예측값 :1614.60$
# 결과값:1400.63$, 예측값 :1045.55$
# 결과값:24027.79$, 예측값 :25048.17$
# 결과값:2292.07$, 예측값 :683.46$
# 결과값:4161.25$, 예측값 :7292.44$
# 결과값:2324.68$, 예측값 :2304.84$
# 결과값:27068.73$, 예측값 :15372.48$
# 결과값:20929.08$, 예측값 :21832.38$
# 결과값:2161.39$, 예측값 :2904.11$
# 결과값:2179.02$, 예측값 :2408.55$
# 결과값:1864.54$, 예측값 :886.91$
# 결과값:2362.83$, 예측값 :2988.72$
# 결과값:1583.70$, 예측값 :705.73$
# 결과값:2098.19$, 예측값 :1459.49$
# 결과값:27551.75$, 예측값 :18881.25$
# 결과값:1279.25$, 예측값 :737.10$
# 결과값:2904.99$, 예측값 :2904.14$
# 결과값:926.91$, 예측값 :760.80$
# 결과값:2021.49$, 예측값 :2461.21$
# 결과값:2895.53$, 예측값 :5196.06$
# 결과값:2057.27$, 예측값 :1957.91$
# 결과값:46774.57$, 예측값 :22972.81$
# 결과값:20344.27$, 예측값 :32834.87$
# 결과값:1401.03$, 예측값 :1755.18$
# 결과값:2069.41$, 예측값 :932.58$
# 결과값:35983.13$, 예측값 :50991.43$
# 결과값:22399.73$, 예측값 :21405.35$
# 결과값:2074.89$, 예측값 :1732.16$
# 결과값:1028.53$, 예측값 :843.39$
# 결과값:34002.34$, 예측값 :43016.96$
# 결과값:1094.00$, 예측값 :773.89$
# 결과값:4148.72$, 예측값 :4437.50$
# 결과값:1024.19$, 예측값 :1211.43$
# 결과값:29652.40$, 예측값 :18393.68$
# 결과값:47167.24$, 예측값 :17748.25$
# 결과값:44230.99$, 예측값 :46042.71$
# 결과값:2448.32$, 예측값 :1747.26$
# 결과값:1988.78$, 예측값 :1726.31$
# 결과값:3815.09$, 예측값 :3138.23$
# 결과값:23700.97$, 예측값 :23195.67$
# 결과값:1423.83$, 예측값 :800.28$
# 결과값:2035.49$, 예측값 :756.21$
# 결과값:34184.09$, 예측값 :48830.10$
# 결과값:1993.46$, 예측값 :1455.33$
# 결과값:1123.55$, 예측값 :1138.97$
# 결과값:2099.04$, 예측값 :2506.31$
# 결과값:2187.06$, 예측값 :2159.82$
# 결과값:1066.07$, 예측값 :933.37$
# 결과값:2061.92$, 예측값 :2116.39$
# 결과값:1598.08$, 예측값 :1249.10$
# 결과값:24041.22$, 예측값 :19847.70$
# 결과값:2077.89$, 예측값 :2284.08$
# 결과값:969.79$, 예측값 :1065.93$
# 결과값:2045.64$, 예측값 :1104.98$
# 결과값:9348.54$, 예측값 :3002.09$
# 결과값:1672.34$, 예측값 :762.12$
# 결과값:22167.26$, 예측값 :38743.47$
# 결과값:2033.31$, 예측값 :2082.18$
# 결과값:2056.00$, 예측값 :1949.33$
# 결과값:1184.12$, 예측값 :1120.64$
# 결과값:57498.09$, 예측값 :48347.38$
# 결과값:9640.53$, 예측값 :12428.76$
# 결과값:25441.10$, 예측값 :29289.50$
# 결과값:26450.86$, 예측값 :12016.52$
# 결과값:1150.70$, 예측값 :910.05$
# 결과값:1983.47$, 예측값 :622.00$
# 결과값:2480.77$, 예측값 :2948.43$
# 결과값:1283.79$, 예측값 :684.82$
# 결과값:1329.81$, 예측값 :1099.11$
# 결과값:32951.72$, 예측값 :32752.50$
# 결과값:3129.89$, 예측값 :3110.01$
# 결과값:2031.06$, 예측값 :1761.14$
# 결과값:1006.26$, 예측값 :1026.09$
# 결과값:1058.95$, 예측값 :818.96$
# 결과값:1948.11$, 예측값 :1802.58$
# 결과값:20419.78$, 예측값 :26651.77$
# 결과값:1750.96$, 예측값 :759.95$
# 결과값:2018.71$, 예측값 :1071.95$
# 결과값:22023.28$, 예측값 :26102.25$
# 결과값:1680.03$, 예측값 :1533.94$
# 결과값:2448.26$, 예측값 :725.05$
# 결과값:4521.00$, 예측값 :2721.16$
# 결과값:3054.69$, 예측값 :4645.30$
# 결과값:49484.99$, 예측값 :21540.14$
# 결과값:1722.11$, 예측값 :1663.19$
# 결과값:2104.09$, 예측값 :1168.59$
# 결과값:13328.09$, 예측값 :4467.73$
# 결과값:1093.23$, 예측값 :1650.92$
# 결과값:1960.82$, 예측값 :1703.78$
# 결과값:34039.04$, 예측값 :38553.36$
# 결과값:35863.89$, 예측값 :39506.01$
# 결과값:1819.29$, 예측값 :842.42$
# 결과값:52363.90$, 예측값 :26942.55$
# 결과값:2192.54$, 예측값 :1738.11$
# 결과값:1131.52$, 예측값 :1033.13$
# 결과값:974.35$, 예측값 :1205.78$
# 결과값:1881.17$, 예측값 :764.67$
# 결과값:1302.80$, 예측값 :1122.65$
# 결과값:57774.21$, 예측값 :61914.18$
# 결과값:55114.43$, 예측값 :50202.70$
# 결과값:67113.49$, 예측값 :61205.96$
# 결과값:1426.55$, 예측값 :1099.79$
# 결과값:1145.90$, 예측값 :545.08$
# 결과값:23495.78$, 예측값 :13219.85$
# 결과값:62259.60$, 예측값 :54375.56$
# 결과값:2080.06$, 예측값 :2125.18$
# 결과값:21269.26$, 예측값 :42633.95$
# 결과값:2304.45$, 예측값 :2475.03$
# 결과값:39855.05$, 예측값 :42266.30$
# 결과값:40999.92$, 예측값 :18556.16$
# 결과값:944.85$, 예측값 :752.19$
# 결과값:3267.15$, 예측값 :735.63$
# 결과값:3327.44$, 예측값 :4452.91$
# 결과값:1537.39$, 예측값 :835.48$
# 결과값:15379.60$, 예측값 :15442.11$
# 결과값:2152.82$, 예측값 :1445.57$
# 결과값:45657.41$, 예측값 :25634.78$
# 결과값:2350.82$, 예측값 :1974.23$
# 결과값:2204.14$, 예측값 :1933.02$
# 결과값:64608.96$, 예측값 :63902.78$
# 결과값:1096.64$, 예측값 :974.20$
# 결과값:3480.49$, 예측값 :2776.72$
# 결과값:6086.00$, 예측값 :7191.02$
# 결과값:2066.16$, 예측값 :1930.14$
# 결과값:26685.53$, 예측값 :13020.80$
# 결과값:1720.93$, 예측값 :1118.69$
# 결과값:1432.39$, 예측값 :784.05$
# 결과값:40466.40$, 예측값 :52233.82$
# 결과값:1622.57$, 예측값 :1704.67$
# 결과값:1699.36$, 예측값 :915.45$
# 결과값:34346.46$, 예측값 :31571.21$
# 결과값:1326.87$, 예측값 :989.59$
# 결과값:1698.83$, 예측값 :866.71$
# 결과값:1453.33$, 예측값 :851.57$
# 결과값:1348.76$, 예측값 :851.22$
# 결과값:1164.15$, 예측값 :743.52$
# 결과값:977.83$, 예측값 :985.56$
# 결과값:1093.02$, 예측값 :889.12$
# 결과값:1524.67$, 예측값 :1424.59$
# 결과값:1281.14$, 예측값 :873.28$
# 결과값:2259.29$, 예측값 :1552.99$
# 결과값:2568.80$, 예측값 :725.50$
# 결과값:1965.55$, 예측값 :1987.76$
# 결과값:1354.03$, 예측값 :1012.54$
# 결과값:29404.60$, 예측값 :13763.76$
# 결과값:30273.44$, 예측값 :29010.43$
# 결과값:56407.68$, 예측값 :24655.22$
# 결과값:21823.85$, 예측값 :14078.41$
# 결과값:2043.45$, 예측값 :1942.68$
# 결과값:4327.67$, 예측값 :6880.11$
# 결과값:2352.55$, 예측값 :774.86$
# 결과값:2157.27$, 예측값 :1433.19$
# 결과값:2351.54$, 예측값 :2763.55$
# 결과값:24460.13$, 예측값 :19421.94$
# 결과값:2122.91$, 예측값 :2204.52$
# 결과값:1086.84$, 예측값 :1051.73$
# 결과값:30234.83$, 예측값 :33079.46$
# 결과값:20483.38$, 예측값 :25964.15$
# 결과값:1581.86$, 예측값 :1059.47$
# 결과값:974.35$, 예측값 :976.57$
# 결과값:2018.05$, 예측값 :1924.24$
# 결과값:2070.33$, 예측값 :404.06$
# 결과값:866.33$, 예측값 :715.78$
# 결과값:1701.95$, 예측값 :1113.58$
# 결과값:898.56$, 예측값 :828.21$
# 결과값:1984.26$, 예측값 :1662.81$
# 결과값:2337.00$, 예측값 :1734.99$
# 결과값:1975.64$, 예측값 :1802.75$
# 결과값:1404.00$, 예측값 :1073.92$
# 결과값:26632.32$, 예측값 :20629.54$
# 결과값:28335.84$, 예측값 :20715.85$
# 결과값:45057.48$, 예측값 :33507.23$
# 결과값:42250.88$, 예측값 :25742.03$
# 결과값:1101.12$, 예측값 :976.13$
# 결과값:20568.60$, 예측값 :26281.29$
# 결과값:21268.81$, 예측값 :14593.04$
# 결과값:36431.97$, 예측값 :49813.52$
# 결과값:904.91$, 예측값 :555.40$
# 결과값:2087.09$, 예측값 :1604.95$
# 결과값:1096.51$, 예측값 :880.21$
# 결과값:2079.38$, 예측값 :1469.40$
# 결과값:50439.17$, 예측값 :56468.07$
# 결과값:2223.08$, 예측값 :815.93$
# 결과값:25892.41$, 예측값 :38110.07$
# 결과값:2139.78$, 예측값 :1689.49$
# 결과값:1524.65$, 예측값 :1067.43$
# 결과값:26064.87$, 예측값 :27486.48$
# 결과값:34948.31$, 예측값 :20804.37$
# 결과값:49397.98$, 예측값 :59893.57$
# 결과값:25135.50$, 예측값 :25953.68$
# 결과값:2099.93$, 예측값 :2246.62$
# 결과값:1048.37$, 예측값 :743.22$
# 결과값:33296.64$, 예측값 :35527.46$
# 결과값:1100.09$, 예측값 :796.12$
# 결과값:5309.69$, 예측값 :1274.00$
# 결과값:2043.65$, 예측값 :1614.27$
# 결과값:974.57$, 예측값 :849.03$
# 결과값:1970.49$, 예측값 :795.48$
# 결과값:1329.03$, 예측값 :846.35$
# 결과값:21631.88$, 예측값 :18096.94$
# 결과값:22235.62$, 예측값 :15538.96$
# 결과값:38007.72$, 예측값 :46660.77$
# 결과값:1529.59$, 예측값 :838.60$
# 결과값:20295.30$, 예측값 :40331.93$
# 결과값:2076.53$, 예측값 :1718.47$
# 결과값:2053.38$, 예측값 :1632.98$
# 결과값:21155.78$, 예측값 :16861.69$
# 결과값:848.80$, 예측값 :845.58$
# 결과값:4029.32$, 예측값 :5202.55$
# 결과값:38225.91$, 예측값 :17284.47$
# 결과값:1165.41$, 예측값 :941.69$
# 결과값:34211.50$, 예측값 :37613.32$
# 결과값:1135.92$, 예측값 :678.08$
# 결과값:1136.53$, 예측값 :908.62$
# 결과값:33785.08$, 예측값 :31597.26$
# 결과값:1799.85$, 예측값 :1188.73$
# 결과값:55489.43$, 예측값 :19549.91$
# 결과값:20128.93$, 예측값 :14481.72$
# 결과값:20612.37$, 예측값 :16235.75$
# 결과값:2337.69$, 예측값 :1780.33$
# 결과값:1580.00$, 예측값 :2340.11$
# 결과값:30774.12$, 예측값 :27280.73$
# 결과값:2187.19$, 예측값 :1962.39$
# 결과값:1108.29$, 예측값 :1239.15$
# 결과값:1997.77$, 예측값 :757.32$
# 결과값:1720.61$, 예측값 :564.73$
# 결과값:2006.01$, 예측값 :2332.69$
# 결과값:2403.31$, 예측값 :2737.82$
# 결과값:922.64$, 예측값 :1474.53$
# 결과값:2074.51$, 예측값 :592.60$
# 결과값:20398.14$, 예측값 :21245.55$
# 결과값:32303.92$, 예측값 :26080.50$
# 결과값:1884.69$, 예측값 :888.00$
# 결과값:901.80$, 예측값 :1159.05$
# 결과값:3043.26$, 예측값 :1067.49$
# 결과값:2299.43$, 예측값 :2685.39$
# 결과값:2015.34$, 예측값 :1915.79$
# 결과값:3483.07$, 예측값 :3920.55$
# 결과값:2665.60$, 예측값 :961.80$
# 결과값:25091.01$, 예측값 :31269.09$
# 결과값:41953.28$, 예측값 :44231.63$
# 결과값:1031.12$, 예측값 :782.10$
# 결과값:2113.04$, 예측값 :2188.39$
# 결과값:2337.05$, 예측값 :2628.39$
# 결과값:3068.11$, 예측값 :1995.78$
# 결과값:2089.62$, 예측값 :1713.70$
# 결과값:943.90$, 예측값 :938.41$
# 결과값:21725.54$, 예측값 :21906.99$
# 결과값:1277.72$, 예측값 :734.30$
# 결과값:49176.27$, 예측값 :16919.13$
# 결과값:1348.62$, 예측값 :1057.77$
# 결과값:1141.31$, 예측값 :921.24$
# 결과값:2851.75$, 예측값 :877.05$
# 결과값:23028.91$, 예측값 :27219.54$
# 결과값:25334.40$, 예측값 :37239.30$
# 결과값:2094.05$, 예측값 :724.84$
# 결과값:2028.12$, 예측값 :1238.44$
# 결과값:1839.55$, 예측값 :1258.38$
# 결과값:2197.80$, 예측값 :1068.46$
# 결과값:31780.32$, 예측값 :17726.05$
# 결과값:64372.54$, 예측값 :23307.83$
# 결과값:26130.53$, 예측값 :36845.00$
# 결과값:2304.07$, 예측값 :1490.39$
# 결과값:1582.79$, 예측값 :1954.26$
# 결과값:2364.87$, 예측값 :1248.89$
# 결과값:1530.31$, 예측값 :1963.51$
# 결과값:57439.15$, 예측값 :56637.20$
# 결과값:55121.16$, 예측값 :51905.25$
# 결과값:1658.90$, 예측값 :1122.84$
# 결과값:1291.89$, 예측값 :848.52$
# 결과값:1134.40$, 예측값 :685.59$
# 결과값:2123.38$, 예측값 :1442.73$
# 결과값:3709.10$, 예측값 :9487.10$
# 결과값:67065.04$, 예측값 :63374.05$
# 결과값:20418.11$, 예측값 :23907.03$
# 결과값:1986.62$, 예측값 :830.39$
# 결과값:21735.81$, 예측값 :15998.37$
# 결과값:898.08$, 예측값 :965.23$
# 결과값:1474.41$, 예측값 :1531.17$
# 결과값:20568.97$, 예측값 :21903.64$
# 결과값:36689.98$, 예측값 :44993.75$
# 결과값:1057.50$, 예측값 :634.15$
# 결과값:1277.75$, 예측값 :1259.25$
# 결과값:1805.77$, 예측값 :2125.42$
# 결과값:2802.83$, 예측값 :828.41$
# 결과값:1012.33$, 예측값 :869.78$
# 결과값:4861.95$, 예측값 :4106.97$
# 결과값:1311.52$, 예측값 :672.91$
# 결과값:2508.85$, 예측값 :1678.88$
# 결과값:1867.55$, 예측값 :957.98$
# 결과값:26926.69$, 예측값 :9799.22$
# 결과값:45075.72$, 예측값 :51412.91$
# 결과값:1156.91$, 예측값 :779.85$
# 결과값:1159.37$, 예측값 :716.16$
# 결과값:2040.00$, 예측값 :1617.62$
# 결과값:58437.60$, 예측값 :56917.83$
# 결과값:44832.26$, 예측값 :45284.14$
# 결과값:1738.11$, 예측값 :793.28$
# 결과값:1041.72$, 예측값 :958.80$
# 결과값:7258.54$, 예측값 :11006.45$
# 결과값:1126.24$, 예측값 :903.84$
# 결과값:6493.52$, 예측값 :7096.46$
# 결과값:1464.42$, 예측값 :1066.90$
# 결과값:1718.73$, 예측값 :1262.03$
# 결과값:1191.85$, 예측값 :770.88$
# 결과값:4545.71$, 예측값 :1189.30$
# 결과값:863.25$, 예측값 :690.41$
# 결과값:1310.83$, 예측값 :836.51$
# 결과값:2145.16$, 예측값 :1638.42$
# 결과값:3260.31$, 예측값 :639.72$
# 결과값:32098.84$, 예측값 :35921.01$
# 결과값:27424.80$, 예측값 :18482.71$
# 결과값:974.54$, 예측값 :737.65$
# 결과값:1124.70$, 예측값 :1030.35$
# 결과값:2969.47$, 예측값 :3224.18$
# 결과값:839.64$, 예측값 :758.36$
# 결과값:1539.35$, 예측값 :874.51$
# 결과값:1040.25$, 예측값 :712.28$
# 결과값:2993.13$, 예측값 :2253.55$
# 결과값:1155.32$, 예측값 :899.42$
# 결과값:13262.90$, 예측값 :9204.46$
# 결과값:21277.73$, 예측값 :24066.12$
# 결과값:29260.48$, 예측값 :19271.24$
# 결과값:38228.78$, 예측값 :16243.26$
# 결과값:59670.09$, 예측값 :25952.24$
# 결과값:1537.92$, 예측값 :714.09$
# 결과값:1854.92$, 예측값 :767.07$
# 결과값:2086.21$, 예측값 :1904.44$
# 결과값:2435.56$, 예측값 :2098.14$
# 결과값:25577.43$, 예측값 :28602.15$
# 결과값:2241.65$, 예측값 :3784.88$
# 결과값:5961.15$, 예측값 :6227.22$
# 결과값:47515.73$, 예측값 :46032.01$
# 결과값:44591.90$, 예측값 :18608.34$
# 결과값:9504.07$, 예측값 :19742.63$
# 결과값:1698.05$, 예측값 :1598.28$
# 결과값:1147.78$, 예측값 :1035.91$
# 결과값:47478.60$, 예측값 :52305.66$
# 결과값:2064.42$, 예측값 :1957.77$
# 결과값:1679.17$, 예측값 :1367.13$
# 결과값:39880.62$, 예측값 :22561.98$
# 결과값:2011.25$, 예측값 :1797.60$
# 결과값:66450.93$, 예측값 :52626.34$
# 결과값:1645.60$, 예측값 :907.93$
# 결과값:2070.39$, 예측값 :781.98$
# 결과값:22106.31$, 예측값 :18839.95$
# 결과값:1036.26$, 예측값 :1325.13$
# 결과값:2953.85$, 예측값 :4752.45$
# 결과값:1836.29$, 예측값 :909.44$
# 결과값:22188.46$, 예측값 :17191.37$
# 결과값:2568.78$, 예측값 :1823.74$
# 결과값:38379.10$, 예측값 :16076.23$
# 결과값:22891.14$, 예측값 :14506.26$
# 결과값:62247.12$, 예측값 :60736.12$
# 결과값:1504.10$, 예측값 :1283.98$
# 결과값:1188.76$, 예측값 :826.36$
# 결과값:2053.49$, 예측값 :1694.68$
# 결과값:1444.09$, 예측값 :917.83$
# 결과값:2083.80$, 예측값 :2239.80$
# 결과값:2631.11$, 예측값 :677.39$
# 결과값:2082.03$, 예측값 :820.41$
# 결과값:1034.69$, 예측값 :883.30$
# 결과값:20148.51$, 예측값 :28815.03$
# 결과값:38389.60$, 예측값 :25799.29$
# 결과값:37005.07$, 예측값 :21876.82$
# 결과값:1876.75$, 예측값 :870.86$
# 결과값:1682.12$, 예측값 :1539.91$
# 결과값:1554.79$, 예측값 :1600.84$
# 결과값:963.82$, 예측값 :840.51$
# 결과값:2102.50$, 예측값 :713.81$
# 결과값:2008.35$, 예측값 :929.87$
# 결과값:20586.85$, 예측값 :29868.94$
# 결과값:2041.08$, 예측값 :814.10$
# 결과값:1349.89$, 예측값 :1203.54$
# 결과값:16186.73$, 예측값 :21421.86$
# 결과값:43216.40$, 예측값 :47590.49$
# 결과값:3521.16$, 예측값 :1942.40$
# 결과값:3908.68$, 예측값 :1011.81$
# 결과값:2180.03$, 예측값 :1454.61$
# 결과값:25803.49$, 예측값 :27854.13$
# 결과값:35880.23$, 예측값 :41269.85$
# 결과값:20564.19$, 예측값 :20582.21$
# 결과값:1615.89$, 예측값 :1632.16$
# 결과값:4379.77$, 예측값 :4207.40$
# 결과값:2274.17$, 예측값 :781.48$
# 결과값:2551.39$, 예측값 :2692.02$
# 결과값:3389.88$, 예측값 :785.55$
# 결과값:1381.79$, 예측값 :737.84$
# 결과값:1273.41$, 예측값 :1047.78$
# 결과값:1199.98$, 예측값 :971.70$
# 결과값:31817.76$, 예측값 :36058.43$
# 결과값:24964.93$, 예측값 :27695.17$
# 결과값:1669.15$, 예측값 :2073.49$
# 결과값:2085.19$, 예측값 :1574.09$
# 결과값:39034.32$, 예측값 :42325.42$
# 결과값:29581.89$, 예측값 :20017.33$
# 결과값:2030.54$, 예측값 :2236.57$
# 결과값:46719.55$, 예측값 :18244.30$
# 결과값:1400.94$, 예측값 :781.19$
# 결과값:1481.75$, 예측값 :485.56$
# 결과값:826.78$, 예측값 :874.06$
# 결과값:1773.89$, 예측값 :2006.43$
# 결과값:2273.98$, 예측값 :1665.33$
# 결과값:60768.12$, 예측값 :59902.27$
# 결과값:1339.58$, 예측값 :1296.69$
# 결과값:31533.98$, 예측값 :33170.91$
# 결과값:68617.96$, 예측값 :24586.12$
# 결과값:26625.14$, 예측값 :25657.25$
# 결과값:2448.26$, 예측값 :601.79$
# 결과값:32102.37$, 예측값 :38838.41$
# 결과값:1332.09$, 예측값 :1393.70$
# 결과값:25659.50$, 예측값 :17541.71$
# 결과값:1497.14$, 예측값 :950.58$
# 결과값:1532.76$, 예측값 :887.58$
# 결과값:2062.70$, 예측값 :1954.73$
# 결과값:16216.19$, 예측값 :24411.72$
# 결과값:2331.76$, 예측값 :1465.60$
# 결과값:1090.42$, 예측값 :833.69$
# 결과값:1205.93$, 예측값 :963.89$
# 결과값:1273.65$, 예측값 :619.29$
# 결과값:1310.14$, 예측값 :769.01$
# 결과값:1041.16$, 예측값 :1710.86$
# 결과값:2723.69$, 예측값 :707.02$
# 결과값:26746.08$, 예측값 :27562.67$
# 결과값:2619.85$, 예측값 :1825.54$
# 결과값:2051.69$, 예측값 :1664.55$
# 결과값:1170.83$, 예측값 :830.33$
# 결과값:3233.01$, 예측값 :939.40$
# 결과값:2111.79$, 예측값 :1778.57$
# 결과값:1407.85$, 예측값 :953.09$
# 결과값:4420.96$, 예측값 :2533.72$
# 결과값:1031.20$, 예측값 :851.23$
# 결과값:2453.69$, 예측값 :1232.10$
# 결과값:66986.79$, 예측값 :45410.37$
# 결과값:2061.11$, 예측값 :1444.69$
# 결과값:1085.42$, 예측값 :944.31$
# 결과값:61698.95$, 예측값 :21280.53$
# 결과값:2080.00$, 예측값 :2291.13$
# 결과값:1022.80$, 예측값 :687.60$
# 결과값:994.18$, 예측값 :788.48$
# 결과값:17875.20$, 예측값 :32522.72$
# 결과값:4782.45$, 예측값 :4868.74$
# 결과값:1063.64$, 예측값 :830.22$
# 결과값:45052.80$, 예측값 :23174.04$
# 결과값:2074.80$, 예측값 :577.35$
# 결과값:2079.61$, 예측값 :1880.19$
# 결과값:28005.62$, 예측값 :19333.78$
# 결과값:2279.60$, 예측값 :1552.26$
# 결과값:1987.22$, 예측값 :1032.15$
# 결과값:1997.22$, 예측값 :1481.29$
# 결과값:2105.05$, 예측값 :663.36$
# 결과값:1088.97$, 예측값 :1106.71$
# 결과값:31098.54$, 예측값 :24008.13$
# 결과값:4958.89$, 예측값 :4458.85$
# 결과값:1212.10$, 예측값 :752.26$
# 결과값:25617.52$, 예측값 :20297.20$
# 결과값:1462.04$, 예측값 :788.39$
# 결과값:1199.71$, 예측값 :676.14$
# 결과값:2088.91$, 예측값 :1875.94$
# 결과값:26153.60$, 예측값 :12775.50$
# 결과값:52930.41$, 예측값 :40527.15$
# 결과값:902.12$, 예측값 :997.84$
# 결과값:18681.64$, 예측값 :17365.36$
# 결과값:28443.36$, 예측값 :33852.38$
# 결과값:1140.55$, 예측값 :872.07$
# 결과값:1039.70$, 예측값 :758.79$
# 결과값:1282.57$, 예측값 :922.73$
# 결과값:1044.12$, 예측값 :895.62$
# 결과값:2061.99$, 예측값 :1810.61$
# 결과값:55408.52$, 예측값 :35893.25$
# 결과값:1133.31$, 예측값 :1877.47$
# 결과값:41917.20$, 예측값 :44426.02$
# 결과값:2544.90$, 예측값 :1036.86$
# 결과값:1473.04$, 예측값 :1217.86$
# 결과값:2109.20$, 예측값 :600.67$
# 결과값:1606.66$, 예측값 :797.35$
# 결과값:1873.45$, 예측값 :1284.31$
# 결과값:1681.61$, 예측값 :1481.39$
# 결과값:1000.72$, 예측값 :1120.25$
# 결과값:1474.59$, 예측값 :1337.61$
# 결과값:2080.00$, 예측값 :3312.70$
# 결과값:1788.78$, 예측값 :649.61$
# 결과값:1650.73$, 예측값 :1092.12$
# 결과값:23199.27$, 예측값 :25069.71$
# 결과값:41928.12$, 예측값 :20588.22$
# 결과값:2939.19$, 예측값 :2855.31$
# 결과값:49799.86$, 예측값 :18889.59$
# 결과값:1153.26$, 예측값 :929.57$
# 결과값:2370.80$, 예측값 :2542.68$
# 결과값:1452.83$, 예측값 :834.93$
# 결과값:2028.27$, 예측값 :1776.57$
# 결과값:1508.36$, 예측값 :840.17$
# 결과값:1462.03$, 예측값 :1330.19$
# 결과값:49105.46$, 예측값 :19017.52$
# 결과값:2027.51$, 예측값 :677.16$
# 결과값:34268.68$, 예측값 :27550.34$
# 결과값:20173.51$, 예측값 :13676.49$
# 결과값:2154.96$, 예측값 :1427.30$
# 결과값:49707.29$, 예측값 :48308.25$
# 결과값:40273.43$, 예측값 :39658.61$
# 결과값:2067.92$, 예측값 :1726.90$
# 결과값:1660.54$, 예측값 :607.25$
# 결과값:1176.27$, 예측값 :974.95$
# 결과값:944.20$, 예측값 :1085.97$
# 결과값:24688.75$, 예측값 :31843.93$
# 결과값:2070.48$, 예측값 :1776.96$
# 결과값:2061.87$, 예측값 :1871.34$
# 결과값:2356.77$, 예측값 :2328.15$
# 결과값:1696.00$, 예측값 :1756.63$
# 결과값:2315.11$, 예측값 :2805.54$
# 결과값:18729.27$, 예측값 :8436.69$
# 결과값:52848.73$, 예측값 :31619.59$
# 결과값:2044.36$, 예측값 :626.38$
# 결과값:1335.20$, 예측값 :933.43$
# 결과값:1973.14$, 예측값 :1975.81$
# 결과값:1463.57$, 예측값 :847.22$
# 결과값:2097.46$, 예측값 :1768.86$
# 결과값:22571.78$, 예측값 :15283.46$
# 결과값:1498.35$, 예측값 :1506.90$
# 결과값:68659.03$, 예측값 :28765.95$
# 결과값:1885.25$, 예측값 :866.17$
# 결과값:23972.19$, 예측값 :13930.18$
# 결과값:2070.35$, 예측값 :2380.18$
# 결과값:1929.08$, 예측값 :1137.12$
# 결과값:37753.27$, 예측값 :26831.69$
# 결과값:945.96$, 예측값 :714.84$
# 결과값:42906.55$, 예측값 :48923.54$
# 결과값:36709.39$, 예측값 :19007.53$
# 결과값:2034.78$, 예측값 :1269.72$
# 결과값:25017.10$, 예측값 :11614.52$
# 결과값:28482.54$, 예측값 :33368.85$
# 결과값:3784.61$, 예측값 :3827.61$
# 결과값:948.46$, 예측값 :791.55$
# 결과값:23382.75$, 예측값 :37432.28$
# 결과값:846.08$, 예측값 :854.97$
# 결과값:50279.42$, 예측값 :36606.12$
# 결과값:31911.25$, 예측값 :32244.76$
# 결과값:1430.74$, 예측값 :1351.82$
# 결과값:2399.71$, 예측값 :3724.29$
# 결과값:1188.42$, 예측값 :984.91$
# 결과값:1534.45$, 예측값 :807.49$
# 결과값:1038.49$, 예측값 :951.38$
# 결과값:2023.78$, 예측값 :1778.40$
# 결과값:1765.71$, 예측값 :1770.14$
# 결과값:36866.22$, 예측값 :44525.62$
# 결과값:1120.39$, 예측값 :747.55$
# 결과값:1148.96$, 예측값 :773.61$
# 결과값:41407.39$, 예측값 :24815.55$
# 결과값:3460.94$, 예측값 :1852.99$
# 결과값:20455.34$, 예측값 :23209.45$
# 결과값:2075.91$, 예측값 :2096.42$
# 결과값:29512.98$, 예측값 :30695.06$
# 결과값:40003.27$, 예측값 :16705.43$
# 결과값:26863.06$, 예측값 :42988.72$
# 결과값:2337.00$, 예측값 :2717.56$
# 결과값:4861.95$, 예측값 :10587.42$
# 결과값:50554.25$, 예측값 :28917.76$
# 결과값:1211.61$, 예측값 :1102.31$
# 결과값:4158.33$, 예측값 :519.17$
# 결과값:1028.04$, 예측값 :903.49$
# 결과값:1030.65$, 예측값 :932.92$
# 결과값:6087.33$, 예측값 :6728.61$
# 결과값:2113.97$, 예측값 :2790.52$
# 결과값:42701.88$, 예측값 :15862.96$
# 결과값:1660.49$, 예측값 :1005.60$
# 결과값:1347.34$, 예측값 :692.76$
# 결과값:2106.75$, 예측값 :2515.89$
# 결과값:31103.12$, 예측값 :14457.40$
# 결과값:28861.48$, 예측값 :13657.18$
# 결과값:1162.92$, 예측값 :696.74$
# 결과값:2123.50$, 예측값 :423.40$
# 결과값:2105.01$, 예측값 :799.31$
# 결과값:1672.80$, 예측값 :1327.25$
# 결과값:1425.61$, 예측값 :613.79$
# 결과값:1142.87$, 예측값 :1326.25$
# 결과값:1423.71$, 예측값 :861.36$
# 결과값:947.09$, 예측값 :992.01$
# 결과값:4115.50$, 예측값 :5474.39$
# 결과값:25383.84$, 예측값 :27767.81$
# 결과값:27314.91$, 예측값 :31154.79$
# 결과값:29978.80$, 예측값 :35729.85$
# 결과값:35416.68$, 예측값 :21785.25$
# 결과값:1528.57$, 예측값 :1279.52$
# 결과값:25202.39$, 예측값 :14730.42$
# 결과값:28350.11$, 예측값 :27299.23$
# 결과값:2724.90$, 예측값 :778.61$
# 결과값:805.98$, 예측값 :1340.09$
# 결과값:51362.03$, 예측값 :21094.57$
# 결과값:9598.23$, 예측값 :10195.59$
# 결과값:43163.33$, 예측값 :44260.33$
# 결과값:1114.96$, 예측값 :696.30$
# 결과값:1460.31$, 예측값 :1183.83$
# 결과값:1403.12$, 예측값 :1299.08$
# 결과값:28995.88$, 예측값 :31512.53$
# 결과값:29871.82$, 예측값 :26091.65$
# 결과값:1985.97$, 예측값 :1878.63$
# 결과값:974.29$, 예측값 :810.43$
# 결과값:1997.86$, 예측값 :975.99$
# 결과값:2200.67$, 예측값 :2102.39$
# 결과값:4833.72$, 예측값 :1439.80$
# 결과값:1036.88$, 예측값 :746.12$
# 결과값:2304.07$, 예측값 :913.30$
# 결과값:1445.15$, 예측값 :622.51$
# 결과값:981.38$, 예측값 :828.01$
# 결과값:1061.40$, 예측값 :777.16$
# 결과값:4856.94$, 예측값 :6292.11$
# 결과값:940.86$, 예측값 :754.25$
# 결과값:2040.22$, 예측값 :1942.25$
# 결과값:2071.45$, 예측값 :1856.13$
# 결과값:1366.28$, 예측값 :995.57$
# 결과값:1018.39$, 예측값 :852.06$
# 결과값:1011.55$, 예측값 :875.86$
# 결과값:22295.68$, 예측값 :32266.04$
# 결과값:1582.45$, 예측값 :1177.41$
# 결과값:25346.44$, 예측값 :30725.84$
# 결과값:35410.46$, 예측값 :41724.82$
# 결과값:1702.71$, 예측값 :1015.10$
# 결과값:3519.28$, 예측값 :4585.18$
# 결과값:3442.51$, 예측값 :5873.86$
# 결과값:1739.96$, 예측값 :2437.33$
# 결과값:2078.36$, 예측값 :2097.94$
# 결과값:27505.31$, 예측값 :29364.08$
# 결과값:25584.00$, 예측값 :16460.56$
# 결과값:2696.13$, 예측값 :3865.95$
# 결과값:2105.76$, 예측값 :1697.27$
# 결과값:30834.02$, 예측값 :16683.01$
# 결과값:2282.33$, 예측값 :2712.89$
# 결과값:1697.10$, 예측값 :1199.08$
# 결과값:26308.95$, 예측값 :17121.28$
# 결과값:24656.52$, 예측값 :29768.60$
# 결과값:44619.79$, 예측값 :44118.40$
# 결과값:1417.83$, 예측값 :819.01$
# 결과값:30959.82$, 예측값 :15618.84$
# 결과값:1309.02$, 예측값 :771.58$
# 결과값:32381.79$, 예측값 :34030.35$
# 결과값:1242.86$, 예측값 :896.56$
# 결과값:1346.68$, 예측값 :745.78$
# 결과값:829.54$, 예측값 :808.93$
# 결과값:2030.57$, 예측값 :1918.70$
# 결과값:21170.51$, 예측값 :24508.98$
# 결과값:1973.74$, 예측값 :1974.08$
# 결과값:1880.97$, 예측값 :916.09$
# 결과값:16480.38$, 예측값 :16308.63$
# 결과값:2067.68$, 예측값 :2111.55$
# 결과값:1030.22$, 예측값 :863.06$
# 결과값:24901.69$, 예측값 :18437.65$
# 결과값:959.62$, 예측값 :822.50$
# 결과값:40550.62$, 예측값 :37933.23$
# 결과값:2078.47$, 예측값 :621.90$
# 결과값:40908.44$, 예측값 :45458.52$
# 결과값:2068.73$, 예측값 :1669.20$
# 결과값:54478.32$, 예측값 :52217.08$
# 결과값:22009.90$, 예측값 :15444.76$
# 결과값:3229.56$, 예측값 :3000.85$
# 결과값:1822.60$, 예측값 :710.05$
# 결과값:2034.00$, 예측값 :1674.47$
# 결과값:2262.98$, 예측값 :1555.81$
# 결과값:1599.11$, 예측값 :1930.38$
# 결과값:36908.43$, 예측값 :19439.17$
# 결과값:2736.71$, 예측값 :705.09$
# 결과값:846.74$, 예측값 :604.26$
# 결과값:1717.94$, 예측값 :830.28$
# 결과값:2075.87$, 예측값 :1828.73$
# 결과값:1465.45$, 예측값 :1574.22$
# 결과값:1702.84$, 예측값 :1052.08$
# 결과값:42306.20$, 예측값 :25337.12$
# 결과값:1290.74$, 예측값 :1388.45$
# 결과값:1368.98$, 예측값 :808.02$
# 결과값:838.41$, 예측값 :741.04$
# 결과값:1032.64$, 예측값 :1911.51$
# 결과값:3655.62$, 예측값 :1947.63$
# 결과값:50907.51$, 예측값 :24213.97$
# 결과값:68574.48$, 예측값 :20003.39$
# 결과값:2078.35$, 예측값 :2277.35$
# 결과값:930.75$, 예측값 :937.85$
# 결과값:53998.15$, 예측값 :33184.50$
# 결과값:1383.13$, 예측값 :1922.96$
# 결과값:1030.65$, 예측값 :892.89$
# 결과값:2082.67$, 예측값 :1939.65$
# 결과값:31056.48$, 예측값 :16547.27$
# 결과값:1679.27$, 예측값 :799.92$
# 결과값:1822.02$, 예측값 :899.59$
# 결과값:764.56$, 예측값 :844.15$
# 결과값:43849.17$, 예측값 :18032.28$
# 결과값:25038.87$, 예측값 :22132.33$
# 결과값:15476.93$, 예측값 :18426.56$
# 결과값:1784.47$, 예측값 :1130.73$
# 결과값:2874.53$, 예측값 :3762.74$
# 결과값:1991.02$, 예측값 :1831.54$
# 결과값:38599.92$, 예측값 :39814.63$
# 결과값:877.68$, 예측값 :808.69$
# 결과값:2353.56$, 예측값 :1265.59$
# 결과값:42905.79$, 예측값 :18958.78$
# 결과값:1289.35$, 예측값 :1284.78$
# 결과값:2086.97$, 예측값 :1170.89$
# 결과값:2090.55$, 예측값 :1239.91$
# 결과값:16067.35$, 예측값 :5082.79$
# 결과값:29117.12$, 예측값 :37448.14$
# 결과값:1040.04$, 예측값 :739.74$
# 결과값:3031.80$, 예측값 :3792.62$
# 결과값:25612.14$, 예측값 :28966.20$
# 결과값:38190.98$, 예측값 :27211.44$
# 결과값:27634.20$, 예측값 :32285.80$
# 결과값:27946.11$, 예측값 :36762.39$
# 결과값:31369.32$, 예측값 :38790.78$
# 결과값:31199.25$, 예측값 :30485.25$
# 결과값:2112.20$, 예측값 :595.65$
# 결과값:20656.12$, 예측값 :23574.10$
# 결과값:21132.06$, 예측값 :12820.77$
# 결과값:1119.46$, 예측값 :705.82$
# 결과값:43148.04$, 예측값 :22965.41$
# 결과값:2036.90$, 예측값 :614.55$
# 결과값:45836.54$, 예측값 :31829.80$
# 결과값:2568.78$, 예측값 :1656.26$
# 결과값:1746.93$, 예측값 :2726.47$
# 결과값:834.91$, 예측값 :684.22$
# 결과값:2453.10$, 예측값 :2267.25$
# 결과값:969.38$, 예측값 :840.42$
# 결과값:2263.49$, 예측값 :2037.45$
# 결과값:21068.75$, 예측값 :20384.00$
# 결과값:1204.23$, 예측값 :863.64$
# 결과값:20139.90$, 예측값 :21216.79$
# 결과값:1789.73$, 예측값 :767.70$
# 결과값:2467.91$, 예측값 :2081.22$
# 결과값:22799.87$, 예측값 :27625.43$
# 결과값:2028.32$, 예측값 :2137.85$
# 결과값:49340.63$, 예측값 :21007.93$
# 결과값:27902.71$, 예측값 :32062.26$
# 결과값:33530.73$, 예측값 :18458.28$
# 결과값:63065.18$, 예측값 :25557.02$
# 결과값:886.62$, 예측값 :894.63$
# 결과값:3067.51$, 예측값 :3995.71$
# 결과값:2059.79$, 예측값 :3424.81$
# 결과값:1056.49$, 예측값 :965.84$
# 결과값:1659.72$, 예측값 :666.86$
# 결과값:1032.69$, 예측값 :560.75$
# 결과값:2054.93$, 예측값 :2399.39$
# 결과값:1498.19$, 예측값 :857.54$
# 결과값:33980.23$, 예측값 :18914.11$
# 결과값:1972.58$, 예측값 :1633.19$
# 결과값:1854.94$, 예측값 :1239.61$
# 결과값:1166.56$, 예측값 :961.16$
# 결과값:945.34$, 예측값 :958.82$
# 결과값:2368.35$, 예측값 :1898.42$
# 결과값:46999.18$, 예측값 :24146.18$
# 결과값:1164.21$, 예측값 :802.20$
# 결과값:1428.42$, 예측값 :930.63$
# 결과값:1095.73$, 예측값 :760.08$
# 결과값:27122.16$, 예측값 :15179.05$
# 결과값:58291.08$, 예측값 :54361.43$
# 결과값:2049.90$, 예측값 :1809.38$
# 결과값:1991.83$, 예측값 :1288.11$
# 결과값:1267.50$, 예측값 :784.84$
# 결과값:1428.81$, 예측값 :2039.54$
# 결과값:954.02$, 예측값 :1146.12$
# 결과값:2081.37$, 예측값 :2170.54$
# 결과값:902.31$, 예측값 :640.02$
# 결과값:1544.19$, 예측값 :952.87$
# 결과값:23272.44$, 예측값 :26971.31$
# 결과값:2480.15$, 예측값 :1609.91$
# 결과값:20500.37$, 예측값 :25913.95$
# 결과값:2073.70$, 예측값 :1691.95$
# 결과값:1292.93$, 예측값 :1224.44$
# 결과값:1740.29$, 예측값 :1482.17$
# 결과값:1624.52$, 예측값 :1864.64$
# 결과값:37187.48$, 예측값 :42951.25$
# 결과값:2062.70$, 예측값 :1825.95$
# 결과값:2079.23$, 예측값 :1251.77$
# 결과값:34746.72$, 예측값 :38295.25$
# 결과값:27413.43$, 예측값 :33619.71$
# 결과값:1056.32$, 예측값 :783.61$
# 결과값:1598.46$, 예측값 :1877.41$
# 결과값:26611.96$, 예측값 :26181.39$
# 결과값:1658.74$, 예측값 :779.38$
# 결과값:1986.00$, 예측값 :2267.05$
# 결과값:20166.87$, 예측값 :22548.11$
# 결과값:32800.56$, 예측값 :24883.28$
# 결과값:57991.13$, 예측값 :32519.28$
# 결과값:21570.62$, 예측값 :25158.43$
# 결과값:70749.53$, 예측값 :46815.26$
# 결과값:994.18$, 예측값 :1138.87$
# 결과값:1118.85$, 예측값 :740.09$
# 결과값:33370.94$, 예측값 :17872.10$
# 결과값:69759.86$, 예측값 :51983.24$
# 결과값:2290.68$, 예측값 :854.09$
# 결과값:30836.52$, 예측값 :22311.68$
# 결과값:2014.73$, 예측값 :1398.69$
# 결과값:3829.74$, 예측값 :3572.22$
# 결과값:1562.27$, 예측값 :1000.21$
# 결과값:1255.25$, 예측값 :1448.95$
# 결과값:2318.26$, 예측값 :770.01$
# 결과값:875.42$, 예측값 :858.61$
# 결과값:853.18$, 예측값 :820.63$
# 결과값:927.64$, 예측값 :824.93$
# 결과값:21931.09$, 예측값 :23694.73$
# 결과값:1565.85$, 예측값 :1647.73$
# 결과값:2459.12$, 예측값 :3539.72$
# 결과값:67290.13$, 예측값 :65050.97$
# 결과값:4443.40$, 예측값 :5337.25$
# 결과값:20158.59$, 예측값 :29406.05$
# 결과값:34225.71$, 예측값 :28878.18$
# 결과값:1965.55$, 예측값 :1979.84$
# 결과값:45322.82$, 예측값 :46891.98$
# 결과값:3514.31$, 예측값 :1996.34$
# 결과값:4510.98$, 예측값 :3863.30$
# 결과값:893.71$, 예측값 :863.26$
# 결과값:1034.60$, 예측값 :842.18$
# 결과값:26256.28$, 예측값 :36984.36$
# 결과값:1968.02$, 예측값 :909.53$
# 결과값:1504.71$, 예측값 :1946.08$
# 결과값:2052.56$, 예측값 :1687.65$
# 결과값:66413.49$, 예측값 :47235.56$
# 결과값:1124.88$, 예측값 :775.18$
# 결과값:2568.78$, 예측값 :1475.71$
# 결과값:21597.14$, 예측값 :7990.32$
# 결과값:837.48$, 예측값 :795.92$
# 결과값:2304.43$, 예측값 :732.89$
# 결과값:1951.16$, 예측값 :1529.92$
# 결과값:30428.44$, 예측값 :39390.76$
# 결과값:53764.84$, 예측값 :25615.73$
# 결과값:23169.18$, 예측값 :20135.78$
# 결과값:901.78$, 예측값 :933.82$
# 결과값:2471.36$, 예측값 :1685.56$
# 결과값:1532.39$, 예측값 :1234.06$
# 결과값:2080.46$, 예측값 :2279.75$
# 결과값:1401.30$, 예측값 :946.18$
# 결과값:41870.40$, 예측값 :27325.31$
# 결과값:1650.38$, 예측값 :865.25$
# 결과값:1799.78$, 예측값 :1195.63$
# 결과값:1403.95$, 예측값 :654.67$
# 결과값:2118.77$, 예측값 :1856.01$
# 결과값:791.33$, 예측값 :939.78$
# 결과값:1537.90$, 예측값 :1553.95$
# 결과값:21091.67$, 예측값 :12767.58$
# 결과값:29596.65$, 예측값 :34712.63$
# 결과값:2094.68$, 예측값 :2561.56$
# 결과값:1328.93$, 예측값 :1267.95$
# 결과값:1992.91$, 예측값 :1140.17$
# 결과값:21089.69$, 예측값 :25948.77$
# 결과값:63271.35$, 예측값 :56872.40$
# 결과값:1093.95$, 예측값 :767.17$
# 결과값:61067.60$, 예측값 :24354.75$
# 결과값:1358.27$, 예측값 :1578.80$
# 결과값:2048.45$, 예측값 :2178.10$
# 결과값:24933.36$, 예측값 :10572.64$
# 결과값:2785.64$, 예측값 :3937.89$
# 결과값:61111.33$, 예측값 :25575.19$
# 결과값:1063.04$, 예측값 :995.48$
# 결과값:1191.82$, 예측값 :657.61$
# 결과값:39604.91$, 예측값 :15715.27$
# 결과값:4408.70$, 예측값 :2183.63$
# 결과값:2242.06$, 예측값 :1117.34$
# 결과값:2247.53$, 예측값 :2011.78$
# 결과값:1751.37$, 예측값 :1698.73$
# 결과값:808.01$, 예측값 :781.20$
# 결과값:1790.38$, 예측값 :1413.88$
# 결과값:1293.26$, 예측값 :1061.45$
# 결과값:1968.43$, 예측값 :1832.96$
# 결과값:1030.68$, 예측값 :818.61$
# 결과값:50138.79$, 예측값 :51878.17$
# 결과값:48094.80$, 예측값 :47708.82$
# 결과값:1473.78$, 예측값 :1493.95$
# 결과값:1660.49$, 예측값 :1114.65$
# 결과값:1474.41$, 예측값 :1522.08$
# 결과값:47252.40$, 예측값 :43830.64$
# 결과값:1514.71$, 예측값 :1303.91$
# 결과값:21273.74$, 예측값 :36411.26$
# 결과값:30920.20$, 예측값 :39637.22$
# 결과값:2095.89$, 예측값 :1619.89$
# 결과값:1027.01$, 예측값 :945.32$
# 결과값:968.78$, 예측값 :695.49$
# 결과값:28308.82$, 예측값 :31263.22$
# 결과값:2551.35$, 예측값 :1997.96$
# 결과값:1371.84$, 예측값 :849.10$
# 결과값:2112.84$, 예측값 :692.78$
# 결과값:27950.91$, 예측값 :21621.76$
# 결과값:43204.90$, 예측값 :19882.87$
# 결과값:27922.66$, 예측값 :38945.64$
# 결과값:1184.83$, 예측값 :777.20$
# 결과값:23504.41$, 예측값 :23246.45$
# 결과값:1973.83$, 예측값 :2277.25$
# 결과값:1786.33$, 예측값 :1921.51$
# 결과값:40836.71$, 예측값 :26941.91$
# 결과값:1145.23$, 예측값 :914.02$
# 결과값:1604.91$, 예측값 :746.69$
# 결과값:1116.82$, 예측값 :778.96$
# 결과값:2104.08$, 예측값 :1726.15$
# 결과값:1010.79$, 예측값 :783.22$
# 결과값:924.62$, 예측값 :885.37$
# 결과값:853.01$, 예측값 :793.54$
# 결과값:13490.76$, 예측값 :10382.18$
# 결과값:2331.52$, 예측값 :463.55$
# 결과값:2116.52$, 예측값 :2134.78$
# 결과값:2452.64$, 예측값 :2480.51$
# 결과값:25034.76$, 예측값 :21145.92$
# 결과값:21579.42$, 예측값 :21363.46$
# 결과값:2033.24$, 예측값 :1727.13$
# 결과값:29651.08$, 예측값 :27624.62$
# 결과값:958.73$, 예측값 :768.85$
# 결과값:1354.57$, 예측값 :923.74$
# 결과값:2063.52$, 예측값 :2584.01$
# 결과값:2084.78$, 예측값 :1817.25$
# 결과값:63530.73$, 예측값 :49621.47$
# 결과값:2055.21$, 예측값 :1930.84$
# 결과값:64294.39$, 예측값 :47211.05$
# 결과값:22801.15$, 예측값 :15025.41$
# 결과값:1968.26$, 예측값 :1069.38$
# 결과값:34571.88$, 예측값 :24829.72$
# 결과값:2060.18$, 예측값 :2094.46$
# 결과값:12627.71$, 예측값 :16577.28$
# 결과값:1587.81$, 예측값 :649.52$
# 결과값:1093.95$, 예측값 :658.54$
# 결과값:1303.33$, 예측값 :782.25$
# 결과값:40852.38$, 예측값 :50951.61$
# 결과값:1114.81$, 예측값 :1585.57$
# 결과값:1175.14$, 예측값 :834.30$
# 결과값:2246.26$, 예측값 :1833.93$
# 결과값:2062.70$, 예측값 :2023.93$
# 결과값:26160.00$, 예측값 :33171.38$
# 결과값:2353.97$, 예측값 :2344.62$
# 결과값:1597.90$, 예측값 :1084.43$
# 결과값:1922.98$, 예측값 :1227.68$
# 결과값:43612.11$, 예측값 :46461.68$
# 결과값:28881.90$, 예측값 :17117.07$
# 결과값:1763.52$, 예측값 :912.40$
# 결과값:1993.46$, 예측값 :1625.45$
# 결과값:2002.26$, 예측값 :505.22$
# 결과값:1587.41$, 예측값 :2044.43$
# 결과값:2071.48$, 예측값 :611.64$
# 결과값:21373.06$, 예측값 :28487.28$
# 결과값:1091.99$, 예측값 :735.62$
# 결과값:9518.21$, 예측값 :7637.88$
# 결과값:1042.12$, 예측값 :893.25$
# 결과값:6096.99$, 예측값 :3623.57$
# 결과값:26083.82$, 예측값 :24110.98$
# 결과값:64839.84$, 예측값 :46716.68$
# 결과값:975.06$, 예측값 :872.17$
# 결과값:49931.34$, 예측값 :42354.17$
# 결과값:58468.02$, 예측값 :27398.65$
# 결과값:1473.68$, 예측값 :1395.35$
# 결과값:1256.24$, 예측값 :862.46$
# 결과값:1135.48$, 예측값 :879.38$
# 결과값:1149.58$, 예측값 :1064.58$
# 결과값:2784.33$, 예측값 :4137.86$
# 결과값:2249.55$, 예측값 :1738.46$
# 결과값:1481.29$, 예측값 :1463.86$
# 결과값:1036.97$, 예측값 :788.87$
# 결과값:7247.40$, 예측값 :7339.24$
# 결과값:1800.96$, 예측값 :792.14$
# 결과값:2078.78$, 예측값 :1600.50$
# 결과값:1472.19$, 예측값 :1756.46$
# 결과값:2057.03$, 예측값 :775.19$
# 결과값:1031.66$, 예측값 :786.49$
# 결과값:40078.74$, 예측값 :23721.65$
# 결과값:20633.28$, 예측값 :14544.98$
# 결과값:12996.87$, 예측값 :13384.17$
# 결과값:2508.02$, 예측값 :1881.88$
# 결과값:1399.57$, 예측값 :1098.96$
# 결과값:1837.89$, 예측값 :749.59$
# 결과값:2106.37$, 예측값 :1551.03$
# 결과값:1352.82$, 예측값 :946.31$
# 결과값:750.97$, 예측값 :856.77$
# 결과값:3172.28$, 예측값 :4298.88$
# 결과값:35719.12$, 예측값 :47277.25$
# 결과값:3650.11$, 예측값 :4804.12$
# 결과값:2047.47$, 예측값 :1770.81$
# 결과값:20141.22$, 예측값 :16866.48$
# 결과값:1403.68$, 예측값 :718.45$
# 결과값:6006.28$, 예측값 :1650.82$
# 결과값:2319.73$, 예측값 :1422.55$
# 결과값:1872.54$, 예측값 :734.20$
# 결과값:1291.97$, 예측값 :786.61$
# 결과값:3664.60$, 예측값 :2402.14$
# 결과값:33084.11$, 예측값 :41275.10$
# 결과값:63873.39$, 예측값 :33018.40$
# 결과값:49596.35$, 예측값 :48113.53$
# 결과값:45801.04$, 예측값 :28981.04$
# 결과값:1063.09$, 예측값 :734.79$
# 결과값:1972.16$, 예측값 :697.37$
# 결과값:21547.23$, 예측값 :29436.88$
# 결과값:2055.01$, 예측값 :1174.76$
# 결과값:868.34$, 예측값 :1192.75$
# 결과값:2249.20$, 예측값 :1323.32$
# 결과값:1277.73$, 예측값 :1151.33$
# 결과값:3135.82$, 예측값 :707.44$
# 결과값:1697.76$, 예측값 :2261.24$
# 결과값:29107.42$, 예측값 :20321.81$
# 결과값:2757.79$, 예측값 :2254.08$
# 결과값:41085.99$, 예측값 :48068.09$
# 결과값:1322.54$, 예측값 :612.61$
# 결과값:2045.06$, 예측값 :2020.35$
# 결과값:2062.01$, 예측값 :2240.67$
# 결과값:2421.52$, 예측값 :3028.78$
# 결과값:1103.49$, 예측값 :816.96$
# 결과값:1555.63$, 예측값 :1333.69$
# 결과값:2015.41$, 예측값 :603.53$
# 결과값:2048.08$, 예측값 :616.76$
# 결과값:55856.35$, 예측값 :55781.25$
# 결과값:2088.91$, 예측값 :1942.57$
# 결과값:69297.88$, 예측값 :22805.11$
# 결과값:41660.11$, 예측값 :49310.91$
# 결과값:1752.72$, 예측값 :1510.71$
# 결과값:2048.45$, 예측값 :1644.09$
# 결과값:49075.34$, 예측값 :49788.47$
# 결과값:1124.10$, 예측값 :734.89$
# 결과값:1969.80$, 예측값 :1974.00$
# 결과값:52687.05$, 예측값 :56275.25$
# 결과값:27628.26$, 예측값 :21967.49$
# 결과값:1526.62$, 예측값 :1520.84$
# 결과값:2028.20$, 예측값 :1727.21$
# 결과값:27909.02$, 예측값 :34910.33$
# 결과값:2263.09$, 예측값 :3045.83$
# 결과값:2067.92$, 예측값 :838.34$
# 결과값:6829.35$, 예측값 :9738.11$
# 결과값:1022.52$, 예측값 :1058.74$
# 결과값:35524.48$, 예측값 :31999.65$
# 결과값:41719.09$, 예측값 :44369.23$
# 결과값:41077.42$, 예측값 :20134.96$
# 결과값:1675.74$, 예측값 :1598.91$
# 결과값:2304.07$, 예측값 :1503.44$
# 결과값:27388.00$, 예측값 :23991.08$
# 결과값:1794.04$, 예측값 :990.03$
# 결과값:1317.62$, 예측값 :1262.25$
# 결과값:4430.27$, 예측값 :4747.29$
# 결과값:21292.03$, 예측값 :9038.40$
# 결과값:27119.82$, 예측값 :16397.18$
# 결과값:1970.54$, 예측값 :1681.87$
# 결과값:57017.00$, 예측값 :26156.72$
# 결과값:1723.88$, 예측값 :1004.06$
# 결과값:1424.92$, 예측값 :902.14$
# 결과값:20647.68$, 예측값 :24061.51$
# 결과값:1428.12$, 예측값 :1102.61$
# 결과값:1533.62$, 예측값 :1059.77$
# 결과값:26046.90$, 예측값 :32616.16$
# 결과값:1018.38$, 예측값 :1066.35$
# 결과값:2179.32$, 예측값 :2362.84$
# 결과값:4007.88$, 예측값 :4035.56$
# 결과값:962.18$, 예측값 :1086.27$
# 결과값:4352.31$, 예측값 :6726.56$
# 결과값:35055.12$, 예측값 :42343.61$
# 결과값:1185.32$, 예측값 :821.00$
# 결과값:945.76$, 예측값 :721.98$
# 결과값:1183.00$, 예측값 :884.66$
# 결과값:1012.26$, 예측값 :722.22$
# 결과값:1276.32$, 예측값 :819.77$
# 결과값:29551.97$, 예측값 :35380.30$
# 결과값:2296.93$, 예측값 :830.98$
# 결과값:24146.99$, 예측값 :31342.12$
# 결과값:2187.15$, 예측값 :2472.33$
# 결과값:1534.57$, 예측값 :1235.08$
# 결과값:2126.49$, 예측값 :2503.59$
# 결과값:1093.73$, 예측값 :597.27$
# 결과값:1986.07$, 예측값 :1251.67$
# 결과값:2006.40$, 예측값 :1581.40$
# 결과값:904.35$, 예측값 :1607.76$
# 결과값:1473.19$, 예측값 :690.75$
# 결과값:51524.24$, 예측값 :65097.44$
# 결과값:33543.70$, 예측값 :13143.94$
# 결과값:1055.41$, 예측값 :1058.58$
# 결과값:47296.08$, 예측값 :24473.46$
# 결과값:32632.75$, 예측값 :32008.02$
# 결과값:1768.87$, 예측값 :612.71$
# 결과값:1743.35$, 예측값 :604.83$
# 결과값:1576.77$, 예측값 :2132.37$
# 결과값:1598.58$, 예측값 :1564.59$
# 결과값:31859.88$, 예측값 :46598.39$
# 결과값:2727.75$, 예측값 :1297.65$
# 결과값:27591.72$, 예측값 :23870.74$
# 결과값:63276.72$, 예측값 :57295.07$
# 결과값:6072.07$, 예측값 :8041.48$
# 결과값:1358.39$, 예측값 :713.40$
# 결과값:1963.28$, 예측값 :1839.44$
# 결과값:20860.01$, 예측값 :9918.90$
# Accuracy: 79.21   RMSE : 7965.40

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)

fig, axes = plt.subplots(1, 2,figsize = (12, 7), sharey = True)

prediction1 = prediction[prediction['label'] < 10000]
axes[0].plot(prediction1.index, prediction1['pred'],label='Prediction',        
        linestyle = '--',)
axes[0].plot(prediction1.index, prediction1['label'], label = 'Truth',
        linestyle = '--',)
axes[0].set_xticks([])
axes[0].legend()
axes[0].set_title("Price under 10000$")
prediction2 = prediction[prediction['label'] > 10000]
axes[1].plot(prediction2.index, prediction2['pred'],label='Prediction',        
        linestyle = '--',)
axes[1].plot(prediction2.index, prediction2['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
axes[1].set_xticks([])
axes[1].legend()
axes[1].set_title("Price over 10000$")
plt.ylabel('prices')
plt.show()
