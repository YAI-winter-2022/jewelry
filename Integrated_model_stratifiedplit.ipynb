# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import random
import albumentations as A
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/'Colab Notebooks'/'yai_9기 겨울방학'/ToyProject
# Out:
# /content/drive/MyDrive/Colab Notebooks/yai_9기 겨울방학/ToyProject

# %%
csv_train_path = "train.csv"
csv_test_path = "train.csv"
csv_val_path = "train.csv"
image_path = "./data/images"
batch_size = 256
epochs = 100
learning_rate = 1e-3
seed = 42

# %%
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
class AllDataset(Dataset):
    def __init__(self, csv_path, image_path, image_transform=transforms.Compose([transforms.ToTensor()])):
        super(AllDataset).__init__()
        csv = pd.read_csv(csv_path)
        csv_np = csv.to_numpy()
        
        self.image_transform = image_transform
        self.ids = list(map(str, csv['Id']))
        self.image_path = image_path
        
        for i in [1, 3, 4, 5, 6, 7, 8]:
            wordset = {word: idx for idx, word in enumerate(np.unique(csv_np[:,i]))}
            for row in range(len(csv_np)):
                csv_np[row][i] = wordset[csv_np[row][i]]
        self.ints = torch.from_numpy(np.array(csv_np[:,[1,3,4,5,6,7,8]], dtype="int"))
        self.floats = torch.from_numpy(np.array(csv_np[:,[2,9,10,11]], dtype="float")).float()
        self.target = torch.from_numpy(np.array(csv_np[:,[12]], dtype="float")).float()
    
    
    def __getitem__(self,idx):
        return self.image_transform(Image.open(self.image_path+'/'+self.ids[idx]+'.jpg')), self.ints[idx],self.floats[idx], self.target[idx]
    
    
    def __len__(self):
        return len(self.ints)

# %%
image_transform = transforms.Compose([transforms.ToTensor()
                                     ])
train_dataset = AllDataset(csv_train_path, image_path, image_transform)
test_dataset = AllDataset(csv_test_path, image_path, image_transform)
val_dataset = AllDataset(csv_val_path, image_path, image_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Sequential(nn.Linear(512, 4096),
                                         nn.BatchNorm1d(4096),
                                         nn.ReLU(),
                                         nn.Dropout()
                                        )
        self.resenet18 = self.resnet18.to(device)
        
        self.emb1 = torch.nn.Embedding(8, 20)
        self.emb2 = torch.nn.Embedding(11, 20)
        self.emb3 = torch.nn.Embedding(20, 20)
        self.emb4 = torch.nn.Embedding(4, 20)
        self.emb5 = torch.nn.Embedding(4, 20)
        self.emb6 = torch.nn.Embedding(4, 20)
        self.emb7 = torch.nn.Embedding(7, 20)
        self.act = nn.ReLU()
        self.fc = nn.Linear(4, 80)
        self.csvbn = nn.BatchNorm1d(80)
        self.csvfc1 = nn.Linear(220, 8192)
        self.csvfc2 = nn.Linear(8192, 8192)
        self.csvfc3 = nn.Linear(8192, 4096)
        self.csvbn1 = nn.BatchNorm1d(8192)
        self.csvbn2 = nn.BatchNorm1d(8192)
        self.csvbn3 = nn.BatchNorm1d(4096)
        
        self.fc1 = nn.Linear(8192, 4096)
        self.fc2 = nn.Linear(4096, 1)
        self.bn1 = nn.BatchNorm1d(4096)
        self.dropout = nn.Dropout()
    
    def forward(self, image, x, y):
        image = self.resnet18(image)
        
        x1 = self.emb1(x[:,0])
        x2 = self.emb2(x[:,1])
        x3 = self.emb3(x[:,2])
        x4 = self.emb4(x[:,3])
        x5 = self.emb5(x[:,4])
        x6 = self.emb6(x[:,5])
        x7 = self.emb7(x[:,6])
        y = self.csvbn(self.fc(y))
        x = torch.cat((x1, x2, x3, x4, x5, x6, x7, y), dim=1)
        
        x = self.dropout(self.act(self.csvbn1(self.csvfc1(x))))
        x = self.dropout(self.act(self.csvbn2(self.csvfc2(x))))
        x = self.dropout(self.act(self.csvbn3(self.csvfc3(x))))
        x = torch.cat((x, image), dim=1)
        
        x = self.dropout(self.act(self.bn1(self.fc1(x))))
        return self.fc2(x)

# %%
model = Net().to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(epochs):
    model.train()
    criterion.train()
    
    avg_loss = 0

    for Img, X1, X2, Y in train_loader:
        Img = Img.to(device)
        X1 = X1.to(device)
        X2 = X2.to(device)
        Y = Y.to(device)

        model.zero_grad()
        prediction = model(Img, X1, X2)
        loss = torch.sqrt(criterion(prediction, Y)).to(device)
        loss.backward()
        optimizer.step()
        avg_loss += loss / len(train_loader)
    print(f'[Epoch: {epoch+1:>2}] Average loss: {avg_loss:.4f}, ', end='')
    
    model.eval()
    criterion.eval()
    with torch.no_grad():
        val_avg_loss = 0.
        for Image_val, X1_val, X2_val, Y_val in val_loader:
            Image_val = Image_val.to(device)
            X1_val = X1_val.to(device)
            X2_val = X2_val.to(device)
            Y_val = Y_val.to(device)
            val_prediction = model(Image_val, X1_val, X2_val)
            val_loss = torch.sqrt(criterion(val_prediction, Y_val)).to(device)
            val_avg_loss += val_loss / len(val_loader)
        
        print(f"val_loss: {val_avg_loss:.4f}")
# Out:
# [Epoch:  1] Average loss: 4385.8887, val_loss: 4022.7563
# [Epoch:  2] Average loss: 4342.8110, val_loss: 4156.6426
# [Epoch:  3] Average loss: 4502.9258, val_loss: 4062.4849
# [Epoch:  4] Average loss: 4360.0371, val_loss: 4342.9448
# [Epoch:  5] Average loss: 4606.0156, val_loss: 4304.4062
# [Epoch:  6] Average loss: 4171.3271, val_loss: 4053.4897
# [Epoch:  7] Average loss: 5594.0625, val_loss: 4242.8301
# [Epoch:  8] Average loss: 3930.6736, val_loss: 4155.1401
# [Epoch:  9] Average loss: 4112.2515, val_loss: 3916.6655
# [Epoch: 10] Average loss: 3942.7434, val_loss: 3835.6345
# [Epoch: 11] Average loss: 3925.5020, val_loss: 3607.1726
# [Epoch: 12] Average loss: 3849.0088, val_loss: 3660.4766
# [Epoch: 13] Average loss: 3923.1287, val_loss: 3842.4321
# [Epoch: 14] Average loss: 3742.9414, val_loss: 3640.5637
# [Epoch: 15] Average loss: 3612.3904, val_loss: 3512.0872
# [Epoch: 16] Average loss: 3643.3457, val_loss: 4975.3198
# [Epoch: 17] Average loss: 3800.7910, val_loss: 3558.6123
# [Epoch: 18] Average loss: 3511.8059, val_loss: 3361.9465
# [Epoch: 19] Average loss: 3392.4075, val_loss: 3379.5039
# [Epoch: 20] Average loss: 3290.1333, val_loss: 2999.4355
# [Epoch: 21] Average loss: 3208.8167, val_loss: 2823.6426
# [Epoch: 22] Average loss: 3208.8613, val_loss: 3291.5576
# [Epoch: 23] Average loss: 3110.6255, val_loss: 2703.0444
# [Epoch: 24] Average loss: 3119.5479, val_loss: 2551.2690
# [Epoch: 25] Average loss: 3148.0981, val_loss: 2560.2505
# [Epoch: 26] Average loss: 2944.7012, val_loss: 2439.0115
# [Epoch: 27] Average loss: 2830.1702, val_loss: 2450.2876
# [Epoch: 28] Average loss: 2775.6260, val_loss: 3107.9429
# [Epoch: 29] Average loss: 2667.5347, val_loss: 2574.0117
# [Epoch: 30] Average loss: 2604.9722, val_loss: 2325.9939
# [Epoch: 31] Average loss: 4177.3413, val_loss: 2672.3088
# [Epoch: 32] Average loss: 2449.2629, val_loss: 2377.1042
# [Epoch: 33] Average loss: 2407.4575, val_loss: 2051.3960
# [Epoch: 34] Average loss: 2322.3264, val_loss: 2062.7383
# [Epoch: 35] Average loss: 2205.5352, val_loss: 1708.8987
# [Epoch: 36] Average loss: 2156.7546, val_loss: 1724.4989
# [Epoch: 37] Average loss: 2075.9397, val_loss: 1766.5664
# [Epoch: 38] Average loss: 2297.5659, val_loss: 1325.0425
# [Epoch: 39] Average loss: 1986.6877, val_loss: 1405.5753
# [Epoch: 40] Average loss: 1956.8146, val_loss: 1464.1953
# [Epoch: 41] Average loss: 1976.4243, val_loss: 2242.3960
# [Epoch: 42] Average loss: 1822.7124, val_loss: 1293.5828
# [Epoch: 43] Average loss: 1730.7936, val_loss: 1556.1510
# [Epoch: 44] Average loss: 1881.8557, val_loss: 1597.2278
# [Epoch: 45] Average loss: 1726.8000, val_loss: 1242.8291
# [Epoch: 46] Average loss: 1603.8361, val_loss: 1680.3640
# [Epoch: 47] Average loss: 1518.0873, val_loss: 936.1435
# [Epoch: 48] Average loss: 1624.9580, val_loss: 1425.3159
# [Epoch: 49] Average loss: 1497.0696, val_loss: 1160.5593
# [Epoch: 50] Average loss: 1601.3706, val_loss: 1532.2908
# [Epoch: 51] Average loss: 1639.1732, val_loss: 1342.3209
# [Epoch: 52] Average loss: 1590.2526, val_loss: 910.4065
# [Epoch: 53] Average loss: 1495.0305, val_loss: 1049.7748
# [Epoch: 54] Average loss: 1522.6487, val_loss: 880.6063
# [Epoch: 55] Average loss: 1426.0275, val_loss: 872.7734
# [Epoch: 56] Average loss: 1487.3304, val_loss: 1298.4349
# [Epoch: 57] Average loss: 1577.1838, val_loss: 1507.0928
# [Epoch: 58] Average loss: 1325.2853, val_loss: 1305.4064
# [Epoch: 59] Average loss: 1222.2378, val_loss: 771.8459
# [Epoch: 60] Average loss: 1365.5748, val_loss: 916.7343
# [Epoch: 61] Average loss: 1589.7848, val_loss: 1171.0044
# [Epoch: 62] Average loss: 1494.6656, val_loss: 1552.8545
# [Epoch: 63] Average loss: 1338.2437, val_loss: 972.9528
# [Epoch: 64] Average loss: 1283.6162, val_loss: 1203.4366
# [Epoch: 65] Average loss: 1344.0964, val_loss: 1607.9170
# [Epoch: 66] Average loss: 1523.1218, val_loss: 957.2469
# [Epoch: 67] Average loss: 1236.3762, val_loss: 1112.1511
# [Epoch: 68] Average loss: 1424.3500, val_loss: 720.3532
# [Epoch: 69] Average loss: 1293.5173, val_loss: 923.7247
# [Epoch: 70] Average loss: 1290.8422, val_loss: 718.7761
# [Epoch: 71] Average loss: 1192.4473, val_loss: 690.0938
# [Epoch: 72] Average loss: 1322.6241, val_loss: 725.1527
# [Epoch: 73] Average loss: 1181.2100, val_loss: 836.2473
# [Epoch: 74] Average loss: 1281.6210, val_loss: 1076.7301
# [Epoch: 75] Average loss: 1821.5270, val_loss: 1351.1084
# [Epoch: 76] Average loss: 1166.0933, val_loss: 798.8548
# [Epoch: 77] Average loss: 1216.7634, val_loss: 1158.6639
# [Epoch: 78] Average loss: 1352.8751, val_loss: 702.3520
# [Epoch: 79] Average loss: 1245.7644, val_loss: 921.1666
# [Epoch: 80] Average loss: 1484.7605, val_loss: 1017.4292
# [Epoch: 81] Average loss: 1229.3235, val_loss: 592.6793
# [Epoch: 82] Average loss: 1193.8180, val_loss: 745.1269
# [Epoch: 83] Average loss: 1336.5790, val_loss: 750.9362
# [Epoch: 84] Average loss: 1215.3925, val_loss: 696.3641
# [Epoch: 85] Average loss: 1182.9066, val_loss: 702.9421
# [Epoch: 86] Average loss: 1381.7833, val_loss: 974.0512
# [Epoch: 87] Average loss: 1249.4722, val_loss: 670.4336
# [Epoch: 88] Average loss: 1097.2977, val_loss: 782.3644
# [Epoch: 89] Average loss: 1168.2415, val_loss: 968.7155
# [Epoch: 90] Average loss: 1103.1238, val_loss: 561.5138
# [Epoch: 91] Average loss: 1269.1299, val_loss: 814.6724
# [Epoch: 92] Average loss: 1160.4409, val_loss: 569.2656
# [Epoch: 93] Average loss: 1106.7332, val_loss: 670.2524
# [Epoch: 94] Average loss: 994.6863, val_loss: 640.2810
# [Epoch: 95] Average loss: 1334.8877, val_loss: 1349.3510
# [Epoch: 96] Average loss: 1282.1932, val_loss: 1510.4460
# [Epoch: 97] Average loss: 1367.1337, val_loss: 1265.2495
# [Epoch: 98] Average loss: 1188.5048, val_loss: 573.1005
# [Epoch: 99] Average loss: 1273.4191, val_loss: 806.7269
# [Epoch: 100] Average loss: 1795.2115, val_loss: 1323.9421

# %%
PATH = './model/'
Name = 'model_stfsplit.pt'
torch.save(model.state_dict(), PATH+Name)

# %%
RMSEs = []
accuracys = []

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 20000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    accuracys.append(accuracy)
    RMSEs.append(RMSE)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}",)
# Out:
# 결과값:74875.06$, 예측값 :48811.09$
# 결과값:41564.56$, 예측값 :28107.31$
# 결과값:64733.52$, 예측값 :48087.17$
# 결과값:48445.27$, 예측값 :45659.11$
# 결과값:30427.92$, 예측값 :22030.00$
# 결과값:31512.41$, 예측값 :22911.29$
# 결과값:49149.09$, 예측값 :37957.49$
# 결과값:41056.65$, 예측값 :27380.97$
# 결과값:64896.07$, 예측값 :49343.81$
# 결과값:41142.29$, 예측값 :27645.90$
# 결과값:76147.68$, 예측값 :51623.75$
# 결과값:68738.52$, 예측값 :41953.43$
# 결과값:30949.54$, 예측값 :23861.35$
# 결과값:38597.36$, 예측값 :26334.03$
# 결과값:38501.90$, 예측값 :27331.09$
# 결과값:30806.38$, 예측값 :21318.04$
# 결과값:39944.72$, 예측값 :28506.25$
# Accuracy: 4.10   RMSE : 15129.34

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 20,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 15000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:17787.42$, 예측값 :15553.92$
# 결과값:15891.75$, 예측값 :8374.68$
# 결과값:15769.57$, 예측값 :10509.15$
# 결과값:64733.52$, 예측값 :48087.17$
# 결과값:74875.06$, 예측값 :48811.09$
# 결과값:76147.68$, 예측값 :51623.75$
# 결과값:48445.27$, 예측값 :45659.11$
# 결과값:16247.87$, 예측값 :10388.85$
# 결과값:39944.72$, 예측값 :28506.25$
# 결과값:15690.71$, 예측값 :10575.52$
# 결과값:15861.09$, 예측값 :9400.42$
# 결과값:16014.16$, 예측값 :9726.73$
# 결과값:15503.29$, 예측값 :10454.48$
# 결과값:16295.40$, 예측값 :11805.90$
# 결과값:30427.92$, 예측값 :22030.00$
# 결과값:15504.29$, 예측값 :10315.76$
# 결과값:18073.74$, 예측값 :12771.19$
# 결과값:41564.56$, 예측값 :28107.31$
# 결과값:16740.69$, 예측값 :10194.66$
# 결과값:38597.36$, 예측값 :26334.03$
# 결과값:41056.65$, 예측값 :27380.97$
# 결과값:16519.20$, 예측값 :11093.78$
# 결과값:15608.70$, 예측값 :9137.21$
# 결과값:41142.29$, 예측값 :27645.90$
# 결과값:30949.54$, 예측값 :23861.35$
# 결과값:49149.09$, 예측값 :37957.49$
# 결과값:15382.34$, 예측값 :11287.20$
# 결과값:18024.06$, 예측값 :11669.45$
# 결과값:30806.38$, 예측값 :21318.04$
# 결과값:16033.96$, 예측값 :10748.19$
# 결과값:15675.88$, 예측값 :10179.09$
# 결과값:15925.23$, 예측값 :9776.18$
# 결과값:18524.37$, 예측값 :12297.69$
# 결과값:38501.90$, 예측값 :27331.09$
# 결과값:15845.90$, 예측값 :11537.22$
# 결과값:68738.52$, 예측값 :41953.43$
# 결과값:31512.41$, 예측값 :22911.29$
# 결과값:16708.74$, 예측값 :10359.68$
# 결과값:64896.07$, 예측값 :49343.81$
# Accuracy: 66.08   RMSE : 10846.00

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 15,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 10000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:11586.96$, 예측값 :7968.44$
# 결과값:16014.16$, 예측값 :9726.73$
# 결과값:12892.04$, 예측값 :8790.94$
# 결과값:15503.29$, 예측값 :10454.48$
# 결과값:13223.02$, 예측값 :10028.49$
# 결과값:12696.18$, 예측값 :9144.17$
# 결과값:12997.82$, 예측값 :7956.89$
# 결과값:17787.42$, 예측값 :15553.92$
# 결과값:15504.29$, 예측값 :10315.76$
# 결과값:15382.34$, 예측값 :11287.20$
# 결과값:16708.74$, 예측값 :10359.68$
# 결과값:30806.38$, 예측값 :21318.04$
# 결과값:74875.06$, 예측값 :48811.09$
# 결과값:11445.17$, 예측값 :6759.76$
# 결과값:30427.92$, 예측값 :22030.00$
# 결과값:15891.75$, 예측값 :8374.68$
# 결과값:11968.98$, 예측값 :6980.11$
# 결과값:15675.88$, 예측값 :10179.09$
# 결과값:13559.94$, 예측값 :7875.60$
# 결과값:68738.52$, 예측값 :41953.43$
# 결과값:15608.70$, 예측값 :9137.21$
# 결과값:11502.51$, 예측값 :6819.90$
# 결과값:13549.56$, 예측값 :8337.53$
# 결과값:30949.54$, 예측값 :23861.35$
# 결과값:16740.69$, 예측값 :10194.66$
# 결과값:16247.87$, 예측값 :10388.85$
# 결과값:15845.90$, 예측값 :11537.22$
# 결과값:13219.49$, 예측값 :8618.35$
# 결과값:18524.37$, 예측값 :12297.69$
# 결과값:38597.36$, 예측값 :26334.03$
# 결과값:64896.07$, 예측값 :49343.81$
# 결과값:41142.29$, 예측값 :27645.90$
# 결과값:13164.25$, 예측값 :7559.16$
# 결과값:15690.71$, 예측값 :10575.52$
# 결과값:18073.74$, 예측값 :12771.19$
# 결과값:15861.09$, 예측값 :9400.42$
# 결과값:38501.90$, 예측값 :27331.09$
# 결과값:11775.93$, 예측값 :7979.54$
# 결과값:41564.56$, 예측값 :28107.31$
# 결과값:48445.27$, 예측값 :45659.11$
# 결과값:13599.96$, 예측값 :9723.46$
# 결과값:11917.48$, 예측값 :9357.39$
# 결과값:76147.68$, 예측값 :51623.75$
# 결과값:49149.09$, 예측값 :37957.49$
# 결과값:13092.02$, 예측값 :8080.78$
# 결과값:15769.57$, 예측값 :10509.15$
# 결과값:31512.41$, 예측값 :22911.29$
# 결과값:13643.46$, 예측값 :9339.20$
# 결과값:15925.23$, 예측값 :9776.18$
# 결과값:64733.52$, 예측값 :48087.17$
# 결과값:13636.68$, 예측값 :9020.64$
# 결과값:11643.30$, 예측값 :7963.56$
# 결과값:16033.96$, 예측값 :10748.19$
# 결과값:13526.75$, 예측값 :9016.91$
# 결과값:16519.20$, 예측값 :11093.78$
# 결과값:41056.65$, 예측값 :27380.97$
# 결과값:13019.69$, 예측값 :8991.53$
# 결과값:39944.72$, 예측값 :28506.25$
# 결과값:18024.06$, 예측값 :11669.45$
# 결과값:16295.40$, 예측값 :11805.90$
# Accuracy: 71.63   RMSE : 9126.72

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 10,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:2040.50$, 예측값 :1777.11$
# 결과값:2028.32$, 예측값 :1717.75$
# 결과값:1371.01$, 예측값 :1133.93$
# 결과값:1208.28$, 예측값 :883.67$
# 결과값:7319.82$, 예측값 :4865.07$
# 결과값:1515.87$, 예측값 :1231.76$
# 결과값:2063.15$, 예측값 :1656.43$
# 결과값:8589.30$, 예측값 :5190.62$
# 결과값:1063.84$, 예측값 :1116.28$
# 결과값:2536.55$, 예측값 :1876.44$
# 결과값:1010.70$, 예측값 :1192.59$
# 결과값:1660.21$, 예측값 :1519.75$
# 결과값:2046.91$, 예측값 :1972.87$
# 결과값:3927.44$, 예측값 :3175.37$
# 결과값:1283.79$, 예측값 :1008.39$
# 결과값:1822.60$, 예측값 :1579.74$
# 결과값:1146.40$, 예측값 :1117.35$
# 결과값:923.62$, 예측값 :635.61$
# 결과값:1284.20$, 예측값 :1172.39$
# 결과값:1986.32$, 예측값 :1748.51$
# 결과값:2993.33$, 예측값 :2183.97$
# 결과값:1699.36$, 예측값 :1110.61$
# 결과값:2323.97$, 예측값 :1872.12$
# 결과값:1533.69$, 예측값 :1431.49$
# 결과값:2066.92$, 예측값 :1693.64$
# 결과값:2324.26$, 예측값 :1939.10$
# 결과값:15891.75$, 예측값 :8374.68$
# 결과값:2020.42$, 예측값 :1647.70$
# 결과값:1587.81$, 예측값 :1583.01$
# 결과값:1263.58$, 예측값 :1023.19$
# 결과값:2443.80$, 예측값 :2382.07$
# 결과값:2104.08$, 예측값 :1917.04$
# 결과값:2411.29$, 예측값 :2841.07$
# 결과값:1316.94$, 예측값 :1268.04$
# 결과값:1409.15$, 예측값 :1198.11$
# 결과값:2048.36$, 예측값 :2142.44$
# 결과값:2112.50$, 예측값 :1830.74$
# 결과값:2055.16$, 예측값 :1732.55$
# 결과값:1721.32$, 예측값 :1575.15$
# 결과값:866.31$, 예측값 :876.75$
# 결과값:13599.96$, 예측값 :9723.46$
# 결과값:2323.93$, 예측값 :2150.18$
# 결과값:1521.07$, 예측값 :1401.04$
# 결과값:778.97$, 예측값 :848.26$
# 결과값:1399.75$, 예측값 :805.85$
# 결과값:2829.58$, 예측값 :2147.91$
# 결과값:876.06$, 예측값 :880.29$
# 결과값:1959.57$, 예측값 :1524.17$
# 결과값:1404.02$, 예측값 :1374.75$
# 결과값:2025.35$, 예측값 :1673.29$
# 결과값:1264.41$, 예측값 :1126.39$
# 결과값:1450.63$, 예측값 :1983.23$
# 결과값:1662.66$, 예측값 :1508.56$
# 결과값:1609.43$, 예측값 :1685.42$
# 결과값:973.36$, 예측값 :664.97$
# 결과값:2092.25$, 예측값 :1635.97$
# 결과값:1601.05$, 예측값 :1401.11$
# 결과값:2938.91$, 예측값 :2198.31$
# 결과값:1067.44$, 예측값 :1004.25$
# 결과값:2024.48$, 예측값 :1872.75$
# 결과값:1532.76$, 예측값 :1554.87$
# 결과값:2348.26$, 예측값 :1935.13$
# 결과값:2091.41$, 예측값 :1862.62$
# 결과값:2077.89$, 예측값 :1676.74$
# 결과값:2817.80$, 예측값 :2631.49$
# 결과값:1874.41$, 예측값 :1686.52$
# 결과값:1782.88$, 예측값 :2184.11$
# 결과값:1858.32$, 예측값 :1614.98$
# 결과값:3840.15$, 예측값 :3749.87$
# 결과값:4413.30$, 예측값 :3185.12$
# 결과값:1275.07$, 예측값 :936.94$
# 결과값:1116.82$, 예측값 :1194.26$
# 결과값:6035.25$, 예측값 :4428.06$
# 결과값:1096.26$, 예측값 :876.99$
# 결과값:1425.99$, 예측값 :1400.97$
# 결과값:1209.04$, 예측값 :1040.71$
# 결과값:880.52$, 예측값 :890.26$
# 결과값:1581.98$, 예측값 :1534.31$
# 결과값:2112.09$, 예측값 :1678.41$
# 결과값:2094.03$, 예측값 :1905.10$
# 결과값:1732.44$, 예측값 :1569.85$
# 결과값:3519.17$, 예측값 :2656.93$
# 결과값:2324.57$, 예측값 :2158.48$
# 결과값:1111.09$, 예측값 :1109.73$
# 결과값:1663.96$, 예측값 :1500.56$
# 결과값:965.65$, 예측값 :621.40$
# 결과값:2059.58$, 예측값 :1918.67$
# 결과값:1552.57$, 예측값 :1294.31$
# 결과값:2186.82$, 예측값 :2004.13$
# 결과값:1096.98$, 예측값 :991.31$
# 결과값:2380.14$, 예측값 :2970.79$
# 결과값:1036.38$, 예측값 :959.73$
# 결과값:1124.77$, 예측값 :1121.37$
# 결과값:1357.61$, 예측값 :1554.43$
# 결과값:1867.06$, 예측값 :1503.09$
# 결과값:1876.91$, 예측값 :1376.00$
# 결과값:2018.05$, 예측값 :1814.28$
# 결과값:1670.49$, 예측값 :1408.06$
# 결과값:1403.31$, 예측값 :1137.78$
# 결과값:1952.46$, 예측값 :1723.98$
# 결과값:1155.27$, 예측값 :1341.57$
# 결과값:31512.41$, 예측값 :22911.29$
# 결과값:1127.36$, 예측값 :989.31$
# 결과값:1598.32$, 예측값 :1684.99$
# 결과값:1504.15$, 예측값 :1258.46$
# 결과값:1163.48$, 예측값 :895.36$
# 결과값:998.15$, 예측값 :1278.41$
# 결과값:3929.77$, 예측값 :3025.16$
# 결과값:1627.21$, 예측값 :1413.23$
# 결과값:2029.93$, 예측값 :1423.70$
# 결과값:2016.12$, 예측값 :1503.86$
# 결과값:849.11$, 예측값 :870.16$
# 결과값:1881.82$, 예측값 :1622.87$
# 결과값:1731.04$, 예측값 :2068.36$
# 결과값:1273.58$, 예측값 :1152.36$
# 결과값:1326.02$, 예측값 :1187.07$
# 결과값:1730.63$, 예측값 :1469.17$
# 결과값:1252.19$, 예측값 :914.23$
# 결과값:1533.95$, 예측값 :1364.16$
# 결과값:1266.84$, 예측값 :1075.86$
# 결과값:1444.75$, 예측값 :1388.79$
# 결과값:1799.95$, 예측값 :1409.87$
# 결과값:1973.87$, 예측값 :1898.55$
# 결과값:1032.71$, 예측값 :1016.95$
# 결과값:1838.77$, 예측값 :1550.98$
# 결과값:1182.41$, 예측값 :1013.74$
# 결과값:1693.78$, 예측값 :1577.13$
# 결과값:1028.04$, 예측값 :801.80$
# 결과값:928.15$, 예측값 :996.46$
# 결과값:1371.47$, 예측값 :1319.98$
# 결과값:1990.22$, 예측값 :2026.18$
# 결과값:1861.34$, 예측값 :1500.36$
# 결과값:4441.26$, 예측값 :2789.73$
# 결과값:1696.22$, 예측값 :1255.80$
# 결과값:1539.81$, 예측값 :1192.05$
# 결과값:1686.79$, 예측값 :1516.15$
# 결과값:2103.46$, 예측값 :1815.14$
# 결과값:1648.09$, 예측값 :1498.50$
# 결과값:2354.34$, 예측값 :1716.62$
# 결과값:1141.88$, 예측값 :933.71$
# 결과값:2052.37$, 예측값 :1638.91$
# 결과값:1126.93$, 예측값 :1173.58$
# 결과값:1188.41$, 예측값 :982.31$
# 결과값:2085.21$, 예측값 :1489.19$
# 결과값:1496.55$, 예측값 :1335.88$
# 결과값:1081.85$, 예측값 :897.12$
# 결과값:1031.12$, 예측값 :1072.81$
# 결과값:1230.89$, 예측값 :1175.65$
# 결과값:1968.17$, 예측값 :1843.11$
# 결과값:900.85$, 예측값 :796.17$
# 결과값:2023.07$, 예측값 :1984.73$
# 결과값:1044.25$, 예측값 :1076.50$
# 결과값:982.48$, 예측값 :843.96$
# 결과값:2073.77$, 예측값 :1924.06$
# 결과값:1986.00$, 예측값 :1754.61$
# 결과값:1532.76$, 예측값 :1496.84$
# 결과값:1936.06$, 예측값 :1584.80$
# 결과값:1303.38$, 예측값 :1174.64$
# 결과값:5280.42$, 예측값 :3902.40$
# 결과값:2870.92$, 예측값 :2235.40$
# 결과값:1430.13$, 예측값 :1287.86$
# 결과값:3126.03$, 예측값 :2565.19$
# 결과값:1661.03$, 예측값 :1417.76$
# 결과값:1885.35$, 예측값 :1499.15$
# 결과값:2083.01$, 예측값 :2029.30$
# 결과값:2408.00$, 예측값 :1867.75$
# 결과값:1012.92$, 예측값 :1097.28$
# 결과값:1143.35$, 예측값 :950.40$
# 결과값:2259.15$, 예측값 :1787.89$
# 결과값:2193.05$, 예측값 :1883.56$
# 결과값:2354.37$, 예측값 :1803.96$
# 결과값:1539.93$, 예측값 :1490.15$
# 결과값:1707.81$, 예측값 :1472.18$
# 결과값:2110.84$, 예측값 :1870.44$
# 결과값:3173.58$, 예측값 :2727.30$
# 결과값:2110.81$, 예측값 :2083.44$
# 결과값:4499.39$, 예측값 :3636.05$
# 결과값:2046.29$, 예측값 :2019.02$
# 결과값:766.58$, 예측값 :611.34$
# 결과값:4325.04$, 예측값 :3372.73$
# 결과값:970.77$, 예측값 :459.18$
# 결과값:1547.89$, 예측값 :1445.18$
# 결과값:2197.80$, 예측값 :1464.05$
# 결과값:1139.06$, 예측값 :893.25$
# 결과값:1318.52$, 예측값 :1671.59$
# 결과값:1970.03$, 예측값 :1736.65$
# 결과값:2094.92$, 예측값 :1742.82$
# 결과값:2025.94$, 예측값 :1593.92$
# 결과값:1055.32$, 예측값 :793.96$
# 결과값:2088.84$, 예측값 :1354.96$
# 결과값:1378.65$, 예측값 :1548.09$
# 결과값:1536.39$, 예측값 :1582.85$
# 결과값:1533.95$, 예측값 :1364.26$
# 결과값:1867.55$, 예측값 :1465.55$
# 결과값:11775.93$, 예측값 :7979.54$
# 결과값:2155.85$, 예측값 :1858.48$
# 결과값:2096.53$, 예측값 :1828.00$
# 결과값:1127.33$, 예측값 :1437.40$
# 결과값:3646.86$, 예측값 :3748.83$
# 결과값:1728.87$, 예측값 :1592.29$
# 결과값:2109.38$, 예측값 :1431.59$
# 결과값:2006.08$, 예측값 :1683.85$
# 결과값:1868.98$, 예측값 :1654.43$
# 결과값:2159.88$, 예측값 :1464.57$
# 결과값:1441.91$, 예측값 :1317.64$
# 결과값:1039.76$, 예측값 :951.74$
# 결과값:1060.00$, 예측값 :1038.70$
# 결과값:1430.09$, 예측값 :1477.37$
# 결과값:3559.23$, 예측값 :3112.18$
# 결과값:1728.14$, 예측값 :1614.90$
# 결과값:1766.67$, 예측값 :1474.63$
# 결과값:1169.67$, 예측값 :928.86$
# 결과값:1026.51$, 예측값 :611.93$
# 결과값:2028.34$, 예측값 :1664.58$
# 결과값:1661.47$, 예측값 :1708.90$
# 결과값:2024.71$, 예측값 :1730.90$
# 결과값:3811.71$, 예측값 :3347.90$
# 결과값:965.72$, 예측값 :1000.70$
# 결과값:3692.00$, 예측값 :3099.78$
# 결과값:725.32$, 예측값 :778.57$
# 결과값:1474.81$, 예측값 :1475.79$
# 결과값:1203.96$, 예측값 :894.89$
# 결과값:1532.76$, 예측값 :1335.75$
# 결과값:3325.50$, 예측값 :2465.04$
# 결과값:1209.36$, 예측값 :1035.96$
# 결과값:1063.21$, 예측값 :905.11$
# 결과값:1683.38$, 예측값 :1414.75$
# 결과값:2105.01$, 예측값 :1767.32$
# 결과값:937.85$, 예측값 :1045.00$
# 결과값:3069.61$, 예측값 :2483.81$
# 결과값:41564.56$, 예측값 :28107.31$
# 결과값:1930.98$, 예측값 :1588.85$
# 결과값:2067.31$, 예측값 :1869.95$
# 결과값:2133.76$, 예측값 :1526.05$
# 결과값:1724.19$, 예측값 :1700.48$
# 결과값:2214.81$, 예측값 :1894.98$
# 결과값:1511.28$, 예측값 :1118.24$
# 결과값:1782.61$, 예측값 :1463.03$
# 결과값:1880.34$, 예측값 :1696.68$
# 결과값:1098.53$, 예측값 :1046.16$
# 결과값:1248.17$, 예측값 :998.48$
# 결과값:1032.64$, 예측값 :1120.09$
# 결과값:1012.78$, 예측값 :931.19$
# 결과값:2067.16$, 예측값 :1392.41$
# 결과값:2267.65$, 예측값 :2232.53$
# 결과값:2962.27$, 예측값 :2346.88$
# 결과값:2081.40$, 예측값 :1891.71$
# 결과값:2042.57$, 예측값 :1590.06$
# 결과값:2347.97$, 예측값 :1982.60$
# 결과값:2060.99$, 예측값 :1798.86$
# 결과값:1788.95$, 예측값 :1386.39$
# 결과값:2064.25$, 예측값 :1925.04$
# 결과값:2363.37$, 예측값 :1826.36$
# 결과값:864.27$, 예측값 :778.65$
# 결과값:2361.00$, 예측값 :1901.26$
# 결과값:3771.04$, 예측값 :2746.51$
# 결과값:2452.64$, 예측값 :2148.06$
# 결과값:2568.50$, 예측값 :1978.00$
# 결과값:41056.65$, 예측값 :27380.97$
# 결과값:1344.58$, 예측값 :1028.46$
# 결과값:1662.61$, 예측값 :1650.08$
# 결과값:1069.46$, 예측값 :1003.13$
# 결과값:2119.15$, 예측값 :1874.57$
# 결과값:2025.02$, 예측값 :1707.95$
# 결과값:2060.14$, 예측값 :1629.75$
# 결과값:2119.15$, 예측값 :1684.38$
# 결과값:1678.17$, 예측값 :1599.47$
# 결과값:922.67$, 예측값 :1469.58$
# 결과값:1349.48$, 예측값 :1315.07$
# 결과값:938.32$, 예측값 :859.12$
# 결과값:2686.39$, 예측값 :2985.84$
# 결과값:1112.06$, 예측값 :1427.12$
# 결과값:2508.86$, 예측값 :1949.99$
# 결과값:1382.59$, 예측값 :1432.09$
# 결과값:1735.41$, 예측값 :1536.82$
# 결과값:2447.39$, 예측값 :2187.80$
# 결과값:2243.22$, 예측값 :1993.55$
# 결과값:1682.56$, 예측값 :1304.70$
# 결과값:2854.35$, 예측값 :2018.66$
# 결과값:841.48$, 예측값 :914.73$
# 결과값:2348.51$, 예측값 :2045.20$
# 결과값:936.77$, 예측값 :679.69$
# 결과값:1540.60$, 예측값 :1464.84$
# 결과값:1018.39$, 예측값 :702.56$
# 결과값:1823.39$, 예측값 :1730.69$
# 결과값:1013.49$, 예측값 :850.19$
# 결과값:1696.00$, 예측값 :1648.40$
# 결과값:1208.47$, 예측값 :1241.79$
# 결과값:3025.51$, 예측값 :2542.39$
# 결과값:3905.91$, 예측값 :2676.95$
# 결과값:2086.39$, 예측값 :1659.25$
# 결과값:1550.22$, 예측값 :1464.05$
# 결과값:2105.63$, 예측값 :1818.07$
# 결과값:2063.52$, 예측값 :1872.85$
# 결과값:945.89$, 예측값 :1071.54$
# 결과값:993.52$, 예측값 :921.13$
# 결과값:2043.47$, 예측값 :1558.29$
# 결과값:2087.77$, 예측값 :1955.75$
# 결과값:2835.39$, 예측값 :3141.93$
# 결과값:2032.09$, 예측값 :1523.87$
# 결과값:1262.33$, 예측값 :900.38$
# 결과값:1622.67$, 예측값 :1201.75$
# 결과값:924.65$, 예측값 :780.84$
# 결과값:1023.48$, 예측값 :1121.48$
# 결과값:1426.55$, 예측값 :1117.72$
# 결과값:2080.80$, 예측값 :2110.38$
# 결과값:2507.91$, 예측값 :1698.76$
# 결과값:1920.05$, 예측값 :1925.50$
# 결과값:1786.50$, 예측값 :1532.13$
# 결과값:2934.67$, 예측값 :2785.77$
# 결과값:1283.45$, 예측값 :804.17$
# 결과값:1925.35$, 예측값 :1447.76$
# 결과값:1429.50$, 예측값 :882.03$
# 결과값:1184.37$, 예측값 :1152.21$
# 결과값:2076.75$, 예측값 :2252.44$
# 결과값:1530.67$, 예측값 :1223.13$
# 결과값:2834.65$, 예측값 :2281.53$
# 결과값:1407.96$, 예측값 :1115.45$
# 결과값:1771.59$, 예측값 :1569.36$
# 결과값:1973.74$, 예측값 :1144.23$
# 결과값:1088.87$, 예측값 :1192.20$
# 결과값:2044.11$, 예측값 :1893.01$
# 결과값:2306.50$, 예측값 :1966.38$
# 결과값:1319.56$, 예측값 :1087.46$
# 결과값:2050.63$, 예측값 :1850.66$
# 결과값:1060.00$, 예측값 :898.07$
# 결과값:1366.08$, 예측값 :1423.90$
# 결과값:3377.27$, 예측값 :2431.58$
# 결과값:975.06$, 예측값 :1033.42$
# 결과값:1301.09$, 예측값 :1342.75$
# 결과값:2086.39$, 예측값 :1867.96$
# 결과값:1088.41$, 예측값 :1102.96$
# 결과값:1746.29$, 예측값 :1589.48$
# 결과값:4434.76$, 예측값 :3323.73$
# 결과값:1534.52$, 예측값 :1488.55$
# 결과값:1973.48$, 예측값 :1797.61$
# 결과값:2048.45$, 예측값 :1905.77$
# 결과값:1087.54$, 예측값 :1279.61$
# 결과값:1950.70$, 예측값 :1664.15$
# 결과값:1135.04$, 예측값 :1002.68$
# 결과값:5414.97$, 예측값 :3542.74$
# 결과값:6541.45$, 예측값 :5268.10$
# 결과값:926.36$, 예측값 :1158.18$
# 결과값:1247.90$, 예측값 :1116.68$
# 결과값:2174.39$, 예측값 :1656.82$
# 결과값:1963.28$, 예측값 :1766.28$
# 결과값:1156.64$, 예측값 :1009.88$
# 결과값:1194.64$, 예측값 :1145.80$
# 결과값:3301.06$, 예측값 :2322.16$
# 결과값:1190.44$, 예측값 :876.73$
# 결과값:9421.62$, 예측값 :6816.12$
# 결과값:1758.85$, 예측값 :1525.66$
# 결과값:2027.74$, 예측값 :1827.29$
# 결과값:4030.43$, 예측값 :2743.81$
# 결과값:2050.02$, 예측값 :1773.98$
# 결과값:840.78$, 예측값 :613.01$
# 결과값:2527.87$, 예측값 :1995.44$
# 결과값:1445.96$, 예측값 :1318.65$
# 결과값:2073.83$, 예측값 :1877.68$
# 결과값:1066.25$, 예측값 :1058.27$
# 결과값:2048.45$, 예측값 :1888.11$
# 결과값:1023.97$, 예측값 :833.49$
# 결과값:1204.23$, 예측값 :1063.60$
# 결과값:1686.70$, 예측값 :1462.83$
# 결과값:2241.67$, 예측값 :3489.87$
# 결과값:1718.73$, 예측값 :1441.82$
# 결과값:2112.65$, 예측값 :1754.18$
# 결과값:1148.07$, 예측값 :1080.87$
# 결과값:3505.15$, 예측값 :2493.40$
# 결과값:1037.24$, 예측값 :1256.55$
# 결과값:1214.62$, 예측값 :618.87$
# 결과값:2075.87$, 예측값 :1847.27$
# 결과값:1063.30$, 예측값 :1064.22$
# 결과값:1065.06$, 예측값 :1063.81$
# 결과값:2094.76$, 예측값 :1731.80$
# 결과값:1523.91$, 예측값 :1644.68$
# 결과값:4431.08$, 예측값 :2998.53$
# 결과값:1330.96$, 예측값 :1029.00$
# 결과값:2448.27$, 예측값 :1807.22$
# 결과값:1939.41$, 예측값 :1602.55$
# 결과값:2040.57$, 예측값 :1863.42$
# 결과값:2059.12$, 예측값 :1863.75$
# 결과값:1063.53$, 예측값 :1283.37$
# 결과값:930.75$, 예측값 :864.11$
# 결과값:1788.16$, 예측값 :1545.50$
# 결과값:2937.92$, 예측값 :2209.73$
# 결과값:2605.37$, 예측값 :1585.01$
# 결과값:2042.53$, 예측값 :2002.68$
# 결과값:2080.00$, 예측값 :1890.06$
# 결과값:879.73$, 예측값 :831.59$
# 결과값:1039.49$, 예측값 :1037.47$
# 결과값:1445.29$, 예측값 :1517.57$
# 결과값:1110.81$, 예측값 :1063.44$
# 결과값:1129.73$, 예측값 :747.08$
# 결과값:951.15$, 예측값 :606.38$
# 결과값:1366.89$, 예측값 :1181.17$
# 결과값:1100.26$, 예측값 :1138.79$
# 결과값:1607.28$, 예측값 :1235.14$
# 결과값:1273.42$, 예측값 :1356.92$
# 결과값:1152.06$, 예측값 :1096.87$
# 결과값:2620.85$, 예측값 :2043.18$
# 결과값:2050.23$, 예측값 :1503.60$
# 결과값:1248.96$, 예측값 :991.20$
# 결과값:2062.32$, 예측값 :1825.30$
# 결과값:899.37$, 예측값 :788.04$
# 결과값:1016.72$, 예측값 :1072.60$
# 결과값:1787.99$, 예측값 :1431.23$
# 결과값:902.81$, 예측값 :868.55$
# 결과값:2082.57$, 예측값 :1835.83$
# 결과값:2197.73$, 예측값 :1887.07$
# 결과값:1414.37$, 예측값 :1388.55$
# 결과값:2470.85$, 예측값 :1797.86$
# 결과값:1281.12$, 예측값 :1142.58$
# 결과값:1705.31$, 예측값 :1558.27$
# 결과값:1159.56$, 예측값 :871.17$
# 결과값:1286.19$, 예측값 :1093.18$
# 결과값:48445.27$, 예측값 :45659.11$
# 결과값:2544.90$, 예측값 :2100.89$
# 결과값:2055.90$, 예측값 :1884.94$
# 결과값:1014.51$, 예측값 :2834.42$
# 결과값:1282.85$, 예측값 :874.18$
# 결과값:2004.41$, 예측값 :1839.30$
# 결과값:2819.34$, 예측값 :2661.88$
# 결과값:1320.14$, 예측값 :1191.46$
# 결과값:2077.86$, 예측값 :2026.46$
# 결과값:2678.20$, 예측값 :2429.39$
# 결과값:1458.21$, 예측값 :1704.96$
# 결과값:847.83$, 예측값 :678.06$
# 결과값:1301.12$, 예측값 :1274.85$
# 결과값:1344.68$, 예측값 :1037.87$
# 결과값:1264.82$, 예측값 :1261.28$
# 결과값:1055.32$, 예측값 :796.15$
# 결과값:1586.10$, 예측값 :1468.56$
# 결과값:1699.36$, 예측값 :1641.08$
# 결과값:903.81$, 예측값 :1025.97$
# 결과값:1731.54$, 예측값 :1564.27$
# 결과값:1211.10$, 예측값 :1040.03$
# 결과값:1022.92$, 예측값 :1007.34$
# 결과값:2057.71$, 예측값 :1703.12$
# 결과값:2224.84$, 예측값 :1922.39$
# 결과값:1813.12$, 예측값 :1649.78$
# 결과값:1529.60$, 예측값 :1418.16$
# 결과값:1251.53$, 예측값 :1114.98$
# 결과값:2425.61$, 예측값 :2429.18$
# 결과값:1796.44$, 예측값 :1532.31$
# 결과값:2784.64$, 예측값 :2442.80$
# 결과값:2337.83$, 예측값 :2078.47$
# 결과값:2471.74$, 예측값 :2059.00$
# 결과값:1530.17$, 예측값 :1325.36$
# 결과값:2085.93$, 예측값 :1852.30$
# 결과값:1001.16$, 예측값 :933.68$
# 결과값:2076.53$, 예측값 :1928.18$
# 결과값:926.15$, 예측값 :677.01$
# 결과값:3148.92$, 예측값 :2441.20$
# 결과값:6168.37$, 예측값 :3748.32$
# 결과값:1160.33$, 예측값 :1171.76$
# 결과값:1164.76$, 예측값 :729.67$
# 결과값:18024.06$, 예측값 :11669.45$
# 결과값:1060.00$, 예측값 :850.94$
# 결과값:1193.29$, 예측값 :1147.81$
# 결과값:926.91$, 예측값 :711.52$
# 결과값:1672.38$, 예측값 :2116.55$
# 결과값:2059.48$, 예측값 :1969.74$
# 결과값:2104.90$, 예측값 :1915.75$
# 결과값:984.43$, 예측값 :1160.66$
# 결과값:978.37$, 예측값 :1032.02$
# 결과값:835.72$, 예측값 :117.42$
# 결과값:1183.24$, 예측값 :1102.39$
# 결과값:2088.91$, 예측값 :1854.73$
# 결과값:1088.41$, 예측값 :1085.49$
# 결과값:1975.61$, 예측값 :1673.91$
# 결과값:1131.56$, 예측값 :987.89$
# 결과값:2036.90$, 예측값 :1315.16$
# 결과값:1963.17$, 예측값 :1632.73$
# 결과값:2048.45$, 예측값 :1835.97$
# 결과값:2299.64$, 예측값 :1703.39$
# 결과값:2089.31$, 예측값 :1770.47$
# 결과값:1082.75$, 예측값 :1048.86$
# 결과값:822.17$, 예측값 :935.63$
# 결과값:926.15$, 예측값 :878.26$
# 결과값:1027.10$, 예측값 :820.01$
# 결과값:1163.80$, 예측값 :1042.69$
# 결과값:982.43$, 예측값 :880.58$
# 결과값:3470.17$, 예측값 :2525.84$
# 결과값:2575.46$, 예측값 :2719.90$
# 결과값:1320.70$, 예측값 :1001.30$
# 결과값:786.71$, 예측값 :908.98$
# 결과값:5260.92$, 예측값 :3345.64$
# 결과값:2180.11$, 예측값 :1984.11$
# 결과값:1465.45$, 예측값 :1326.36$
# 결과값:1166.12$, 예측값 :952.52$
# 결과값:5979.00$, 예측값 :4149.44$
# 결과값:6935.70$, 예측값 :3841.11$
# 결과값:1732.55$, 예측값 :1508.20$
# 결과값:4794.36$, 예측값 :3922.31$
# 결과값:3195.90$, 예측값 :2424.56$
# 결과값:979.25$, 예측값 :847.60$
# 결과값:1649.96$, 예측값 :1413.45$
# 결과값:3914.58$, 예측값 :3177.56$
# 결과값:1143.13$, 예측값 :1368.69$
# 결과값:3506.48$, 예측값 :2803.42$
# 결과값:2350.94$, 예측값 :2038.20$
# 결과값:1663.91$, 예측값 :1254.56$
# 결과값:2305.73$, 예측값 :1747.34$
# 결과값:6976.29$, 예측값 :5099.46$
# 결과값:1156.87$, 예측값 :1206.86$
# 결과값:754.50$, 예측값 :861.81$
# 결과값:993.94$, 예측값 :755.60$
# 결과값:2105.06$, 예측값 :1368.48$
# 결과값:2100.82$, 예측값 :1578.00$
# 결과값:1139.57$, 예측값 :959.61$
# 결과값:2034.08$, 예측값 :1910.24$
# 결과값:2110.71$, 예측값 :1896.47$
# 결과값:923.11$, 예측값 :759.25$
# 결과값:1090.74$, 예측값 :841.21$
# 결과값:2028.12$, 예측값 :1769.60$
# 결과값:897.27$, 예측값 :916.83$
# 결과값:1342.60$, 예측값 :1191.72$
# 결과값:49149.09$, 예측값 :37957.49$
# 결과값:5330.81$, 예측값 :4048.57$
# 결과값:2062.66$, 예측값 :1765.19$
# 결과값:1086.48$, 예측값 :529.30$
# 결과값:1650.38$, 예측값 :1476.83$
# 결과값:1747.15$, 예측값 :1612.00$
# 결과값:2101.80$, 예측값 :1801.51$
# 결과값:1928.94$, 예측값 :1631.95$
# 결과값:15675.88$, 예측값 :10179.09$
# 결과값:987.31$, 예측값 :1011.32$
# 결과값:1133.55$, 예측값 :995.53$
# 결과값:1012.43$, 예측값 :1167.84$
# 결과값:974.34$, 예측값 :1198.11$
# 결과값:1696.13$, 예측값 :1205.56$
# 결과값:2198.03$, 예측값 :1701.80$
# 결과값:901.31$, 예측값 :1142.41$
# 결과값:1681.70$, 예측값 :1415.67$
# 결과값:1389.25$, 예측값 :1318.25$
# 결과값:2079.23$, 예측값 :1928.92$
# 결과값:1286.36$, 예측값 :1246.92$
# 결과값:2074.68$, 예측값 :1813.36$
# 결과값:3510.08$, 예측값 :2816.08$
# 결과값:64896.07$, 예측값 :49343.81$
# 결과값:861.93$, 예측값 :827.57$
# 결과값:1038.27$, 예측값 :1106.57$
# 결과값:2080.06$, 예측값 :1592.54$
# 결과값:3758.85$, 예측값 :2997.93$
# 결과값:1458.81$, 예측값 :1317.07$
# 결과값:3632.78$, 예측값 :2819.54$
# 결과값:2350.94$, 예측값 :2152.58$
# 결과값:1052.87$, 예측값 :1076.38$
# 결과값:1520.76$, 예측값 :1507.80$
# 결과값:1155.69$, 예측값 :1001.77$
# 결과값:1087.94$, 예측값 :766.20$
# 결과값:2404.83$, 예측값 :1966.70$
# 결과값:1642.21$, 예측값 :1493.69$
# 결과값:1287.10$, 예측값 :1122.14$
# 결과값:1041.82$, 예측값 :1223.80$
# 결과값:1124.39$, 예측값 :873.78$
# 결과값:1960.60$, 예측값 :1827.66$
# 결과값:2551.42$, 예측값 :2042.37$
# 결과값:6209.44$, 예측값 :4219.03$
# 결과값:1156.81$, 예측값 :1055.24$
# 결과값:1467.59$, 예측값 :1063.15$
# 결과값:1062.00$, 예측값 :874.60$
# 결과값:2058.37$, 예측값 :1337.29$
# 결과값:1407.43$, 예측값 :1052.84$
# 결과값:2227.90$, 예측값 :1878.88$
# 결과값:2079.30$, 예측값 :2201.01$
# 결과값:1283.00$, 예측값 :1192.97$
# 결과값:1748.41$, 예측값 :1536.70$
# 결과값:2123.49$, 예측값 :1756.57$
# 결과값:1701.70$, 예측값 :1583.72$
# 결과값:2419.01$, 예측값 :1835.09$
# 결과값:1659.84$, 예측값 :1336.61$
# 결과값:1800.58$, 예측값 :1543.31$
# 결과값:2075.87$, 예측값 :1802.26$
# 결과값:2049.78$, 예측값 :1877.23$
# 결과값:1575.99$, 예측값 :1484.78$
# 결과값:3280.34$, 예측값 :3270.19$
# 결과값:1277.78$, 예측값 :961.69$
# 결과값:16033.96$, 예측값 :10748.19$
# 결과값:1031.20$, 예측값 :1075.82$
# 결과값:1314.90$, 예측값 :1188.19$
# 결과값:2344.52$, 예측값 :1968.11$
# 결과값:2259.45$, 예측값 :1790.16$
# 결과값:897.69$, 예측값 :472.36$
# 결과값:1374.36$, 예측값 :1279.42$
# 결과값:1324.64$, 예측값 :1324.61$
# 결과값:1170.21$, 예측값 :1209.15$
# 결과값:2031.77$, 예측값 :1892.63$
# 결과값:2437.61$, 예측값 :2064.85$
# 결과값:1145.90$, 예측값 :1100.11$
# 결과값:2181.55$, 예측값 :1903.20$
# 결과값:869.06$, 예측값 :1009.19$
# 결과값:1801.64$, 예측값 :1376.01$
# 결과값:1248.50$, 예측값 :1131.76$
# 결과값:1069.67$, 예측값 :916.24$
# 결과값:1062.49$, 예측값 :277.17$
# 결과값:1000.56$, 예측값 :1046.37$
# 결과값:3824.50$, 예측값 :3070.18$
# 결과값:2299.95$, 예측값 :1824.77$
# 결과값:1521.74$, 예측값 :1525.97$
# 결과값:1451.86$, 예측값 :1246.40$
# 결과값:1040.18$, 예측값 :1300.16$
# 결과값:2351.70$, 예측값 :1893.96$
# 결과값:2034.19$, 예측값 :1697.73$
# 결과값:2285.03$, 예측값 :2197.08$
# 결과값:3375.01$, 예측값 :2520.68$
# 결과값:2089.70$, 예측값 :1981.98$
# 결과값:1406.93$, 예측값 :1306.00$
# 결과값:838.43$, 예측값 :805.61$
# 결과값:1194.84$, 예측값 :1205.64$
# 결과값:1200.41$, 예측값 :963.29$
# 결과값:1515.25$, 예측값 :1771.00$
# 결과값:1055.71$, 예측값 :1045.64$
# 결과값:1176.97$, 예측값 :1143.73$
# 결과값:3155.22$, 예측값 :2529.81$
# 결과값:1515.12$, 예측값 :1626.55$
# 결과값:2036.90$, 예측값 :1447.40$
# 결과값:1520.86$, 예측값 :1565.14$
# 결과값:2006.18$, 예측값 :1774.21$
# 결과값:11586.96$, 예측값 :7968.44$
# 결과값:4378.37$, 예측값 :3073.45$
# 결과값:2337.64$, 예측값 :1974.85$
# 결과값:2100.82$, 예측값 :1231.52$
# 결과값:1597.90$, 예측값 :1414.29$
# 결과값:2061.99$, 예측값 :1775.27$
# 결과값:38501.90$, 예측값 :27331.09$
# 결과값:1985.09$, 예측값 :1873.31$
# 결과값:1237.55$, 예측값 :1246.13$
# 결과값:2048.36$, 예측값 :1798.17$
# 결과값:2611.79$, 예측값 :1550.80$
# 결과값:2018.99$, 예측값 :1551.21$
# 결과값:2786.32$, 예측값 :2166.12$
# 결과값:3086.89$, 예측값 :2091.86$
# 결과값:2096.28$, 예측값 :2180.51$
# 결과값:1455.25$, 예측값 :1221.09$
# 결과값:2322.17$, 예측값 :2109.53$
# 결과값:2470.85$, 예측값 :1940.84$
# 결과값:2030.72$, 예측값 :1541.35$
# 결과값:1137.07$, 예측값 :1098.48$
# 결과값:963.25$, 예측값 :590.60$
# 결과값:2551.46$, 예측값 :2309.53$
# 결과값:2084.78$, 예측값 :1675.11$
# 결과값:1382.23$, 예측값 :1474.40$
# 결과값:1699.57$, 예측값 :1180.32$
# 결과값:2029.85$, 예측값 :1801.70$
# 결과값:3579.91$, 예측값 :2818.65$
# 결과값:1315.77$, 예측값 :1329.57$
# 결과값:1165.48$, 예측값 :977.84$
# 결과값:1502.54$, 예측값 :1283.89$
# 결과값:1735.83$, 예측값 :1403.71$
# 결과값:959.96$, 예측값 :1265.47$
# 결과값:2094.84$, 예측값 :2101.83$
# 결과값:1750.96$, 예측값 :1618.57$
# 결과값:4363.61$, 예측값 :3493.68$
# 결과값:974.83$, 예측값 :989.76$
# 결과값:2090.41$, 예측값 :1785.59$
# 결과값:1961.21$, 예측값 :1394.98$
# 결과값:2049.83$, 예측값 :1862.42$
# 결과값:904.35$, 예측값 :833.51$
# 결과값:2048.45$, 예측값 :1841.39$
# 결과값:15925.23$, 예측값 :9776.18$
# 결과값:2123.65$, 예측값 :1623.93$
# 결과값:2323.78$, 예측값 :1710.11$
# 결과값:1328.87$, 예측값 :1493.30$
# 결과값:1527.02$, 예측값 :1204.33$
# 결과값:1661.02$, 예측값 :1518.12$
# 결과값:2255.38$, 예측값 :1987.28$
# 결과값:1358.98$, 예측값 :1371.80$
# 결과값:3582.57$, 예측값 :2806.27$
# 결과값:1967.74$, 예측값 :1855.58$
# 결과값:902.60$, 예측값 :1089.16$
# 결과값:2083.80$, 예측값 :1866.45$
# 결과값:4115.60$, 예측값 :2947.22$
# 결과값:1148.68$, 예측값 :1148.91$
# 결과값:13223.02$, 예측값 :10028.49$
# 결과값:1960.60$, 예측값 :1693.56$
# 결과값:757.14$, 예측값 :364.53$
# 결과값:2075.91$, 예측값 :1765.51$
# 결과값:1103.57$, 예측값 :1040.85$
# 결과값:3640.86$, 예측값 :2737.02$
# 결과값:1285.80$, 예측값 :874.62$
# 결과값:1044.25$, 예측값 :738.96$
# 결과값:1960.06$, 예측값 :1825.68$
# 결과값:3514.62$, 예측값 :2549.68$
# 결과값:1978.97$, 예측값 :1464.23$
# 결과값:3071.64$, 예측값 :2174.44$
# 결과값:1185.70$, 예측값 :1151.13$
# 결과값:1599.59$, 예측값 :1417.09$
# 결과값:1176.98$, 예측값 :1061.37$
# 결과값:1744.96$, 예측값 :1644.85$
# 결과값:2331.36$, 예측값 :1501.10$
# 결과값:1169.50$, 예측값 :1099.63$
# 결과값:2820.67$, 예측값 :2449.41$
# 결과값:4324.44$, 예측값 :3372.59$
# 결과값:2304.57$, 예측값 :1779.24$
# 결과값:1477.08$, 예측값 :1395.77$
# 결과값:1017.77$, 예측값 :1093.73$
# 결과값:903.73$, 예측값 :937.96$
# 결과값:2092.32$, 예측값 :1536.42$
# 결과값:1697.67$, 예측값 :1277.98$
# 결과값:1748.47$, 예측값 :1409.13$
# 결과값:1524.32$, 예측값 :1484.73$
# 결과값:5298.17$, 예측값 :4388.86$
# 결과값:3633.68$, 예측값 :2714.58$
# 결과값:2011.10$, 예측값 :1768.09$
# 결과값:1588.29$, 예측값 :1479.22$
# 결과값:3236.98$, 예측값 :2784.28$
# 결과값:3419.67$, 예측값 :2899.72$
# 결과값:1585.22$, 예측값 :1543.59$
# 결과값:1063.75$, 예측값 :793.43$
# 결과값:981.36$, 예측값 :1203.71$
# 결과값:5215.69$, 예측값 :4404.66$
# 결과값:1181.66$, 예측값 :870.80$
# 결과값:1063.69$, 예측값 :1073.09$
# 결과값:809.54$, 예측값 :726.29$
# 결과값:1474.06$, 예측값 :1680.75$
# 결과값:1879.45$, 예측값 :1413.00$
# 결과값:2433.19$, 예측값 :2078.14$
# 결과값:2224.06$, 예측값 :2454.51$
# 결과값:1997.22$, 예측값 :1757.60$
# 결과값:1820.01$, 예측값 :1237.28$
# 결과값:2351.54$, 예측값 :1992.76$
# 결과값:1526.92$, 예측값 :1310.20$
# 결과값:2142.72$, 예측값 :1443.01$
# 결과값:2033.30$, 예측값 :1824.49$
# 결과값:1539.81$, 예측값 :1747.24$
# 결과값:2289.70$, 예측값 :2185.48$
# 결과값:2132.05$, 예측값 :1852.19$
# 결과값:15690.71$, 예측값 :10575.52$
# 결과값:1960.60$, 예측값 :1591.82$
# 결과값:1690.88$, 예측값 :1138.03$
# 결과값:981.55$, 예측값 :1142.74$
# 결과값:1702.79$, 예측값 :1466.17$
# 결과값:1328.48$, 예측값 :1231.32$
# 결과값:3144.12$, 예측값 :2358.37$
# 결과값:1521.54$, 예측값 :1332.99$
# 결과값:2842.98$, 예측값 :2380.30$
# 결과값:1985.15$, 예측값 :2200.13$
# 결과값:5301.59$, 예측값 :4093.56$
# 결과값:6582.87$, 예측값 :4663.09$
# 결과값:1969.73$, 예측값 :1582.82$
# 결과값:1244.88$, 예측값 :1040.53$
# 결과값:1169.48$, 예측값 :1080.95$
# 결과값:1516.30$, 예측값 :1495.79$
# 결과값:1445.12$, 예측값 :1478.31$
# 결과값:2109.38$, 예측값 :1894.69$
# 결과값:2207.90$, 예측값 :1656.65$
# 결과값:1127.41$, 예측값 :1189.85$
# 결과값:1036.88$, 예측값 :763.82$
# 결과값:1589.66$, 예측값 :1378.84$
# 결과값:1983.34$, 예측값 :1802.76$
# 결과값:2916.55$, 예측값 :3066.26$
# 결과값:1950.57$, 예측값 :1809.05$
# 결과값:1871.82$, 예측값 :1687.43$
# 결과값:1034.31$, 예측값 :671.44$
# 결과값:1682.97$, 예측값 :1292.36$
# 결과값:1748.16$, 예측값 :1409.78$
# 결과값:869.83$, 예측값 :1165.13$
# 결과값:1698.66$, 예측값 :1525.48$
# 결과값:1452.81$, 예측값 :1043.65$
# 결과값:2028.12$, 예측값 :1864.00$
# 결과값:15861.09$, 예측값 :9400.42$
# 결과값:2058.47$, 예측값 :1802.29$
# 결과값:2108.86$, 예측값 :1967.21$
# 결과값:2404.99$, 예측값 :1920.22$
# 결과값:1749.78$, 예측값 :1518.45$
# 결과값:1682.56$, 예측값 :1145.50$
# 결과값:1004.74$, 예측값 :1052.83$
# 결과값:1458.30$, 예측값 :1328.94$
# 결과값:920.12$, 예측값 :1026.39$
# 결과값:1739.08$, 예측값 :1521.44$
# 결과값:1547.25$, 예측값 :1370.08$
# 결과값:2088.44$, 예측값 :1962.38$
# 결과값:904.35$, 예측값 :634.15$
# 결과값:2058.82$, 예측값 :1613.83$
# 결과값:2337.00$, 예측값 :1887.27$
# 결과값:967.71$, 예측값 :1117.82$
# 결과값:2239.27$, 예측값 :1766.46$
# 결과값:2088.42$, 예측값 :1887.36$
# 결과값:1277.78$, 예측값 :1382.12$
# 결과값:3680.92$, 예측값 :3000.83$
# 결과값:1056.91$, 예측값 :1105.37$
# 결과값:2083.08$, 예측값 :1806.65$
# 결과값:1534.37$, 예측값 :1185.83$
# 결과값:1472.04$, 예측값 :1601.65$
# 결과값:3188.48$, 예측값 :2498.62$
# 결과값:1582.12$, 예측값 :1256.73$
# 결과값:4346.65$, 예측값 :3273.70$
# 결과값:1177.26$, 예측값 :1079.86$
# 결과값:2081.18$, 예측값 :2173.44$
# 결과값:1400.65$, 예측값 :1514.77$
# 결과값:1731.56$, 예측값 :1494.83$
# 결과값:3723.50$, 예측값 :3121.70$
# 결과값:1011.84$, 예측값 :1227.47$
# 결과값:2292.30$, 예측값 :1971.41$
# 결과값:1013.41$, 예측값 :950.72$
# 결과값:1963.14$, 예측값 :1946.11$
# 결과값:1864.64$, 예측값 :1557.48$
# 결과값:1551.61$, 예측값 :1223.07$
# 결과값:2081.08$, 예측값 :1880.47$
# 결과값:1041.78$, 예측값 :656.29$
# 결과값:2053.78$, 예측값 :1548.27$
# 결과값:1401.35$, 예측값 :1375.62$
# 결과값:1740.70$, 예측값 :1706.00$
# 결과값:1650.45$, 예측값 :1073.53$
# 결과값:969.43$, 예측값 :1169.56$
# 결과값:2171.12$, 예측값 :1105.20$
# 결과값:1149.61$, 예측값 :999.56$
# 결과값:2111.03$, 예측값 :1875.06$
# 결과값:1855.11$, 예측값 :1942.19$
# 결과값:1285.89$, 예측값 :1363.05$
# 결과값:1351.32$, 예측값 :1219.25$
# 결과값:13636.68$, 예측값 :9020.64$
# 결과값:1877.74$, 예측값 :1690.44$
# 결과값:1987.62$, 예측값 :1671.13$
# 결과값:2344.89$, 예측값 :1862.76$
# 결과값:1481.62$, 예측값 :1679.26$
# 결과값:1529.25$, 예측값 :1748.75$
# 결과값:1481.75$, 예측값 :1440.57$
# 결과값:1521.07$, 예측값 :1361.39$
# 결과값:2081.72$, 예측값 :1800.02$
# 결과값:1641.28$, 예측값 :1351.20$
# 결과값:2053.24$, 예측값 :1751.98$
# 결과값:2106.75$, 예측값 :2020.15$
# 결과값:2077.81$, 예측값 :2004.37$
# 결과값:1445.12$, 예측값 :1247.71$
# 결과값:2076.27$, 예측값 :1755.23$
# 결과값:2045.18$, 예측값 :1959.28$
# 결과값:2096.53$, 예측값 :1852.72$
# 결과값:896.75$, 예측값 :801.14$
# 결과값:2111.38$, 예측값 :1828.71$
# 결과값:1690.32$, 예측값 :1231.94$
# 결과값:1158.55$, 예측값 :882.85$
# 결과값:977.53$, 예측값 :995.19$
# 결과값:2078.29$, 예측값 :1808.34$
# 결과값:2103.41$, 예측값 :1935.65$
# 결과값:2922.70$, 예측값 :2382.72$
# 결과값:1254.22$, 예측값 :1109.61$
# 결과값:1939.42$, 예측값 :1635.38$
# 결과값:3638.36$, 예측값 :4451.80$
# 결과값:2087.35$, 예측값 :2081.04$
# 결과값:1330.50$, 예측값 :1489.78$
# 결과값:1268.26$, 예측값 :1321.67$
# 결과값:2006.69$, 예측값 :1521.40$
# 결과값:1624.24$, 예측값 :1514.56$
# 결과값:1148.44$, 예측값 :1114.41$
# 결과값:2323.78$, 예측값 :2066.38$
# 결과값:926.93$, 예측값 :944.33$
# 결과값:1310.61$, 예측값 :875.89$
# 결과값:1029.67$, 예측값 :992.04$
# 결과값:800.42$, 예측값 :489.18$
# 결과값:2291.34$, 예측값 :2055.59$
# 결과값:1816.83$, 예측값 :1449.23$
# 결과값:2016.71$, 예측값 :2134.11$
# 결과값:2087.81$, 예측값 :1935.12$
# 결과값:960.48$, 예측값 :401.21$
# 결과값:2859.51$, 예측값 :2208.04$
# 결과값:2551.36$, 예측값 :1972.07$
# 결과값:1660.78$, 예측값 :1526.02$
# 결과값:2087.15$, 예측값 :1446.38$
# 결과값:896.04$, 예측값 :1427.94$
# 결과값:2902.28$, 예측값 :2535.96$
# 결과값:1139.50$, 예측값 :990.54$
# 결과값:985.51$, 예측값 :1030.85$
# 결과값:1025.51$, 예측값 :1038.08$
# 결과값:2099.21$, 예측값 :1629.00$
# 결과값:1169.31$, 예측값 :984.18$
# 결과값:2081.29$, 예측값 :1851.32$
# 결과값:1352.05$, 예측값 :1127.91$
# 결과값:1729.82$, 예측값 :1568.63$
# 결과값:798.10$, 예측값 :691.00$
# 결과값:2012.64$, 예측값 :1650.60$
# 결과값:1371.25$, 예측값 :937.34$
# 결과값:1138.43$, 예측값 :995.03$
# 결과값:2026.66$, 예측값 :1739.40$
# 결과값:1437.21$, 예측값 :1400.01$
# 결과값:2059.28$, 예측값 :1548.82$
# 결과값:1057.44$, 예측값 :976.40$
# 결과값:3447.56$, 예측값 :2543.31$
# 결과값:2050.77$, 예측값 :2146.98$
# 결과값:2077.03$, 예측값 :1725.04$
# 결과값:2052.06$, 예측값 :1896.51$
# 결과값:2448.26$, 예측값 :2172.67$
# 결과값:1150.79$, 예측값 :1064.83$
# 결과값:1497.46$, 예측값 :1433.94$
# 결과값:1186.09$, 예측값 :1084.20$
# 결과값:2040.02$, 예측값 :1802.67$
# 결과값:1434.83$, 예측값 :1270.72$
# 결과값:963.03$, 예측값 :1064.57$
# 결과값:2080.00$, 예측값 :1929.29$
# 결과값:1142.49$, 예측값 :1009.78$
# 결과값:4131.98$, 예측값 :3276.98$
# 결과값:1946.14$, 예측값 :1494.06$
# 결과값:2083.08$, 예측값 :1837.62$
# 결과값:1352.98$, 예측값 :1023.04$
# 결과값:2055.24$, 예측값 :1837.14$
# 결과값:1131.49$, 예측값 :1042.58$
# 결과값:1411.99$, 예측값 :1224.05$
# 결과값:1273.53$, 예측값 :1119.65$
# 결과값:2405.80$, 예측값 :1321.01$
# 결과값:1658.80$, 예측값 :1600.74$
# 결과값:2322.91$, 예측값 :1513.20$
# 결과값:1465.23$, 예측값 :1319.09$
# 결과값:1950.45$, 예측값 :1681.69$
# 결과값:1088.41$, 예측값 :1201.02$
# 결과값:2109.38$, 예측값 :1765.17$
# 결과값:2207.81$, 예측값 :1812.69$
# 결과값:1472.67$, 예측값 :1323.84$
# 결과값:2680.12$, 예측값 :1576.99$
# 결과값:1697.27$, 예측값 :1607.73$
# 결과값:2489.86$, 예측값 :2018.38$
# 결과값:2032.24$, 예측값 :1652.59$
# 결과값:1241.42$, 예측값 :937.93$
# 결과값:927.00$, 예측값 :828.41$
# 결과값:1055.84$, 예측값 :999.21$
# 결과값:1310.78$, 예측값 :980.98$
# 결과값:2550.82$, 예측값 :1997.63$
# 결과값:1973.18$, 예측값 :1753.65$
# 결과값:2024.71$, 예측값 :1764.76$
# 결과값:1481.75$, 예측값 :1485.24$
# 결과값:1420.53$, 예측값 :1225.58$
# 결과값:973.58$, 예측값 :892.65$
# 결과값:840.96$, 예측값 :1001.93$
# 결과값:2042.45$, 예측값 :1918.91$
# 결과값:1973.69$, 예측값 :1395.90$
# 결과값:1320.36$, 예측값 :1194.35$
# 결과값:1275.95$, 예측값 :991.90$
# 결과값:903.31$, 예측값 :1081.73$
# 결과값:1985.09$, 예측값 :1556.77$
# 결과값:1423.99$, 예측값 :1289.81$
# 결과값:2079.65$, 예측값 :1889.92$
# 결과값:2106.04$, 예측값 :1882.02$
# 결과값:2435.56$, 예측값 :2358.04$
# 결과값:972.97$, 예측값 :933.88$
# 결과값:2552.97$, 예측값 :1991.48$
# 결과값:4447.63$, 예측값 :2695.03$
# 결과값:1658.89$, 예측값 :1656.11$
# 결과값:1974.76$, 예측값 :1619.47$
# 결과값:1985.18$, 예측값 :1791.50$
# 결과값:2043.82$, 예측값 :1895.67$
# 결과값:2039.59$, 예측값 :2035.01$
# 결과값:3535.96$, 예측값 :2502.57$
# 결과값:1191.82$, 예측값 :1075.78$
# 결과값:2095.57$, 예측값 :1910.11$
# 결과값:2528.23$, 예측값 :2085.73$
# 결과값:6087.78$, 예측값 :3554.17$
# 결과값:2352.55$, 예측값 :1709.33$
# 결과값:2084.78$, 예측값 :1915.12$
# 결과값:1035.13$, 예측값 :1206.23$
# 결과값:2062.70$, 예측값 :1780.25$
# 결과값:2340.48$, 예측값 :1707.22$
# 결과값:2323.53$, 예측값 :1982.74$
# 결과값:2186.89$, 예측값 :1668.48$
# 결과값:2018.05$, 예측값 :1743.02$
# 결과값:1082.46$, 예측값 :926.55$
# 결과값:1133.52$, 예측값 :1180.64$
# 결과값:2366.05$, 예측값 :1891.17$
# 결과값:1520.66$, 예측값 :1395.42$
# 결과값:1869.33$, 예측값 :1588.98$
# 결과값:4322.60$, 예측값 :3502.68$
# 결과값:1431.11$, 예측값 :1159.47$
# 결과값:1275.51$, 예측값 :1094.45$
# 결과값:897.69$, 예측값 :1071.49$
# 결과값:2030.87$, 예측값 :1684.95$
# 결과값:3842.37$, 예측값 :3174.03$
# 결과값:1684.09$, 예측값 :1914.07$
# 결과값:815.59$, 예측값 :910.97$
# 결과값:2435.50$, 예측값 :2332.64$
# 결과값:1527.02$, 예측값 :1357.53$
# 결과값:1412.05$, 예측값 :1014.41$
# 결과값:1161.37$, 예측값 :1001.36$
# 결과값:11502.51$, 예측값 :6819.90$
# 결과값:891.17$, 예측값 :1047.07$
# 결과값:837.95$, 예측값 :1043.24$
# 결과값:848.60$, 예측값 :736.54$
# 결과값:1271.45$, 예측값 :1226.86$
# 결과값:1816.14$, 예측값 :1511.81$
# 결과값:1042.07$, 예측값 :1150.02$
# 결과값:1532.20$, 예측값 :1387.75$
# 결과값:1262.89$, 예측값 :1074.05$
# 결과값:2147.80$, 예측값 :2218.50$
# 결과값:1454.46$, 예측값 :1488.42$
# 결과값:788.23$, 예측값 :1045.85$
# 결과값:1533.86$, 예측값 :1254.58$
# 결과값:1435.74$, 예측값 :1188.79$
# 결과값:1118.81$, 예측값 :975.83$
# 결과값:1036.71$, 예측값 :983.68$
# 결과값:1092.72$, 예측값 :560.02$
# 결과값:1440.44$, 예측값 :1369.33$
# 결과값:1788.05$, 예측값 :1504.51$
# 결과값:1113.76$, 예측값 :1132.90$
# 결과값:2352.70$, 예측값 :1790.81$
# 결과값:2018.05$, 예측값 :1776.83$
# 결과값:1256.62$, 예측값 :1129.27$
# 결과값:1591.14$, 예측값 :1380.89$
# 결과값:923.13$, 예측값 :837.70$
# 결과값:1984.99$, 예측값 :1304.55$
# 결과값:2344.01$, 예측값 :2102.96$
# 결과값:2073.83$, 예측값 :1856.48$
# 결과값:3064.20$, 예측값 :2503.54$
# 결과값:6495.53$, 예측값 :4265.70$
# 결과값:3631.94$, 예측값 :2989.34$
# 결과값:1700.64$, 예측값 :1296.94$
# 결과값:975.06$, 예측값 :956.27$
# 결과값:2551.31$, 예측값 :2351.96$
# 결과값:2054.53$, 예측값 :1741.31$
# 결과값:9433.00$, 예측값 :7577.29$
# 결과값:974.56$, 예측값 :1046.56$
# 결과값:974.29$, 예측값 :856.80$
# 결과값:967.36$, 예측값 :1175.19$
# 결과값:2071.31$, 예측값 :1828.97$
# 결과값:2098.28$, 예측값 :2105.16$
# 결과값:1016.45$, 예측값 :820.61$
# 결과값:1251.53$, 예측값 :986.35$
# 결과값:1131.49$, 예측값 :1026.87$
# 결과값:999.50$, 예측값 :907.12$
# 결과값:1199.60$, 예측값 :1002.53$
# 결과값:3590.27$, 예측값 :2690.91$
# 결과값:2082.93$, 예측값 :1907.06$
# 결과값:2236.75$, 예측값 :1895.80$
# 결과값:896.41$, 예측값 :980.02$
# 결과값:2088.84$, 예측값 :2021.08$
# 결과값:2040.60$, 예측값 :1840.72$
# 결과값:2304.07$, 예측값 :2095.02$
# 결과값:2028.12$, 예측값 :1698.70$
# 결과값:1800.49$, 예측값 :2795.32$
# 결과값:901.16$, 예측값 :1209.19$
# 결과값:3522.97$, 예측값 :2771.46$
# 결과값:6851.88$, 예측값 :5152.33$
# 결과값:984.66$, 예측값 :902.59$
# 결과값:1109.43$, 예측값 :1091.17$
# 결과값:1704.97$, 예측값 :1608.09$
# 결과값:1108.13$, 예측값 :895.60$
# 결과값:1035.72$, 예측값 :788.74$
# 결과값:1679.27$, 예측값 :1341.60$
# 결과값:2078.07$, 예측값 :1771.43$
# 결과값:1462.32$, 예측값 :1174.36$
# 결과값:1423.32$, 예측값 :1054.58$
# 결과값:1999.88$, 예측값 :1470.31$
# 결과값:2091.23$, 예측값 :1957.26$
# 결과값:2006.08$, 예측값 :1666.22$
# 결과값:2111.79$, 예측값 :1784.24$
# 결과값:1013.41$, 예측값 :929.57$
# 결과값:1969.86$, 예측값 :1853.50$
# 결과값:962.62$, 예측값 :974.27$
# 결과값:1312.12$, 예측값 :1129.18$
# 결과값:1836.29$, 예측값 :1366.33$
# 결과값:1116.84$, 예측값 :1034.94$
# 결과값:1328.87$, 예측값 :1260.14$
# 결과값:2006.18$, 예측값 :1790.92$
# 결과값:2023.92$, 예측값 :1910.11$
# 결과값:1741.58$, 예측값 :1372.84$
# 결과값:2448.26$, 예측값 :1993.03$
# 결과값:3180.61$, 예측값 :2592.61$
# 결과값:2056.05$, 예측값 :1708.02$
# 결과값:1158.73$, 예측값 :1148.45$
# 결과값:1055.95$, 예측값 :1149.25$
# 결과값:1800.96$, 예측값 :1573.11$
# 결과값:3196.62$, 예측값 :2476.59$
# 결과값:2152.06$, 예측값 :1707.93$
# 결과값:1153.52$, 예측값 :1251.62$
# 결과값:2448.28$, 예측값 :2219.68$
# 결과값:1538.95$, 예측값 :1473.06$
# 결과값:816.68$, 예측값 :824.99$
# 결과값:1596.26$, 예측값 :1427.29$
# 결과값:2798.33$, 예측값 :2208.93$
# 결과값:1538.75$, 예측값 :1300.73$
# 결과값:3915.77$, 예측값 :2934.56$
# 결과값:890.14$, 예측값 :1125.17$
# 결과값:2053.49$, 예측값 :1802.11$
# 결과값:822.22$, 예측값 :975.58$
# 결과값:2508.11$, 예측값 :1966.96$
# 결과값:1246.32$, 예측값 :917.39$
# 결과값:956.74$, 예측값 :1036.61$
# 결과값:808.53$, 예측값 :1053.14$
# 결과값:7289.18$, 예측값 :5047.69$
# 결과값:6889.54$, 예측값 :5058.27$
# 결과값:840.96$, 예측값 :852.99$
# 결과값:7142.75$, 예측값 :5397.94$
# 결과값:1426.36$, 예측값 :1201.52$
# 결과값:1002.83$, 예측값 :631.97$
# 결과값:18073.74$, 예측값 :12771.19$
# 결과값:2074.51$, 예측값 :1978.06$
# 결과값:2004.48$, 예측값 :1544.35$
# 결과값:967.10$, 예측값 :696.32$
# 결과값:2053.92$, 예측값 :2038.28$
# 결과값:1090.32$, 예측값 :989.05$
# 결과값:3539.54$, 예측값 :1620.43$
# 결과값:1833.75$, 예측값 :1623.65$
# 결과값:1582.23$, 예측값 :1395.43$
# 결과값:1447.35$, 예측값 :1163.72$
# 결과값:1984.99$, 예측값 :1920.25$
# 결과값:1155.32$, 예측값 :1069.75$
# 결과값:3849.88$, 예측값 :3027.38$
# 결과값:3621.08$, 예측값 :3091.89$
# 결과값:2041.52$, 예측값 :1901.45$
# 결과값:1650.76$, 예측값 :1487.83$
# 결과값:2551.50$, 예측값 :2182.90$
# 결과값:1659.65$, 예측값 :1224.82$
# 결과값:2069.27$, 예측값 :2121.27$
# 결과값:2197.98$, 예측값 :2021.22$
# 결과값:1311.39$, 예측값 :1121.49$
# 결과값:1441.23$, 예측값 :1325.19$
# 결과값:1867.55$, 예측값 :1629.64$
# 결과값:1022.80$, 예측값 :1061.40$
# 결과값:6548.07$, 예측값 :4379.47$
# 결과값:4338.46$, 예측값 :3331.29$
# 결과값:5248.91$, 예측값 :3563.30$
# 결과값:2064.10$, 예측값 :1997.90$
# 결과값:1283.05$, 예측값 :992.64$
# 결과값:2010.47$, 예측값 :1639.03$
# 결과값:1275.76$, 예측값 :1293.76$
# 결과값:3653.05$, 예측값 :2814.13$
# 결과값:1175.14$, 예측값 :1039.40$
# 결과값:1150.05$, 예측값 :1047.93$
# 결과값:2024.71$, 예측값 :1818.62$
# 결과값:836.89$, 예측값 :827.71$
# 결과값:1150.93$, 예측값 :1355.57$
# 결과값:1594.88$, 예측값 :1085.07$
# 결과값:1199.94$, 예측값 :1091.78$
# 결과값:891.80$, 예측값 :850.44$
# 결과값:6518.33$, 예측값 :4457.30$
# 결과값:2075.66$, 예측값 :1882.26$
# 결과값:1056.96$, 예측값 :991.07$
# 결과값:1434.83$, 예측값 :1250.38$
# 결과값:1978.20$, 예측값 :1334.62$
# 결과값:1959.99$, 예측값 :1611.81$
# 결과값:974.29$, 예측값 :1059.80$
# 결과값:1867.55$, 예측값 :1372.65$
# 결과값:1514.71$, 예측값 :1538.33$
# 결과값:1978.02$, 예측값 :1738.55$
# 결과값:2327.93$, 예측값 :1931.56$
# 결과값:1822.02$, 예측값 :1518.44$
# 결과값:974.84$, 예측값 :626.32$
# 결과값:1819.56$, 예측값 :1845.17$
# 결과값:1043.24$, 예측값 :1251.66$
# 결과값:815.15$, 예측값 :646.20$
# 결과값:1814.98$, 예측값 :1450.18$
# 결과값:9393.72$, 예측값 :6273.60$
# 결과값:2019.55$, 예측값 :1525.48$
# 결과값:1082.68$, 예측값 :988.82$
# 결과값:1085.42$, 예측값 :1080.52$
# 결과값:2987.38$, 예측값 :2485.04$
# 결과값:1302.04$, 예측값 :1128.23$
# 결과값:1404.71$, 예측값 :2257.73$
# 결과값:2082.57$, 예측값 :1869.70$
# 결과값:937.26$, 예측값 :434.26$
# 결과값:1301.11$, 예측값 :1352.57$
# 결과값:1030.22$, 예측값 :1178.52$
# 결과값:1067.13$, 예측값 :920.89$
# 결과값:1118.85$, 예측값 :854.53$
# 결과값:1152.66$, 예측값 :1095.99$
# 결과값:1445.41$, 예측값 :1218.73$
# 결과값:2083.65$, 예측값 :1861.35$
# 결과값:1369.69$, 예측값 :1213.59$
# 결과값:1416.14$, 예측값 :1017.49$
# 결과값:1954.96$, 예측값 :1521.35$
# 결과값:1263.38$, 예측값 :1194.72$
# 결과값:1542.95$, 예측값 :1301.08$
# 결과값:1940.92$, 예측값 :1658.55$
# 결과값:1973.48$, 예측값 :1747.65$
# 결과값:1931.69$, 예측값 :1357.21$
# 결과값:2047.50$, 예측값 :1962.34$
# 결과값:2105.76$, 예측값 :1913.74$
# 결과값:1044.18$, 예측값 :1213.83$
# 결과값:1465.15$, 예측값 :1271.43$
# 결과값:1276.25$, 예측값 :1302.04$
# 결과값:1430.75$, 예측값 :1294.26$
# 결과값:1041.78$, 예측값 :1267.01$
# 결과값:1061.61$, 예측값 :796.19$
# 결과값:981.47$, 예측값 :525.57$
# 결과값:1020.11$, 예측값 :774.12$
# 결과값:16014.16$, 예측값 :9726.73$
# 결과값:2113.36$, 예측값 :1864.81$
# 결과값:2197.80$, 예측값 :1409.55$
# 결과값:1329.20$, 예측값 :1347.42$
# 결과값:1183.00$, 예측값 :1221.04$
# 결과값:1066.63$, 예측값 :958.85$
# 결과값:807.58$, 예측값 :522.90$
# 결과값:1926.62$, 예측값 :1673.01$
# 결과값:1520.79$, 예측값 :1186.43$
# 결과값:2146.49$, 예측값 :1551.84$
# 결과값:944.42$, 예측값 :738.06$
# 결과값:1099.75$, 예측값 :918.76$
# 결과값:1975.38$, 예측값 :1837.04$
# 결과값:1033.10$, 예측값 :783.10$
# 결과값:1401.03$, 예측값 :1306.32$
# 결과값:2154.55$, 예측값 :1765.74$
# 결과값:1591.15$, 예측값 :1437.85$
# 결과값:1075.21$, 예측값 :1188.91$
# 결과값:2928.00$, 예측값 :2250.73$
# 결과값:1400.33$, 예측값 :1262.11$
# 결과값:2490.50$, 예측값 :1905.33$
# 결과값:6927.96$, 예측값 :4095.89$
# 결과값:1646.55$, 예측값 :1411.91$
# 결과값:3215.28$, 예측값 :2631.53$
# 결과값:1985.77$, 예측값 :1668.71$
# 결과값:1261.41$, 예측값 :1211.55$
# 결과값:1697.93$, 예측값 :1634.67$
# 결과값:1746.62$, 예측값 :1568.04$
# 결과값:6206.88$, 예측값 :4295.40$
# 결과값:2068.92$, 예측값 :1837.32$
# 결과값:2111.82$, 예측값 :1999.46$
# 결과값:1596.87$, 예측값 :1383.14$
# 결과값:3814.51$, 예측값 :2861.07$
# 결과값:2017.02$, 예측값 :1809.50$
# 결과값:1311.58$, 예측값 :1270.49$
# 결과값:4092.27$, 예측값 :3823.65$
# 결과값:1536.74$, 예측값 :1552.19$
# 결과값:6840.40$, 예측값 :5672.04$
# 결과값:1191.53$, 예측값 :1119.42$
# 결과값:1437.68$, 예측값 :947.51$
# 결과값:2092.25$, 예측값 :1777.55$
# 결과값:1156.79$, 예측값 :1021.12$
# 결과값:1241.81$, 예측값 :1067.31$
# 결과값:2243.65$, 예측값 :1386.15$
# 결과값:15845.90$, 예측값 :11537.22$
# 결과값:2551.49$, 예측값 :2016.17$
# 결과값:1863.44$, 예측값 :1699.58$
# 결과값:6879.87$, 예측값 :4314.35$
# 결과값:1767.01$, 예측값 :1297.87$
# 결과값:1470.58$, 예측값 :1310.60$
# 결과값:2921.58$, 예측값 :2613.21$
# 결과값:952.99$, 예측값 :641.53$
# 결과값:2077.03$, 예측값 :1796.43$
# 결과값:1202.55$, 예측값 :884.68$
# 결과값:1041.65$, 예측값 :912.85$
# 결과값:1038.25$, 예측값 :498.68$
# 결과값:5247.17$, 예측값 :3286.91$
# 결과값:1871.54$, 예측값 :1915.57$
# 결과값:1124.39$, 예측값 :875.03$
# 결과값:1973.90$, 예측값 :2014.90$
# 결과값:2568.80$, 예측값 :1915.52$
# 결과값:932.20$, 예측값 :1072.88$
# 결과값:13559.94$, 예측값 :7875.60$
# 결과값:1066.14$, 예측값 :1133.34$
# 결과값:3365.27$, 예측값 :2728.62$
# 결과값:1645.30$, 예측값 :1367.84$
# 결과값:2059.40$, 예측값 :1697.03$
# 결과값:2070.33$, 예측값 :1501.08$
# 결과값:771.13$, 예측값 :625.64$
# 결과값:1804.92$, 예측값 :1607.59$
# 결과값:2039.54$, 예측값 :1944.40$
# 결과값:1187.06$, 예측값 :1040.14$
# 결과값:2038.84$, 예측값 :1711.16$
# 결과값:1867.39$, 예측값 :1647.70$
# 결과값:2057.65$, 예측값 :1820.13$
# 결과값:2043.41$, 예측값 :1690.41$
# 결과값:9383.95$, 예측값 :6064.07$
# 결과값:2348.26$, 예측값 :1808.84$
# 결과값:2112.50$, 예측값 :1436.27$
# 결과값:5959.52$, 예측값 :3747.69$
# 결과값:2248.78$, 예측값 :1597.45$
# 결과값:1739.86$, 예측값 :1495.29$
# 결과값:1985.92$, 예측값 :1595.55$
# 결과값:2135.66$, 예측값 :1622.57$
# 결과값:2108.97$, 예측값 :2112.57$
# 결과값:1983.44$, 예측값 :1072.82$
# 결과값:2353.97$, 예측값 :2087.60$
# 결과값:1212.10$, 예측값 :1035.67$
# 결과값:921.66$, 예측값 :886.36$
# 결과값:2100.82$, 예측값 :1536.35$
# 결과값:982.40$, 예측값 :567.75$
# 결과값:900.28$, 예측값 :979.22$
# 결과값:2684.81$, 예측값 :2300.07$
# 결과값:844.75$, 예측값 :836.69$
# 결과값:882.52$, 예측값 :893.57$
# 결과값:2074.89$, 예측값 :1768.47$
# 결과값:2003.66$, 예측값 :1802.10$
# 결과값:5430.25$, 예측값 :3738.00$
# 결과값:2092.25$, 예측값 :1803.51$
# 결과값:1548.18$, 예측값 :1370.54$
# 결과값:6176.57$, 예측값 :4363.29$
# 결과값:2092.26$, 예측값 :1793.04$
# 결과값:2008.37$, 예측값 :1761.11$
# 결과값:993.04$, 예측값 :1140.14$
# 결과값:1970.44$, 예측값 :1857.80$
# 결과값:2737.06$, 예측값 :2691.39$
# 결과값:1022.45$, 예측값 :1066.79$
# 결과값:1137.81$, 예측값 :1088.85$
# 결과값:2602.91$, 예측값 :2160.45$
# 결과값:2353.27$, 예측값 :2231.21$
# 결과값:2344.10$, 예측값 :1310.59$
# 결과값:1310.14$, 예측값 :1015.14$
# 결과값:942.67$, 예측값 :983.85$
# 결과값:2323.97$, 예측값 :1969.62$
# 결과값:1424.75$, 예측값 :1268.39$
# 결과값:39944.72$, 예측값 :28506.25$
# 결과값:1392.90$, 예측값 :640.48$
# 결과값:1465.73$, 예측값 :1404.14$
# 결과값:5325.26$, 예측값 :3931.06$
# 결과값:2106.75$, 예측값 :1936.08$
# 결과값:3053.85$, 예측값 :2898.12$
# 결과값:1106.65$, 예측값 :1113.99$
# 결과값:1697.79$, 예측값 :1556.48$
# 결과값:1865.76$, 예측값 :1612.79$
# 결과값:1862.50$, 예측값 :1490.96$
# 결과값:2685.07$, 예측값 :2146.43$
# 결과값:2348.41$, 예측값 :1730.88$
# 결과값:2080.42$, 예측값 :1814.63$
# 결과값:1047.87$, 예측값 :963.82$
# 결과값:798.73$, 예측값 :886.69$
# 결과값:1495.95$, 예측값 :1365.16$
# 결과값:4805.37$, 예측값 :4032.46$
# 결과값:4379.85$, 예측값 :3625.74$
# 결과값:2331.00$, 예측값 :2030.26$
# 결과값:1651.44$, 예측값 :1471.39$
# 결과값:2076.37$, 예측값 :1516.09$
# 결과값:3536.54$, 예측값 :2952.92$
# 결과값:2289.26$, 예측값 :1590.94$
# 결과값:1674.78$, 예측값 :1771.19$
# 결과값:1920.85$, 예측값 :1574.47$
# 결과값:2048.33$, 예측값 :1510.41$
# 결과값:1693.38$, 예측값 :1565.76$
# 결과값:925.63$, 예측값 :421.04$
# 결과값:2106.20$, 예측값 :1942.67$
# 결과값:1652.03$, 예측값 :1257.19$
# 결과값:2433.77$, 예측값 :2711.80$
# 결과값:1032.64$, 예측값 :1064.63$
# 결과값:1812.78$, 예측값 :1488.89$
# 결과값:1155.94$, 예측값 :1187.60$
# 결과값:1529.30$, 예측값 :1323.93$
# 결과값:1935.12$, 예측값 :1597.51$
# 결과값:2007.94$, 예측값 :1407.11$
# 결과값:2321.01$, 예측값 :1668.17$
# 결과값:1682.51$, 예측값 :1435.04$
# 결과값:794.30$, 예측값 :694.85$
# 결과값:899.27$, 예측값 :907.33$
# 결과값:2935.14$, 예측값 :1960.29$
# 결과값:2060.11$, 예측값 :1809.35$
# 결과값:2069.27$, 예측값 :2091.43$
# 결과값:2784.64$, 예측값 :2334.02$
# 결과값:1983.44$, 예측값 :1832.55$
# 결과값:1522.10$, 예측값 :2203.32$
# 결과값:1202.65$, 예측값 :853.03$
# 결과값:2077.03$, 예측값 :1843.15$
# 결과값:2447.64$, 예측값 :1767.43$
# 결과값:1043.17$, 예측값 :843.62$
# 결과값:2178.56$, 예측값 :1871.05$
# 결과값:1932.33$, 예측값 :1549.83$
# 결과값:927.17$, 예측값 :641.39$
# 결과값:900.77$, 예측값 :875.81$
# 결과값:1325.01$, 예측값 :1338.29$
# 결과값:1058.18$, 예측값 :985.67$
# 결과값:770.27$, 예측값 :724.44$
# 결과값:1182.43$, 예측값 :982.60$
# 결과값:1137.03$, 예측값 :593.05$
# 결과값:2095.82$, 예측값 :1793.14$
# 결과값:2067.16$, 예측값 :1234.58$
# 결과값:2583.70$, 예측값 :2207.04$
# 결과값:2179.46$, 예측값 :1859.89$
# 결과값:2470.85$, 예측값 :1890.76$
# 결과값:1738.17$, 예측값 :1454.19$
# 결과값:1786.50$, 예측값 :1356.01$
# 결과값:1505.69$, 예측값 :1078.87$
# 결과값:3424.50$, 예측값 :3011.58$
# 결과값:2111.99$, 예측값 :1988.46$
# 결과값:2983.04$, 예측값 :2377.58$
# 결과값:2045.27$, 예측값 :1904.55$
# 결과값:1985.09$, 예측값 :1679.78$
# 결과값:2448.49$, 예측값 :1808.54$
# 결과값:1086.40$, 예측값 :904.30$
# 결과값:2048.45$, 예측값 :1896.69$
# 결과값:1303.27$, 예측값 :1229.11$
# 결과값:1522.55$, 예측값 :1347.05$
# 결과값:964.69$, 예측값 :928.77$
# 결과값:925.63$, 예측값 :1040.89$
# 결과값:15608.70$, 예측값 :9137.21$
# 결과값:981.59$, 예측값 :1000.49$
# 결과값:1528.47$, 예측값 :1087.12$
# 결과값:1969.85$, 예측값 :1823.15$
# 결과값:986.28$, 예측값 :603.64$
# 결과값:2350.94$, 예측값 :2226.32$
# 결과값:1534.52$, 예측값 :1415.59$
# 결과값:2072.41$, 예측값 :2203.11$
# 결과값:1114.08$, 예측값 :831.39$
# 결과값:2067.33$, 예측값 :1963.11$
# 결과값:1462.86$, 예측값 :1316.10$
# 결과값:2462.49$, 예측값 :1755.35$
# 결과값:1691.91$, 예측값 :1424.03$
# 결과값:2237.49$, 예측값 :1907.30$
# 결과값:2332.28$, 예측값 :1938.92$
# 결과값:1661.83$, 예측값 :1235.08$
# 결과값:1521.83$, 예측값 :1441.51$
# 결과값:6514.30$, 예측값 :4952.27$
# 결과값:2623.10$, 예측값 :1817.77$
# 결과값:1162.92$, 예측값 :504.20$
# 결과값:926.91$, 예측값 :671.35$
# 결과값:2991.07$, 예측값 :2392.42$
# 결과값:1505.96$, 예측값 :1404.27$
# 결과값:788.23$, 예측값 :752.82$
# 결과값:3136.03$, 예측값 :2055.86$
# 결과값:906.85$, 예측값 :1011.96$
# 결과값:2046.52$, 예측값 :1894.47$
# 결과값:973.91$, 예측값 :1031.18$
# 결과값:2038.02$, 예측값 :1822.17$
# 결과값:2070.68$, 예측값 :1844.11$
# 결과값:1450.97$, 예측값 :1240.78$
# 결과값:2618.67$, 예측값 :2279.31$
# 결과값:3443.55$, 예측값 :2757.48$
# 결과값:1172.20$, 예측값 :941.80$
# 결과값:3436.68$, 예측값 :2687.11$
# 결과값:1014.76$, 예측값 :1091.07$
# 결과값:1329.24$, 예측값 :1545.21$
# 결과값:1281.90$, 예측값 :1183.65$
# 결과값:1143.79$, 예측값 :1267.57$
# 결과값:1156.91$, 예측값 :973.58$
# 결과값:2111.87$, 예측값 :2028.89$
# 결과값:1948.74$, 예측값 :1720.36$
# 결과값:1065.38$, 예측값 :983.24$
# 결과값:2232.52$, 예측값 :1805.66$
# 결과값:983.07$, 예측값 :1178.03$
# 결과값:1404.24$, 예측값 :1277.76$
# 결과값:1638.40$, 예측값 :1300.06$
# 결과값:1985.09$, 예측값 :1772.95$
# 결과값:1997.25$, 예측값 :1462.24$
# 결과값:2112.65$, 예측값 :1866.55$
# 결과값:2043.41$, 예측값 :1589.64$
# 결과값:3660.36$, 예측값 :2862.88$
# 결과값:1661.42$, 예측값 :1564.66$
# 결과값:3368.06$, 예측값 :2641.16$
# 결과값:2039.46$, 예측값 :1268.40$
# 결과값:1658.89$, 예측값 :1409.26$
# 결과값:6151.30$, 예측값 :4356.52$
# 결과값:2043.45$, 예측값 :1716.41$
# 결과값:2049.33$, 예측값 :1827.02$
# 결과값:1096.52$, 예측값 :1083.61$
# 결과값:1137.56$, 예측값 :858.01$
# 결과값:2567.05$, 예측값 :1860.91$
# 결과값:1185.06$, 예측값 :1108.72$
# 결과값:1290.11$, 예측값 :1173.61$
# 결과값:884.61$, 예측값 :849.27$
# 결과값:1163.62$, 예측값 :856.46$
# 결과값:2064.17$, 예측값 :1917.02$
# 결과값:1922.38$, 예측값 :1579.29$
# 결과값:1030.12$, 예측값 :1074.90$
# 결과값:2106.80$, 예측값 :1594.18$
# 결과값:1965.57$, 예측값 :2040.65$
# 결과값:1123.26$, 예측값 :517.75$
# 결과값:2096.03$, 예측값 :1965.60$
# 결과값:1520.79$, 예측값 :1585.64$
# 결과값:16247.87$, 예측값 :10388.85$
# 결과값:1328.87$, 예측값 :1380.39$
# 결과값:1013.53$, 예측값 :856.03$
# 결과값:2030.54$, 예측값 :2174.32$
# 결과값:1521.54$, 예측값 :1384.78$
# 결과값:1123.92$, 예측값 :976.58$
# 결과값:1324.32$, 예측값 :1181.35$
# 결과값:1424.37$, 예측값 :1246.51$
# 결과값:1105.46$, 예측값 :1170.02$
# 결과값:4837.05$, 예측값 :2976.98$
# 결과값:30949.54$, 예측값 :23861.35$
# 결과값:1486.18$, 예측값 :926.44$
# 결과값:1082.31$, 예측값 :654.44$
# 결과값:1499.35$, 예측값 :1254.99$
# 결과값:2108.58$, 예측값 :1864.46$
# 결과값:1889.32$, 예측값 :1521.01$
# 결과값:1013.49$, 예측값 :467.71$
# 결과값:1448.04$, 예측값 :1266.56$
# 결과값:2054.93$, 예측값 :1768.91$
# 결과값:1316.56$, 예측값 :1109.38$
# 결과값:1539.81$, 예측값 :1421.10$
# 결과값:2106.28$, 예측값 :1879.28$
# 결과값:1973.69$, 예측값 :1594.68$
# 결과값:1875.93$, 예측값 :1682.73$
# 결과값:2095.41$, 예측값 :1835.90$
# 결과값:2095.55$, 예측값 :1214.00$
# 결과값:1858.32$, 예측값 :1521.65$
# 결과값:1989.32$, 예측값 :1476.56$
# 결과값:2762.63$, 예측값 :2054.21$
# 결과값:1977.98$, 예측값 :1880.42$
# 결과값:1339.21$, 예측값 :1474.64$
# 결과값:1407.77$, 예측값 :1038.75$
# 결과값:1801.59$, 예측값 :1577.32$
# 결과값:2682.54$, 예측값 :1958.47$
# 결과값:2038.02$, 예측값 :2094.24$
# 결과값:900.97$, 예측값 :864.89$
# 결과값:1161.20$, 예측값 :910.57$
# 결과값:16740.69$, 예측값 :10194.66$
# 결과값:765.12$, 예측값 :1046.16$
# 결과값:3212.69$, 예측값 :2509.44$
# 결과값:1151.31$, 예측값 :928.96$
# 결과값:1109.50$, 예측값 :1200.18$
# 결과값:2034.32$, 예측값 :1839.25$
# 결과값:1750.21$, 예측값 :1701.08$
# 결과값:2046.73$, 예측값 :1601.49$
# 결과값:1934.17$, 예측값 :1736.64$
# 결과값:1975.07$, 예측값 :1616.33$
# 결과값:2351.87$, 예측값 :1682.72$
# 결과값:2046.62$, 예측값 :1746.74$
# 결과값:1807.95$, 예측값 :1567.08$
# 결과값:1041.90$, 예측값 :853.07$
# 결과값:1370.67$, 예측값 :1227.47$
# 결과값:1481.34$, 예측값 :1453.63$
# 결과값:1751.36$, 예측값 :1755.58$
# 결과값:2061.11$, 예측값 :1555.64$
# 결과값:2352.56$, 예측값 :1904.54$
# 결과값:900.77$, 예측값 :862.16$
# 결과값:2041.08$, 예측값 :1812.83$
# 결과값:2116.08$, 예측값 :1751.06$
# 결과값:5976.89$, 예측값 :4608.47$
# 결과값:1930.93$, 예측값 :1663.45$
# 결과값:904.35$, 예측값 :915.72$
# 결과값:1013.39$, 예측값 :1077.60$
# 결과값:1533.73$, 예측값 :1278.67$
# 결과값:2080.00$, 예측값 :1982.77$
# 결과값:1369.42$, 예측값 :1117.42$
# 결과값:1770.93$, 예측값 :1453.80$
# 결과값:1761.66$, 예측값 :1197.60$
# 결과값:2606.31$, 예측값 :2081.69$
# 결과값:2097.14$, 예측값 :1836.50$
# 결과값:1516.10$, 예측값 :1546.64$
# 결과값:1100.09$, 예측값 :765.63$
# 결과값:2330.97$, 예측값 :2133.82$
# 결과값:998.71$, 예측값 :784.00$
# 결과값:1108.64$, 예측값 :1083.09$
# 결과값:1354.60$, 예측값 :1325.20$
# 결과값:2283.52$, 예측값 :1475.34$
# 결과값:1013.39$, 예측값 :882.03$
# 결과값:1100.09$, 예측값 :1072.48$
# 결과값:2470.92$, 예측값 :1982.37$
# 결과값:2111.21$, 예측값 :1823.82$
# 결과값:9588.25$, 예측값 :6185.31$
# 결과값:1324.17$, 예측값 :1276.47$
# 결과값:1136.46$, 예측값 :923.93$
# 결과값:1283.94$, 예측값 :951.98$
# 결과값:882.52$, 예측값 :926.39$
# 결과값:74875.06$, 예측값 :48811.09$
# 결과값:2150.69$, 예측값 :1684.65$
# 결과값:2051.74$, 예측값 :1694.96$
# 결과값:1261.48$, 예측값 :1048.93$
# 결과값:1205.70$, 예측값 :988.12$
# 결과값:1123.34$, 예측값 :1145.81$
# 결과값:3572.14$, 예측값 :3159.09$
# 결과값:8003.01$, 예측값 :6085.96$
# 결과값:2031.45$, 예측값 :1730.95$
# 결과값:1051.28$, 예측값 :741.24$
# 결과값:1107.00$, 예측값 :1081.06$
# 결과값:927.71$, 예측값 :1053.46$
# 결과값:1315.73$, 예측값 :1254.13$
# 결과값:1139.08$, 예측값 :969.74$
# 결과값:2568.50$, 예측값 :2355.01$
# 결과값:9350.66$, 예측값 :5907.92$
# 결과값:4805.29$, 예측값 :3353.42$
# 결과값:5963.12$, 예측값 :4477.28$
# 결과값:1693.38$, 예측값 :1607.25$
# 결과값:2526.48$, 예측값 :2277.66$
# 결과값:1988.57$, 예측값 :1917.38$
# 결과값:1403.36$, 예측값 :1465.03$
# 결과값:803.80$, 예측값 :809.17$
# 결과값:5385.14$, 예측값 :3220.99$
# 결과값:1651.20$, 예측값 :1324.86$
# 결과값:3303.52$, 예측값 :2618.05$
# 결과값:7272.31$, 예측값 :5609.64$
# 결과값:1039.76$, 예측값 :964.78$
# 결과값:1014.30$, 예측값 :896.21$
# 결과값:2107.75$, 예측값 :1887.15$
# 결과값:1680.01$, 예측값 :1477.34$
# 결과값:1065.76$, 예측값 :902.39$
# 결과값:6824.22$, 예측값 :4615.24$
# 결과값:2078.40$, 예측값 :1826.25$
# 결과값:2304.07$, 예측값 :1847.67$
# 결과값:1268.18$, 예측값 :1218.28$
# 결과값:1176.27$, 예측값 :1113.54$
# 결과값:2090.50$, 예측값 :1802.17$
# 결과값:1192.45$, 예측값 :1020.66$
# 결과값:7974.06$, 예측값 :5409.89$
# 결과값:6560.13$, 예측값 :5417.50$
# 결과값:902.81$, 예측값 :992.32$
# 결과값:1681.45$, 예측값 :1600.49$
# 결과값:2088.15$, 예측값 :1762.55$
# 결과값:1960.60$, 예측값 :1568.10$
# 결과값:4429.69$, 예측값 :3431.05$
# 결과값:3343.19$, 예측값 :2591.42$
# 결과값:2296.49$, 예측값 :2068.52$
# 결과값:7832.91$, 예측값 :5057.71$
# 결과값:1790.56$, 예측값 :1571.43$
# 결과값:2191.89$, 예측값 :1677.32$
# 결과값:975.35$, 예측값 :802.85$
# 결과값:4143.10$, 예측값 :3547.04$
# 결과값:1646.18$, 예측값 :1529.30$
# 결과값:1418.92$, 예측값 :1233.84$
# 결과값:1968.16$, 예측값 :1833.12$
# 결과값:1445.12$, 예측값 :1406.23$
# 결과값:2110.84$, 예측값 :1839.65$
# 결과값:1942.06$, 예측값 :1391.66$
# 결과값:1020.96$, 예측값 :1204.36$
# 결과값:2020.70$, 예측값 :1711.58$
# 결과값:1588.74$, 예측값 :1224.01$
# 결과값:1275.49$, 예측값 :1187.80$
# 결과값:1366.53$, 예측값 :1272.84$
# 결과값:2048.36$, 예측값 :1803.86$
# 결과값:1678.34$, 예측값 :1444.52$
# 결과값:3560.20$, 예측값 :2711.67$
# 결과값:1023.48$, 예측값 :1081.64$
# 결과값:1587.13$, 예측값 :1554.68$
# 결과값:2017.05$, 예측값 :1814.47$
# 결과값:2291.32$, 예측값 :1900.72$
# 결과값:2868.84$, 예측값 :2128.01$
# 결과값:1122.21$, 예측값 :863.82$
# 결과값:1678.34$, 예측값 :1578.11$
# 결과값:1430.74$, 예측값 :1086.76$
# 결과값:2058.50$, 예측값 :1876.27$
# 결과값:2257.43$, 예측값 :1622.92$
# 결과값:2524.34$, 예측값 :1989.85$
# 결과값:1502.60$, 예측값 :1338.60$
# 결과값:1749.91$, 예측값 :1418.06$
# 결과값:1281.19$, 예측값 :1059.98$
# 결과값:3381.53$, 예측값 :2654.07$
# 결과값:2105.05$, 예측값 :1781.67$
# 결과값:1939.41$, 예측값 :1493.57$
# 결과값:1022.45$, 예측값 :1054.57$
# 결과값:3684.33$, 예측값 :3214.75$
# 결과값:1056.18$, 예측값 :1017.32$
# 결과값:2100.82$, 예측값 :1319.13$
# 결과값:2302.77$, 예측값 :1493.76$
# 결과값:1663.21$, 예측값 :1516.11$
# 결과값:829.28$, 예측값 :707.01$
# 결과값:2098.28$, 예측값 :1896.43$
# 결과값:2399.32$, 예측값 :2114.90$
# 결과값:1822.67$, 예측값 :1480.17$
# 결과값:1438.34$, 예측값 :1417.84$
# 결과값:1141.12$, 예측값 :985.37$
# 결과값:1307.33$, 예측값 :1496.85$
# 결과값:1399.79$, 예측값 :1384.82$
# 결과값:2447.48$, 예측값 :2010.06$
# 결과값:1041.78$, 예측값 :850.19$
# 결과값:1260.01$, 예측값 :1465.31$
# 결과값:1295.14$, 예측값 :954.02$
# 결과값:2072.04$, 예측값 :1864.85$
# 결과값:1025.40$, 예측값 :1021.49$
# 결과값:4994.60$, 예측값 :3556.83$
# 결과값:3856.69$, 예측값 :2809.55$
# 결과값:1815.26$, 예측값 :1622.85$
# 결과값:1472.64$, 예측값 :1213.58$
# 결과값:2859.30$, 예측값 :2351.13$
# 결과값:1659.46$, 예측값 :1258.11$
# 결과값:1812.12$, 예측값 :1493.93$
# 결과값:1256.73$, 예측값 :851.72$
# 결과값:1091.99$, 예측값 :1079.83$
# 결과값:1650.32$, 예측값 :1430.85$
# 결과값:718.92$, 예측값 :459.42$
# 결과값:2085.19$, 예측값 :1890.53$
# 결과값:1267.50$, 예측값 :1140.76$
# 결과값:3728.59$, 예측값 :2602.36$
# 결과값:2097.03$, 예측값 :1895.80$
# 결과값:1478.33$, 예측값 :943.26$
# 결과값:2292.32$, 예측값 :1762.75$
# 결과값:1682.51$, 예측값 :1430.52$
# 결과값:2119.75$, 예측값 :1705.34$
# 결과값:1548.04$, 예측값 :1333.64$
# 결과값:1822.02$, 예측값 :1505.64$
# 결과값:1978.20$, 예측값 :1503.76$
# 결과값:884.06$, 예측값 :834.38$
# 결과값:3000.90$, 예측값 :2274.27$
# 결과값:2143.77$, 예측값 :1752.59$
# 결과값:1034.63$, 예측값 :1541.25$
# 결과값:1123.92$, 예측값 :1226.13$
# 결과값:2683.59$, 예측값 :1587.30$
# 결과값:3187.67$, 예측값 :2369.99$
# 결과값:2063.00$, 예측값 :1943.43$
# 결과값:972.70$, 예측값 :1088.10$
# 결과값:1612.64$, 예측값 :1280.03$
# 결과값:1880.89$, 예측값 :1699.73$
# 결과값:1748.11$, 예측값 :1456.84$
# 결과값:1137.37$, 예측값 :1145.11$
# 결과값:1094.53$, 예측값 :943.84$
# 결과값:1140.11$, 예측값 :811.39$
# 결과값:2070.35$, 예측값 :1794.73$
# 결과값:2187.19$, 예측값 :2101.17$
# 결과값:1518.90$, 예측값 :1393.38$
# 결과값:2104.83$, 예측값 :1800.17$
# 결과값:2358.80$, 예측값 :1460.25$
# 결과값:1311.20$, 예측값 :1351.04$
# 결과값:2473.38$, 예측값 :2179.09$
# 결과값:799.39$, 예측값 :741.70$
# 결과값:6068.45$, 예측값 :4768.45$
# 결과값:2097.38$, 예측값 :2021.95$
# 결과값:1920.30$, 예측값 :1889.71$
# 결과값:1370.49$, 예측값 :1145.04$
# 결과값:1621.42$, 예측값 :1473.11$
# 결과값:1592.88$, 예측값 :1402.28$
# 결과값:1652.03$, 예측값 :1170.14$
# 결과값:1170.60$, 예측값 :1306.86$
# 결과값:6151.17$, 예측값 :4132.24$
# 결과값:3650.01$, 예측값 :2518.99$
# 결과값:2105.06$, 예측값 :1785.99$
# 결과값:2448.27$, 예측값 :1778.92$
# 결과값:1324.67$, 예측값 :1304.92$
# 결과값:1507.62$, 예측값 :1397.73$
# 결과값:993.74$, 예측값 :1098.57$
# 결과값:3286.48$, 예측값 :2718.76$
# 결과값:2053.39$, 예측값 :1875.56$
# 결과값:786.98$, 예측값 :527.92$
# 결과값:1114.99$, 예측값 :1064.93$
# 결과값:3561.17$, 예측값 :2491.03$
# 결과값:1535.06$, 예측값 :1113.15$
# 결과값:1579.27$, 예측값 :1355.24$
# 결과값:2177.16$, 예측값 :1679.56$
# 결과값:926.46$, 예측값 :945.97$
# 결과값:1647.77$, 예측값 :1454.78$
# 결과값:1802.15$, 예측값 :1298.46$
# 결과값:2028.32$, 예측값 :1762.84$
# 결과값:2478.69$, 예측값 :1874.96$
# 결과값:1058.38$, 예측값 :955.03$
# 결과값:850.12$, 예측값 :860.39$
# 결과값:1446.78$, 예측값 :1539.33$
# 결과값:2901.56$, 예측값 :2082.23$
# 결과값:3221.83$, 예측값 :2661.87$
# 결과값:2517.03$, 예측값 :2372.40$
# 결과값:1984.06$, 예측값 :1930.72$
# 결과값:1042.80$, 예측값 :965.67$
# 결과값:1445.29$, 예측값 :1332.56$
# 결과값:1761.98$, 예측값 :1624.74$
# 결과값:1990.74$, 예측값 :1655.20$
# 결과값:3825.69$, 예측값 :3524.11$
# 결과값:2099.32$, 예측값 :2027.34$
# 결과값:2059.67$, 예측값 :1715.92$
# 결과값:924.28$, 예측값 :791.46$
# 결과값:6056.16$, 예측값 :3826.30$
# 결과값:2927.66$, 예측값 :2520.05$
# 결과값:2028.19$, 예측값 :1479.61$
# 결과값:3471.87$, 예측값 :2840.04$
# 결과값:4813.17$, 예측값 :3499.87$
# 결과값:1406.96$, 예측값 :1130.21$
# 결과값:7283.46$, 예측값 :4175.29$
# ...
# 결과값:2081.59$, 예측값 :1887.12$
# 결과값:1975.38$, 예측값 :1737.46$
# 결과값:1029.21$, 예측값 :1037.33$
# 결과값:1822.67$, 예측값 :1748.17$
# 결과값:2368.37$, 예측값 :1943.46$
# 결과값:1373.97$, 예측값 :1072.08$
# 결과값:2099.91$, 예측값 :1869.88$
# 결과값:1022.48$, 예측값 :927.36$
# 결과값:1257.36$, 예측값 :1195.49$
# 결과값:2064.13$, 예측값 :1820.71$
# 결과값:9578.57$, 예측값 :5371.38$
# 결과값:5425.03$, 예측값 :4177.09$
# 결과값:1136.10$, 예측값 :1241.68$
# 결과값:1173.57$, 예측값 :1099.05$
# 결과값:2078.77$, 예측값 :1537.24$
# 결과값:2896.80$, 예측값 :2559.53$
# 결과값:2936.02$, 예측값 :2160.57$
# 결과값:1322.72$, 예측값 :1239.98$
# 결과값:1279.60$, 예측값 :1213.00$
# 결과값:1646.69$, 예측값 :1390.46$
# 결과값:1400.22$, 예측값 :1240.95$
# 결과값:1183.09$, 예측값 :1150.88$
# 결과값:2080.00$, 예측값 :1668.34$
# 결과값:2240.16$, 예측값 :1905.46$
# 결과값:2105.06$, 예측값 :1653.57$
# 결과값:1824.49$, 예측값 :1437.69$
# 결과값:3404.80$, 예측값 :2675.29$
# 결과값:2528.05$, 예측값 :2161.23$
# 결과값:1318.95$, 예측값 :1313.03$
# 결과값:2802.49$, 예측값 :2242.17$
# 결과값:1044.25$, 예측값 :645.28$
# 결과값:1124.75$, 예측값 :1314.22$
# 결과값:1099.26$, 예측값 :820.31$
# 결과값:2041.33$, 예측값 :1876.54$
# 결과값:3475.48$, 예측값 :2507.86$
# 결과값:2237.86$, 예측값 :1930.12$
# 결과값:1876.49$, 예측값 :1462.08$
# 결과값:1259.09$, 예측값 :1090.89$
# 결과값:30806.38$, 예측값 :21318.04$
# 결과값:2006.89$, 예측값 :1500.99$
# 결과값:1263.99$, 예측값 :1214.20$
# 결과값:1255.45$, 예측값 :1151.96$
# 결과값:1058.97$, 예측값 :1136.14$
# 결과값:1199.98$, 예측값 :1002.85$
# 결과값:2319.32$, 예측값 :1889.34$
# 결과값:1678.34$, 예측값 :1289.02$
# 결과값:1282.25$, 예측값 :1135.65$
# 결과값:1382.12$, 예측값 :1255.30$
# 결과값:4854.47$, 예측값 :2909.20$
# 결과값:2619.95$, 예측값 :2203.33$
# 결과값:1972.25$, 예측값 :1622.39$
# 결과값:2109.47$, 예측값 :1686.13$
# 결과값:2030.90$, 예측값 :1934.04$
# 결과값:4134.35$, 예측값 :2677.41$
# 결과값:781.64$, 예측값 :660.06$
# 결과값:13019.69$, 예측값 :8991.53$
# 결과값:2090.03$, 예측값 :1524.47$
# 결과값:974.30$, 예측값 :901.95$
# 결과값:2073.85$, 예측값 :1891.95$
# 결과값:1739.01$, 예측값 :1405.23$
# 결과값:1403.92$, 예측값 :1321.77$
# 결과값:2033.09$, 예측값 :1961.99$
# 결과값:941.03$, 예측값 :946.94$
# 결과값:1367.58$, 예측값 :1165.65$
# 결과값:4362.47$, 예측값 :3374.98$
# 결과값:1425.46$, 예측값 :1010.96$
# 결과값:2854.70$, 예측값 :2793.79$
# 결과값:1974.55$, 예측값 :1707.77$
# 결과값:2061.76$, 예측값 :1891.89$
# 결과값:2361.12$, 예측값 :1799.07$
# 결과값:2053.39$, 예측값 :1167.47$
# 결과값:1164.21$, 예측값 :977.27$
# 결과값:923.72$, 예측값 :520.41$
# 결과값:1477.31$, 예측값 :957.18$
# 결과값:811.49$, 예측값 :645.21$
# 결과값:2016.74$, 예측값 :2003.65$
# 결과값:1162.09$, 예측값 :947.88$
# 결과값:899.94$, 예측값 :1004.48$
# 결과값:1283.86$, 예측값 :1050.02$
# 결과값:1624.24$, 예측값 :1312.66$
# 결과값:1984.04$, 예측값 :1813.34$
# 결과값:2077.03$, 예측값 :1673.12$
# 결과값:2104.08$, 예측값 :1494.74$
# 결과값:2301.83$, 예측값 :1799.19$
# 결과값:1628.78$, 예측값 :1536.89$
# 결과값:1276.14$, 예측값 :1374.91$
# 결과값:2034.00$, 예측값 :1830.65$
# 결과값:1535.38$, 예측값 :927.87$
# 결과값:2254.49$, 예측값 :1928.48$
# 결과값:960.77$, 예측값 :2389.17$
# 결과값:1526.21$, 예측값 :1098.81$
# 결과값:1264.05$, 예측값 :1034.83$
# 결과값:984.43$, 예측값 :1016.77$
# 결과값:1299.08$, 예측값 :1352.59$
# 결과값:1028.45$, 예측값 :1064.98$
# 결과값:2527.95$, 예측값 :2053.88$
# 결과값:925.17$, 예측값 :622.90$
# 결과값:1920.08$, 예측값 :1846.22$
# 결과값:2257.32$, 예측값 :1883.39$
# 결과값:1027.54$, 예측값 :1153.96$
# 결과값:858.18$, 예측값 :832.93$
# 결과값:2094.84$, 예측값 :1806.56$
# 결과값:1212.64$, 예측값 :1087.60$
# 결과값:1025.00$, 예측값 :978.04$
# 결과값:1201.96$, 예측값 :1035.09$
# 결과값:2838.02$, 예측값 :2379.79$
# 결과값:2059.12$, 예측값 :1825.25$
# 결과값:1013.32$, 예측값 :883.98$
# 결과값:1158.58$, 예측값 :1235.03$
# 결과값:2369.66$, 예측값 :1877.05$
# 결과값:1291.89$, 예측값 :1144.84$
# 결과값:2103.90$, 예측값 :1932.55$
# 결과값:3644.99$, 예측값 :2991.25$
# 결과값:1214.05$, 예측값 :1296.46$
# 결과값:2011.95$, 예측값 :1626.27$
# 결과값:923.08$, 예측값 :943.60$
# 결과값:1008.24$, 예측값 :1067.06$
# 결과값:3792.23$, 예측값 :2978.32$
# 결과값:2623.08$, 예측값 :2120.92$
# 결과값:1660.54$, 예측값 :1107.05$
# 결과값:12892.04$, 예측값 :8790.94$
# 결과값:2447.17$, 예측값 :1812.04$
# 결과값:1158.58$, 예측값 :1074.49$
# 결과값:2077.87$, 예측값 :1850.51$
# 결과값:3138.17$, 예측값 :2365.86$
# 결과값:895.21$, 예측값 :985.99$
# 결과값:924.67$, 예측값 :902.74$
# 결과값:1925.69$, 예측값 :1472.27$
# 결과값:2080.06$, 예측값 :1647.93$
# 결과값:3466.30$, 예측값 :2697.24$
# 결과값:1301.98$, 예측값 :1134.06$
# 결과값:3684.67$, 예측값 :3173.58$
# 결과값:984.98$, 예측값 :979.05$
# 결과값:1036.87$, 예측값 :1048.53$
# 결과값:1408.65$, 예측값 :1028.93$
# 결과값:3425.25$, 예측값 :3219.65$
# 결과값:1099.23$, 예측값 :958.25$
# 결과값:3779.11$, 예측값 :2787.55$
# 결과값:1985.09$, 예측값 :1886.06$
# 결과값:2096.50$, 예측값 :1470.26$
# 결과값:1560.02$, 예측값 :1341.99$
# 결과값:3198.96$, 예측값 :3745.88$
# 결과값:1619.99$, 예측값 :1448.66$
# 결과값:2078.18$, 예측값 :1711.08$
# 결과값:1702.24$, 예측값 :1423.74$
# 결과값:2217.08$, 예측값 :1673.86$
# 결과값:1801.69$, 예측값 :1427.70$
# 결과값:2028.32$, 예측값 :1761.45$
# 결과값:2296.25$, 예측값 :1730.85$
# 결과값:2099.14$, 예측값 :1908.77$
# 결과값:1788.02$, 예측값 :1404.82$
# 결과값:2040.31$, 예측값 :1706.50$
# 결과값:1541.82$, 예측값 :1335.26$
# 결과값:1147.19$, 예측값 :1200.75$
# 결과값:1147.23$, 예측값 :1154.62$
# 결과값:2053.24$, 예측값 :1805.16$
# 결과값:1939.31$, 예측값 :1354.06$
# 결과값:1800.70$, 예측값 :1428.33$
# 결과값:2105.75$, 예측값 :1993.12$
# 결과값:3051.67$, 예측값 :2762.89$
# 결과값:1013.39$, 예측값 :927.65$
# 결과값:1144.57$, 예측값 :1187.40$
# 결과값:1143.35$, 예측값 :1012.28$
# 결과값:975.81$, 예측값 :1113.55$
# 결과값:1799.95$, 예측값 :1537.23$
# 결과값:2040.02$, 예측값 :1765.36$
# 결과값:1292.63$, 예측값 :1071.70$
# 결과값:1951.16$, 예측값 :1665.46$
# 결과값:2044.56$, 예측값 :1875.81$
# 결과값:2117.68$, 예측값 :1578.48$
# 결과값:1798.51$, 예측값 :1763.43$
# 결과값:1180.03$, 예측값 :1234.77$
# 결과값:2200.95$, 예측값 :1701.83$
# 결과값:1284.91$, 예측값 :832.13$
# 결과값:2131.11$, 예측값 :1601.66$
# 결과값:3641.97$, 예측값 :2642.27$
# 결과값:1143.99$, 예측값 :957.84$
# 결과값:2080.00$, 예측값 :1761.12$
# 결과값:2109.38$, 예측값 :1775.87$
# 결과값:1800.96$, 예측값 :1311.45$
# 결과값:1880.65$, 예측값 :1905.44$
# 결과값:1442.43$, 예측값 :1418.18$
# 결과값:2319.63$, 예측값 :2023.58$
# 결과값:2098.47$, 예측값 :1808.16$
# 결과값:1304.75$, 예측값 :1160.06$
# 결과값:2447.64$, 예측값 :2318.27$
# 결과값:2106.80$, 예측값 :2032.21$
# 결과값:2350.90$, 예측값 :2070.76$
# 결과값:1983.20$, 예측값 :1526.81$
# 결과값:1398.81$, 예측값 :1478.79$
# 결과값:1647.77$, 예측값 :1483.70$
# 결과값:1530.53$, 예측값 :1476.91$
# 결과값:1534.72$, 예측값 :1326.23$
# 결과값:1451.69$, 예측값 :1336.06$
# 결과값:1817.02$, 예측값 :1524.55$
# 결과값:1309.48$, 예측값 :957.09$
# 결과값:2539.38$, 예측값 :2225.45$
# 결과값:2032.29$, 예측값 :1737.89$
# 결과값:2084.40$, 예측값 :1235.04$
# 결과값:1773.52$, 예측값 :1248.63$
# 결과값:1155.23$, 예측값 :1056.05$
# 결과값:2379.12$, 예측값 :2089.88$
# 결과값:1135.41$, 예측값 :877.61$
# 결과값:2092.21$, 예측값 :1891.06$
# 결과값:1550.50$, 예측값 :1366.95$
# 결과값:966.24$, 예측값 :855.98$
# 결과값:1985.46$, 예측값 :1811.52$
# 결과값:5000.80$, 예측값 :3984.25$
# 결과값:1516.09$, 예측값 :1371.19$
# 결과값:1069.70$, 예측값 :854.95$
# 결과값:1155.28$, 예측값 :893.16$
# 결과값:2095.77$, 예측값 :1694.22$
# 결과값:1274.08$, 예측값 :1257.60$
# 결과값:895.73$, 예측값 :273.05$
# 결과값:2560.39$, 예측값 :2300.42$
# 결과값:1621.94$, 예측값 :1548.25$
# 결과값:1975.35$, 예측값 :1784.05$
# 결과값:2350.89$, 예측값 :2054.20$
# 결과값:2100.75$, 예측값 :1875.84$
# 결과값:927.73$, 예측값 :909.33$
# 결과값:1033.64$, 예측값 :990.93$
# 결과값:1433.29$, 예측값 :1346.02$
# 결과값:2708.48$, 예측값 :2319.07$
# 결과값:2336.97$, 예측값 :1683.84$
# 결과값:971.75$, 예측값 :458.70$
# 결과값:15769.57$, 예측값 :10509.15$
# 결과값:925.61$, 예측값 :791.78$
# 결과값:1099.85$, 예측값 :1070.21$
# 결과값:1307.12$, 예측값 :1162.53$
# 결과값:2304.00$, 예측값 :1918.75$
# 결과값:2716.99$, 예측값 :2753.06$
# 결과값:1675.40$, 예측값 :2993.10$
# 결과값:1029.62$, 예측값 :888.39$
# 결과값:1125.39$, 예측값 :1052.83$
# 결과값:1628.99$, 예측값 :1289.68$
# 결과값:2057.14$, 예측값 :1701.78$
# 결과값:1180.63$, 예측값 :1168.60$
# 결과값:974.29$, 예측값 :1280.45$
# 결과값:1281.83$, 예측값 :1121.68$
# 결과값:2053.79$, 예측값 :1625.46$
# 결과값:1865.76$, 예측값 :1568.78$
# 결과값:2057.77$, 예측값 :1496.65$
# 결과값:1091.99$, 예측값 :1087.38$
# 결과값:1674.71$, 예측값 :1469.45$
# 결과값:2045.02$, 예측값 :1484.64$
# 결과값:1496.80$, 예측값 :1426.20$
# 결과값:1555.32$, 예측값 :1233.74$
# 결과값:1089.90$, 예측값 :958.22$
# 결과값:2344.61$, 예측값 :1957.28$
# 결과값:2355.76$, 예측값 :1793.40$
# 결과값:864.27$, 예측값 :666.64$
# 결과값:1291.50$, 예측값 :1092.34$
# 결과값:2030.57$, 예측값 :1820.41$
# 결과값:1312.26$, 예측값 :1364.89$
# 결과값:1792.38$, 예측값 :1597.78$
# 결과값:1404.00$, 예측값 :1168.98$
# 결과값:1543.82$, 예측값 :1083.92$
# 결과값:1681.58$, 예측값 :1556.81$
# 결과값:2352.62$, 예측값 :1950.15$
# 결과값:1034.28$, 예측값 :975.06$
# 결과값:952.28$, 예측값 :1021.57$
# 결과값:1263.48$, 예측값 :1052.47$
# 결과값:6012.71$, 예측값 :4219.59$
# 결과값:2597.79$, 예측값 :2183.49$
# 결과값:2447.07$, 예측값 :2104.87$
# 결과값:1143.64$, 예측값 :922.27$
# 결과값:832.33$, 예측값 :812.48$
# 결과값:1508.15$, 예측값 :1506.05$
# 결과값:1659.80$, 예측값 :1663.28$
# 결과값:1041.82$, 예측값 :720.11$
# 결과값:1620.97$, 예측값 :1333.52$
# 결과값:2147.95$, 예측값 :1987.31$
# 결과값:981.38$, 예측값 :656.70$
# 결과값:1453.40$, 예측값 :1039.13$
# 결과값:2550.85$, 예측값 :2096.89$
# 결과값:1729.82$, 예측값 :1519.78$
# 결과값:3778.83$, 예측값 :2998.46$
# 결과값:1134.55$, 예측값 :1329.36$
# 결과값:1097.99$, 예측값 :945.98$
# 결과값:3830.65$, 예측값 :2857.90$
# 결과값:2315.40$, 예측값 :1947.21$
# 결과값:1793.75$, 예측값 :1379.75$
# 결과값:2088.62$, 예측값 :1701.67$
# 결과값:1319.66$, 예측값 :1248.46$
# 결과값:2358.48$, 예측값 :1898.42$
# 결과값:1567.03$, 예측값 :2586.96$
# 결과값:804.49$, 예측값 :485.53$
# 결과값:1014.00$, 예측값 :769.68$
# 결과값:1743.37$, 예측값 :1468.60$
# 결과값:2067.78$, 예측값 :1797.62$
# 결과값:2244.08$, 예측값 :1699.75$
# 결과값:7225.17$, 예측값 :5230.40$
# 결과값:1789.27$, 예측값 :1371.23$
# 결과값:1162.86$, 예측값 :1001.46$
# 결과값:1973.83$, 예측값 :1849.40$
# 결과값:2567.32$, 예측값 :2114.34$
# 결과값:1037.24$, 예측값 :876.48$
# 결과값:1264.81$, 예측값 :1184.91$
# 결과값:924.26$, 예측값 :476.92$
# 결과값:1402.39$, 예측값 :1424.19$
# 결과값:1978.08$, 예측값 :1986.98$
# 결과값:13643.46$, 예측값 :9339.20$
# 결과값:1433.27$, 예측값 :1425.59$
# 결과값:9641.69$, 예측값 :6025.68$
# 결과값:2048.21$, 예측값 :1819.35$
# 결과값:1366.03$, 예측값 :1248.19$
# 결과값:1761.90$, 예측값 :1532.46$
# 결과값:1960.08$, 예측값 :1535.78$
# 결과값:1303.67$, 예측값 :2443.23$
# 결과값:1862.45$, 예측값 :1479.47$
# 결과값:2108.90$, 예측값 :1844.25$
# 결과값:1421.51$, 예측값 :1136.63$
# 결과값:2079.00$, 예측값 :1440.25$
# 결과값:1978.20$, 예측값 :1298.42$
# 결과값:38597.36$, 예측값 :26334.03$
# 결과값:1329.02$, 예측값 :1022.25$
# 결과값:2044.12$, 예측값 :1593.97$
# 결과값:1081.85$, 예측값 :967.03$
# 결과값:1309.56$, 예측값 :1095.97$
# 결과값:1143.79$, 예측값 :995.86$
# 결과값:2283.34$, 예측값 :2091.91$
# 결과값:1034.63$, 예측값 :596.74$
# 결과값:1042.22$, 예측값 :1017.24$
# 결과값:1984.06$, 예측값 :2056.36$
# 결과값:2088.70$, 예측값 :1951.01$
# 결과값:1426.87$, 예측값 :1164.89$
# 결과값:1066.91$, 예측값 :833.87$
# 결과값:5348.66$, 예측값 :4067.04$
# 결과값:794.37$, 예측값 :900.57$
# 결과값:1127.50$, 예측값 :963.90$
# 결과값:1526.90$, 예측값 :1532.12$
# 결과값:1969.05$, 예측값 :1442.23$
# 결과값:2035.27$, 예측값 :1697.27$
# 결과값:1103.42$, 예측값 :1187.75$
# 결과값:3546.35$, 예측값 :3459.70$
# 결과값:2957.87$, 예측값 :2331.21$
# 결과값:2074.96$, 예측값 :1795.12$
# 결과값:1286.93$, 예측값 :1199.93$
# 결과값:1458.27$, 예측값 :1306.48$
# 결과값:935.25$, 예측값 :702.45$
# 결과값:979.81$, 예측값 :1291.16$
# 결과값:1322.34$, 예측값 :1256.75$
# 결과값:2046.41$, 예측값 :1805.73$
# 결과값:3193.78$, 예측값 :2625.37$
# 결과값:11445.17$, 예측값 :6759.76$
# 결과값:1329.32$, 예측값 :1210.39$
# 결과값:1808.53$, 예측값 :1577.10$
# 결과값:1055.39$, 예측값 :914.24$
# 결과값:2067.07$, 예측값 :1831.41$
# 결과값:2455.65$, 예측값 :2326.86$
# 결과값:1106.04$, 예측값 :1043.33$
# 결과값:2237.73$, 예측값 :1862.26$
# 결과값:1879.42$, 예측값 :1628.40$
# 결과값:1087.94$, 예측값 :1059.10$
# 결과값:1047.87$, 예측값 :1050.83$
# 결과값:1473.68$, 예측값 :1063.23$
# 결과값:1400.93$, 예측값 :1082.31$
# 결과값:3539.38$, 예측값 :3312.59$
# 결과값:1670.45$, 예측값 :1435.33$
# 결과값:1124.91$, 예측값 :1054.83$
# 결과값:1984.03$, 예측값 :1777.21$
# 결과값:4396.73$, 예측값 :3380.00$
# 결과값:15503.29$, 예측값 :10454.48$
# 결과값:1508.36$, 예측값 :1056.23$
# 결과값:1326.11$, 예측값 :931.37$
# 결과값:1065.24$, 예측값 :1150.77$
# 결과값:4838.19$, 예측값 :3559.46$
# 결과값:7255.43$, 예측값 :4354.31$
# 결과값:1013.85$, 예측값 :645.66$
# 결과값:2187.06$, 예측값 :1819.02$
# 결과값:1292.65$, 예측값 :1295.26$
# 결과값:1202.10$, 예측값 :1132.28$
# 결과값:1879.72$, 예측값 :1600.85$
# 결과값:4166.86$, 예측값 :3289.36$
# 결과값:977.20$, 예측값 :1353.09$
# 결과값:776.32$, 예측값 :934.43$
# 결과값:1748.41$, 예측값 :1566.55$
# 결과값:2337.04$, 예측값 :1702.32$
# 결과값:1963.33$, 예측값 :2066.03$
# 결과값:1600.60$, 예측값 :1559.49$
# 결과값:1880.29$, 예측값 :1612.76$
# 결과값:1037.17$, 예측값 :1033.77$
# 결과값:2080.16$, 예측값 :1474.31$
# 결과값:1290.62$, 예측값 :1060.44$
# 결과값:2030.12$, 예측값 :1753.16$
# 결과값:1168.23$, 예측값 :944.57$
# 결과값:1311.55$, 예측값 :1386.57$
# 결과값:2351.80$, 예측값 :2001.52$
# 결과값:2023.84$, 예측값 :1737.56$
# 결과값:3916.89$, 예측값 :3505.00$
# 결과값:30427.92$, 예측값 :22030.00$
# 결과값:2090.53$, 예측값 :1806.59$
# 결과값:1660.49$, 예측값 :1199.67$
# 결과값:1257.85$, 예측값 :1247.86$
# 결과값:1481.58$, 예측값 :1240.53$
# 결과값:1059.43$, 예측값 :916.51$
# 결과값:2453.41$, 예측값 :2053.37$
# 결과값:1796.54$, 예측값 :1507.60$
# 결과값:1136.53$, 예측값 :1040.51$
# 결과값:958.65$, 예측값 :909.74$
# 결과값:1590.63$, 예측값 :1099.83$
# 결과값:1404.22$, 예측값 :1044.77$
# 결과값:2041.19$, 예측값 :1857.12$
# 결과값:3170.35$, 예측값 :2674.60$
# 결과값:4458.04$, 예측값 :3344.49$
# 결과값:4114.22$, 예측값 :3235.00$
# 결과값:1299.00$, 예측값 :1465.07$
# 결과값:1796.44$, 예측값 :1331.55$
# 결과값:5988.19$, 예측값 :4046.66$
# 결과값:2197.80$, 예측값 :1834.40$
# 결과값:963.92$, 예측값 :1324.55$
# 결과값:881.03$, 예측값 :1108.36$
# 결과값:4806.83$, 예측값 :3704.32$
# 결과값:1861.46$, 예측값 :1446.76$
# 결과값:2074.15$, 예측값 :1926.73$
# 결과값:2071.25$, 예측값 :1427.67$
# 결과값:855.14$, 예측값 :886.60$
# 결과값:1793.23$, 예측값 :1712.11$
# 결과값:2486.84$, 예측값 :2114.08$
# 결과값:1003.83$, 예측값 :301.25$
# 결과값:1520.66$, 예측값 :1441.97$
# 결과값:4959.29$, 예측값 :3504.81$
# 결과값:2603.86$, 예측값 :1768.85$
# 결과값:2043.41$, 예측값 :1961.58$
# 결과값:845.05$, 예측값 :928.37$
# 결과값:1310.72$, 예측값 :1090.39$
# 결과값:1985.09$, 예측값 :1769.50$
# 결과값:2237.16$, 예측값 :1768.95$
# 결과값:4395.96$, 예측값 :2982.64$
# 결과값:1104.84$, 예측값 :1117.79$
# 결과값:1312.45$, 예측값 :1292.64$
# 결과값:2032.39$, 예측값 :1975.73$
# 결과값:962.08$, 예측값 :408.68$
# 결과값:2092.22$, 예측값 :1913.08$
# 결과값:1539.93$, 예측값 :1523.51$
# 결과값:3461.91$, 예측값 :2984.24$
# 결과값:1990.18$, 예측값 :1687.62$
# 결과값:7173.99$, 예측값 :5049.99$
# 결과값:1650.29$, 예측값 :1472.58$
# 결과값:1681.03$, 예측값 :1669.64$
# 결과값:1173.54$, 예측값 :872.58$
# 결과값:2099.04$, 예측값 :1838.81$
# 결과값:1198.33$, 예측값 :817.35$
# 결과값:1032.39$, 예측값 :987.78$
# 결과값:2232.76$, 예측값 :1977.65$
# 결과값:2039.54$, 예측값 :1848.79$
# 결과값:2087.23$, 예측값 :1763.07$
# 결과값:1576.77$, 예측값 :1313.54$
# 결과값:1408.11$, 예측값 :1083.47$
# 결과값:1761.83$, 예측값 :1577.45$
# 결과값:1533.95$, 예측값 :1491.69$
# 결과값:3801.62$, 예측값 :2625.25$
# 결과값:2577.77$, 예측값 :1918.65$
# 결과값:1642.87$, 예측값 :1563.26$
# 결과값:2209.85$, 예측값 :1653.98$
# 결과값:837.87$, 예측값 :907.74$
# 결과값:4163.48$, 예측값 :2733.18$
# 결과값:2344.71$, 예측값 :2004.29$
# 결과값:2109.52$, 예측값 :2128.00$
# 결과값:1291.19$, 예측값 :1271.51$
# 결과값:1146.40$, 예측값 :984.53$
# 결과값:974.29$, 예측값 :870.73$
# 결과값:1568.43$, 예측값 :1111.71$
# 결과값:1134.18$, 예측값 :807.62$
# 결과값:1103.97$, 예측값 :1081.44$
# 결과값:1093.95$, 예측값 :868.16$
# 결과값:1989.27$, 예측값 :1482.76$
# 결과값:1422.76$, 예측값 :1406.32$
# 결과값:2347.68$, 예측값 :1884.80$
# 결과값:1785.49$, 예측값 :1594.37$
# 결과값:1985.56$, 예측값 :1591.05$
# 결과값:1138.52$, 예측값 :941.94$
# 결과값:1968.35$, 예측값 :2079.82$
# 결과값:15504.29$, 예측값 :10315.76$
# 결과값:2157.93$, 예측값 :1611.81$
# 결과값:1659.80$, 예측값 :1361.67$
# 결과값:1730.63$, 예측값 :1348.14$
# 결과값:1446.07$, 예측값 :1295.39$
# 결과값:838.87$, 예측값 :897.01$
# 결과값:1534.49$, 예측값 :1122.96$
# 결과값:904.91$, 예측값 :1215.33$
# 결과값:1539.35$, 예측값 :1447.11$
# 결과값:3624.45$, 예측값 :2725.86$
# 결과값:1041.16$, 예측값 :950.31$
# 결과값:1329.02$, 예측값 :941.51$
# 결과값:2036.90$, 예측값 :1426.85$
# 결과값:1427.21$, 예측값 :1295.29$
# 결과값:1268.26$, 예측값 :926.25$
# 결과값:13164.25$, 예측값 :7559.16$
# 결과값:1114.76$, 예측값 :1085.38$
# 결과값:1502.51$, 예측값 :1112.46$
# 결과값:746.81$, 예측값 :387.65$
# 결과값:1289.67$, 예측값 :1183.34$
# 결과값:983.93$, 예측값 :1247.44$
# 결과값:68738.52$, 예측값 :41953.43$
# 결과값:2352.51$, 예측값 :2012.39$
# 결과값:1747.93$, 예측값 :1345.57$
# 결과값:1405.34$, 예측값 :1368.18$
# 결과값:76147.68$, 예측값 :51623.75$
# 결과값:1329.24$, 예측값 :1460.81$
# 결과값:3083.53$, 예측값 :2370.42$
# 결과값:1044.37$, 예측값 :53.43$
# 결과값:2020.46$, 예측값 :1858.94$
# 결과값:955.64$, 예측값 :683.38$
# 결과값:2039.37$, 예측값 :1955.25$
# 결과값:2110.10$, 예측값 :1656.45$
# 결과값:7228.95$, 예측값 :5544.56$
# 결과값:2052.37$, 예측값 :1872.64$
# 결과값:1473.73$, 예측값 :1872.30$
# 결과값:1630.65$, 예측값 :1275.96$
# 결과값:2092.32$, 예측값 :1966.89$
# 결과값:1401.42$, 예측값 :1399.89$
# 결과값:2109.14$, 예측값 :1818.31$
# 결과값:1481.75$, 예측값 :1312.04$
# 결과값:3336.97$, 예측값 :2839.08$
# 결과값:7196.19$, 예측값 :4092.20$
# 결과값:3071.17$, 예측값 :2623.43$
# 결과값:2237.88$, 예측값 :1486.81$
# 결과값:1354.06$, 예측값 :1243.31$
# 결과값:1087.64$, 예측값 :766.97$
# 결과값:1166.56$, 예측값 :951.95$
# 결과값:2525.64$, 예측값 :2249.55$
# 결과값:3768.42$, 예측값 :3360.56$
# 결과값:2551.31$, 예측값 :2270.57$
# 결과값:1818.08$, 예측값 :1635.17$
# 결과값:2048.87$, 예측값 :1822.51$
# 결과값:961.61$, 예측값 :559.35$
# 결과값:1153.70$, 예측값 :887.04$
# 결과값:1082.19$, 예측값 :985.56$
# 결과값:1738.37$, 예측값 :1642.59$
# 결과값:2040.20$, 예측값 :1837.90$
# 결과값:2082.67$, 예측값 :1794.36$
# 결과값:1584.58$, 예측값 :1205.03$
# 결과값:1193.06$, 예측값 :910.75$
# 결과값:1305.46$, 예측값 :1134.33$
# 결과값:919.06$, 예측값 :885.29$
# 결과값:1118.31$, 예측값 :934.97$
# 결과값:2078.47$, 예측값 :1824.91$
# 결과값:1524.38$, 예측값 :741.61$
# 결과값:1328.24$, 예측값 :1051.74$
# 결과값:942.85$, 예측값 :546.61$
# 결과값:2622.65$, 예측값 :2218.08$
# 결과값:1969.33$, 예측값 :1737.80$
# 결과값:1026.02$, 예측값 :910.70$
# 결과값:2027.41$, 예측값 :1595.78$
# 결과값:2104.61$, 예측값 :1800.87$
# 결과값:1263.82$, 예측값 :872.46$
# 결과값:2680.97$, 예측값 :2240.43$
# 결과값:1044.34$, 예측값 :851.03$
# 결과값:952.01$, 예측값 :837.61$
# 결과값:5422.06$, 예측값 :4742.15$
# 결과값:1660.49$, 예측값 :1432.42$
# 결과값:1014.51$, 예측값 :1027.91$
# 결과값:1118.85$, 예측값 :940.27$
# 결과값:1473.78$, 예측값 :1449.12$
# 결과값:1497.35$, 예측값 :1286.97$
# 결과값:1985.94$, 예측값 :1940.88$
# 결과값:1031.68$, 예측값 :603.33$
# 결과값:2109.38$, 예측값 :1760.80$
# 결과값:2071.25$, 예측값 :1880.67$
# 결과값:2062.70$, 예측값 :1822.27$
# 결과값:1717.94$, 예측값 :1475.14$
# 결과값:1870.83$, 예측값 :1356.31$
# 결과값:1103.49$, 예측값 :1297.10$
# 결과값:1664.14$, 예측값 :1600.71$
# 결과값:2048.36$, 예측값 :1808.15$
# 결과값:1457.65$, 예측값 :1305.79$
# 결과값:1973.69$, 예측값 :1562.67$
# 결과값:2805.30$, 예측값 :2540.79$
# 결과값:64733.52$, 예측값 :48087.17$
# 결과값:3800.19$, 예측값 :2400.56$
# 결과값:1264.15$, 예측값 :1051.69$
# 결과값:1659.18$, 예측값 :1287.47$
# 결과값:1425.16$, 예측값 :1099.85$
# Accuracy: 88.31   RMSE : 1434.65

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)

fig, axes = plt.subplots(1, 2,figsize = (12, 7), sharey = True)

prediction1 = prediction[prediction['label'] < 10000]
axes[0].plot(prediction1.index, prediction1['pred'],label='Prediction',        
        linestyle = '--',)
axes[0].plot(prediction1.index, prediction1['label'], label = 'Truth',
        linestyle = '--',)
axes[0].set_xticks([])
axes[0].legend()
axes[0].set_title("Price under 10000$")
prediction2 = prediction[prediction['label'] > 10000]
axes[1].plot(prediction2.index, prediction2['pred'],label='Prediction',        
        linestyle = '--',)
axes[1].plot(prediction2.index, prediction2['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
axes[1].set_xticks([])
axes[1].legend()
axes[1].set_title("Price over 10000$")
plt.ylabel('prices')
plt.show()
