# %%
import pandas as pd
import numpy as np
from PIL import Image
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
import random
import albumentations as A
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/'Colab Notebooks'/'yai_9기 겨울방학'/ToyProject
# Out:
# /content/drive/MyDrive/Colab Notebooks/yai_9기 겨울방학/ToyProject

# %%
csv_train_path = "train.csv"
csv_test_path = "test.csv"
csv_val_path = "val.csv"
image_path = "./data/images"
batch_size = 256
epochs = 100
learning_rate = 1e-3
seed = 42

# %%
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
class AllDataset(Dataset):
    def __init__(self, csv_path, image_path, image_transform=transforms.Compose([transforms.ToTensor()])):
        super(AllDataset).__init__()
        csv = pd.read_csv(csv_path)
        csv_np = csv.to_numpy()
        
        self.image_transform = image_transform
        self.ids = list(map(str, csv['Id']))
        self.image_path = image_path
        
        for i in [1, 3, 4, 5, 6, 7, 8]:
            wordset = {word: idx for idx, word in enumerate(np.unique(csv_np[:,i]))}
            for row in range(len(csv_np)):
                csv_np[row][i] = wordset[csv_np[row][i]]
        self.ints = torch.from_numpy(np.array(csv_np[:,[1,3,4,5,6,7,8]], dtype="int"))
        self.floats = torch.from_numpy(np.array(csv_np[:,[2,9,10,11]], dtype="float")).float()
        self.target = torch.from_numpy(np.array(csv_np[:,[12]], dtype="float")).float()
    
    
    def __getitem__(self,idx):
        return self.image_transform(Image.open(self.image_path+'/'+self.ids[idx]+'.jpg')), self.ints[idx],self.floats[idx], self.target[idx]
    
    
    def __len__(self):
        return len(self.ints)

# %%
image_transform = transforms.Compose([transforms.ToTensor()
                                     ])
train_dataset = AllDataset(csv_train_path, image_path, image_transform)
test_dataset = AllDataset(csv_test_path, image_path, image_transform)
val_dataset = AllDataset(csv_val_path, image_path, image_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=False)
        self.resnet18.fc = nn.Sequential(nn.Linear(512, 4096),
                                         nn.BatchNorm1d(4096),
                                         nn.ReLU(),
                                         nn.Dropout()
                                        )
        self.resenet18 = self.resnet18.to(device)
        
        self.emb1 = torch.nn.Embedding(8, 20)
        self.emb2 = torch.nn.Embedding(11, 20)
        self.emb3 = torch.nn.Embedding(20, 20)
        self.emb4 = torch.nn.Embedding(4, 20)
        self.emb5 = torch.nn.Embedding(4, 20)
        self.emb6 = torch.nn.Embedding(4, 20)
        self.emb7 = torch.nn.Embedding(7, 20)
        self.act = nn.ReLU()
        self.fc = nn.Linear(4, 80)
        self.csvbn = nn.BatchNorm1d(80)
        self.csvfc1 = nn.Linear(220, 8192)
        self.csvfc2 = nn.Linear(8192, 8192)
        self.csvfc3 = nn.Linear(8192, 4096)
        self.csvbn1 = nn.BatchNorm1d(8192)
        self.csvbn2 = nn.BatchNorm1d(8192)
        self.csvbn3 = nn.BatchNorm1d(4096)
        
        self.fc1 = nn.Linear(8192, 4096)
        self.fc2 = nn.Linear(4096, 1)
        self.bn1 = nn.BatchNorm1d(4096)
        self.dropout = nn.Dropout()
    
    def forward(self, image, x, y):
        image = self.resnet18(image)
        
        x1 = self.emb1(x[:,0])
        x2 = self.emb2(x[:,1])
        x3 = self.emb3(x[:,2])
        x4 = self.emb4(x[:,3])
        x5 = self.emb5(x[:,4])
        x6 = self.emb6(x[:,5])
        x7 = self.emb7(x[:,6])
        y = self.csvbn(self.fc(y))
        x = torch.cat((x1, x2, x3, x4, x5, x6, x7, y), dim=1)
        
        x = self.dropout(self.act(self.csvbn1(self.csvfc1(x))))
        x = self.dropout(self.act(self.csvbn2(self.csvfc2(x))))
        x = self.dropout(self.act(self.csvbn3(self.csvfc3(x))))
        x = torch.cat((x, image), dim=1)
        
        x = self.dropout(self.act(self.bn1(self.fc1(x))))
        return self.fc2(x)

# %%
model = Net().to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(epochs):
    model.train()
    criterion.train()
    
    avg_loss = 0

    for Img, X1, X2, Y in train_loader:
        Img = Img.to(device)
        X1 = X1.to(device)
        X2 = X2.to(device)
        Y = Y.to(device)

        model.zero_grad()
        prediction = model(Img, X1, X2)
        loss = torch.sqrt(criterion(prediction, Y)).to(device)
        loss.backward()
        optimizer.step()
        avg_loss += loss / len(train_loader)
    print(f'[Epoch: {epoch+1:>2}] Average loss: {avg_loss:.4f}, ', end='')
    
    model.eval()
    criterion.eval()
    with torch.no_grad():
        val_avg_loss = 0.
        for Image_val, X1_val, X2_val, Y_val in val_loader:
            Image_val = Image_val.to(device)
            X1_val = X1_val.to(device)
            X2_val = X2_val.to(device)
            Y_val = Y_val.to(device)
            val_prediction = model(Image_val, X1_val, X2_val)
            val_loss = torch.sqrt(criterion(val_prediction, Y_val)).to(device)
            val_avg_loss += val_loss / len(val_loader)
        
        print(f"val_loss: {val_avg_loss:.4f}")
# Out:
# [Epoch:  1] Average loss: 4385.8887, val_loss: 3676.4951
# [Epoch:  2] Average loss: 4342.8110, val_loss: 4521.2822
# [Epoch:  3] Average loss: 4502.9258, val_loss: 4096.2012
# [Epoch:  4] Average loss: 4360.0371, val_loss: 4482.4678
# [Epoch:  5] Average loss: 4606.0156, val_loss: 4329.3003
# [Epoch:  6] Average loss: 4171.3271, val_loss: 4157.4995
# [Epoch:  7] Average loss: 5594.0625, val_loss: 4223.0635
# [Epoch:  8] Average loss: 3930.6736, val_loss: 4140.6382
# [Epoch:  9] Average loss: 4112.2515, val_loss: 4155.2705
# [Epoch: 10] Average loss: 3942.7434, val_loss: 3941.4077
# [Epoch: 11] Average loss: 3925.5020, val_loss: 3788.5476
# [Epoch: 12] Average loss: 3849.0088, val_loss: 3850.1096
# [Epoch: 13] Average loss: 3923.1287, val_loss: 3720.3455
# [Epoch: 14] Average loss: 3742.9414, val_loss: 3720.2781
# [Epoch: 15] Average loss: 3612.3904, val_loss: 3574.9775
# [Epoch: 16] Average loss: 3643.3457, val_loss: 3608.1006
# [Epoch: 17] Average loss: 3800.7910, val_loss: 3806.4961
# [Epoch: 18] Average loss: 3511.8059, val_loss: 3349.6494
# [Epoch: 19] Average loss: 3392.4075, val_loss: 3411.8696
# [Epoch: 20] Average loss: 3290.1333, val_loss: 3115.8115
# [Epoch: 21] Average loss: 3208.8167, val_loss: 3056.4419
# [Epoch: 22] Average loss: 3208.8613, val_loss: 3260.0300
# [Epoch: 23] Average loss: 3110.6255, val_loss: 2912.9749
# [Epoch: 24] Average loss: 3119.5479, val_loss: 2853.9858
# [Epoch: 25] Average loss: 3148.0981, val_loss: 2592.0623
# [Epoch: 26] Average loss: 2944.7012, val_loss: 2690.0256
# [Epoch: 27] Average loss: 2830.1702, val_loss: 2671.1536
# [Epoch: 28] Average loss: 2775.6260, val_loss: 2698.3079
# [Epoch: 29] Average loss: 2667.5347, val_loss: 2727.9607
# [Epoch: 30] Average loss: 2604.9722, val_loss: 2295.8281
# [Epoch: 31] Average loss: 4177.3413, val_loss: 2583.7466
# [Epoch: 32] Average loss: 2449.2629, val_loss: 2448.4434
# [Epoch: 33] Average loss: 2407.4575, val_loss: 2082.0142
# [Epoch: 34] Average loss: 2322.3264, val_loss: 2198.3015
# [Epoch: 35] Average loss: 2205.5352, val_loss: 1905.2112
# [Epoch: 36] Average loss: 2156.7546, val_loss: 1876.2156
# [Epoch: 37] Average loss: 2075.9397, val_loss: 1950.8506
# [Epoch: 38] Average loss: 2297.5659, val_loss: 1621.1323
# [Epoch: 39] Average loss: 1986.6877, val_loss: 1680.9297
# [Epoch: 40] Average loss: 1956.8146, val_loss: 1662.6823
# [Epoch: 41] Average loss: 1976.4243, val_loss: 1699.6279
# [Epoch: 42] Average loss: 1822.7124, val_loss: 1667.3405
# [Epoch: 43] Average loss: 1730.7936, val_loss: 1596.6514
# [Epoch: 44] Average loss: 1881.8557, val_loss: 1719.2576
# [Epoch: 45] Average loss: 1726.8000, val_loss: 1497.7939
# [Epoch: 46] Average loss: 1603.8361, val_loss: 1614.0477
# [Epoch: 47] Average loss: 1518.0873, val_loss: 1471.4531
# [Epoch: 48] Average loss: 1624.9580, val_loss: 1535.6559
# [Epoch: 49] Average loss: 1497.0696, val_loss: 1705.3999
# [Epoch: 50] Average loss: 1601.3706, val_loss: 1651.3728
# [Epoch: 51] Average loss: 1639.1732, val_loss: 1686.2883
# [Epoch: 52] Average loss: 1590.2526, val_loss: 1314.8947
# [Epoch: 53] Average loss: 1495.0305, val_loss: 1295.0022
# [Epoch: 54] Average loss: 1522.6487, val_loss: 1237.4320
# [Epoch: 55] Average loss: 1426.0275, val_loss: 1257.4316
# [Epoch: 56] Average loss: 1487.3304, val_loss: 1361.4155
# [Epoch: 57] Average loss: 1577.1838, val_loss: 1525.1123
# [Epoch: 58] Average loss: 1325.2853, val_loss: 1513.0549
# [Epoch: 59] Average loss: 1222.2378, val_loss: 1219.4742
# [Epoch: 60] Average loss: 1365.5748, val_loss: 1366.7719
# [Epoch: 61] Average loss: 1589.7848, val_loss: 1487.8379
# [Epoch: 62] Average loss: 1494.6656, val_loss: 1715.4180
# [Epoch: 63] Average loss: 1338.2437, val_loss: 1487.5516
# [Epoch: 64] Average loss: 1283.6162, val_loss: 1426.9082
# [Epoch: 65] Average loss: 1344.0964, val_loss: 2336.5205
# [Epoch: 66] Average loss: 1523.1218, val_loss: 1368.7241
# [Epoch: 67] Average loss: 1236.3762, val_loss: 1390.5575
# [Epoch: 68] Average loss: 1424.3500, val_loss: 1112.2815
# [Epoch: 69] Average loss: 1293.5173, val_loss: 1219.3894
# [Epoch: 70] Average loss: 1290.8422, val_loss: 1197.8489
# [Epoch: 71] Average loss: 1192.4473, val_loss: 1266.1227
# [Epoch: 72] Average loss: 1322.6241, val_loss: 1218.1472
# [Epoch: 73] Average loss: 1181.2100, val_loss: 1184.6421
# [Epoch: 74] Average loss: 1281.6210, val_loss: 1266.7677
# [Epoch: 75] Average loss: 1821.5270, val_loss: 1442.2874
# [Epoch: 76] Average loss: 1166.0933, val_loss: 1621.3445
# [Epoch: 77] Average loss: 1216.7634, val_loss: 1301.3718
# [Epoch: 78] Average loss: 1352.8751, val_loss: 1373.8057
# [Epoch: 79] Average loss: 1245.7644, val_loss: 1215.8619
# [Epoch: 80] Average loss: 1484.7605, val_loss: 1469.9362
# [Epoch: 81] Average loss: 1229.3235, val_loss: 1259.1910
# [Epoch: 82] Average loss: 1193.8180, val_loss: 1221.1224
# [Epoch: 83] Average loss: 1336.5790, val_loss: 1345.2726
# [Epoch: 84] Average loss: 1215.3925, val_loss: 1211.5286
# [Epoch: 85] Average loss: 1182.9066, val_loss: 1365.5657
# [Epoch: 86] Average loss: 1381.7833, val_loss: 1545.1279
# [Epoch: 87] Average loss: 1249.4722, val_loss: 1385.0442
# [Epoch: 88] Average loss: 1097.2977, val_loss: 1233.6753
# [Epoch: 89] Average loss: 1168.2415, val_loss: 1380.5339
# [Epoch: 90] Average loss: 1103.1238, val_loss: 1396.5269
# [Epoch: 91] Average loss: 1269.1299, val_loss: 1340.4457
# [Epoch: 92] Average loss: 1160.4409, val_loss: 1446.0288
# [Epoch: 93] Average loss: 1106.7332, val_loss: 1240.5656
# [Epoch: 94] Average loss: 994.6863, val_loss: 1361.3464
# [Epoch: 95] Average loss: 1334.8877, val_loss: 1598.1342
# [Epoch: 96] Average loss: 1282.1932, val_loss: 2182.7476
# [Epoch: 97] Average loss: 1367.1337, val_loss: 1533.1620
# [Epoch: 98] Average loss: 1188.5048, val_loss: 1226.0367
# [Epoch: 99] Average loss: 1273.4191, val_loss: 1357.6625
# [Epoch: 100] Average loss: 1795.2115, val_loss: 1683.8611

# %%
PATH = './model/'
Name = 'model_stfsplit.pt'
torch.save(model.state_dict(), PATH+Name)

# %%
RMSEs = []
accuracys = []

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 20000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    accuracys.append(accuracy)
    RMSEs.append(RMSE)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}",)
# Out:
# 결과값:70749.53$, 예측값 :39505.61$
# 결과값:49865.46$, 예측값 :28503.57$
# 결과값:55408.52$, 예측값 :33156.56$
# 결과값:41719.09$, 예측값 :47504.37$
# 결과값:37753.27$, 예측값 :27074.40$
# 결과값:49075.34$, 예측값 :35230.98$
# Accuracy: -235.46   RMSE : 19437.24

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 20,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 15000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:18439.82$, 예측값 :8365.26$
# 결과값:18729.27$, 예측값 :8229.72$
# 결과값:55408.52$, 예측값 :33156.56$
# 결과값:15379.60$, 예측값 :11589.66$
# 결과값:16186.73$, 예측값 :9804.58$
# 결과값:37753.27$, 예측값 :27074.40$
# 결과값:17875.20$, 예측값 :16538.63$
# 결과값:16067.35$, 예측값 :5618.16$
# 결과값:70749.53$, 예측값 :39505.61$
# 결과값:16216.19$, 예측값 :16136.02$
# 결과값:15476.93$, 예측값 :12193.14$
# 결과값:49075.34$, 예측값 :35230.98$
# 결과값:49865.46$, 예측값 :28503.57$
# 결과값:16480.38$, 예측값 :17091.16$
# 결과값:41719.09$, 예측값 :47504.37$
# 결과값:18681.64$, 예측값 :12364.48$
# Accuracy: 45.85   RMSE : 12980.06

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 15,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        if Y_test < 10000:
            continue
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:16480.38$, 예측값 :17091.16$
# 결과값:13262.90$, 예측값 :8113.77$
# 결과값:18439.82$, 예측값 :8365.26$
# 결과값:49075.34$, 예측값 :35230.98$
# 결과값:12627.71$, 예측값 :10445.99$
# 결과값:13500.16$, 예측값 :14760.27$
# 결과값:55408.52$, 예측값 :33156.56$
# 결과값:13328.09$, 예측값 :5320.87$
# 결과값:18729.27$, 예측값 :8229.72$
# 결과값:13410.72$, 예측값 :8694.96$
# 결과값:11755.98$, 예측값 :7230.63$
# 결과값:18681.64$, 예측값 :12364.48$
# 결과값:17875.20$, 예측값 :16538.63$
# 결과값:13490.76$, 예측값 :16373.42$
# 결과값:15379.60$, 예측값 :11589.66$
# 결과값:13326.63$, 예측값 :8878.66$
# 결과값:13336.86$, 예측값 :9582.87$
# 결과값:70749.53$, 예측값 :39505.61$
# 결과값:16216.19$, 예측값 :16136.02$
# 결과값:16186.73$, 예측값 :9804.58$
# 결과값:37753.27$, 예측값 :27074.40$
# 결과값:12996.87$, 예측값 :9209.94$
# 결과값:15476.93$, 예측값 :12193.14$
# 결과값:49865.46$, 예측값 :28503.57$
# 결과값:41719.09$, 예측값 :47504.37$
# 결과값:16067.35$, 예측값 :5618.16$
# Accuracy: 56.59   RMSE : 10546.48

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)
fig, ax = plt.subplots(1, 1,figsize = (10, 7))

ax.plot(prediction.index, prediction['pred'],label='Prediction',        
        marker = 'o',
        linestyle = '--',)
ax.plot(prediction.index, prediction['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
ax.set_title(f"prediction vs Truth : over 10,000$", loc='left', fontsize=20, va= 'bottom', fontweight='semibold')
ax.legend()
plt.ylabel('prices')
plt.xticks([])
ax.set_xticks([])
plt.show()

# %%
model.eval()
criterion.eval()
ss_tot = 0
ss_res = 0
test_loader = DataLoader(test_dataset, batch_size=1, shuffle = True)
pred = []
label = []
with torch.no_grad():
    for Image_test, X1_test, X2_test, Y_test in test_loader:
        Image_test =Image_test.to(device)
        X1_test = X1_test.to(device)
        X2_test = X2_test.to(device)
        Y_test = Y_test.to(device)
        prediction = model(Image_test, X1_test, X2_test)
        print(f"결과값:{Y_test.item():.2f}$, 예측값 :{prediction.item():.2f}$")
        pred.append(prediction)
        label.append(Y_test)
    pred = torch.tensor(pred)
    label = torch.tensor(label)
    mean = torch.mean(label)
    ss_tot += torch.sum((label - mean) ** 2)
    ss_res += torch.sum((label - pred) ** 2)
    
    accuracy = 1 - ss_res/ss_tot
    RMSE = (torch.sum((label - pred)**2) / len(pred.numpy()))**(1/2)
    print(f"Accuracy: {accuracy*100:.2f}   RMSE : {RMSE:.2f}", )
# Out:
# 결과값:1429.00$, 예측값 :1219.27$
# 결과값:13336.86$, 예측값 :9582.87$
# 결과값:1763.52$, 예측값 :1433.12$
# 결과값:1805.77$, 예측값 :1700.15$
# 결과값:1993.46$, 예측값 :2274.62$
# 결과값:2006.01$, 예측값 :1661.27$
# 결과값:2350.82$, 예측값 :2163.46$
# 결과값:2078.78$, 예측값 :2133.17$
# 결과값:2068.73$, 예측값 :2266.82$
# 결과값:2262.98$, 예측값 :1645.90$
# 결과값:1022.80$, 예측값 :682.30$
# 결과값:2074.51$, 예측값 :1499.57$
# 결과값:943.90$, 예측값 :829.27$
# 결과값:2055.02$, 예측값 :1263.79$
# 결과값:2448.26$, 예측값 :1595.19$
# 결과값:1031.12$, 예측값 :626.60$
# 결과값:15476.93$, 예측값 :12193.14$
# 결과값:2100.82$, 예측값 :1790.95$
# 결과값:1565.85$, 예측값 :1105.25$
# 결과값:2077.11$, 예측값 :1504.21$
# 결과값:2028.98$, 예측값 :2348.29$
# 결과값:1030.65$, 예측값 :782.42$
# 결과값:1139.13$, 예측값 :1030.91$
# 결과값:1276.32$, 예측값 :1158.42$
# 결과값:1423.83$, 예측값 :1079.74$
# 결과값:2071.45$, 예측값 :2166.97$
# 결과값:1279.25$, 예측값 :747.11$
# 결과값:1576.77$, 예측값 :1558.48$
# 결과값:2071.48$, 예측값 :1520.45$
# 결과값:13490.76$, 예측값 :16373.42$
# 결과값:2122.91$, 예측값 :2562.02$
# 결과값:18729.27$, 예측값 :8229.72$
# 결과값:1881.17$, 예측값 :1531.74$
# 결과값:1462.03$, 예측값 :1493.78$
# 결과값:1530.31$, 예측값 :1228.18$
# 결과값:1041.72$, 예측값 :688.38$
# 결과값:1256.24$, 예측값 :674.93$
# 결과값:1153.26$, 예측값 :1139.65$
# 결과값:1091.99$, 예측값 :1432.92$
# 결과값:1876.75$, 예측값 :1358.43$
# 결과값:1533.62$, 예측값 :1693.75$
# 결과값:1972.37$, 예측값 :1676.93$
# 결과값:2080.00$, 예측값 :2083.35$
# 결과값:2337.00$, 예측값 :2743.10$
# 결과값:2274.17$, 예측값 :1363.31$
# 결과값:2351.54$, 예측값 :2295.86$
# 결과값:13328.09$, 예측값 :5320.87$
# 결과값:1460.31$, 예측값 :2184.07$
# 결과값:1329.03$, 예측값 :990.63$
# 결과값:6086.00$, 예측값 :8666.15$
# 결과값:1986.62$, 예측값 :1695.82$
# 결과값:2075.91$, 예측값 :1877.57$
# 결과값:1696.00$, 예측값 :1573.38$
# 결과값:1371.84$, 예측값 :1247.71$
# 결과값:1093.02$, 예측값 :1226.98$
# 결과값:1310.14$, 예측값 :924.48$
# 결과값:1786.33$, 예측값 :1799.64$
# 결과값:1698.05$, 예측값 :1220.39$
# 결과값:2082.67$, 예측값 :1575.99$
# 결과값:2313.96$, 예측값 :2139.78$
# 결과값:1326.87$, 예측값 :963.10$
# 결과값:1030.22$, 예측값 :1240.80$
# 결과값:1972.16$, 예측값 :1601.14$
# 결과값:1722.11$, 예측값 :2733.12$
# 결과값:926.91$, 예측값 :577.08$
# 결과값:2006.40$, 예측값 :2189.71$
# 결과값:2596.11$, 예측값 :3574.18$
# 결과값:1041.16$, 예측값 :862.41$
# 결과값:2047.47$, 예측값 :2258.99$
# 결과값:1675.74$, 예측값 :1644.09$
# 결과값:2508.02$, 예측값 :1886.29$
# 결과값:2213.67$, 예측값 :1905.05$
# 결과값:2851.75$, 예측값 :2062.64$
# 결과값:2247.53$, 예측값 :1926.50$
# 결과값:1587.41$, 예측값 :1831.44$
# 결과값:1056.49$, 예측값 :1046.12$
# 결과값:2105.01$, 예측값 :1554.46$
# 결과값:2263.49$, 예측값 :1515.34$
# 결과값:1042.26$, 예측값 :875.44$
# 결과값:2508.64$, 예측값 :2675.22$
# 결과값:1718.73$, 예측값 :1365.89$
# 결과값:1188.42$, 예측값 :822.99$
# 결과값:1030.68$, 예측값 :976.43$
# 결과값:1544.19$, 예측값 :1493.43$
# 결과값:1164.21$, 예측값 :997.97$
# 결과값:1965.55$, 예측값 :1781.42$
# 결과값:1424.92$, 예측값 :1349.95$
# 결과값:2080.00$, 예측값 :1974.21$
# 결과값:3521.16$, 예측값 :1254.55$
# 결과값:6150.68$, 예측값 :3921.63$
# 결과값:1124.70$, 예측값 :1462.04$
# 결과값:1445.15$, 예측값 :1531.41$
# 결과값:1012.99$, 예측값 :746.36$
# 결과값:1123.55$, 예측값 :874.47$
# 결과값:2324.68$, 예측값 :2079.15$
# 결과값:926.34$, 예측값 :867.47$
# 결과값:1291.97$, 예측값 :903.27$
# 결과값:1752.72$, 예측값 :2112.55$
# 결과값:1951.16$, 예측값 :1815.76$
# 결과값:1120.39$, 예측값 :756.28$
# 결과값:1048.37$, 예측값 :776.13$
# 결과값:1212.63$, 예측값 :1015.87$
# 결과값:2762.91$, 예측값 :1406.52$
# 결과값:1277.73$, 예측값 :936.55$
# 결과값:1404.00$, 예측값 :1646.00$
# 결과값:1135.92$, 예측값 :424.17$
# 결과값:819.30$, 예측값 :432.01$
# 결과값:1658.74$, 예측값 :1162.90$
# 결과값:1183.00$, 예측값 :1379.63$
# 결과값:1063.09$, 예측값 :787.31$
# 결과값:1156.91$, 예측값 :1130.17$
# 결과값:1191.82$, 예측값 :746.19$
# 결과값:2102.50$, 예측값 :1550.14$
# 결과값:945.76$, 예측값 :772.56$
# 결과값:2145.16$, 예측값 :2261.28$
# 결과값:1701.95$, 예측값 :1349.67$
# 결과값:1720.61$, 예측값 :600.58$
# 결과값:2015.41$, 예측값 :1263.42$
# 결과값:3784.61$, 예측값 :5110.10$
# 결과값:1993.12$, 예측값 :1779.78$
# 결과값:1752.65$, 예측값 :1291.62$
# 결과값:2318.26$, 예측값 :2231.66$
# 결과값:1929.08$, 예측값 :1576.28$
# 결과값:2304.07$, 예측값 :1887.08$
# 결과값:3129.89$, 예측값 :4083.75$
# 결과값:2044.65$, 예측값 :2073.13$
# 결과값:2092.25$, 예측값 :2305.19$
# 결과값:1124.10$, 예측값 :832.05$
# 결과값:1768.87$, 예측값 :1344.06$
# 결과값:1114.96$, 예측값 :974.03$
# 결과값:945.96$, 예측값 :553.47$
# 결과값:2304.45$, 예측값 :1888.63$
# 결과값:2157.27$, 예측값 :1806.22$
# 결과값:1973.70$, 예측값 :1756.66$
# 결과값:2056.00$, 예측값 :1927.09$
# 결과값:1537.92$, 예측값 :1340.73$
# 결과값:1996.74$, 예측값 :1382.61$
# 결과값:1723.88$, 예측값 :1209.43$
# 결과값:1474.41$, 예측값 :1206.86$
# 결과값:1862.80$, 예측값 :2101.82$
# 결과값:2053.38$, 예측값 :2319.27$
# 결과값:1672.34$, 예측값 :1557.69$
# 결과값:1085.42$, 예측값 :589.33$
# 결과값:1032.69$, 예측값 :832.99$
# 결과값:2187.19$, 예측값 :1734.51$
# 결과값:1983.47$, 예측값 :1435.39$
# 결과값:1293.26$, 예측값 :1010.06$
# 결과값:1615.89$, 예측값 :2159.45$
# 결과값:2242.06$, 예측값 :1959.67$
# 결과값:2090.55$, 예측값 :1722.28$
# 결과값:1303.33$, 예측값 :824.42$
# 결과값:2118.77$, 예측값 :1884.08$
# 결과값:1310.83$, 예측값 :593.62$
# 결과값:2527.87$, 예측값 :1959.63$
# 결과값:1789.73$, 예측값 :1270.29$
# 결과값:1038.49$, 예측값 :738.82$
# 결과값:2453.69$, 예측값 :1715.22$
# 결과값:1624.52$, 예측값 :1227.07$
# 결과값:1347.34$, 예측값 :977.89$
# 결과값:2084.78$, 예측값 :1825.07$
# 결과값:981.38$, 예측값 :825.74$
# 결과값:2029.39$, 예측값 :1682.10$
# 결과값:1660.49$, 예측값 :1254.15$
# 결과값:1346.68$, 예측값 :904.17$
# 결과값:853.18$, 예측값 :1116.33$
# 결과값:3460.94$, 예측값 :2186.73$
# 결과값:1028.04$, 예측값 :887.69$
# 결과값:2062.70$, 예측값 :1983.28$
# 결과값:1508.36$, 예측값 :1116.04$
# 결과값:1532.04$, 예측값 :800.12$
# 결과값:2045.06$, 예측값 :1807.32$
# 결과값:1093.95$, 예측값 :948.02$
# 결과값:9598.23$, 예측값 :10606.55$
# 결과값:2757.79$, 예측값 :3644.79$
# 결과값:1015.23$, 예측값 :528.94$
# 결과값:2471.39$, 예측값 :3324.09$
# 결과값:1040.08$, 예측값 :946.54$
# 결과값:2048.45$, 예측값 :2077.18$
# 결과값:946.42$, 예측값 :1077.88$
# 결과값:2619.85$, 예측값 :1843.59$
# 결과값:1839.55$, 예측값 :1656.31$
# 결과값:1188.76$, 예측값 :1174.65$
# 결과값:1143.64$, 예측값 :828.74$
# 결과값:1427.29$, 예측값 :1088.99$
# 결과값:1699.36$, 예측값 :1114.36$
# 결과값:2544.90$, 예측값 :1641.22$
# 결과값:1445.34$, 예측값 :1407.86$
# 결과값:1150.70$, 예측값 :1045.93$
# 결과값:2105.76$, 예측값 :1767.58$
# 결과값:2126.49$, 예측값 :1760.30$
# 결과값:4148.72$, 예측값 :6765.11$
# 결과값:2817.63$, 예측값 :2421.88$
# 결과값:2028.12$, 예측값 :1533.77$
# 결과값:1562.27$, 예측값 :787.27$
# 결과값:4379.77$, 예측값 :4820.95$
# 결과값:1325.28$, 예측값 :1408.50$
# 결과값:1255.25$, 예측값 :1386.37$
# 결과값:13326.63$, 예측값 :8878.66$
# 결과값:1277.72$, 예측값 :1282.38$
# 결과값:3456.76$, 예측값 :2744.28$
# 결과값:1463.57$, 예측값 :979.76$
# 결과값:969.38$, 예측값 :729.80$
# 결과값:2062.41$, 예측값 :1613.51$
# 결과값:1836.29$, 예측값 :1341.04$
# 결과값:2078.36$, 예측값 :2479.44$
# 결과값:2062.70$, 예측값 :2053.78$
# 결과값:4443.40$, 예측값 :15442.33$
# 결과값:2048.36$, 예측값 :1451.70$
# 결과값:1335.20$, 예측값 :1168.36$
# 결과값:1524.67$, 예측값 :1165.01$
# 결과값:2448.26$, 예측값 :1754.45$
# 결과값:947.09$, 예측값 :1325.09$
# 결과값:1199.71$, 예측값 :957.62$
# 결과값:1211.61$, 예측값 :1320.30$
# 결과값:3260.31$, 예측값 :1988.15$
# 결과값:1184.83$, 예측값 :1338.74$
# 결과값:2021.84$, 예측값 :1764.95$
# 결과값:2011.25$, 예측값 :2457.01$
# 결과값:2421.52$, 예측값 :1900.87$
# 결과값:2680.62$, 예측값 :2454.23$
# 결과값:2775.23$, 예측값 :3642.96$
# 결과값:70749.53$, 예측값 :39505.61$
# 결과값:2069.61$, 예측값 :1650.16$
# 결과값:1975.64$, 예측값 :1822.23$
# 결과값:3519.28$, 예측값 :2725.46$
# 결과값:2337.00$, 예측값 :1959.99$
# 결과값:1055.41$, 예측값 :1129.19$
# 결과값:764.56$, 예측값 :870.52$
# 결과값:2008.35$, 예측값 :1449.34$
# 결과값:1141.31$, 예측값 :983.27$
# 결과값:1498.35$, 예측값 :1465.54$
# 결과값:1126.24$, 예측값 :1230.40$
# 결과값:1742.54$, 예측값 :1233.77$
# 결과값:1260.79$, 예측값 :923.76$
# 결과값:1529.59$, 예측값 :1586.11$
# 결과값:1010.79$, 예측값 :1088.35$
# 결과값:13262.90$, 예측값 :8113.77$
# 결과값:1963.28$, 예측값 :1794.05$
# 결과값:17875.20$, 예측값 :16538.63$
# 결과값:904.91$, 예측값 :929.45$
# 결과값:975.06$, 예측값 :1018.09$
# 결과값:1031.20$, 예측값 :875.46$
# 결과값:1660.49$, 예측값 :1008.12$
# 결과값:1267.50$, 예측값 :659.12$
# 결과값:974.54$, 예측값 :925.80$
# 결과값:901.80$, 예측값 :897.53$
# 결과값:1407.85$, 예측값 :1249.12$
# 결과값:1031.66$, 예측값 :978.12$
# 결과값:1969.80$, 예측값 :1942.55$
# 결과값:2028.32$, 예측값 :1856.36$
# 결과값:829.54$, 예측값 :916.10$
# 결과값:1679.17$, 예측값 :1572.47$
# 결과값:1430.75$, 예측값 :1360.86$
# 결과값:2036.90$, 예측값 :1459.94$
# 결과값:2043.65$, 예측값 :1951.47$
# 결과값:3229.56$, 예측값 :2566.79$
# 결과값:902.31$, 예측값 :861.83$
# 결과값:2665.60$, 예측값 :1522.22$
# 결과값:1885.25$, 예측값 :1348.45$
# 결과값:750.97$, 예측값 :859.10$
# 결과값:1985.97$, 예측값 :1929.46$
# 결과값:2113.04$, 예측값 :2756.48$
# 결과값:1854.92$, 예측값 :1335.31$
# 결과값:1739.96$, 예측값 :1955.78$
# 결과값:954.02$, 예측값 :223.38$
# 결과값:1034.60$, 예측값 :839.44$
# 결과값:1283.79$, 예측값 :1121.79$
# 결과값:1473.19$, 예측값 :4348.16$
# 결과값:1581.86$, 예측값 :1363.81$
# 결과값:1403.12$, 예측값 :1447.85$
# 결과값:3267.15$, 예측값 :1977.54$
# 결과값:1155.32$, 예측값 :1012.97$
# 결과값:1794.04$, 예측값 :1359.61$
# 결과값:2304.43$, 예측값 :1634.46$
# 결과값:1326.33$, 예측값 :952.16$
# 결과값:1470.58$, 예측값 :1993.93$
# 결과값:1176.27$, 예측값 :1146.14$
# 결과값:753.77$, 예측값 :692.18$
# 결과값:6829.35$, 예측값 :11965.22$
# 결과값:1854.94$, 예측값 :1626.26$
# 결과값:1018.39$, 예측값 :809.61$
# 결과값:15379.60$, 예측값 :11589.66$
# 결과값:2179.02$, 예측값 :1785.88$
# 결과값:1036.97$, 예측값 :773.83$
# 결과값:1784.47$, 예측값 :1413.59$
# 결과값:1452.83$, 예측값 :1185.62$
# 결과값:2993.13$, 예측값 :2526.83$
# 결과값:1444.09$, 예측값 :1152.45$
# 결과값:2337.05$, 예측값 :2079.40$
# 결과값:3650.11$, 예측값 :3059.26$
# 결과값:944.20$, 예측값 :750.48$
# 결과값:1173.20$, 예측값 :1157.70$
# 결과값:1057.50$, 예측값 :862.62$
# 결과값:1474.41$, 예측값 :1389.72$
# 결과값:2356.77$, 예측값 :1547.66$
# 결과값:1149.58$, 예측값 :1463.21$
# 결과값:1598.58$, 예측값 :1579.90$
# 결과값:1786.96$, 예측값 :1357.45$
# 결과값:898.56$, 예측값 :850.83$
# 결과값:1418.06$, 예측값 :2419.45$
# 결과값:1403.95$, 예측값 :1373.25$
# 결과값:1093.73$, 예측값 :794.19$
# 결과값:2070.39$, 예측값 :1695.99$
# 결과값:808.48$, 예측값 :1227.88$
# 결과값:2031.70$, 예측값 :2323.62$
# 결과값:1399.57$, 예측값 :1190.37$
# 결과값:3068.11$, 예측값 :2269.26$
# 결과값:3018.02$, 예측값 :5005.79$
# 결과값:1354.03$, 예측값 :1554.39$
# 결과값:1534.57$, 예측값 :1248.32$
# 결과값:1731.02$, 예측값 :2042.19$
# 결과값:1057.31$, 예측값 :868.86$
# 결과값:2044.11$, 예측값 :2311.92$
# 결과값:1366.28$, 예측값 :1310.15$
# 결과값:1417.83$, 예측값 :922.50$
# 결과값:1212.10$, 예측값 :791.16$
# 결과값:1604.70$, 예측값 :1897.05$
# 결과값:1332.09$, 예측값 :1045.23$
# 결과값:2350.82$, 예측값 :2452.90$
# 결과값:2179.32$, 예측값 :1555.85$
# 결과값:2241.65$, 예측값 :2653.12$
# 결과값:1141.09$, 예측값 :899.24$
# 결과값:2106.18$, 예측값 :1997.12$
# 결과값:1867.55$, 예측값 :1337.08$
# 결과값:1534.45$, 예측값 :1049.22$
# 결과값:1428.42$, 예측값 :1028.53$
# 결과값:2069.41$, 예측값 :1388.68$
# 결과값:2043.45$, 예측값 :1892.11$
# 결과값:3632.78$, 예측값 :2137.47$
# 결과값:3829.74$, 예측값 :4367.29$
# 결과값:1960.82$, 예측값 :2164.17$
# 결과값:1302.80$, 예측값 :1779.10$
# 결과값:2113.97$, 예측값 :2090.98$
# 결과값:2033.24$, 예측값 :4700.51$
# 결과값:2631.11$, 예측값 :1680.90$
# 결과값:2031.58$, 예측값 :1459.76$
# 결과값:1555.63$, 예측값 :1260.41$
# 결과값:940.86$, 예측값 :995.25$
# 결과값:2471.36$, 예측값 :2043.71$
# 결과값:16480.38$, 예측값 :17091.16$
# 결과값:1145.23$, 예측값 :848.31$
# 결과값:1163.62$, 예측값 :1351.05$
# 결과값:1532.39$, 예측값 :1132.37$
# 결과값:1196.50$, 예측값 :786.88$
# 결과값:1170.83$, 예측값 :624.94$
# 결과값:2412.96$, 예측값 :1712.79$
# 결과값:1328.98$, 예측값 :1076.64$
# 결과값:2057.27$, 예측값 :2394.43$
# 결과값:2031.45$, 예측값 :1791.82$
# 결과값:1697.76$, 예측값 :1613.13$
# 결과값:2028.20$, 예측값 :2311.24$
# 결과값:866.33$, 예측값 :841.06$
# 결과값:1132.50$, 예측값 :1362.21$
# 결과값:1018.38$, 예측값 :830.87$
# 결과값:959.62$, 예측값 :939.48$
# 결과값:1022.52$, 예측값 :1248.24$
# 결과값:1465.45$, 예측값 :1430.28$
# 결과값:2508.85$, 예측값 :1830.53$
# 결과값:1773.89$, 예측값 :2164.58$
# 결과값:9348.54$, 예측값 :4902.06$
# 결과값:1039.70$, 예측값 :890.79$
# 결과값:2074.80$, 예측값 :1382.00$
# 결과값:2480.77$, 예측값 :1749.21$
# 결과값:3655.62$, 예측값 :3556.81$
# 결과값:1540.60$, 예측값 :1478.59$
# 결과값:1101.12$, 예측값 :767.72$
# 결과값:1532.76$, 예측값 :1264.00$
# 결과값:2161.39$, 예측값 :1612.13$
# 결과값:2080.06$, 예측값 :1602.65$
# 결과값:2452.64$, 예측값 :2267.93$
# 결과값:1291.89$, 예측값 :1090.41$
# 결과값:1114.81$, 예측값 :507.71$
# 결과값:2149.05$, 예측값 :1791.83$
# 결과값:1837.89$, 예측값 :1369.09$
# 결과값:826.78$, 예측값 :1052.76$
# 결과값:1118.85$, 예측값 :1056.89$
# 결과값:838.41$, 예측값 :1115.32$
# 결과값:1702.71$, 예측값 :1253.71$
# 결과값:18439.82$, 예측값 :8365.26$
# 결과값:2337.35$, 예측값 :2059.45$
# 결과값:2021.49$, 예측값 :1600.42$
# 결과값:2060.18$, 예측값 :1943.28$
# 결과값:1965.55$, 예측값 :1878.54$
# 결과값:1681.61$, 예측값 :1646.29$
# 결과값:1660.54$, 예측값 :915.73$
# 결과값:1281.80$, 예측값 :965.31$
# 결과값:2088.91$, 예측값 :1859.88$
# 결과값:1030.06$, 예측값 :1015.43$
# 결과값:1931.92$, 예측값 :1411.55$
# 결과값:2723.69$, 예측값 :1620.28$
# 결과값:4011.70$, 예측값 :2727.19$
# 결과값:1400.63$, 예측값 :1503.38$
# 결과값:1740.29$, 예측값 :1869.05$
# 결과값:1116.82$, 예측값 :741.89$
# 결과값:2098.19$, 예측값 :1857.08$
# 결과값:1328.93$, 예측값 :1066.59$
# 결과값:1090.42$, 예측값 :1004.38$
# 결과값:3173.68$, 예측값 :2537.30$
# 결과값:2036.90$, 예측값 :951.01$
# 결과값:2784.33$, 예측값 :2296.12$
# 결과값:1973.83$, 예측값 :1893.15$
# 결과값:2040.22$, 예측값 :1779.17$
# 결과값:2304.05$, 예측값 :2142.33$
# 결과값:1658.90$, 예측값 :1695.78$
# 결과값:2018.71$, 예측값 :1680.17$
# 결과값:3650.16$, 예측값 :2390.98$
# 결과값:1281.14$, 예측값 :955.83$
# 결과값:2104.09$, 예측값 :1712.32$
# 결과값:1822.02$, 예측값 :1137.25$
# 결과값:1582.79$, 예측값 :1759.56$
# 결과값:893.71$, 예측값 :945.84$
# 결과값:2152.82$, 예측값 :2027.23$
# 결과값:2516.77$, 예측값 :2056.43$
# 결과값:2364.87$, 예측값 :1757.95$
# 결과값:1650.73$, 예측값 :1785.20$
# 결과값:4861.95$, 예측값 :4923.64$
# 결과값:1423.71$, 예측값 :1058.13$
# 결과값:974.29$, 예측값 :794.17$
# 결과값:2245.14$, 예측값 :2457.43$
# 결과값:2259.29$, 예측값 :2008.93$
# 결과값:2076.53$, 예측값 :2313.53$
# 결과값:1624.24$, 예측값 :1536.70$
# 결과값:2112.84$, 예측값 :893.62$
# 결과값:1036.26$, 예측값 :1182.78$
# 결과값:1311.52$, 예측값 :907.44$
# 결과값:1697.10$, 예측값 :1161.69$
# 결과값:1997.77$, 예측값 :1617.32$
# 결과값:1597.90$, 예측값 :1589.57$
# 결과값:1024.19$, 예측값 :884.34$
# 결과값:1861.10$, 예측값 :2129.58$
# 결과값:1379.74$, 예측값 :1018.52$
# 결과값:2041.08$, 예측값 :1624.95$
# 결과값:1739.94$, 예측값 :1811.63$
# 결과값:1122.50$, 예측값 :1174.81$
# 결과값:1027.01$, 예측값 :1020.60$
# 결과값:1799.85$, 예측값 :1687.97$
# 결과값:853.01$, 예측값 :586.15$
# 결과값:6087.33$, 예측값 :7054.06$
# 결과값:2002.90$, 예측값 :1521.97$
# 결과값:12996.87$, 예측값 :9209.94$
# 결과값:974.35$, 예측값 :922.38$
# 결과값:2296.93$, 예측값 :1708.35$
# 결과값:16186.73$, 예측값 :9804.58$
# 결과값:2044.36$, 예측값 :1826.59$
# 결과값:808.01$, 예측값 :1375.76$
# 결과값:2105.05$, 예측값 :1703.57$
# 결과값:2070.33$, 예측값 :1557.35$
# 결과값:1991.83$, 예측값 :2280.32$
# 결과값:2362.83$, 예측값 :3332.86$
# 결과값:1799.85$, 예측값 :828.71$
# 결과값:2094.05$, 예측값 :1739.31$
# 결과값:2399.71$, 예측값 :2842.14$
# 결과값:1872.54$, 예측값 :1337.75$
# 결과값:2290.68$, 예측값 :1642.65$
# 결과값:895.73$, 예측값 :1105.87$
# 결과값:1950.75$, 예측값 :1569.82$
# 결과값:1765.71$, 예측값 :1828.03$
# 결과값:2192.54$, 예측값 :1624.36$
# 결과값:2187.15$, 예측값 :2465.78$
# 결과값:875.42$, 예측값 :1098.59$
# 결과값:2106.37$, 예측값 :1846.80$
# 결과값:821.61$, 예측값 :845.66$
# 결과값:2331.52$, 예측값 :1835.15$
# 결과값:2070.35$, 예측값 :2303.82$
# 결과값:2353.56$, 예측값 :1709.97$
# 결과값:1986.07$, 예측값 :1615.48$
# 결과값:1432.39$, 예측값 :898.18$
# 결과값:974.35$, 예측값 :928.46$
# 결과값:2099.04$, 예측값 :2110.98$
# 결과값:4782.45$, 예측값 :3395.43$
# 결과값:1751.37$, 예측값 :1750.44$
# 결과값:2061.80$, 예측값 :1882.77$
# 결과값:2987.55$, 예측값 :3861.51$
# 결과값:1006.26$, 예측값 :744.86$
# 결과값:4833.72$, 예측값 :3024.87$
# 결과값:3664.60$, 예측값 :2918.51$
# 결과값:3233.01$, 예측값 :2020.29$
# 결과값:944.85$, 예측값 :961.50$
# 결과값:2197.80$, 예측값 :1266.30$
# 결과값:1032.64$, 예측값 :1007.50$
# 결과값:1474.59$, 예측값 :965.93$
# 결과값:1034.69$, 예측값 :832.06$
# 결과값:2067.68$, 예측값 :1893.50$
# 결과값:1169.51$, 예측값 :967.78$
# 결과값:2246.26$, 예측값 :1861.57$
# 결과값:958.73$, 예측값 :1083.07$
# 결과값:1650.38$, 예측값 :1202.52$
# 결과값:1142.87$, 예측값 :1188.97$
# 결과값:2080.46$, 예측값 :2185.20$
# 결과값:1463.57$, 예측값 :1022.88$
# 결과값:2014.75$, 예측값 :1621.04$
# 결과값:977.83$, 예측값 :438.23$
# 결과값:2123.38$, 예측값 :1977.63$
# 결과값:924.62$, 예측값 :714.32$
# 결과값:1115.81$, 예측값 :681.20$
# 결과값:1425.61$, 예측값 :1373.17$
# 결과값:1063.62$, 예측값 :719.92$
# 결과값:1504.71$, 예측값 :1370.86$
# 결과값:2061.11$, 예측값 :1928.25$
# 결과값:1166.56$, 예측값 :1111.45$
# 결과값:1970.54$, 예측값 :2311.90$
# 결과값:4861.95$, 예측값 :4915.57$
# 결과값:2292.07$, 예측값 :1312.47$
# 결과값:1538.85$, 예측값 :1311.34$
# 결과값:2736.71$, 예측값 :1698.75$
# 결과값:1426.55$, 예측값 :1067.69$
# 결과값:1922.98$, 예측값 :1721.68$
# 결과값:2086.21$, 예측값 :2106.21$
# 결과값:3815.09$, 예측값 :4104.57$
# 결과값:18681.64$, 예측값 :12364.48$
# 결과값:2055.21$, 예측값 :2063.69$
# 결과값:2074.89$, 예측값 :1643.66$
# 결과값:3327.44$, 예측값 :2762.50$
# 결과값:1191.85$, 예측값 :781.52$
# 결과값:1428.81$, 예측값 :1427.20$
# 결과값:2077.89$, 예측값 :1554.10$
# 결과값:1683.22$, 예측값 :1334.63$
# 결과값:1669.15$, 예측값 :2044.60$
# 결과값:943.90$, 예측값 :827.15$
# 결과값:2724.90$, 예측값 :1691.37$
# 결과값:2568.78$, 예측값 :2237.84$
# 결과값:2053.49$, 예측값 :1804.02$
# 결과값:1430.74$, 예측값 :1637.73$
# 결과값:1473.68$, 예측값 :1509.72$
# 결과값:1446.08$, 예측값 :1066.87$
# 결과값:1698.83$, 예측값 :1192.43$
# 결과값:1583.70$, 예측값 :1264.84$
# 결과값:3483.07$, 예측값 :2217.54$
# 결과값:2049.90$, 예측값 :2281.67$
# 결과값:1063.04$, 예측값 :778.31$
# 결과값:1622.57$, 예측값 :1720.50$
# 결과값:1788.78$, 예측값 :1242.02$
# 결과값:1105.87$, 예측값 :1078.50$
# 결과값:904.35$, 예측값 :707.62$
# 결과값:2060.62$, 예측값 :1984.71$
# 결과값:4521.00$, 예측값 :2917.72$
# 결과값:2045.64$, 예측값 :1719.32$
# 결과값:1526.62$, 예측값 :1515.09$
# 결과값:1743.35$, 예측값 :1563.88$
# 결과값:1322.54$, 예측값 :716.49$
# 결과값:1819.29$, 예측값 :1548.76$
# 결과값:1147.78$, 예측값 :1147.32$
# 결과값:1682.12$, 예측값 :1451.89$
# 결과값:1880.97$, 예측값 :1402.57$
# 결과값:1623.88$, 예측값 :4350.86$
# 결과값:1528.57$, 예측값 :1279.36$
# 결과값:4408.70$, 예측값 :3349.87$
# 결과값:1204.23$, 예측값 :864.48$
# 결과값:2054.93$, 예측값 :2631.29$
# 결과값:2095.89$, 예측값 :3440.31$
# 결과값:2083.80$, 예측값 :2121.23$
# 결과값:2727.75$, 예측값 :1726.49$
# 결과값:1088.97$, 예측값 :828.95$
# 결과값:1028.53$, 예측값 :966.06$
# 결과값:1717.94$, 예측값 :909.93$
# 결과값:2030.57$, 예측값 :2153.36$
# 결과값:1968.02$, 예측값 :1501.04$
# 결과값:1140.55$, 예측값 :922.48$
# 결과값:2904.99$, 예측값 :3360.57$
# 결과값:946.40$, 예측값 :975.11$
# 결과값:1992.91$, 예측값 :1883.68$
# 결과값:863.25$, 예측값 :912.69$
# 결과값:1134.51$, 예측값 :896.07$
# 결과값:1580.00$, 예측값 :1979.54$
# 결과값:2551.39$, 예측값 :2209.92$
# 결과값:2051.69$, 예측값 :2299.34$
# 결과값:1843.82$, 예측값 :1297.72$
# 결과값:1447.35$, 예측값 :1188.27$
# 결과값:992.57$, 예측값 :902.68$
# 결과값:4510.98$, 예측값 :3388.01$
# 결과값:49865.46$, 예측값 :28503.57$
# 결과값:969.79$, 예측값 :834.07$
# 결과값:1985.94$, 예측값 :2258.22$
# 결과값:1056.32$, 예측값 :1051.55$
# 결과값:3908.68$, 예측값 :2424.95$
# 결과값:1882.12$, 예측값 :1340.48$
# 결과값:1650.45$, 예측값 :1526.13$
# 결과값:1382.34$, 예측값 :1555.64$
# 결과값:2448.32$, 예측값 :1847.93$
# 결과값:2139.78$, 예측값 :1979.86$
# 결과값:2435.56$, 예측값 :2026.37$
# 결과값:1537.39$, 예측값 :1394.81$
# 결과값:1598.08$, 예측값 :1835.39$
# 결과값:41719.09$, 예측값 :47504.37$
# 결과값:930.75$, 예측값 :962.16$
# 결과값:2125.23$, 예측값 :1663.09$
# 결과값:4430.27$, 예측값 :5367.29$
# 결과값:1538.81$, 예측값 :2006.17$
# 결과값:1159.37$, 예측값 :845.61$
# 결과값:1400.94$, 예측값 :1242.43$
# 결과값:1175.14$, 예측값 :1126.65$
# 결과값:2086.97$, 예측값 :1729.32$
# 결과값:2035.49$, 예측값 :1606.03$
# 결과값:1011.55$, 예측값 :2715.76$
# 결과값:3054.69$, 예측값 :2657.38$
# 결과값:902.12$, 예측값 :1129.98$
# 결과값:2018.05$, 예측값 :1797.35$
# 결과값:1273.41$, 예측값 :872.80$
# 결과값:1100.09$, 예측값 :721.66$
# 결과값:2062.01$, 예측값 :1830.20$
# 결과값:1282.57$, 예측값 :1184.86$
# 결과값:945.34$, 예측값 :825.85$
# 결과값:1539.35$, 예측값 :1190.05$
# 결과값:1672.80$, 예측값 :1708.91$
# 결과값:4352.31$, 예측값 :3895.65$
# 결과값:2014.73$, 예측값 :1297.11$
# 결과값:1864.54$, 예측값 :1536.76$
# 결과값:2070.48$, 예측값 :1677.38$
# 결과값:1935.25$, 예측값 :1388.15$
# 결과값:1348.62$, 예측값 :1493.37$
# 결과값:1800.96$, 예측값 :1433.91$
# 결과값:1107.02$, 예측값 :1508.41$
# 결과값:49075.34$, 예측값 :35230.98$
# 결과값:1997.86$, 예측값 :1644.50$
# 결과값:1462.04$, 예측값 :1309.63$
# 결과값:974.29$, 예측값 :1118.53$
# 결과값:2204.14$, 예측값 :2581.81$
# 결과값:2066.92$, 예측값 :2271.53$
# 결과값:1165.41$, 예측값 :756.45$
# 결과값:2568.80$, 예측값 :1724.47$
# 결과값:2802.83$, 예측값 :1829.23$
# 결과값:3514.31$, 예측값 :2279.62$
# 결과값:1973.23$, 예측값 :1289.01$
# 결과값:12627.71$, 예측값 :10445.99$
# 결과값:16067.35$, 예측값 :5618.16$
# 결과값:1659.72$, 예측값 :1209.67$
# 결과값:877.68$, 예측값 :872.00$
# 결과값:1599.11$, 예측값 :2478.81$
# 결과값:954.65$, 예측값 :645.37$
# 결과값:2078.35$, 예측값 :1943.22$
# 결과값:1164.15$, 예측값 :1021.26$
# 결과값:1990.53$, 예측값 :1913.14$
# 결과값:2097.46$, 예측값 :2300.86$
# 결과값:2033.31$, 예측값 :1700.79$
# 결과값:2353.97$, 예측값 :2240.09$
# 결과값:2953.85$, 예측값 :5302.56$
# 결과값:1103.49$, 예측값 :958.55$
# 결과값:1180.68$, 예측값 :1432.43$
# 결과값:1056.25$, 예측값 :593.57$
# 결과값:1093.95$, 예측값 :934.52$
# 결과값:4856.94$, 예측값 :3924.78$
# 결과값:1327.11$, 예측값 :1647.33$
# 결과값:1199.98$, 예측값 :1011.46$
# 결과값:3135.82$, 예측값 :1883.85$
# 결과값:1358.27$, 예측값 :1478.61$
# 결과값:2273.98$, 예측값 :1541.58$
# 결과값:1554.79$, 예측값 :1120.19$
# 결과값:1242.86$, 예측값 :963.94$
# 결과값:5991.94$, 예측값 :3587.30$
# 결과값:927.64$, 예측값 :776.78$
# 결과값:2040.00$, 예측값 :2456.23$
# 결과값:1606.66$, 예측값 :1273.24$
# 결과값:2087.09$, 예측값 :2347.10$
# 결과값:2934.68$, 예측값 :2726.48$
# 결과값:1424.77$, 예측값 :1126.63$
# 결과값:1030.65$, 예측값 :673.35$
# 결과값:1948.11$, 예측값 :2520.33$
# 결과값:4007.88$, 예측값 :3776.21$
# 결과값:1972.43$, 예측값 :1405.90$
# 결과값:2055.01$, 예측값 :1635.00$
# 결과값:2874.53$, 예측값 :2443.94$
# 결과값:1094.00$, 예측값 :787.96$
# 결과값:2031.06$, 예측값 :2457.10$
# 결과값:1603.42$, 예측값 :1097.18$
# 결과값:1988.78$, 예측값 :1690.24$
# 결과값:37753.27$, 예측값 :27074.40$
# 결과값:1058.89$, 예측값 :962.39$
# 결과값:1972.58$, 예측값 :2147.29$
# 결과값:2104.05$, 예측값 :1839.11$
# 결과값:901.78$, 예측값 :1150.44$
# 결과값:1292.93$, 예측값 :1055.54$
# 결과값:1604.91$, 예측값 :718.45$
# 결과값:1044.12$, 예측값 :724.23$
# 결과값:2112.20$, 예측값 :1771.27$
# 결과값:1381.79$, 예측값 :1261.20$
# 결과값:848.80$, 예측값 :701.39$
# 결과값:1250.19$, 예측값 :752.66$
# 결과값:1473.78$, 예측값 :1867.26$
# 결과값:886.62$, 예측값 :1017.18$
# 결과값:1746.93$, 예측값 :4600.98$
# 결과값:1096.51$, 예측값 :1130.47$
# 결과값:2249.55$, 예측값 :1817.76$
# 결과값:1424.23$, 예측값 :883.77$
# 결과값:1135.48$, 예측값 :1071.22$
# 결과값:2299.43$, 예측값 :1895.80$
# 결과값:2048.36$, 예측값 :1794.10$
# 결과값:1978.08$, 예측값 :1803.88$
# 결과값:2315.11$, 예측값 :1778.97$
# 결과값:4115.50$, 예측값 :3140.74$
# 결과값:926.68$, 예측값 :1034.79$
# 결과값:2459.12$, 예측값 :4838.39$
# 결과값:1997.22$, 예측값 :1841.98$
# 결과값:2073.70$, 예측값 :2247.24$
# 결과값:1205.93$, 예측값 :1016.67$
# 결과값:1884.69$, 예측값 :1356.98$
# 결과값:2249.20$, 예측값 :1412.14$
# 결과값:6006.28$, 예측값 :3308.60$
# 결과값:2067.92$, 예측값 :2154.37$
# 결과값:2331.76$, 예측값 :1876.95$
# 결과값:1751.48$, 예측값 :1304.12$
# 결과값:7258.54$, 예측값 :12411.29$
# 결과값:11755.98$, 예측값 :7230.63$
# 결과값:1973.14$, 예측값 :1746.97$
# 결과값:4327.67$, 예측값 :4078.84$
# 결과값:1738.11$, 예측값 :1002.27$
# 결과값:1403.68$, 예측값 :1164.34$
# 결과값:2088.91$, 예측값 :1851.24$
# 결과값:1012.26$, 예측값 :648.56$
# 결과값:1199.98$, 예측값 :769.07$
# 결과값:4092.84$, 예측값 :2274.96$
# 결과값:2059.52$, 예측값 :2245.62$
# 결과값:3001.29$, 예측값 :5774.01$
# 결과값:2304.07$, 예측값 :1917.19$
# 결과값:1428.12$, 예측값 :1146.40$
# 결과값:1096.64$, 예측값 :732.08$
# 결과값:2089.62$, 예측값 :1271.87$
# 결과값:1093.01$, 예측값 :923.53$
# 결과값:2027.51$, 예측값 :1421.56$
# 결과값:1091.99$, 예측값 :677.23$
# 결과값:2048.45$, 예측값 :2271.30$
# 결과값:2034.78$, 예측값 :1728.92$
# 결과값:1086.84$, 예측값 :905.94$
# 결과값:1066.07$, 예측값 :1116.30$
# 결과값:3442.51$, 예측값 :5660.77$
# 결과값:1347.34$, 예측값 :963.33$
# 결과값:4161.25$, 예측값 :7020.33$
# 결과값:2066.16$, 예측값 :1800.42$
# 결과값:2223.08$, 예측값 :1342.26$
# 결과값:2583.82$, 예측값 :2485.21$
# 결과값:1061.40$, 예측값 :836.95$
# 결과값:2551.35$, 예측값 :2107.71$
# 결과값:2282.33$, 예측값 :1616.71$
# 결과값:2528.27$, 예측값 :1292.58$
# 결과값:994.18$, 예측값 :306.96$
# 결과값:2079.38$, 예측값 :1737.48$
# 결과값:1504.10$, 예측값 :1558.62$
# 결과값:1401.03$, 예측값 :1526.98$
# 결과값:1063.64$, 예측값 :883.39$
# 결과값:974.57$, 예측값 :774.77$
# 결과값:898.08$, 예측값 :637.16$
# 결과값:2063.52$, 예측값 :1890.65$
# 결과값:2002.26$, 예측값 :1478.48$
# 결과값:1473.04$, 예측값 :1345.30$
# 결과값:1349.89$, 예측값 :1418.51$
# 결과값:1172.15$, 예측값 :1174.32$
# 결과값:2082.03$, 예측값 :1785.95$
# 결과값:4158.33$, 예측값 :2264.07$
# 결과값:1582.45$, 예측값 :1814.35$
# 결과값:969.79$, 예측값 :1258.91$
# 결과값:3480.49$, 예측값 :2358.62$
# 결과값:2154.96$, 예측값 :2066.93$
# 결과값:2322.22$, 예측값 :2487.08$
# 결과값:2354.34$, 예측값 :1596.53$
# 결과값:2696.13$, 예측값 :2592.75$
# 결과값:868.34$, 예측값 :586.19$
# 결과값:2109.20$, 예측값 :1672.51$
# 결과값:1149.54$, 예측값 :1461.55$
# 결과값:2061.92$, 예측값 :1954.59$
# 결과값:1790.94$, 예측값 :1462.10$
# 결과값:838.36$, 예측값 :1007.41$
# 결과값:4029.32$, 예측값 :3158.07$
# 결과값:9640.53$, 예측값 :6135.71$
# 결과값:839.64$, 예측값 :744.27$
# 결과값:3049.30$, 예측값 :1903.21$
# 결과값:1040.25$, 예측값 :781.92$
# 결과값:2111.79$, 예측값 :2332.68$
# 결과값:2064.42$, 예측값 :1875.47$
# 결과값:3709.10$, 예측값 :14996.83$
# 결과값:1463.08$, 예측값 :1659.87$
# 결과값:1184.12$, 예측값 :1127.75$
# 결과값:1790.38$, 예측값 :1499.03$
# 결과값:1453.33$, 예측값 :1212.03$
# 결과값:2030.54$, 예측값 :2415.86$
# 결과값:2061.99$, 예측값 :1799.95$
# 결과값:55408.52$, 예측값 :33156.56$
# 결과값:1309.02$, 예측값 :1579.66$
# 결과값:1354.57$, 예측값 :918.84$
# 결과값:805.98$, 예측값 :648.80$
# 결과값:1145.90$, 예측값 :868.24$
# 결과값:2081.37$, 예측값 :1616.07$
# 결과값:1368.98$, 예측값 :1049.85$
# 결과값:2023.78$, 예측값 :1980.36$
# 결과값:1997.75$, 예측값 :2181.20$
# 결과값:1042.12$, 예측값 :1108.99$
# 결과값:3172.28$, 예측값 :2630.40$
# 결과값:2040.00$, 예측값 :2296.91$
# 결과값:2015.34$, 예측값 :1786.47$
# 결과값:1358.39$, 예측값 :978.95$
# 결과값:2079.61$, 예측값 :2310.12$
# 결과값:1986.00$, 예측값 :2015.78$
# 결과값:1702.84$, 예측값 :1202.39$
# 결과값:846.08$, 예측값 :1034.32$
# 결과값:2785.64$, 예측값 :2389.47$
# 결과값:1164.88$, 예측값 :1257.92$
# 결과값:1993.46$, 예측값 :2019.38$
# 결과값:1645.60$, 예측값 :1274.64$
# 결과값:2263.09$, 예측값 :2100.02$
# 결과값:1799.78$, 예측값 :1582.30$
# 결과값:1968.26$, 예측값 :1570.75$
# 결과값:962.18$, 예측값 :721.96$
# 결과값:2752.50$, 예측값 :2998.31$
# 결과값:1822.60$, 예측값 :1391.76$
# 결과값:1329.81$, 예측값 :757.58$
# 결과값:1135.71$, 예측값 :1174.59$
# 결과값:1680.03$, 예측값 :1732.30$
# 결과값:1498.19$, 예측값 :1095.53$
# 결과값:2180.03$, 예측값 :1214.74$
# 결과값:2101.62$, 예측값 :2290.22$
# 결과값:3021.19$, 예측값 :2429.48$
# 결과값:2304.07$, 예측값 :1113.30$
# 결과값:1162.92$, 예측값 :995.63$
# 결과값:2104.08$, 예측값 :2231.51$
# 결과값:13500.16$, 예측값 :14760.27$
# 결과값:1140.06$, 예측값 :756.32$
# 결과값:1317.62$, 예측값 :1296.32$
# 결과값:2895.53$, 예측값 :6187.49$
# 결과값:7247.40$, 예측값 :8062.40$
# 결과값:2123.50$, 예측값 :1851.78$
# 결과값:1973.74$, 예측값 :1412.32$
# 결과값:2024.70$, 예측값 :1726.29$
# 결과값:1290.74$, 예측값 :963.59$
# 결과값:1185.32$, 예측값 :1104.69$
# 결과값:994.18$, 예측값 :963.92$
# 결과값:1598.46$, 예측값 :1770.19$
# 결과값:2166.14$, 예측값 :1249.81$
# 결과값:6072.07$, 예측값 :4424.54$
# 결과값:2094.68$, 예측값 :1890.24$
# 결과값:1131.52$, 예측값 :1014.68$
# 결과값:1000.72$, 예측값 :778.63$
# 결과값:1036.88$, 예측값 :819.70$
# 결과값:2568.78$, 예측값 :2285.30$
# 결과값:1270.22$, 예측값 :1338.59$
# 결과값:2319.73$, 예측값 :1704.57$
# 결과값:1289.35$, 예측값 :1149.58$
# 결과값:2969.47$, 예측값 :3352.12$
# 결과값:1133.31$, 예측값 :1285.92$
# 결과값:5961.15$, 예측값 :6698.54$
# 결과값:4420.96$, 예측값 :2197.90$
# 결과값:968.78$, 예측값 :1320.76$
# 결과값:2059.79$, 예측값 :2225.01$
# 결과값:1991.02$, 예측값 :1679.68$
# 결과값:1717.94$, 예측값 :1481.09$
# 결과값:9504.07$, 예측값 :13791.51$
# 결과값:2067.92$, 예측값 :1018.36$
# 결과값:1339.58$, 예측값 :1372.73$
# 결과값:2337.69$, 예측값 :1986.73$
# 결과값:1720.93$, 예측값 :1153.19$
# 결과값:1587.81$, 예측값 :942.10$
# 결과값:1738.38$, 예측값 :1260.50$
# 결과값:1481.75$, 예측값 :1628.66$
# 결과값:2075.87$, 예측값 :2220.99$
# 결과값:2453.10$, 예측값 :2094.24$
# 결과값:1984.26$, 예측값 :2361.74$
# 결과값:1679.27$, 예측값 :805.81$
# 결과값:1556.58$, 예측값 :1082.18$
# 결과값:2034.00$, 예측값 :1772.65$
# 결과값:2078.47$, 예측값 :1400.48$
# 결과값:4545.71$, 예측값 :2962.91$
# 결과값:2085.19$, 예측값 :1762.35$
# 결과값:846.74$, 예측값 :598.16$
# 결과값:2403.31$, 예측값 :1627.98$
# 결과값:1514.71$, 예측값 :1658.53$
# 결과값:1003.72$, 예측값 :803.75$
# 결과값:3067.51$, 예측값 :2310.89$
# 결과값:1401.30$, 예측값 :1459.32$
# 결과값:1524.65$, 예측값 :1594.93$
# 결과값:1497.14$, 예측값 :1505.07$
# 결과값:2061.87$, 예측값 :2311.95$
# 결과값:4958.89$, 예측값 :3395.72$
# 결과값:13410.72$, 예측값 :8694.96$
# 결과값:1785.62$, 예측값 :507.01$
# 결과값:2370.80$, 예측값 :1705.33$
# 결과값:3389.88$, 예측값 :2132.20$
# 결과값:1987.22$, 예측값 :1627.40$
# 결과값:6493.52$, 예측값 :10720.62$
# 결과값:948.46$, 예측값 :1072.85$
# 결과값:1273.65$, 예측값 :707.16$
# 결과값:1750.96$, 예측값 :1164.20$
# 결과값:2038.04$, 예측값 :2321.59$
# 결과값:2939.19$, 예측값 :11343.55$
# 결과값:2452.64$, 예측값 :2252.49$
# 결과값:1537.90$, 예측값 :1339.15$
# 결과값:791.33$, 예측값 :1023.14$
# 결과값:2200.67$, 예측값 :1691.42$
# 결과값:928.62$, 예측값 :969.61$
# 결과값:2568.78$, 예측값 :2144.86$
# 결과값:834.91$, 예측값 :934.66$
# 결과값:963.82$, 예측값 :817.49$
# 결과값:1040.04$, 예측값 :1295.93$
# 결과값:1796.39$, 예측값 :1181.46$
# 결과값:2094.76$, 예측값 :2337.78$
# 결과값:1464.42$, 예측값 :1764.71$
# 결과값:1119.46$, 예측값 :936.61$
# 결과값:1277.75$, 예측값 :1095.87$
# 결과값:2533.68$, 예측값 :1854.44$
# 결과값:1093.23$, 예측값 :926.89$
# 결과값:2062.70$, 예측값 :1950.84$
# 결과값:1516.44$, 예측값 :1602.94$
# 결과값:2368.35$, 예측값 :2351.92$
# 결과값:3043.26$, 예측값 :2064.31$
# 결과값:2028.27$, 예측값 :1710.44$
# 결과값:837.48$, 예측값 :666.38$
# 결과값:1873.45$, 예측값 :1501.61$
# 결과값:2048.08$, 예측값 :1618.61$
# 결과값:1348.76$, 예측값 :1036.19$
# 결과값:1134.40$, 예측값 :876.90$
# 결과값:16216.19$, 예측값 :16136.02$
# 결과값:1968.43$, 예측값 :1623.84$
# 결과값:1108.29$, 예측값 :1655.73$
# 결과값:2116.52$, 예측값 :2688.45$
# 결과값:4116.79$, 예측값 :2286.43$
# 결과값:3031.80$, 예측값 :4647.37$
# 결과값:1136.53$, 예측값 :823.01$
# 결과값:2480.15$, 예측값 :1851.14$
# 결과값:3122.16$, 예측값 :1919.68$
# 결과값:1148.96$, 예측값 :1064.48$
# 결과값:2057.03$, 예측값 :1268.62$
# 결과값:922.64$, 예측값 :550.86$
# 결과값:1058.95$, 예측값 :993.30$
# 결과값:2467.91$, 예측값 :2224.56$
# 결과값:2187.06$, 예측값 :1668.60$
# 결과값:2079.23$, 예측값 :1720.48$
# 결과값:1383.13$, 예측값 :1574.33$
# 결과값:2099.93$, 예측값 :1519.01$
# 결과값:1324.27$, 예측값 :1066.31$
# 결과값:1481.29$, 예측값 :1139.95$
# 결과값:1012.33$, 예측값 :1095.79$
# 결과값:2106.75$, 예측값 :2021.47$
# 결과값:1970.49$, 예측값 :1358.79$
# 결과값:1161.67$, 예측값 :1288.76$
# 결과값:1352.82$, 예측값 :1112.79$
# 결과값:3642.69$, 예측값 :2248.53$
# 결과값:1095.73$, 예측값 :791.90$
# 결과값:2352.55$, 예측값 :1708.43$
# 결과값:1124.88$, 예측값 :716.53$
# 결과값:9518.21$, 예측값 :5449.02$
# 결과값:1472.19$, 예측값 :2176.50$
# 결과값:6096.99$, 예측값 :3999.88$
# 결과값:2031.82$, 예측값 :1428.59$
# 결과값:5309.69$, 예측값 :2883.24$
# 결과값:2279.60$, 예측값 :1810.69$
# 결과값:2052.56$, 예측값 :2139.76$
# Accuracy: 80.83   RMSE : 1978.65

# %%
prediction = pd.DataFrame({'pred': pred.numpy().tolist(),
                          'label': label.numpy().tolist()})
prediction = prediction.sort_values(by=['label'])
prediction = prediction.reset_index(drop=True)

fig, axes = plt.subplots(1, 2,figsize = (12, 7), sharey = True)

prediction1 = prediction[prediction['label'] < 10000]
axes[0].plot(prediction1.index, prediction1['pred'],label='Prediction',        
        linestyle = '--',)
axes[0].plot(prediction1.index, prediction1['label'], label = 'Truth',
        linestyle = '--',)
axes[0].set_xticks([])
axes[0].legend()
axes[0].set_title("Price under 10000$")
prediction2 = prediction[prediction['label'] > 10000]
axes[1].plot(prediction2.index, prediction2['pred'],label='Prediction',        
        linestyle = '--',)
axes[1].plot(prediction2.index, prediction2['label'], label = 'Truth',
        marker = 'o',
        linestyle = '--',)
axes[1].set_xticks([])
axes[1].legend()
axes[1].set_title("Price over 10000$")
plt.ylabel('prices')
plt.show()
